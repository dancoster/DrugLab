# %% [markdown]
# ## Utils

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from src.parsers import mimic
from src.utils import constants
from scipy import stats
import numpy as np

# %%
import sys
# import win32com.client
import os
import pandas as pd

def setup_io_config(root_path):
    """
    Input - Output config. Add dataset paths
    :root_path -> Repo path which contains 'data' and 'res' folders
    """

    # MIMIC
    is_shortcut = True if "data.lnk" in os.listdir(root_path) else False 
    
    if (is_shortcut):
        path_shortcut =  os.path.join(root_path, "data.lnk")
        shell = win32com.client.Dispatch("WScript.Shell")
        mimic_data = shell.CreateShortCut(path_shortcut).Targetpath
    else:
        mimic_data = os.path.join(f"{root_path}", "data") 
    mimic_path = os.path.join(f"{root_path}", "results")

    # HIRID
    hirid_data = f'{root_path}/data/hirid-a-high-time-resolution-icu-dataset-1.1.1/raw_stage/'
    hirid_path = f'{root_path}/data/hirid-a-high-time-resolution-icu-dataset-1.1.1'
    
    return mimic_data, mimic_path, hirid_data, hirid_path

def setup_stratification_config():
    gender="MF"
    age_b=40
    age_a=80 
    ethnicity="WHITE" 
    lab_mapping= constants.LAB_MAPPING
    b_w = [(0,6), (6,12)]
    a_w = [(0,4), (4,8), (8,12)]
    before_windows = b_w
    after_windows = a_w
    return gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows

# %%
# IO Config
# root_path ="C:\\Users\\danco\\My Drive\\Master\\Datasets\\MIMIC iii"
root_path = "/Users/pavan/Library/CloudStorage/GoogleDrive-f20190038@hyderabad.bits-pilani.ac.in/My Drive/TAU/Code/DrugLab"
data, res, raw_path, res_path = setup_io_config(root_path=root_path)

# Stratification Config
gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows = setup_stratification_config()

# %% [markdown]
# ## MIMIC

# %%
mimic_parser = mimic.MIMICParser(data=data, res=res, gender=gender, age_b=age_b, age_a=age_a, ethnicity=ethnicity, load="AUTOMATIC_MAPPING_MIMIC")
m_n_meds, m_labs = mimic_parser.parse(load_raw_chartevents=False, n_meds=True)
# Out:
# Loading med data...
# Loaded med data.
# Load Med data...
# Load Lab data...
# /Users/pavan/Desktop/TAU/DrugLab/src/parsers/mimic.py:240: DtypeWarning: Columns (9,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   labs = pd.read_csv(os.path.join(self.data, constants.MIMIC_III_PREPROCESSED_PATH, constants.MIMIC_III_PREPROCESSED_LABDATA))
# Loaded Lab data.
# Loading 1 med data...
# Loaded 1 med data with 138658 medication administrations.
# Loading 2 med data...
# Loaded 2 med data with 101664 medication administrations.
# Loading 3 med data...
# Loaded 3 med data with 81753 medication administrations.
# Loading 4 med data...
# Loaded 4 med data with 67896 medication administrations.
# Loading 5 med data...
# Loaded 5 med data with 58458 medication administrations.
# Loading 6 med data...
# Loaded 6 med data with 51001 medication administrations.
# Loading 7 med data...
# Loaded 7 med data with 45266 medication administrations.
# Loading 8 med data...
# Loaded 8 med data with 40652 medication administrations.
# Loading 9 med data...
# Loaded 9 med data with 36770 medication administrations.
# Loading 10 med data...
# Loaded 10 med data with 33559 medication administrations.
# Loading 11 med data...
# Loaded 11 med data with 30773 medication administrations.
# Loading 12 med data...
# Loaded 12 med data with 28399 medication administrations.
# Loading 13 med data...
# Loaded 13 med data with 26325 medication administrations.
# Loading 14 med data...
# Loaded 14 med data with 24399 medication administrations.
# Loading 15 med data...
# Loaded 15 med data with 22770 medication administrations.
# Loading 16 med data...
# Loaded 16 med data with 21350 medication administrations.
# Loading 17 med data...
# Loaded 17 med data with 20034 medication administrations.
# Loading 18 med data...
# Loaded 18 med data with 18792 medication administrations.
# Loading 19 med data...
# Loaded 19 med data with 17735 medication administrations.
# Loading 20 med data...
# Loaded 20 med data with 16755 medication administrations.
# Loading 21 med data...
# Loaded 21 med data with 15906 medication administrations.
# Loading 22 med data...
# Loaded 22 med data with 15063 medication administrations.
# Loading 23 med data...
# Loaded 23 med data with 14339 medication administrations.
# Loading 24 med data...
# Loaded 24 med data with 13603 medication administrations.
# Loading 25 med data...
# Loaded 25 med data with 12926 medication administrations.
# Loading 26 med data...
# Loaded 26 med data with 12327 medication administrations.
# Loading 27 med data...
# Loaded 27 med data with 11772 medication administrations.
# Loading 28 med data...
# Loaded 28 med data with 11276 medication administrations.
# Loading 29 med data...
# Loaded 29 med data with 10809 medication administrations.
# Loading 30 med data...
# Loaded 30 med data with 10360 medication administrations.
# Loading 31 med data...
# Loaded 31 med data with 9930 medication administrations.
# Loading 32 med data...
# Loaded 32 med data with 9525 medication administrations.
# Loading 33 med data...
# Loaded 33 med data with 9178 medication administrations.
# Loading 34 med data...
# Loaded 34 med data with 8822 medication administrations.
# Loading 35 med data...
# Loaded 35 med data with 8485 medication administrations.
# /Users/pavan/Desktop/TAU/DrugLab/src/parsers/mimic.py:102: DtypeWarning: Columns (12,18,23,28,29,30,36,45,46,53,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   med_k = pd.read_csv(med_vect_data_path) if not load_from_raw and os.path.exists(med_vect_data_path) else self.generate_med_k_vect(med_preprocessed=med_preprocessed, k=k)
# Loading 36 med data...
# Loaded 36 med data with 8193 medication administrations.
# Loading 37 med data...
# Loaded 37 med data with 7896 medication administrations.
# Loading 38 med data...
# Loaded 38 med data with 7606 medication administrations.
# Loading 39 med data...
# Loaded 39 med data with 7349 medication administrations.
# Loading 40 med data...
# Loaded 40 med data with 7098 medication administrations.
# Loading 41 med data...
# Loaded 41 med data with 6890 medication administrations.
# Loading 42 med data...
# Loaded 42 med data with 6671 medication administrations.
# Loading 43 med data...
# Loaded 43 med data with 6475 medication administrations.
# Loading 44 med data...
# Loaded 44 med data with 6240 medication administrations.
# Loading 45 med data...
# Loaded 45 med data with 6062 medication administrations.
# Loading 46 med data...
# Loaded 46 med data with 5914 medication administrations.
# Loading 47 med data...
# Loaded 47 med data with 5761 medication administrations.
# Loading 48 med data...
# Loaded 48 med data with 5610 medication administrations.
# Loading 49 med data...
# Loaded 49 med data with 5452 medication administrations.
# Loading 50 med data...
# Loaded 50 med data with 5289 medication administrations.
# Loading 51 med data...
# Loaded 51 med data with 5138 medication administrations.
# Loading 52 med data...
# Loaded 52 med data with 5004 medication administrations.
# Loading 53 med data...
# Loaded 53 med data with 4894 medication administrations.
# Loading 54 med data...
# Loaded 54 med data with 4775 medication administrations.
# Loading 55 med data...
# Loaded 55 med data with 4652 medication administrations.
# Loading 56 med data...
# Loaded 56 med data with 4537 medication administrations.
# Loading 57 med data...
# Loaded 57 med data with 4409 medication administrations.
# Loading 58 med data...
# Loaded 58 med data with 4315 medication administrations.
# Loading 59 med data...
# Loaded 59 med data with 4199 medication administrations.
# Loading 60 med data...
# Loaded 60 med data with 4096 medication administrations.
# Loading 61 med data...
# Loaded 61 med data with 3996 medication administrations.
# Loading 62 med data...
# Loaded 62 med data with 3899 medication administrations.
# Loading 63 med data...
# Loaded 63 med data with 3804 medication administrations.
# Loading 64 med data...
# Loaded 64 med data with 3714 medication administrations.
# Loading 65 med data...
# Loaded 65 med data with 3623 medication administrations.
# Loading 66 med data...
# Loaded 66 med data with 3559 medication administrations.
# Loading 67 med data...
# Loaded 67 med data with 3464 medication administrations.
# Loading 68 med data...
# Loaded 68 med data with 3393 medication administrations.
# Loading 69 med data...
# Loaded 69 med data with 3312 medication administrations.
# Loading 70 med data...
# Loaded 70 med data with 3232 medication administrations.
# Loading 71 med data...
# Loaded 71 med data with 3156 medication administrations.
# Loading 72 med data...
# Loaded 72 med data with 3083 medication administrations.
# Loading 73 med data...
# Loaded 73 med data with 3011 medication administrations.
# Loading 74 med data...
# Loaded 74 med data with 2949 medication administrations.
# Loading 75 med data...
# Loaded 75 med data with 2883 medication administrations.
# Loading 76 med data...
# Loaded 76 med data with 2807 medication administrations.
# Loading 77 med data...
# Loaded 77 med data with 2744 medication administrations.
# Loading 78 med data...
# Loaded 78 med data with 2685 medication administrations.
# Loading 79 med data...
# Loaded 79 med data with 2643 medication administrations.
# Loading 80 med data...
# Loaded 80 med data with 2592 medication administrations.
# Loading 81 med data...
# Loaded 81 med data with 2534 medication administrations.
# Loading 82 med data...
# Loaded 82 med data with 2479 medication administrations.
# Loading 83 med data...
# Loaded 83 med data with 2423 medication administrations.
# Loading 84 med data...
# Loaded 84 med data with 2376 medication administrations.
# Loading 85 med data...
# Loaded 85 med data with 2326 medication administrations.
# Loading 86 med data...
# Loaded 86 med data with 2275 medication administrations.
# Loading 87 med data...
# Loaded 87 med data with 2228 medication administrations.
# Loading 88 med data...
# Loaded 88 med data with 2175 medication administrations.
# Loading 89 med data...
# Loaded 89 med data with 2129 medication administrations.
# Loading 90 med data...
# Loaded 90 med data with 2092 medication administrations.
# Loading 91 med data...
# Loaded 91 med data with 2068 medication administrations.
# Loading 92 med data...
# Loaded 92 med data with 2024 medication administrations.
# Loading 93 med data...
# Loaded 93 med data with 1991 medication administrations.
# Loading 94 med data...
# Loaded 94 med data with 1937 medication administrations.
# Loading 95 med data...
# Loaded 95 med data with 1909 medication administrations.
# Loading 96 med data...
# Loaded 96 med data with 1880 medication administrations.
# Loading 97 med data...
# Loaded 97 med data with 1841 medication administrations.
# Loading 98 med data...
# Loaded 98 med data with 1813 medication administrations.
# Loading 99 med data...
# Loaded 99 med data with 1776 medication administrations.
# Loading 100 med data...
# Loaded 100 med data with 1746 medication administrations.
# Loading 101 med data...
# Loaded 101 med data with 1710 medication administrations.
# Loading 102 med data...
# Loaded 102 med data with 1682 medication administrations.
# Loading 103 med data...
# Loaded 103 med data with 1658 medication administrations.
# Loading 104 med data...
# Loaded 104 med data with 1634 medication administrations.
# Loading 105 med data...
# Loaded 105 med data with 1600 medication administrations.
# Loading 106 med data...
# Loaded 106 med data with 1575 medication administrations.
# Loading 107 med data...
# Loaded 107 med data with 1553 medication administrations.
# Loading 108 med data...
# Loaded 108 med data with 1530 medication administrations.
# Loading 109 med data...
# Loaded 109 med data with 1504 medication administrations.
# Loading 110 med data...
# Loaded 110 med data with 1485 medication administrations.
# Loading 111 med data...
# Loaded 111 med data with 1460 medication administrations.
# Loading 112 med data...
# Loaded 112 med data with 1436 medication administrations.
# Loading 113 med data...
# Loaded 113 med data with 1406 medication administrations.
# Loading 114 med data...
# Loaded 114 med data with 1370 medication administrations.
# Loading 115 med data...
# Loaded 115 med data with 1348 medication administrations.
# Loading 116 med data...
# Loaded 116 med data with 1330 medication administrations.
# Loading 117 med data...
# Loaded 117 med data with 1305 medication administrations.
# Loading 118 med data...
# Loaded 118 med data with 1285 medication administrations.
# Loading 119 med data...
# Loaded 119 med data with 1264 medication administrations.
# Loading 120 med data...
# Loaded 120 med data with 1243 medication administrations.
# Loading 121 med data...
# Loaded 121 med data with 1218 medication administrations.
# Loading 122 med data...
# Loaded 122 med data with 1199 medication administrations.
# Loading 123 med data...
# Loaded 123 med data with 1176 medication administrations.
# Loading 124 med data...
# Loaded 124 med data with 1158 medication administrations.
# Loading 125 med data...
# Loaded 125 med data with 1144 medication administrations.
# Loading 126 med data...
# Loaded 126 med data with 1123 medication administrations.
# Loading 127 med data...
# Loaded 127 med data with 1108 medication administrations.
# Loading 128 med data...
# Loaded 128 med data with 1090 medication administrations.
# Loading 129 med data...
# Loaded 129 med data with 1066 medication administrations.
# Loading 130 med data...
# Loaded 130 med data with 1049 medication administrations.
# Loading 131 med data...
# Loaded 131 med data with 1028 medication administrations.
# Loading 132 med data...
# Loaded 132 med data with 1017 medication administrations.
# Loading 133 med data...
# Loaded 133 med data with 1009 medication administrations.
# Loading 134 med data...
# Loaded 134 med data with 986 medication administrations.
# Loading 135 med data...
# Loaded 135 med data with 976 medication administrations.
# Loading 136 med data...
# Loaded 136 med data with 965 medication administrations.
# Loading 137 med data...
# Loaded 137 med data with 952 medication administrations.
# Loading 138 med data...
# Loaded 138 med data with 938 medication administrations.
# Loading 139 med data...
# Loaded 139 med data with 921 medication administrations.
# Loading 140 med data...
# Loaded 140 med data with 905 medication administrations.
# Loading 141 med data...
# Loaded 141 med data with 893 medication administrations.
# Loading 142 med data...
# Loaded 142 med data with 887 medication administrations.
# Loading 143 med data...
# Loaded 143 med data with 869 medication administrations.
# Loading 144 med data...
# Loaded 144 med data with 860 medication administrations.
# Loading 145 med data...
# Loaded 145 med data with 846 medication administrations.
# Loading 146 med data...
# Loaded 146 med data with 830 medication administrations.
# Loading 147 med data...
# Loaded 147 med data with 817 medication administrations.
# Loading 148 med data...
# Loaded 148 med data with 806 medication administrations.
# Loading 149 med data...
# Loaded 149 med data with 792 medication administrations.
# Loading 150 med data...
# Loaded 150 med data with 775 medication administrations.
# Loading 151 med data...
# Loaded 151 med data with 765 medication administrations.
# Loading 152 med data...
# Loaded 152 med data with 755 medication administrations.
# Loading 153 med data...
# Loaded 153 med data with 742 medication administrations.
# Loading 154 med data...
# Loaded 154 med data with 737 medication administrations.
# Loading 155 med data...
# Loaded 155 med data with 731 medication administrations.
# Loading 156 med data...
# Loaded 156 med data with 721 medication administrations.
# Loading 157 med data...
# Loaded 157 med data with 709 medication administrations.
# Loading 158 med data...
# Loaded 158 med data with 696 medication administrations.
# Loading 159 med data...
# Loaded 159 med data with 683 medication administrations.
# Loading 160 med data...
# Loaded 160 med data with 667 medication administrations.
# Loading 161 med data...
# Loaded 161 med data with 659 medication administrations.
# Loading 162 med data...
# Loaded 162 med data with 648 medication administrations.
# Loading 163 med data...
# Loaded 163 med data with 639 medication administrations.
# Loading 164 med data...
# Loaded 164 med data with 630 medication administrations.
# Loading 165 med data...
# Loaded 165 med data with 621 medication administrations.
# Loading 166 med data...
# Loaded 166 med data with 611 medication administrations.
# Loading 167 med data...
# Loaded 167 med data with 608 medication administrations.
# Loading 168 med data...
# Loaded 168 med data with 603 medication administrations.
# Loading 169 med data...
# Loaded 169 med data with 597 medication administrations.
# Loading 170 med data...
# Loaded 170 med data with 596 medication administrations.
# Loading 171 med data...
# Loaded 171 med data with 590 medication administrations.
# Loading 172 med data...
# Loaded 172 med data with 586 medication administrations.
# Loading 173 med data...
# Loaded 173 med data with 580 medication administrations.
# Loading 174 med data...
# Loaded 174 med data with 576 medication administrations.
# Loading 175 med data...
# Loaded 175 med data with 568 medication administrations.
# Loading 176 med data...
# Loaded 176 med data with 563 medication administrations.
# Loading 177 med data...
# Loaded 177 med data with 553 medication administrations.
# Loading 178 med data...
# Loaded 178 med data with 547 medication administrations.
# Loading 179 med data...
# Loaded 179 med data with 539 medication administrations.
# Loading 180 med data...
# Loaded 180 med data with 534 medication administrations.
# Loading 181 med data...
# Loaded 181 med data with 524 medication administrations.
# Loading 182 med data...
# Loaded 182 med data with 517 medication administrations.
# Loading 183 med data...
# Loaded 183 med data with 507 medication administrations.
# Loading 184 med data...
# Loaded 184 med data with 503 medication administrations.
# Loading 185 med data...
# Loaded 185 med data with 495 medication administrations.
# Loading 186 med data...
# Loaded 186 med data with 488 medication administrations.
# Loading 187 med data...
# Loaded 187 med data with 484 medication administrations.
# Loading 188 med data...
# Loaded 188 med data with 479 medication administrations.
# Loading 189 med data...
# Loaded 189 med data with 468 medication administrations.
# Loading 190 med data...
# Loaded 190 med data with 465 medication administrations.
# Loading 191 med data...
# Loaded 191 med data with 456 medication administrations.
# Loading 192 med data...
# Loaded 192 med data with 449 medication administrations.
# Loading 193 med data...
# Loaded 193 med data with 446 medication administrations.
# Loading 194 med data...
# Loaded 194 med data with 442 medication administrations.
# Loading 195 med data...
# Loaded 195 med data with 436 medication administrations.
# Loading 196 med data...
# Loaded 196 med data with 431 medication administrations.
# Loading 197 med data...
# Loaded 197 med data with 429 medication administrations.
# Loading 198 med data...
# Loaded 198 med data with 422 medication administrations.
# Loading 199 med data...
# Loaded 199 med data with 418 medication administrations.
# Loading 200 med data...
# Loaded 200 med data with 414 medication administrations.
# Loading 201 med data...
# Loaded 201 med data with 408 medication administrations.
# Loading 202 med data...
# Loaded 202 med data with 403 medication administrations.
# Loading 203 med data...
# Loaded 203 med data with 394 medication administrations.
# Loading 204 med data...
# Loaded 204 med data with 385 medication administrations.
# Loading 205 med data...
# Loaded 205 med data with 381 medication administrations.
# Loading 206 med data...
# Loaded 206 med data with 375 medication administrations.
# Loading 207 med data...
# Loaded 207 med data with 372 medication administrations.
# Loading 208 med data...
# Loaded 208 med data with 370 medication administrations.
# Loading 209 med data...
# Loaded 209 med data with 365 medication administrations.
# Loading 210 med data...
# Loaded 210 med data with 363 medication administrations.
# Loading 211 med data...
# Loaded 211 med data with 357 medication administrations.
# Loading 212 med data...
# Loaded 212 med data with 352 medication administrations.
# Loading 213 med data...
# Loaded 213 med data with 346 medication administrations.
# Loading 214 med data...
# Loaded 214 med data with 343 medication administrations.
# Loading 215 med data...
# Loaded 215 med data with 335 medication administrations.
# Loading 216 med data...
# Loaded 216 med data with 330 medication administrations.
# Loading 217 med data...
# Loaded 217 med data with 327 medication administrations.
# Loading 218 med data...
# Loaded 218 med data with 321 medication administrations.
# Loading 219 med data...
# Loaded 219 med data with 317 medication administrations.
# Loading 220 med data...
# Loaded 220 med data with 314 medication administrations.
# Loading 221 med data...
# Loaded 221 med data with 314 medication administrations.
# Loading 222 med data...
# Loaded 222 med data with 310 medication administrations.
# Loading 223 med data...
# Loaded 223 med data with 307 medication administrations.
# Loading 224 med data...
# Loaded 224 med data with 302 medication administrations.
# Loading 225 med data...
# Loaded 225 med data with 301 medication administrations.
# Loading 226 med data...
# Loaded 226 med data with 300 medication administrations.
# Loading 227 med data...
# Loaded 227 med data with 298 medication administrations.
# Loading 228 med data...
# Loaded 228 med data with 294 medication administrations.
# Loading 229 med data...
# Loaded 229 med data with 291 medication administrations.
# Loading 230 med data...
# Loaded 230 med data with 289 medication administrations.
# Loading 231 med data...
# Loaded 231 med data with 282 medication administrations.
# Loading 232 med data...
# Loaded 232 med data with 281 medication administrations.
# Loading 233 med data...
# Loaded 233 med data with 279 medication administrations.
# Loading 234 med data...
# Loaded 234 med data with 273 medication administrations.
# Loading 235 med data...
# Loaded 235 med data with 269 medication administrations.
# Loading 236 med data...
# Loaded 236 med data with 266 medication administrations.
# Loading 237 med data...
# Loaded 237 med data with 265 medication administrations.
# Loading 238 med data...
# Loaded 238 med data with 263 medication administrations.
# Loading 239 med data...
# Loaded 239 med data with 258 medication administrations.
# Loading 240 med data...
# Loaded 240 med data with 255 medication administrations.
# Loading 241 med data...
# Loaded 241 med data with 252 medication administrations.
# Loading 242 med data...
# Loaded 242 med data with 251 medication administrations.
# Loading 243 med data...
# Loaded 243 med data with 249 medication administrations.
# Loading 244 med data...
# Loaded 244 med data with 247 medication administrations.
# Loading 245 med data...
# Loaded 245 med data with 245 medication administrations.
# Loading 246 med data...
# Loaded 246 med data with 244 medication administrations.
# Loading 247 med data...
# Loaded 247 med data with 241 medication administrations.
# Loading 248 med data...
# Loaded 248 med data with 240 medication administrations.
# Loading 249 med data...
# Loaded 249 med data with 239 medication administrations.
# Loading 250 med data...
# Loaded 250 med data with 237 medication administrations.
# Loading 251 med data...
# Loaded 251 med data with 234 medication administrations.
# Loading 252 med data...
# Loaded 252 med data with 233 medication administrations.
# Loading 253 med data...
# Loaded 253 med data with 230 medication administrations.
# Loading 254 med data...
# Loaded 254 med data with 224 medication administrations.
# Loading 255 med data...
# Loaded 255 med data with 221 medication administrations.
# Loading 256 med data...
# Loaded 256 med data with 219 medication administrations.
# Loading 257 med data...
# Loaded 257 med data with 216 medication administrations.
# Loading 258 med data...
# Loaded 258 med data with 215 medication administrations.
# Loading 259 med data...
# Loaded 259 med data with 214 medication administrations.
# Loading 260 med data...
# Loaded 260 med data with 210 medication administrations.
# Loading 261 med data...
# Loaded 261 med data with 208 medication administrations.
# Loading 262 med data...
# Loaded 262 med data with 206 medication administrations.
# Loading 263 med data...
# Loaded 263 med data with 203 medication administrations.
# Loading 264 med data...
# Loaded 264 med data with 200 medication administrations.
# Loading 265 med data...
# Loaded 265 med data with 197 medication administrations.
# Loading 266 med data...
# Loaded 266 med data with 189 medication administrations.
# Loading 267 med data...
# Loaded 267 med data with 186 medication administrations.
# Loading 268 med data...
# Loaded 268 med data with 182 medication administrations.
# Loading 269 med data...
# Loaded 269 med data with 180 medication administrations.
# Loading 270 med data...
# Loaded 270 med data with 177 medication administrations.
# Loading 271 med data...
# Loaded 271 med data with 176 medication administrations.
# Loading 272 med data...
# Loaded 272 med data with 174 medication administrations.
# Loading 273 med data...
# Loaded 273 med data with 173 medication administrations.
# Loading 274 med data...
# Loaded 274 med data with 169 medication administrations.
# Loading 275 med data...
# Loaded 275 med data with 166 medication administrations.
# Loading 276 med data...
# Loaded 276 med data with 164 medication administrations.
# Loading 277 med data...
# Loaded 277 med data with 161 medication administrations.
# Loading 278 med data...
# Loaded 278 med data with 160 medication administrations.
# Loading 279 med data...
# Loaded 279 med data with 157 medication administrations.
# Loading 280 med data...
# Loaded 280 med data with 157 medication administrations.
# Loading 281 med data...
# Loaded 281 med data with 155 medication administrations.
# Loading 282 med data...
# Loaded 282 med data with 154 medication administrations.
# Loading 283 med data...
# Loaded 283 med data with 152 medication administrations.
# Loading 284 med data...
# Loaded 284 med data with 151 medication administrations.
# Loading 285 med data...
# Loaded 285 med data with 150 medication administrations.
# Loading 286 med data...
# Loaded 286 med data with 149 medication administrations.
# Loading 287 med data...
# Loaded 287 med data with 149 medication administrations.
# Loading 288 med data...
# Loaded 288 med data with 149 medication administrations.
# Loading 289 med data...
# Loaded 289 med data with 149 medication administrations.
# Loading 290 med data...
# Loaded 290 med data with 147 medication administrations.
# Loading 291 med data...
# Loaded 291 med data with 147 medication administrations.
# Loading 292 med data...
# Loaded 292 med data with 147 medication administrations.
# Loading 293 med data...
# Loaded 293 med data with 145 medication administrations.
# Loading 294 med data...
# Loaded 294 med data with 144 medication administrations.
# Loading 295 med data...
# Loaded 295 med data with 140 medication administrations.
# Loading 296 med data...
# Loaded 296 med data with 139 medication administrations.
# Loading 297 med data...
# Loaded 297 med data with 139 medication administrations.
# Loading 298 med data...
# Loaded 298 med data with 139 medication administrations.
# Loading 299 med data...
# Loaded 299 med data with 139 medication administrations.
# Loading 300 med data...
# Loaded 300 med data with 138 medication administrations.
# Loading 301 med data...
# Loaded 301 med data with 135 medication administrations.
# Loading 302 med data...
# Loaded 302 med data with 135 medication administrations.
# Loading 303 med data...
# Loaded 303 med data with 133 medication administrations.
# Loading 304 med data...
# Loaded 304 med data with 132 medication administrations.
# Loading 305 med data...
# Loaded 305 med data with 131 medication administrations.
# Loading 306 med data...
# Loaded 306 med data with 131 medication administrations.
# Loading 307 med data...
# Loaded 307 med data with 131 medication administrations.
# Loading 308 med data...
# Loaded 308 med data with 130 medication administrations.
# Loading 309 med data...
# Loaded 309 med data with 128 medication administrations.
# Loading 310 med data...
# Loaded 310 med data with 125 medication administrations.
# Loading 311 med data...
# Loaded 311 med data with 125 medication administrations.
# Loading 312 med data...
# Loaded 312 med data with 125 medication administrations.
# Loading 313 med data...
# Loaded 313 med data with 124 medication administrations.
# Loading 314 med data...
# Loaded 314 med data with 123 medication administrations.
# Loading 315 med data...
# Loaded 315 med data with 121 medication administrations.
# Loading 316 med data...
# Loaded 316 med data with 121 medication administrations.
# Loading 317 med data...
# Loaded 317 med data with 121 medication administrations.
# Loading 318 med data...
# Loaded 318 med data with 118 medication administrations.
# Loading 319 med data...
# Loaded 319 med data with 116 medication administrations.
# Loading 320 med data...
# Loaded 320 med data with 115 medication administrations.
# Loading 321 med data...
# Loaded 321 med data with 115 medication administrations.
# Loading 322 med data...
# Loaded 322 med data with 113 medication administrations.
# Loading 323 med data...
# Loaded 323 med data with 112 medication administrations.
# Loading 324 med data...
# Loaded 324 med data with 111 medication administrations.
# Loading 325 med data...
# Loaded 325 med data with 111 medication administrations.
# Loading 326 med data...
# Loaded 326 med data with 110 medication administrations.
# Loading 327 med data...
# Loaded 327 med data with 109 medication administrations.
# Loading 328 med data...
# Loaded 328 med data with 109 medication administrations.
# Loading 329 med data...
# Loaded 329 med data with 108 medication administrations.
# Loading 330 med data...
# Loaded 330 med data with 108 medication administrations.
# Loading 331 med data...
# Loaded 331 med data with 108 medication administrations.
# Loading 332 med data...
# Loaded 332 med data with 107 medication administrations.
# Loading 333 med data...
# Loaded 333 med data with 105 medication administrations.
# Loading 334 med data...
# Loaded 334 med data with 105 medication administrations.
# Loading 335 med data...
# Loaded 335 med data with 105 medication administrations.
# Loading 336 med data...
# Loaded 336 med data with 104 medication administrations.
# Loading 337 med data...
# Loaded 337 med data with 104 medication administrations.
# Loading 338 med data...
# Loaded 338 med data with 104 medication administrations.
# Loading 339 med data...
# Loaded 339 med data with 104 medication administrations.
# Loading 340 med data...
# Loaded 340 med data with 103 medication administrations.
# Loading 341 med data...
# Loaded 341 med data with 103 medication administrations.
# Loading 342 med data...
# Loaded 342 med data with 101 medication administrations.
# Loading 343 med data...
# Loaded 343 med data with 99 medication administrations.
# Loading 344 med data...
# Loaded 344 med data with 99 medication administrations.
# Loading 345 med data...
# Loaded 345 med data with 98 medication administrations.
# Loading 346 med data...
# Loaded 346 med data with 97 medication administrations.
# Loading 347 med data...
# Loaded 347 med data with 97 medication administrations.
# Loading 348 med data...
# Loaded 348 med data with 96 medication administrations.
# Loading 349 med data...
# Loaded 349 med data with 96 medication administrations.
# Loading 350 med data...
# Loaded 350 med data with 96 medication administrations.
# Loading 351 med data...
# Loaded 351 med data with 96 medication administrations.
# Loading 352 med data...
# Loaded 352 med data with 94 medication administrations.
# Loading 353 med data...
# Loaded 353 med data with 92 medication administrations.
# Loading 354 med data...
# Loaded 354 med data with 91 medication administrations.
# Loading 355 med data...
# Loaded 355 med data with 89 medication administrations.
# Loading 356 med data...
# Loaded 356 med data with 89 medication administrations.
# Loading 357 med data...
# Loaded 357 med data with 88 medication administrations.
# Loading 358 med data...
# Loaded 358 med data with 86 medication administrations.
# Loading 359 med data...
# Loaded 359 med data with 85 medication administrations.
# Loading 360 med data...
# Loaded 360 med data with 84 medication administrations.
# Loading 361 med data...
# Loaded 361 med data with 84 medication administrations.
# Loading 362 med data...
# Loaded 362 med data with 83 medication administrations.
# Loading 363 med data...
# Loaded 363 med data with 80 medication administrations.
# Loading 364 med data...
# Loaded 364 med data with 80 medication administrations.
# Loading 365 med data...
# Loaded 365 med data with 79 medication administrations.
# Loading 366 med data...
# Loaded 366 med data with 79 medication administrations.
# Loading 367 med data...
# Loaded 367 med data with 79 medication administrations.
# Loading 368 med data...
# Loaded 368 med data with 78 medication administrations.
# Loading 369 med data...
# Loaded 369 med data with 75 medication administrations.
# Loading 370 med data...
# Loaded 370 med data with 75 medication administrations.
# Loading 371 med data...
# Loaded 371 med data with 75 medication administrations.
# Loading 372 med data...
# Loaded 372 med data with 74 medication administrations.
# Loading 373 med data...
# Loaded 373 med data with 74 medication administrations.
# Loading 374 med data...
# Loaded 374 med data with 74 medication administrations.
# Loading 375 med data...
# Loaded 375 med data with 74 medication administrations.
# Loading 376 med data...
# Loaded 376 med data with 74 medication administrations.
# Loading 377 med data...
# Loaded 377 med data with 74 medication administrations.
# Loading 378 med data...
# Loaded 378 med data with 74 medication administrations.
# Loading 379 med data...
# Loaded 379 med data with 74 medication administrations.
# Loading 380 med data...
# Loaded 380 med data with 74 medication administrations.
# Loading 381 med data...
# Loaded 381 med data with 73 medication administrations.
# Loading 382 med data...
# Loaded 382 med data with 73 medication administrations.
# Loading 383 med data...
# Loaded 383 med data with 73 medication administrations.
# Loading 384 med data...
# Loaded 384 med data with 73 medication administrations.
# Loading 385 med data...
# Loaded 385 med data with 73 medication administrations.
# Loading 386 med data...
# Loaded 386 med data with 72 medication administrations.
# Loading 387 med data...
# Loaded 387 med data with 71 medication administrations.
# Loading 388 med data...
# Loaded 388 med data with 70 medication administrations.
# Loading 389 med data...
# Loaded 389 med data with 70 medication administrations.
# Loading 390 med data...
# Loaded 390 med data with 69 medication administrations.
# Loading 391 med data...
# Loaded 391 med data with 69 medication administrations.
# Loading 392 med data...
# Loaded 392 med data with 69 medication administrations.
# Loading 393 med data...
# Loaded 393 med data with 69 medication administrations.
# Loading 394 med data...
# Loaded 394 med data with 68 medication administrations.
# Loading 395 med data...
# Loaded 395 med data with 67 medication administrations.
# Loading 396 med data...
# Loaded 396 med data with 67 medication administrations.
# Loading 397 med data...
# Loaded 397 med data with 67 medication administrations.
# Loading 398 med data...
# Loaded 398 med data with 66 medication administrations.
# Loading 399 med data...
# Loaded 399 med data with 65 medication administrations.
# Loading 400 med data...
# Loaded 400 med data with 65 medication administrations.
# Loading 401 med data...
# Loaded 401 med data with 64 medication administrations.
# Loading 402 med data...
# Loaded 402 med data with 64 medication administrations.
# Loading 403 med data...
# Loaded 403 med data with 64 medication administrations.
# Loading 404 med data...
# Loaded 404 med data with 64 medication administrations.
# Loading 405 med data...
# Loaded 405 med data with 64 medication administrations.
# Loading 406 med data...
# Loaded 406 med data with 64 medication administrations.
# Loading 407 med data...
# Loaded 407 med data with 64 medication administrations.
# Loading 408 med data...
# Loaded 408 med data with 64 medication administrations.
# Loading 409 med data...
# Loaded 409 med data with 64 medication administrations.
# Loading 410 med data...
# Loaded 410 med data with 64 medication administrations.
# Loading 411 med data...
# Loaded 411 med data with 62 medication administrations.
# Loading 412 med data...
# Loaded 412 med data with 62 medication administrations.
# Loading 413 med data...
# Loaded 413 med data with 61 medication administrations.
# Loading 414 med data...
# Loaded 414 med data with 61 medication administrations.
# Loading 415 med data...
# Loaded 415 med data with 61 medication administrations.
# Loading 416 med data...
# Loaded 416 med data with 61 medication administrations.
# Loading 417 med data...
# Loaded 417 med data with 61 medication administrations.
# Loading 418 med data...
# Loaded 418 med data with 61 medication administrations.
# Loading 419 med data...
# Loaded 419 med data with 59 medication administrations.
# Loading 420 med data...
# Loaded 420 med data with 59 medication administrations.
# Loading 421 med data...
# Loaded 421 med data with 59 medication administrations.
# Loading 422 med data...
# Loaded 422 med data with 59 medication administrations.
# Loading 423 med data...
# Loaded 423 med data with 59 medication administrations.
# Loading 424 med data...
# Loaded 424 med data with 59 medication administrations.
# Loading 425 med data...
# Loaded 425 med data with 59 medication administrations.
# Loading 426 med data...
# Loaded 426 med data with 59 medication administrations.
# Loading 427 med data...
# Loaded 427 med data with 59 medication administrations.
# Loading 428 med data...
# Loaded 428 med data with 59 medication administrations.
# Loading 429 med data...
# Loaded 429 med data with 59 medication administrations.
# Loading 430 med data...
# Loaded 430 med data with 59 medication administrations.
# Loading 431 med data...
# Loaded 431 med data with 59 medication administrations.
# Loading 432 med data...
# Loaded 432 med data with 59 medication administrations.
# Loading 433 med data...
# Loaded 433 med data with 59 medication administrations.
# Loading 434 med data...
# Loaded 434 med data with 59 medication administrations.
# Loading 435 med data...
# Loaded 435 med data with 59 medication administrations.
# Loading 436 med data...
# Loaded 436 med data with 59 medication administrations.
# Loading 437 med data...
# Loaded 437 med data with 58 medication administrations.
# Loading 438 med data...
# Loaded 438 med data with 57 medication administrations.
# Loading 439 med data...
# Loaded 439 med data with 57 medication administrations.
# Loading 440 med data...
# Loaded 440 med data with 57 medication administrations.
# Loading 441 med data...
# Loaded 441 med data with 57 medication administrations.
# Loading 442 med data...
# Loaded 442 med data with 57 medication administrations.
# Loading 443 med data...
# Loaded 443 med data with 57 medication administrations.
# Loading 444 med data...
# Loaded 444 med data with 57 medication administrations.
# Loading 445 med data...
# Loaded 445 med data with 55 medication administrations.
# Loading 446 med data...
# Loaded 446 med data with 55 medication administrations.
# Loading 447 med data...
# Loaded 447 med data with 55 medication administrations.
# Loading 448 med data...
# Loaded 448 med data with 54 medication administrations.
# Loading 449 med data...
# Loaded 449 med data with 54 medication administrations.
# Loading 450 med data...
# Loaded 450 med data with 54 medication administrations.
# Loading 451 med data...
# Loaded 451 med data with 54 medication administrations.
# Loading 452 med data...
# Loaded 452 med data with 54 medication administrations.
# Loading 453 med data...
# Loaded 453 med data with 54 medication administrations.
# Loading 454 med data...
# Loaded 454 med data with 54 medication administrations.
# Loading 455 med data...
# Loaded 455 med data with 54 medication administrations.
# Loading 456 med data...
# Loaded 456 med data with 53 medication administrations.
# Loading 457 med data...
# Loaded 457 med data with 53 medication administrations.
# Loading 458 med data...
# Loaded 458 med data with 53 medication administrations.
# Loading 459 med data...
# Loaded 459 med data with 53 medication administrations.
# Loading 460 med data...
# Loaded 460 med data with 52 medication administrations.
# Loading 461 med data...
# Loaded 461 med data with 52 medication administrations.
# Loading 462 med data...
# Loaded 462 med data with 51 medication administrations.
# Loading 463 med data...
# Loaded 463 med data with 51 medication administrations.
# Loading 464 med data...
# Loaded 464 med data with 51 medication administrations.
# Loading 465 med data...
# Loaded 465 med data with 51 medication administrations.
# Loading 466 med data...
# Loaded 466 med data with 51 medication administrations.
# Loading 467 med data...
# Loaded 467 med data with 51 medication administrations.
# Loading 468 med data...
# Loaded 468 med data with 50 medication administrations.
# Loading 469 med data...
# Loaded 469 med data with 50 medication administrations.
# Loading 470 med data...
# Loaded 470 med data with 49 medication administrations.
# Loading 471 med data...
# Loaded 471 med data with 48 medication administrations.
# Loading 472 med data...
# Loaded 472 med data with 48 medication administrations.
# Loading 473 med data...
# Loaded 473 med data with 47 medication administrations.
# Loading 474 med data...
# Loaded 474 med data with 47 medication administrations.
# Loading 475 med data...
# Loaded 475 med data with 47 medication administrations.
# Loading 476 med data...
# Loaded 476 med data with 47 medication administrations.
# Loading 477 med data...
# Loaded 477 med data with 46 medication administrations.
# Loading 478 med data...
# Loaded 478 med data with 45 medication administrations.
# Loading 479 med data...
# Loaded 479 med data with 45 medication administrations.
# Loading 480 med data...
# Loaded 480 med data with 44 medication administrations.
# Loading 481 med data...
# Loaded 481 med data with 44 medication administrations.
# Loading 482 med data...
# Loaded 482 med data with 44 medication administrations.
# Loading 483 med data...
# Loaded 483 med data with 44 medication administrations.
# Loading 484 med data...
# Loaded 484 med data with 44 medication administrations.
# Loading 485 med data...
# Loaded 485 med data with 44 medication administrations.
# Loading 486 med data...
# Loaded 486 med data with 44 medication administrations.
# Loading 487 med data...
# Loaded 487 med data with 44 medication administrations.
# Loading 488 med data...
# Loaded 488 med data with 44 medication administrations.
# Loading 489 med data...
# Loaded 489 med data with 44 medication administrations.
# Loading 490 med data...
# Loaded 490 med data with 43 medication administrations.
# Loading 491 med data...
# Loaded 491 med data with 43 medication administrations.
# Loading 492 med data...
# Loaded 492 med data with 43 medication administrations.
# Loading 493 med data...
# Loaded 493 med data with 43 medication administrations.
# Loading 494 med data...
# Loaded 494 med data with 42 medication administrations.
# Loading 495 med data...
# Loaded 495 med data with 42 medication administrations.
# Loading 496 med data...
# Loaded 496 med data with 42 medication administrations.
# Loading 497 med data...
# Loaded 497 med data with 42 medication administrations.
# Loading 498 med data...
# Loaded 498 med data with 41 medication administrations.
# Loading 499 med data...
# Loaded 499 med data with 40 medication administrations.
# Loading 500 med data...
# Loaded 500 med data with 40 medication administrations.
# Loading 501 med data...
# Loaded 501 med data with 40 medication administrations.
# Loading 502 med data...
# Loaded 502 med data with 40 medication administrations.
# Loading 503 med data...
# Loaded 503 med data with 40 medication administrations.
# Loading 504 med data...
# Loaded 504 med data with 40 medication administrations.
# Loading 505 med data...
# Loaded 505 med data with 40 medication administrations.
# Loading 506 med data...
# Loaded 506 med data with 40 medication administrations.
# Loading 507 med data...
# Loaded 507 med data with 40 medication administrations.
# Loading 508 med data...
# Loaded 508 med data with 40 medication administrations.
# Loading 509 med data...
# Loaded 509 med data with 40 medication administrations.
# Loading 510 med data...
# Loaded 510 med data with 40 medication administrations.
# Loading 511 med data...
# Loaded 511 med data with 40 medication administrations.
# Loading 512 med data...
# Loaded 512 med data with 40 medication administrations.
# Loading 513 med data...
# Loaded 513 med data with 40 medication administrations.
# Loading 514 med data...
# Loaded 514 med data with 40 medication administrations.
# Loading 515 med data...
# Loaded 515 med data with 40 medication administrations.
# Loading 516 med data...
# Loaded 516 med data with 40 medication administrations.
# Loading 517 med data...
# Loaded 517 med data with 40 medication administrations.
# Loading 518 med data...
# Loaded 518 med data with 40 medication administrations.
# Loading 519 med data...
# Loaded 519 med data with 40 medication administrations.
# Loading 520 med data...
# Loaded 520 med data with 39 medication administrations.
# Loading 521 med data...
# Loaded 521 med data with 39 medication administrations.
# Loading 522 med data...
# Loaded 522 med data with 39 medication administrations.
# Loading 523 med data...
# Loaded 523 med data with 39 medication administrations.
# Loading 524 med data...
# Loaded 524 med data with 39 medication administrations.
# Loading 525 med data...
# Loaded 525 med data with 39 medication administrations.
# Loading 526 med data...
# Loaded 526 med data with 39 medication administrations.
# Loading 527 med data...
# Loaded 527 med data with 39 medication administrations.
# Loading 528 med data...
# Loaded 528 med data with 39 medication administrations.
# Loading 529 med data...
# Loaded 529 med data with 39 medication administrations.
# Loading 530 med data...
# Loaded 530 med data with 38 medication administrations.
# Loading 531 med data...
# Loaded 531 med data with 37 medication administrations.
# Loading 532 med data...
# Loaded 532 med data with 36 medication administrations.
# Loading 533 med data...
# Loaded 533 med data with 36 medication administrations.
# Loading 534 med data...
# Loaded 534 med data with 36 medication administrations.
# Loading 535 med data...
# Loaded 535 med data with 35 medication administrations.
# Loading 536 med data...
# Loaded 536 med data with 35 medication administrations.
# Loading 537 med data...
# Loaded 537 med data with 35 medication administrations.
# Loading 538 med data...
# Loaded 538 med data with 35 medication administrations.
# Loading 539 med data...
# Loaded 539 med data with 35 medication administrations.
# Loading 540 med data...
# Loaded 540 med data with 35 medication administrations.
# Loading 541 med data...
# Loaded 541 med data with 35 medication administrations.
# Loading 542 med data...
# Loaded 542 med data with 34 medication administrations.
# Loading 543 med data...
# Loaded 543 med data with 34 medication administrations.
# Loading 544 med data...
# Loaded 544 med data with 33 medication administrations.
# Loading 545 med data...
# Loaded 545 med data with 32 medication administrations.
# Loading 546 med data...
# Loaded 546 med data with 32 medication administrations.
# Loading 547 med data...
# Loaded 547 med data with 32 medication administrations.
# Loading 548 med data...
# Loaded 548 med data with 32 medication administrations.
# Loading 549 med data...
# Loaded 549 med data with 32 medication administrations.
# Loading 550 med data...
# Loaded 550 med data with 31 medication administrations.
# Loading 551 med data...
# Loaded 551 med data with 31 medication administrations.
# Loading 552 med data...
# Loaded 552 med data with 31 medication administrations.
# Loading 553 med data...
# Loaded 553 med data with 29 medication administrations.
# Loading 554 med data...
# Loaded 554 med data with 29 medication administrations.
# Loading 555 med data...
# Loaded 555 med data with 29 medication administrations.
# Loading 556 med data...
# Loaded 556 med data with 29 medication administrations.
# Loading 557 med data...
# Loaded 557 med data with 29 medication administrations.
# Loading 558 med data...
# Loaded 558 med data with 29 medication administrations.
# Loading 559 med data...
# Loaded 559 med data with 29 medication administrations.
# Loading 560 med data...
# Loaded 560 med data with 28 medication administrations.
# Loading 561 med data...
# Loaded 561 med data with 28 medication administrations.
# Loading 562 med data...
# Loaded 562 med data with 28 medication administrations.
# Loading 563 med data...
# Loaded 563 med data with 28 medication administrations.
# Loading 564 med data...
# Loaded 564 med data with 27 medication administrations.
# Loading 565 med data...
# Loaded 565 med data with 27 medication administrations.
# Loading 566 med data...
# Loaded 566 med data with 27 medication administrations.
# Loading 567 med data...
# Loaded 567 med data with 27 medication administrations.
# Loading 568 med data...
# Loaded 568 med data with 26 medication administrations.
# Loading 569 med data...
# Loaded 569 med data with 26 medication administrations.
# Loading 570 med data...
# Loaded 570 med data with 26 medication administrations.
# Loading 571 med data...
# Loaded 571 med data with 25 medication administrations.
# Loading 572 med data...
# Loaded 572 med data with 24 medication administrations.
# Loading 573 med data...
# Loaded 573 med data with 24 medication administrations.
# Loading 574 med data...
# Loaded 574 med data with 24 medication administrations.
# Loading 575 med data...
# Loaded 575 med data with 23 medication administrations.
# Loading 576 med data...
# Loaded 576 med data with 23 medication administrations.
# Loading 577 med data...
# Loaded 577 med data with 22 medication administrations.
# Loading 578 med data...
# Loaded 578 med data with 22 medication administrations.
# Loading 579 med data...
# Loaded 579 med data with 22 medication administrations.
# Loading 580 med data...
# Loaded 580 med data with 22 medication administrations.
# Loading 581 med data...
# Loaded 581 med data with 22 medication administrations.
# Loading 582 med data...
# Loaded 582 med data with 22 medication administrations.
# Loading 583 med data...
# Loaded 583 med data with 22 medication administrations.
# Loading 584 med data...
# Loaded 584 med data with 22 medication administrations.
# Loading 585 med data...
# Loaded 585 med data with 22 medication administrations.
# Loading 586 med data...
# Loaded 586 med data with 22 medication administrations.
# Loading 587 med data...
# ...
# Loaded 912 med data with 3 medication administrations.
# Loading 913 med data...
# Loaded 913 med data with 3 medication administrations.
# Loading 914 med data...
# Loaded 914 med data with 3 medication administrations.
# Loading 915 med data...
# Loaded 915 med data with 3 medication administrations.
# Loading 916 med data...
# Loaded 916 med data with 3 medication administrations.
# Loading 917 med data...
# Loaded 917 med data with 3 medication administrations.
# Loading 918 med data...
# Loaded 918 med data with 3 medication administrations.
# Loading 919 med data...
# Loaded 919 med data with 3 medication administrations.
# Loading 920 med data...
# Loaded 920 med data with 3 medication administrations.
# Loading 921 med data...
# Loaded 921 med data with 3 medication administrations.
# Loading 922 med data...
# Loaded 922 med data with 3 medication administrations.
# Loading 923 med data...
# Loaded 923 med data with 3 medication administrations.
# Loading 924 med data...
# Loaded 924 med data with 3 medication administrations.
# Loading 925 med data...
# Loaded 925 med data with 3 medication administrations.
# Loading 926 med data...
# Loaded 926 med data with 3 medication administrations.
# Loading 927 med data...
# Loaded 927 med data with 3 medication administrations.
# Loading 928 med data...
# Loaded 928 med data with 3 medication administrations.
# Loading 929 med data...
# Loaded 929 med data with 3 medication administrations.
# Loading 930 med data...
# Loaded 930 med data with 3 medication administrations.
# Loading 931 med data...
# Loaded 931 med data with 3 medication administrations.
# Loading 932 med data...
# Loaded 932 med data with 3 medication administrations.
# Loading 933 med data...
# Loaded 933 med data with 3 medication administrations.
# Loading 934 med data...
# Loaded 934 med data with 3 medication administrations.
# Loading 935 med data...
# Loaded 935 med data with 3 medication administrations.
# Loading 936 med data...
# Loaded 936 med data with 3 medication administrations.
# Loading 937 med data...
# Loaded 937 med data with 3 medication administrations.
# Loading 938 med data...
# Loaded 938 med data with 3 medication administrations.
# Loading 939 med data...
# Loaded 939 med data with 3 medication administrations.
# Loading 940 med data...
# Loaded 940 med data with 3 medication administrations.
# Loading 941 med data...
# Loaded 941 med data with 3 medication administrations.
# Loading 942 med data...
# Loaded 942 med data with 3 medication administrations.
# Loading 943 med data...
# Loaded 943 med data with 3 medication administrations.
# Loading 944 med data...
# Loaded 944 med data with 3 medication administrations.
# Loading 945 med data...
# Loaded 945 med data with 3 medication administrations.
# Loading 946 med data...
# Loaded 946 med data with 3 medication administrations.
# Loading 947 med data...
# Loaded 947 med data with 3 medication administrations.
# Loading 948 med data...
# Loaded 948 med data with 3 medication administrations.
# Loading 949 med data...
# Loaded 949 med data with 3 medication administrations.
# Loading 950 med data...
# Loaded 950 med data with 3 medication administrations.
# Loading 951 med data...
# Loaded 951 med data with 3 medication administrations.
# Loading 952 med data...
# Loaded 952 med data with 3 medication administrations.
# Loading 953 med data...
# Loaded 953 med data with 3 medication administrations.
# Loading 954 med data...
# Loaded 954 med data with 3 medication administrations.
# Loading 955 med data...
# Loaded 955 med data with 3 medication administrations.
# Loading 956 med data...
# Loaded 956 med data with 3 medication administrations.
# Loading 957 med data...
# Loaded 957 med data with 3 medication administrations.
# Loading 958 med data...
# Loaded 958 med data with 3 medication administrations.
# Loading 959 med data...
# Loaded 959 med data with 3 medication administrations.
# Loading 960 med data...
# Loaded 960 med data with 3 medication administrations.
# Loading 961 med data...
# Loaded 961 med data with 3 medication administrations.
# Loading 962 med data...
# Loaded 962 med data with 3 medication administrations.
# Loading 963 med data...
# Loaded 963 med data with 3 medication administrations.
# Loading 964 med data...
# Loaded 964 med data with 3 medication administrations.
# Loading 965 med data...
# Loaded 965 med data with 3 medication administrations.
# Loading 966 med data...
# Loaded 966 med data with 3 medication administrations.
# Loading 967 med data...
# Loaded 967 med data with 3 medication administrations.
# Loading 968 med data...
# Loaded 968 med data with 3 medication administrations.
# Loading 969 med data...
# Loaded 969 med data with 3 medication administrations.
# Loading 970 med data...
# Loaded 970 med data with 3 medication administrations.
# Loading 971 med data...
# Loaded 971 med data with 3 medication administrations.
# Loading 972 med data...
# Loaded 972 med data with 3 medication administrations.
# Loading 973 med data...
# Loaded 973 med data with 3 medication administrations.
# Loading 974 med data...
# Loaded 974 med data with 3 medication administrations.
# Loading 975 med data...
# Loaded 975 med data with 2 medication administrations.
# Loading 976 med data...
# Loaded 976 med data with 2 medication administrations.
# Loading 977 med data...
# Loaded 977 med data with 2 medication administrations.
# Loading 978 med data...
# Loaded 978 med data with 2 medication administrations.
# Loading 979 med data...
# Loaded 979 med data with 2 medication administrations.
# Loading 980 med data...
# Loaded 980 med data with 2 medication administrations.
# Loading 981 med data...
# Loaded 981 med data with 2 medication administrations.
# Loading 982 med data...
# Loaded 982 med data with 2 medication administrations.
# Loading 983 med data...
# Loaded 983 med data with 2 medication administrations.
# Loading 984 med data...
# Loaded 984 med data with 2 medication administrations.
# Loading 985 med data...
# Loaded 985 med data with 2 medication administrations.
# Loading 986 med data...
# Loaded 986 med data with 2 medication administrations.
# Loading 987 med data...
# Loaded 987 med data with 2 medication administrations.
# Loading 988 med data...
# Loaded 988 med data with 2 medication administrations.
# Loading 989 med data...
# Loaded 989 med data with 2 medication administrations.
# Loading 990 med data...
# Loaded 990 med data with 2 medication administrations.
# Loading 991 med data...
# Loaded 991 med data with 2 medication administrations.
# Loading 992 med data...
# Loaded 992 med data with 2 medication administrations.
# Loading 993 med data...
# Loaded 993 med data with 2 medication administrations.
# Loading 994 med data...
# Loaded 994 med data with 2 medication administrations.
# Loading 995 med data...
# Loaded 995 med data with 2 medication administrations.
# Loading 996 med data...
# Loaded 996 med data with 2 medication administrations.
# Loading 997 med data...
# Loaded 997 med data with 2 medication administrations.
# Loading 998 med data...
# Loaded 998 med data with 2 medication administrations.
# Loading 999 med data...
# Loaded 999 med data with 2 medication administrations.
# Loading 1000 med data...
# Loaded 1000 med data with 2 medication administrations.
# Loading 1001 med data...
# Loaded 1001 med data with 2 medication administrations.
# Loading 1002 med data...
# Loaded 1002 med data with 2 medication administrations.
# Loading 1003 med data...
# Loaded 1003 med data with 2 medication administrations.
# Loading 1004 med data...
# Loaded 1004 med data with 2 medication administrations.
# Loading 1005 med data...
# Loaded 1005 med data with 2 medication administrations.
# Loading 1006 med data...
# Loaded 1006 med data with 2 medication administrations.
# Loading 1007 med data...
# Loaded 1007 med data with 2 medication administrations.
# Loading 1008 med data...
# Loaded 1008 med data with 2 medication administrations.
# Loading 1009 med data...
# Loaded 1009 med data with 2 medication administrations.
# Loading 1010 med data...
# Loaded 1010 med data with 2 medication administrations.
# Loading 1011 med data...
# Loaded 1011 med data with 2 medication administrations.
# Loading 1012 med data...
# Loaded 1012 med data with 2 medication administrations.
# Loading 1013 med data...
# Loaded 1013 med data with 2 medication administrations.
# Loading 1014 med data...
# Loaded 1014 med data with 2 medication administrations.
# Loading 1015 med data...
# Loaded 1015 med data with 2 medication administrations.
# Loading 1016 med data...
# Loaded 1016 med data with 2 medication administrations.
# Loading 1017 med data...
# Loaded 1017 med data with 2 medication administrations.
# Loading 1018 med data...
# Loaded 1018 med data with 2 medication administrations.
# Loading 1019 med data...
# Loaded 1019 med data with 2 medication administrations.
# Loading 1020 med data...
# Loaded 1020 med data with 2 medication administrations.
# Loading 1021 med data...
# Loaded 1021 med data with 2 medication administrations.
# Loading 1022 med data...
# Loaded 1022 med data with 2 medication administrations.
# Loading 1023 med data...
# Loaded 1023 med data with 2 medication administrations.
# Loading 1024 med data...
# Loaded 1024 med data with 2 medication administrations.
# Loading 1025 med data...
# Loaded 1025 med data with 1 medication administrations.
# Loading 1026 med data...
# Loaded 1026 med data with 1 medication administrations.
# Loading 1027 med data...
# Loaded 1027 med data with 1 medication administrations.
# Loading 1028 med data...
# Loaded 1028 med data with 1 medication administrations.
# Loading 1029 med data...
# Loaded 1029 med data with 1 medication administrations.
# Loading 1030 med data...
# Loaded 1030 med data with 1 medication administrations.
# Loading 1031 med data...
# Loaded 1031 med data with 1 medication administrations.
# Loading 1032 med data...
# Loaded 1032 med data with 1 medication administrations.
# Loading 1033 med data...
# Loaded 1033 med data with 1 medication administrations.
# Loading 1034 med data...
# Loaded 1034 med data with 1 medication administrations.
# Loading 1035 med data...
# Loaded 1035 med data with 1 medication administrations.
# Loading 1036 med data...
# Loaded 1036 med data with 1 medication administrations.
# Loading 1037 med data...
# Loaded 1037 med data with 1 medication administrations.
# Loading 1038 med data...
# Loaded 1038 med data with 1 medication administrations.
# Loading 1039 med data...
# Loaded 1039 med data with 1 medication administrations.
# Loading 1040 med data...
# Loaded 1040 med data with 1 medication administrations.
# Loading 1041 med data...
# Loaded 1041 med data with 1 medication administrations.
# Loading 1042 med data...
# Loaded 1042 med data with 1 medication administrations.
# Loading 1043 med data...
# Loaded 1043 med data with 1 medication administrations.
# Loading 1044 med data...
# Loaded 1044 med data with 1 medication administrations.
# Loading 1045 med data...
# Loaded 1045 med data with 1 medication administrations.
# Loading 1046 med data...
# Loaded 1046 med data with 1 medication administrations.
# Loading 1047 med data...
# Loaded 1047 med data with 1 medication administrations.
# Loading 1048 med data...
# Loaded 1048 med data with 1 medication administrations.
# Loading 1049 med data...
# Loaded 1049 med data with 1 medication administrations.
# Loading 1050 med data...
# Loaded 1050 med data with 1 medication administrations.
# Loading 1051 med data...
# Loaded 1051 med data with 1 medication administrations.
# Loading 1052 med data...
# Loaded 1052 med data with 1 medication administrations.
# Loading 1053 med data...
# Loaded 1053 med data with 1 medication administrations.
# Loading 1054 med data...
# Loaded 1054 med data with 1 medication administrations.
# Loading 1055 med data...
# Loaded 1055 med data with 1 medication administrations.
# Loading 1056 med data...
# Loaded 1056 med data with 1 medication administrations.
# Loading 1057 med data...
# Loaded 1057 med data with 1 medication administrations.
# Loading 1058 med data...
# Loaded 1058 med data with 1 medication administrations.
# Loading 1059 med data...
# Loaded 1059 med data with 1 medication administrations.
# Loading 1060 med data...
# Loaded 1060 med data with 1 medication administrations.
# Loading 1061 med data...
# Loaded 1061 med data with 1 medication administrations.
# Loading 1062 med data...
# Loaded 1062 med data with 1 medication administrations.
# Loading 1063 med data...
# Loaded 1063 med data with 1 medication administrations.
# Loading 1064 med data...
# Loaded 1064 med data with 1 medication administrations.
# Loading 1065 med data...
# Loaded 1065 med data with 1 medication administrations.
# Loading 1066 med data...
# Loaded 1066 med data with 1 medication administrations.
# Loading 1067 med data...
# Loaded 1067 med data with 1 medication administrations.
# Loading 1068 med data...
# Loaded 1068 med data with 1 medication administrations.
# Loading 1069 med data...
# Loaded 1069 med data with 1 medication administrations.
# Loading 1070 med data...
# Loaded 1070 med data with 1 medication administrations.
# Loading 1071 med data...
# Loaded 1071 med data with 1 medication administrations.
# Loading 1072 med data...
# Loaded 1072 med data with 1 medication administrations.
# Loading 1073 med data...
# Loaded 1073 med data with 1 medication administrations.
# Loading 1074 med data...
# Loaded 1074 med data with 1 medication administrations.
# Loading 1075 med data...
# Loaded 1075 med data with 1 medication administrations.
# Loading 1076 med data...
# Loaded 1076 med data with 1 medication administrations.
# Loading 1077 med data...
# Loaded 1077 med data with 1 medication administrations.
# Loading 1078 med data...
# Loaded 1078 med data with 1 medication administrations.
# Loading 1079 med data...
# Loaded 1079 med data with 1 medication administrations.
# Loading 1080 med data...
# Loaded 1080 med data with 1 medication administrations.
# Loading 1081 med data...
# Loaded 1081 med data with 1 medication administrations.
# Loading 1082 med data...
# Loaded 1082 med data with 1 medication administrations.
# Loading 1083 med data...
# Loaded 1083 med data with 1 medication administrations.
# Loading 1084 med data...
# Loaded 1084 med data with 1 medication administrations.
# Loading 1085 med data...
# Loaded 1085 med data with 1 medication administrations.
# Loading 1086 med data...
# Loaded 1086 med data with 1 medication administrations.
# Loading 1087 med data...
# Loaded 1087 med data with 1 medication administrations.
# Loading 1088 med data...
# Loaded 1088 med data with 1 medication administrations.
# Loading 1089 med data...
# Loaded 1089 med data with 1 medication administrations.
# Loading 1090 med data...
# Loaded 1090 med data with 1 medication administrations.
# Loading 1091 med data...
# Loaded 1091 med data with 1 medication administrations.
# Loading 1092 med data...
# Loaded 1092 med data with 1 medication administrations.
# Loading 1093 med data...
# Loaded 1093 med data with 1 medication administrations.
# Loading 1094 med data...
# Loaded 1094 med data with 1 medication administrations.
# Loading 1095 med data...
# Loaded 1095 med data with 1 medication administrations.
# Loading 1096 med data...
# Loaded 1096 med data with 1 medication administrations.
# Loading 1097 med data...
# Loaded 1097 med data with 1 medication administrations.
# Loading 1098 med data...
# Loaded 1098 med data with 1 medication administrations.
# Loading 1099 med data...
# Loaded 1099 med data with 1 medication administrations.
# Loading 1100 med data...
# Loaded 1100 med data with 1 medication administrations.
# Loading 1101 med data...
# Loaded 1101 med data with 1 medication administrations.
# Loading 1102 med data...
# Loaded 1102 med data with 1 medication administrations.
# Loading 1103 med data...
# Loaded 1103 med data with 1 medication administrations.
# Loading 1104 med data...
# Loaded 1104 med data with 1 medication administrations.
# Loading 1105 med data...
# Loaded 1105 med data with 1 medication administrations.
# Loading 1106 med data...
# Loaded 1106 med data with 1 medication administrations.
# Loading 1107 med data...
# Loaded 1107 med data with 1 medication administrations.
# Loading 1108 med data...
# Loaded 1108 med data with 1 medication administrations.
# Loading 1109 med data...
# Loaded 1109 med data with 1 medication administrations.
# Loading 1110 med data...
# Loaded 1110 med data with 1 medication administrations.
# Loading 1111 med data...
# Loaded 1111 med data with 1 medication administrations.

# %%
from src.modeling import querier
## Querier
mimic_data_querier = querier.DatasetQuerier(
    data = data,
    res = res,
    t_labs=m_labs, 
    meds=m_n_meds[180:185],
    gender=gender, 
    age_b=age_b, 
    age_a=age_a, 
    ethnicity=ethnicity, 
    lab_mapping=lab_mapping
)

# %%
# query pairs for all medication and lab tests
final_pairs_data, interim_pairs_data = mimic_data_querier.generate_med_lab_data(before_windows, after_windows, lab_parts=(0,1000))
# Out:
# 100%|██████████| 5/5 [03:54<00:00, 46.81s/it]

# %%
[k.shape for k in final_pairs_data]
# Out:
# [(3285, 96), (2535, 96), (2485, 96), (2457, 96), (3051, 96)]

# %%
m_n_meds[180].shape, m_n_meds[0].shape
# Out:
# ((524, 69), (138658, 68))

# %%
concat_final_pairs_data = pd.concat(final_pairs_data)

# %%
from src.modeling import discovery
## Discovery Analysis for the queried medication and lab test pairs in the chosen before and after windows
analyzer = discovery.ClinicalDiscoveryAnalysis(concat_final_pairs_data)
pvals_med_lab = analyzer.analyze(before_windows, after_windows)
pvals_ratio_sampled = analyzer.analyze_ratio(before_windows, after_windows)

# %%
pvals_med_lab
# Out:
#                     Lab Name     Med Name Before Window (in Hours)  \
# 0   Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 1   Diastolic blood pressure  Dextrose 5%                  (6, 12)
# 2   Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 3   Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 4                 Heart Rate  Dextrose 5%                   (0, 6)
# 5                 Heart Rate  Dextrose 5%                  (6, 12)
# 6                 Heart Rate  Dextrose 5%                   (0, 6)
# 7                 Heart Rate  Dextrose 5%                   (0, 6)
# 8             Pulse oximetry  Dextrose 5%                   (0, 6)
# 9             Pulse oximetry  Dextrose 5%                  (6, 12)
# 10            Pulse oximetry  Dextrose 5%                   (0, 6)
# 11            Pulse oximetry  Dextrose 5%                   (0, 6)
# 12          Respiratory rate  Dextrose 5%                   (0, 6)
# 13          Respiratory rate  Dextrose 5%                  (6, 12)
# 14          Respiratory rate  Dextrose 5%                   (0, 6)
# 15          Respiratory rate  Dextrose 5%                   (0, 6)
# 16   Systolic blood pressure  Dextrose 5%                   (0, 6)
# 17   Systolic blood pressure  Dextrose 5%                  (6, 12)
# 18   Systolic blood pressure  Dextrose 5%                   (0, 6)
# 19   Systolic blood pressure  Dextrose 5%                   (0, 6)
# 20           Temperature (F)  Dextrose 5%                   (0, 6)
# 21  Diastolic blood pressure    NaCl 0.9%                   (0, 6)
# 22  Diastolic blood pressure    NaCl 0.9%                  (6, 12)
# 23  Diastolic blood pressure    NaCl 0.9%                   (0, 6)
# 24  Diastolic blood pressure    NaCl 0.9%                   (0, 6)
# 25                Heart Rate    NaCl 0.9%                   (0, 6)
# 26                Heart Rate    NaCl 0.9%                  (6, 12)
# 27                Heart Rate    NaCl 0.9%                   (0, 6)
# 28                Heart Rate    NaCl 0.9%                   (0, 6)
# 29            Pulse oximetry    NaCl 0.9%                   (0, 6)
# 30            Pulse oximetry    NaCl 0.9%                  (6, 12)
# 31            Pulse oximetry    NaCl 0.9%                   (0, 6)
# 32            Pulse oximetry    NaCl 0.9%                   (0, 6)
# 33          Respiratory rate    NaCl 0.9%                   (0, 6)
# 34          Respiratory rate    NaCl 0.9%                  (6, 12)
# 35          Respiratory rate    NaCl 0.9%                   (0, 6)
# 36          Respiratory rate    NaCl 0.9%                   (0, 6)
# 37   Systolic blood pressure    NaCl 0.9%                   (0, 6)
# 38   Systolic blood pressure    NaCl 0.9%                  (6, 12)
# 39   Systolic blood pressure    NaCl 0.9%                   (0, 6)
# 40   Systolic blood pressure    NaCl 0.9%                   (0, 6)
# 41           Temperature (F)    NaCl 0.9%                   (0, 6)
# 42  Diastolic blood pressure     Solution                   (0, 6)
# 43   Systolic blood pressure     Solution                   (0, 6)
#
#    After Window (in Hours)  Mannwhitneyu Test  TTest Independent  \
# 0                   (0, 4)           0.869181           0.814442
# 1                   (0, 4)           0.772127           0.559803
# 2                   (4, 8)           0.943172           0.978470
# 3                  (8, 12)           0.995403           0.909159
# 4                   (0, 4)           0.482301           0.423557
# 5                   (0, 4)           0.476579           0.411156
# 6                   (4, 8)           0.520203           0.611674
# 7                  (8, 12)           0.640685           0.511485
# 8                   (0, 4)           0.330995           0.520080
# 9                   (0, 4)           0.289240           0.249883
# 10                  (4, 8)           0.580546           0.712092
# 11                 (8, 12)           0.239738           0.753175
# 12                  (0, 4)           0.792722           0.646032
# 13                  (0, 4)           0.792647           0.958265
# 14                  (4, 8)           0.825656           0.758775
# 15                 (8, 12)           0.180827           0.225393
# 16                  (0, 4)           0.986038           0.982350
# 17                  (0, 4)           0.760692           0.580084
# 18                  (4, 8)           0.794701           0.587680
# 19                 (8, 12)           0.633336           0.391933
# 20                  (0, 4)           0.976847           0.803063
# 21                  (0, 4)           0.673498           0.947095
# 22                  (0, 4)           0.540517           0.298657
# 23                  (4, 8)           0.953556           0.996428
# 24                 (8, 12)           0.694856           0.908884
# 25                  (0, 4)           0.661787           0.726118
# 26                  (0, 4)           0.692098           0.729976
# 27                  (4, 8)           0.800785           0.936182
# 28                 (8, 12)           0.260513           0.231355
# 29                  (0, 4)           0.574639           0.844613
# 30                  (0, 4)           0.620073           0.870615
# 31                  (4, 8)           0.816499           0.783948
# 32                 (8, 12)           0.345052           0.119568
# 33                  (0, 4)           0.935216           1.000000
# 34                  (0, 4)           0.097549           0.161462
# 35                  (4, 8)           0.656789           0.578166
# 36                 (8, 12)           0.487232           0.591208
# 37                  (0, 4)           0.772471           0.804741
# 38                  (0, 4)           0.699679           0.502016
# 39                  (4, 8)           0.955224           0.856899
# 40                 (8, 12)           0.931933           0.995163
# 41                  (0, 4)           0.569498           0.616923
# 42                  (0, 4)           0.746935           0.744352
# 43                  (0, 4)           0.422055           0.608629
#
#     TTest Paired  No of Patients Type
# 0       0.651946             323  abs
# 1       0.327799             129  abs
# 2       0.966841             149  abs
# 3       0.864936             104  abs
# 4       0.046956             321  abs
# 5       0.187444             128  abs
# 6       0.328822             147  abs
# 7       0.299478             104  abs
# 8       0.253191             318  abs
# 9       0.105499             128  abs
# 10      0.667587             147  abs
# 11      0.703983             103  abs
# 12      0.602662             323  abs
# 13      0.945760             128  abs
# 14      0.718772             148  abs
# 15      0.183841             105  abs
# 16      0.967976             323  abs
# 17      0.437686             129  abs
# 18      0.439249             149  abs
# 19      0.244978             104  abs
# 20      0.628175             144  abs
# 21      0.905911             355  abs
# 22      0.123215             139  abs
# 23      0.994168             146  abs
# 24      0.855294             121  abs
# 25      0.285190             352  abs
# 26      0.527641             138  abs
# 27      0.870255             146  abs
# 28      0.048497             121  abs
# 29      0.627006             345  abs
# 30      0.811575             138  abs
# 31      0.633157             143  abs
# 32      0.042005             117  abs
# 33      1.000000             352  abs
# 34      0.124591             139  abs
# 35      0.529207             146  abs
# 36      0.554790             120  abs
# 37      0.675304             355  abs
# 38      0.354040             139  abs
# 39      0.771544             146  abs
# 40      0.992534             121  abs
# 41      0.179391             145  abs
# 42      0.628344             100  abs
# 43      0.466026             100  abs

# %%
pvals_ratio_sampled
# Out:
#                      Lab Name     Med Name Before Window (in Hours)  \
# 0    Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 1    Diastolic blood pressure  Dextrose 5%                  (6, 12)
# 2    Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 3    Diastolic blood pressure  Dextrose 5%                  (6, 12)
# 4    Diastolic blood pressure  Dextrose 5%                   (0, 6)
# ..                        ...          ...                      ...
# 123           Temperature (F)     Solution                   (0, 6)
# 124           Temperature (F)     Solution                  (6, 12)
# 125           Temperature (F)     Solution                   (0, 6)
# 126           Temperature (F)     Solution                  (6, 12)
# 127           Temperature (F)     Solution                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 0                    (0, 4)              299         0.098280
# 1                    (0, 4)              117         0.035804
# 2                    (4, 8)              142         0.175400
# 3                    (4, 8)               49         0.185905
# 4                   (8, 12)               98         0.570025
# ..                      ...              ...              ...
# 123                  (0, 4)               53         0.021065
# 124                  (0, 4)               32         0.813956
# 125                  (4, 8)               30         0.629980
# 126                  (4, 8)               15         0.913140
# 127                 (8, 12)               24         0.757504
#
# [128 rows x 6 columns]

# %%
test_pval_data, significant_hard_thres, significant_bonferroni, significant_fdr = analyzer.generate_significant(pvals_med_lab)
merged_sig_pairs = pd.merge(pd.merge(significant_fdr, significant_bonferroni, how="inner"), significant_hard_thres, how="inner")

# %%
merged_sig_pairs
# Out:
# Empty DataFrame
# Columns: [Lab Name, Med Name, Before Window (in Hours), After Window (in Hours), Mannwhitneyu Test, TTest Independent, TTest Paired, No of Patients, Type, BonferroniPvals, FDR Benjamini Corrected]
# Index: []

# %%
test_pval_data_ratio, significant_hard_thres_ratio, significant_bonferroni_ratio, significant_fdr_ratio = analyzer.generate_significant(pvals_ratio_sampled[pvals_ratio_sampled["No. of Patients"]>100].dropna(), statistical_test="1-Sampled Ttest")
merged_sig_pairs_ratio = pd.merge(pd.merge(significant_fdr_ratio, significant_bonferroni_ratio, how="inner"), significant_hard_thres_ratio, how="inner")

# %%
merged_sig_pairs_ratio
# Out:
#            Lab Name   Med Name Before Window (in Hours)  \
# 0  Respiratory rate  NaCl 0.9%                  (6, 12)
#
#   After Window (in Hours)  No. of Patients  1-Sampled Ttest  BonferroniPvals  \
# 0                  (0, 4)              110         0.000084         0.002676
#
#    FDR Benjamini Corrected
# 0                 0.002676

# %% [markdown]
# ## HIRID

# %%
from src.parsers import hirid

# %%
hirid_mapping = constants.HIRID_MAPPING
hirid_parser = hirid.HiRiDParser(data=raw_path, res=res_path, gender=gender, age_b=age_b, age_a=age_a, load="AUTOMATIC_MAPPING_HIRID")
h_meds, h_labs = hirid_parser.parse(lab_parts=(0,5), n_med_limit=1000)
lab_ids = [l for k in hirid_mapping.values() for l in k]
h_labs_1 = h_labs[h_labs.OldITEMID.isin(lab_ids)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 hirid_mapping = constants.HIRID_MAPPING
#       2 hirid_parser = hirid.HiRiDParser(data=raw_path, res=res_path, gender=gender, age_b=age_b, age_a=age_a, load="AUTOMATIC_MAPPING_HIRID")
# ----> 3 h_meds, h_labs = hirid_parser.parse(lab_parts=(0,5), n_med_limit=1000)
#       4 lab_ids = [l for k in hirid_mapping.values() for l in k]
#       5 h_labs_1 = h_labs[h_labs.OldITEMID.isin(lab_ids)]
#
# File ~/Desktop/TAU/DrugLab/src/parsers/hirid.py:164, in HiRiDParser.parse(self, use_pairs, lab_parts, n_med_limit)
#     162     hadms.append(hadm)
#     163     i+=1
# --> 164     med, hadm = self.load_medk(i)
#     166 labs = self.load_lab(hadms, n_parts=lab_parts)
#     167 t_labs = labs.copy()
#
# File ~/Desktop/TAU/DrugLab/src/parsers/hirid.py:46, in HiRiDParser.load_medk(self, k)
#      41 def load_medk(self, k):
#      42     """
#      43     Load kth Medication data
#      44     """
# ---> 46     med1 = self.pharma_records_with_name.sort_values(["HADM_ID", "STARTTIME"]).groupby(["HADM_ID", "ITEMID"]).nth(k-1).reset_index()
#      48     # stratification
#      49     h_adm_1 = med1["HADM_ID"].to_list()
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/groupby/indexing.py:300, in GroupByNthSelector.__call__(self, n, dropna)
#     295 def __call__(
#     296     self,
#     297     n: PositionalIndexer | tuple,
#     298     dropna: Literal["any", "all", None] = None,
#     299 ) -> DataFrame | Series:
# --> 300     return self.groupby_object._nth(n, dropna)
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:3165, in GroupBy._nth(self, n, dropna)
#    3162 # Drop NA values in grouping
#    3163 mask = mask & (ids != -1)
# -> 3165 out = self._mask_selected_obj(mask)
#    3166 if not self.as_index:
#    3167     return out
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:4112, in GroupBy._mask_selected_obj(self, mask)
#    4109 mask = mask & (ids != -1)
#    4111 if self.axis == 0:
# -> 4112     return self._selected_obj[mask]
#    4113 else:
#    4114     return self._selected_obj.iloc[:, mask]
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:752, in BaseGroupBy._selected_obj(self)
#     750 if self._selection is None or isinstance(self.obj, Series):
#     751     if self._group_selection is not None:
# --> 752         return self.obj[self._group_selection]
#     753     return self.obj
#     754 else:
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/frame.py:3819, in DataFrame.__getitem__(self, key)
#    3816 if getattr(indexer, "dtype", None) == bool:
#    3817     indexer = np.where(indexer)[0]
# -> 3819 data = self._take_with_is_copy(indexer, axis=1)
#    3821 if is_single_key:
#    3822     # What does looking for a single key in a non-unique index return?
#    3823     # The behavior is inconsistent. It returns a Series, except when
#    3824     # - the key itself is repeated (test on data.shape, #9519), or
#    3825     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    3826     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
#    3827         # GH#26490 using data[key] can cause RecursionError
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/generic.py:3902, in NDFrame._take_with_is_copy(self, indices, axis)
#    3894 def _take_with_is_copy(self: NDFrameT, indices, axis=0) -> NDFrameT:
#    3895     """
#    3896     Internal version of the `take` method that sets the `_is_copy`
#    3897     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3900     See the docstring of `take` for full explanation of the parameters.
#    3901     """
# -> 3902     result = self._take(indices=indices, axis=axis)
#    3903     # Maybe set copy if we didn't actually change the index.
#    3904     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/generic.py:3886, in NDFrame._take(self, indices, axis, convert_indices)
#    3879 """
#    3880 Internal version of the `take` allowing specification of additional args.
#    3881
#    3882 See the docstring of `take` for full explanation of the parameters.
#    3883 """
#    3884 self._consolidate_inplace()
# -> 3886 new_data = self._mgr.take(
#    3887     indices,
#    3888     axis=self._get_block_manager_axis(axis),
#    3889     verify=True,
#    3890     convert_indices=convert_indices,
#    3891 )
#    3892 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py:978, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     975     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     977 new_labels = self.axes[axis].take(indexer)
# --> 978 return self.reindex_indexer(
#     979     new_axis=new_labels,
#     980     indexer=indexer,
#     981     axis=axis,
#     982     allow_dups=True,
#     983     copy=None,
#     984 )
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py:743, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     740     raise IndexError("Requested axis not found in manager")
#     742 if axis == 0:
# --> 743     new_blocks, new_refs = self._slice_take_blocks_ax0(
#     744         indexer,
#     745         fill_value=fill_value,
#     746         only_slice=only_slice,
#     747         use_na_proxy=use_na_proxy,
#     748     )
#     749     parent = None if com.all_none(*new_refs) else self
#     750 else:
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py:912, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     910         refs.append(weakref.ref(blk))
#     911 else:
# --> 912     nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     913     blocks.append(nb)
#     914     refs.append(None)
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/internals/blocks.py:880, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     877     allow_fill = True
#     879 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 880 new_values = algos.take_nd(
#     881     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     882 )
#     884 # Called from three places in managers, all of which satisfy
#     885 #  this assertion
#     886 assert not (axis == 0 and new_mgr_locs is None)
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/Desktop/TAU/DrugLab/venv/lib/python3.9/site-packages/pandas/core/array_algos/take.py:163, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
# --> 163 func(arr, indexer, out, fill_value)
#     165 if flip_order:
#     166     out = out.T
#
# KeyboardInterrupt:

# %%
h_meds

# %%
hirid_data_querier = querier.DatasetQuerier(
    data = raw_path,
    res = res_path,
    t_labs=h_labs, 
    meds=h_meds[len(h_meds)-20 : len(h_meds)-15],
    gender=gender, 
    age_b=age_b, 
    age_a=age_a, 
    ethnicity=ethnicity, 
)

# %%
# query pairs for all medication and lab tests
final_pairs_data_h, interim_pairs_data_h = hirid_data_querier.generate_med_lab_data(before_windows, after_windows, lab_parts=(0,1000))
# Out:
# 100%|██████████| 5/5 [03:54<00:00, 46.81s/it]

# %%
[k.shape for k in final_pairs_data]
# Out:
# [(3285, 96), (2535, 96), (2485, 96), (2457, 96), (3051, 96)]

# %%
h_meds[len(h_meds)-20].shape, h_meds[0].shape
# Out:
# ((524, 69), (138658, 68))

# %%
concat_final_pairs_data = pd.concat(final_pairs_data)

# %%
from src.modeling import discovery
## Discovery Analysis for the queried medication and lab test pairs in the chosen before and after windows
analyzer = discovery.ClinicalDiscoveryAnalysis(concat_final_pairs_data)
pvals_med_lab = analyzer.analyze(before_windows, after_windows)
pvals_ratio_sampled = analyzer.analyze_ratio(before_windows, after_windows)

# %%
pvals_med_lab
# Out:
#                     Lab Name     Med Name Before Window (in Hours)  \
# 0   Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 1   Diastolic blood pressure  Dextrose 5%                  (6, 12)
# 2   Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 3   Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 4                 Heart Rate  Dextrose 5%                   (0, 6)
# 5                 Heart Rate  Dextrose 5%                  (6, 12)
# 6                 Heart Rate  Dextrose 5%                   (0, 6)
# 7                 Heart Rate  Dextrose 5%                   (0, 6)
# 8             Pulse oximetry  Dextrose 5%                   (0, 6)
# 9             Pulse oximetry  Dextrose 5%                  (6, 12)
# 10            Pulse oximetry  Dextrose 5%                   (0, 6)
# 11            Pulse oximetry  Dextrose 5%                   (0, 6)
# 12          Respiratory rate  Dextrose 5%                   (0, 6)
# 13          Respiratory rate  Dextrose 5%                  (6, 12)
# 14          Respiratory rate  Dextrose 5%                   (0, 6)
# 15          Respiratory rate  Dextrose 5%                   (0, 6)
# 16   Systolic blood pressure  Dextrose 5%                   (0, 6)
# 17   Systolic blood pressure  Dextrose 5%                  (6, 12)
# 18   Systolic blood pressure  Dextrose 5%                   (0, 6)
# 19   Systolic blood pressure  Dextrose 5%                   (0, 6)
# 20           Temperature (F)  Dextrose 5%                   (0, 6)
# 21  Diastolic blood pressure    NaCl 0.9%                   (0, 6)
# 22  Diastolic blood pressure    NaCl 0.9%                  (6, 12)
# 23  Diastolic blood pressure    NaCl 0.9%                   (0, 6)
# 24  Diastolic blood pressure    NaCl 0.9%                   (0, 6)
# 25                Heart Rate    NaCl 0.9%                   (0, 6)
# 26                Heart Rate    NaCl 0.9%                  (6, 12)
# 27                Heart Rate    NaCl 0.9%                   (0, 6)
# 28                Heart Rate    NaCl 0.9%                   (0, 6)
# 29            Pulse oximetry    NaCl 0.9%                   (0, 6)
# 30            Pulse oximetry    NaCl 0.9%                  (6, 12)
# 31            Pulse oximetry    NaCl 0.9%                   (0, 6)
# 32            Pulse oximetry    NaCl 0.9%                   (0, 6)
# 33          Respiratory rate    NaCl 0.9%                   (0, 6)
# 34          Respiratory rate    NaCl 0.9%                  (6, 12)
# 35          Respiratory rate    NaCl 0.9%                   (0, 6)
# 36          Respiratory rate    NaCl 0.9%                   (0, 6)
# 37   Systolic blood pressure    NaCl 0.9%                   (0, 6)
# 38   Systolic blood pressure    NaCl 0.9%                  (6, 12)
# 39   Systolic blood pressure    NaCl 0.9%                   (0, 6)
# 40   Systolic blood pressure    NaCl 0.9%                   (0, 6)
# 41           Temperature (F)    NaCl 0.9%                   (0, 6)
# 42  Diastolic blood pressure     Solution                   (0, 6)
# 43   Systolic blood pressure     Solution                   (0, 6)
#
#    After Window (in Hours)  Mannwhitneyu Test  TTest Independent  \
# 0                   (0, 4)           0.869181           0.814442
# 1                   (0, 4)           0.772127           0.559803
# 2                   (4, 8)           0.943172           0.978470
# 3                  (8, 12)           0.995403           0.909159
# 4                   (0, 4)           0.482301           0.423557
# 5                   (0, 4)           0.476579           0.411156
# 6                   (4, 8)           0.520203           0.611674
# 7                  (8, 12)           0.640685           0.511485
# 8                   (0, 4)           0.330995           0.520080
# 9                   (0, 4)           0.289240           0.249883
# 10                  (4, 8)           0.580546           0.712092
# 11                 (8, 12)           0.239738           0.753175
# 12                  (0, 4)           0.792722           0.646032
# 13                  (0, 4)           0.792647           0.958265
# 14                  (4, 8)           0.825656           0.758775
# 15                 (8, 12)           0.180827           0.225393
# 16                  (0, 4)           0.986038           0.982350
# 17                  (0, 4)           0.760692           0.580084
# 18                  (4, 8)           0.794701           0.587680
# 19                 (8, 12)           0.633336           0.391933
# 20                  (0, 4)           0.976847           0.803063
# 21                  (0, 4)           0.673498           0.947095
# 22                  (0, 4)           0.540517           0.298657
# 23                  (4, 8)           0.953556           0.996428
# 24                 (8, 12)           0.694856           0.908884
# 25                  (0, 4)           0.661787           0.726118
# 26                  (0, 4)           0.692098           0.729976
# 27                  (4, 8)           0.800785           0.936182
# 28                 (8, 12)           0.260513           0.231355
# 29                  (0, 4)           0.574639           0.844613
# 30                  (0, 4)           0.620073           0.870615
# 31                  (4, 8)           0.816499           0.783948
# 32                 (8, 12)           0.345052           0.119568
# 33                  (0, 4)           0.935216           1.000000
# 34                  (0, 4)           0.097549           0.161462
# 35                  (4, 8)           0.656789           0.578166
# 36                 (8, 12)           0.487232           0.591208
# 37                  (0, 4)           0.772471           0.804741
# 38                  (0, 4)           0.699679           0.502016
# 39                  (4, 8)           0.955224           0.856899
# 40                 (8, 12)           0.931933           0.995163
# 41                  (0, 4)           0.569498           0.616923
# 42                  (0, 4)           0.746935           0.744352
# 43                  (0, 4)           0.422055           0.608629
#
#     TTest Paired  No of Patients Type
# 0       0.651946             323  abs
# 1       0.327799             129  abs
# 2       0.966841             149  abs
# 3       0.864936             104  abs
# 4       0.046956             321  abs
# 5       0.187444             128  abs
# 6       0.328822             147  abs
# 7       0.299478             104  abs
# 8       0.253191             318  abs
# 9       0.105499             128  abs
# 10      0.667587             147  abs
# 11      0.703983             103  abs
# 12      0.602662             323  abs
# 13      0.945760             128  abs
# 14      0.718772             148  abs
# 15      0.183841             105  abs
# 16      0.967976             323  abs
# 17      0.437686             129  abs
# 18      0.439249             149  abs
# 19      0.244978             104  abs
# 20      0.628175             144  abs
# 21      0.905911             355  abs
# 22      0.123215             139  abs
# 23      0.994168             146  abs
# 24      0.855294             121  abs
# 25      0.285190             352  abs
# 26      0.527641             138  abs
# 27      0.870255             146  abs
# 28      0.048497             121  abs
# 29      0.627006             345  abs
# 30      0.811575             138  abs
# 31      0.633157             143  abs
# 32      0.042005             117  abs
# 33      1.000000             352  abs
# 34      0.124591             139  abs
# 35      0.529207             146  abs
# 36      0.554790             120  abs
# 37      0.675304             355  abs
# 38      0.354040             139  abs
# 39      0.771544             146  abs
# 40      0.992534             121  abs
# 41      0.179391             145  abs
# 42      0.628344             100  abs
# 43      0.466026             100  abs

# %%
pvals_ratio_sampled
# Out:
#                      Lab Name     Med Name Before Window (in Hours)  \
# 0    Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 1    Diastolic blood pressure  Dextrose 5%                  (6, 12)
# 2    Diastolic blood pressure  Dextrose 5%                   (0, 6)
# 3    Diastolic blood pressure  Dextrose 5%                  (6, 12)
# 4    Diastolic blood pressure  Dextrose 5%                   (0, 6)
# ..                        ...          ...                      ...
# 123           Temperature (F)     Solution                   (0, 6)
# 124           Temperature (F)     Solution                  (6, 12)
# 125           Temperature (F)     Solution                   (0, 6)
# 126           Temperature (F)     Solution                  (6, 12)
# 127           Temperature (F)     Solution                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 0                    (0, 4)              299         0.098280
# 1                    (0, 4)              117         0.035804
# 2                    (4, 8)              142         0.175400
# 3                    (4, 8)               49         0.185905
# 4                   (8, 12)               98         0.570025
# ..                      ...              ...              ...
# 123                  (0, 4)               53         0.021065
# 124                  (0, 4)               32         0.813956
# 125                  (4, 8)               30         0.629980
# 126                  (4, 8)               15         0.913140
# 127                 (8, 12)               24         0.757504
#
# [128 rows x 6 columns]

# %%
test_pval_data, significant_hard_thres, significant_bonferroni, significant_fdr = analyzer.generate_significant(pvals_med_lab)
merged_sig_pairs = pd.merge(pd.merge(significant_fdr, significant_bonferroni, how="inner"), significant_hard_thres, how="inner")

# %%
merged_sig_pairs
# Out:
# Empty DataFrame
# Columns: [Lab Name, Med Name, Before Window (in Hours), After Window (in Hours), Mannwhitneyu Test, TTest Independent, TTest Paired, No of Patients, Type, BonferroniPvals, FDR Benjamini Corrected]
# Index: []

# %%
test_pval_data_ratio, significant_hard_thres_ratio, significant_bonferroni_ratio, significant_fdr_ratio = analyzer.generate_significant(pvals_ratio_sampled[pvals_ratio_sampled["No. of Patients"]>100].dropna(), statistical_test="1-Sampled Ttest")
merged_sig_pairs_ratio = pd.merge(pd.merge(significant_fdr_ratio, significant_bonferroni_ratio, how="inner"), significant_hard_thres_ratio, how="inner")

# %%
merged_sig_pairs_ratio
# Out:
#            Lab Name   Med Name Before Window (in Hours)  \
# 0  Respiratory rate  NaCl 0.9%                  (6, 12)
#
#   After Window (in Hours)  No. of Patients  1-Sampled Ttest  BonferroniPvals  \
# 0                  (0, 4)              110         0.000084         0.002676
#
#    FDR Benjamini Corrected
# 0                 0.002676
