# %%
data = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/data"
res = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/results"

# %%
import pandas as pd
import os

# %% [markdown]
# ## Medication Patient Data

# %% [markdown]
# ## Filter Meds

# %% [markdown]
# ### Med 1

# %%
# Female, 60-70, WHITE

# %%
gender = "F"
age_b = 60
age_a = 70
ethnicity = "WHITE"
stratify_prefix = f"{age_b}-{age_a}_{gender}_{ethnicity}"

# %%
med1 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med1_vectorized.csv"))

# %%
med1 = med1.drop(columns=["Unnamed: 0"])

# %%
import matplotlib.pyplot as plt
t = med1[med1["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
med1.shape
# Out:
# (323007, 64)

# %%
med1 = med1[med1["AGE"]>=age_b]
med1 = med1[med1["AGE"]<=age_a]

# %%
med1 = med1[med1["GENDER"]==gender]
med1 = med1[med1["ETHNICITY"]==ethnicity]

# %%
import matplotlib.pyplot as plt
t = med1[med1["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
med1.shape
# Out:
# (22176, 63)

# %%
med1
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 194            735  2068-03-06      F  2128-07-04 00:00:00            1
# 195            735  2068-03-06      F  2128-07-04 00:00:00            1
# 196            735  2068-03-06      F  2128-07-04 00:00:00            1
# 197            735  2068-03-06      F  2128-07-04 00:00:00            1
# 198            735  2068-03-06      F  2128-07-04 00:00:00            1
# ...            ...         ...    ...                  ...          ...
# 322871       44082  2056-04-27      F                  NaN            0
# 322872       44082  2056-04-27      F                  NaN            0
# 322873       44082  2056-04-27      F                  NaN            0
# 322874       44082  2056-04-27      F                  NaN            0
# 322875       44082  2056-04-27      F                  NaN            0
#
#         ITEMID  HADM_ID  ICUSTAY_ID            STARTTIME              ENDTIME  \
# 194     225158   140547    298103.0  2128-05-27 16:27:00  2128-05-27 16:28:00
# 195     225974   140547    298103.0  2128-05-27 16:41:00  2128-05-27 16:42:00
# 196     225828   140547    298103.0  2128-05-27 21:27:00  2128-05-27 21:28:00
# 197     226452   140547    298103.0  2128-05-29 00:17:00  2128-05-29 00:18:00
# 198     225154   140547    298103.0  2128-05-29 08:45:00  2128-05-29 08:46:00
# ...        ...      ...         ...                  ...                  ...
# 322871  225154   178322    233193.0  2122-04-08 06:55:00  2122-04-08 06:56:00
# 322872  225159   178322    233193.0  2122-04-07 22:43:00  2122-04-08 08:43:00
# 322873  223260   178322    233193.0  2122-04-08 10:00:00  2122-04-08 10:01:00
# 322874  223262   178322    233193.0  2122-04-08 12:00:00  2122-04-08 12:01:00
# 322875  225975   178322    233193.0  2122-04-09 08:30:00  2122-04-09 08:31:00
#
#         ...                         LABEL                  ABBREVIATION  \
# 194     ...                     NaCl 0.9%                     NaCl 0.9%
# 195     ...                    Metoprolol                    Metoprolol
# 196     ...                            LR                            LR
# 197     ...                     PO Intake                     PO Intake
# 198     ...              Morphine Sulfate              Morphine Sulfate
# ...     ...                           ...                           ...
# 322871  ...              Morphine Sulfate              Morphine Sulfate
# 322872  ...                    NaCl 0.45%                    NaCl 0.45%
# 322873  ...            Insulin - Glargine            Insulin - Glargine
# 322874  ...             Insulin - Humalog             Insulin - Humalog
# 322875  ...  Heparin Sodium (Prophylaxis)  Heparin Sodium (Prophylaxis)
#
#           DBSOURCE         LINKSTO       CATEGORY  UNITNAME  PARAM_TYPE  \
# 194     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 195     metavision  inputevents_mv    Medications        mg    Solution
# 196     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 197     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 198     metavision  inputevents_mv    Medications        mg    Solution
# ...            ...             ...            ...       ...         ...
# 322871  metavision  inputevents_mv    Medications        mg    Solution
# 322872  metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 322873  metavision  inputevents_mv    Medications     units    Solution
# 322874  metavision  inputevents_mv    Medications     units    Solution
# 322875  metavision  inputevents_mv    Medications      dose    Solution
#
#         CONCEPTID MedTimeFromAdmit   AGE
# 194           NaN  3 days 00:50:00  60.0
# 195           NaN  3 days 01:04:00  60.0
# 196           NaN  3 days 05:50:00  60.0
# 197           NaN  4 days 08:40:00  60.0
# 198           NaN  4 days 17:08:00  60.0
# ...           ...              ...   ...
# 322871        NaN  0 days 09:54:00  66.0
# 322872        NaN  0 days 11:41:00  66.0
# 322873        NaN  0 days 12:59:00  66.0
# 322874        NaN  0 days 14:59:00  66.0
# 322875        NaN  1 days 11:29:00  66.0
#
# [22176 rows x 63 columns]

# %% [markdown]
# ### Med 2

# %%
med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_51949/27638116.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))

# %%
med2 = med2.drop(columns=["Unnamed: 0"])

# %%
med2 = med2[med2["AGE"]>=age_b]
med2 = med2[med2["AGE"]<=age_a]

# %%
med2 = med2[med2["GENDER"]==gender]
med2 = med2[med2["ETHNICITY"]==ethnicity]

# %%
med2
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 145            735  2068-03-06      F  2128-07-04 00:00:00            1
# 146            735  2068-03-06      F  2128-07-04 00:00:00            1
# 147            735  2068-03-06      F  2128-07-04 00:00:00            1
# 148            735  2068-03-06      F  2128-07-04 00:00:00            1
# 149            735  2068-03-06      F  2128-07-04 00:00:00            1
# ...            ...         ...    ...                  ...          ...
# 237516       44082  2056-04-27      F                  NaN            0
# 237517       44082  2056-04-27      F                  NaN            0
# 237518       44082  2056-04-27      F                  NaN            0
# 237519       44082  2056-04-27      F                  NaN            0
# 237520       44082  2056-04-27      F                  NaN            0
#
#         ITEMID  HADM_ID  ICUSTAY_ID            STARTTIME              ENDTIME  \
# 145     225974   140547    298103.0  2128-05-27 17:48:00  2128-05-27 17:49:00
# 146     225158   140547    298103.0  2128-05-27 20:00:00  2128-05-27 20:01:00
# 147     225828   140547    298103.0  2128-05-27 21:28:00  2128-05-28 11:35:00
# 148     226452   140547    298103.0  2128-05-29 08:58:00  2128-05-29 08:59:00
# 149     225154   140547    298103.0  2128-05-29 10:00:00  2128-05-29 10:01:00
# ...        ...      ...         ...                  ...                  ...
# 237516  223262   178322    233193.0  2122-04-08 18:00:00  2122-04-08 18:01:00
# 237517  221824   178322    233193.0  2122-04-09 04:45:00  2122-04-09 04:46:00
# 237518  223260   178322    233193.0  2122-04-09 09:10:00  2122-04-09 09:11:00
# 237519  225975   178322    233193.0  2122-04-09 17:00:00  2122-04-09 17:01:00
# 237520  225158   178322    233193.0  2122-04-09 17:05:00  2122-04-09 17:06:00
#
#         ...                         LABEL                  ABBREVIATION  \
# 145     ...                    Metoprolol                    Metoprolol
# 146     ...                     NaCl 0.9%                     NaCl 0.9%
# 147     ...                            LR                            LR
# 148     ...                     PO Intake                     PO Intake
# 149     ...              Morphine Sulfate              Morphine Sulfate
# ...     ...                           ...                           ...
# 237516  ...             Insulin - Humalog             Insulin - Humalog
# 237517  ...          Haloperidol (Haldol)          Haloperidol (Haldol)
# 237518  ...            Insulin - Glargine            Insulin - Glargine
# 237519  ...  Heparin Sodium (Prophylaxis)  Heparin Sodium (Prophylaxis)
# 237520  ...                     NaCl 0.9%                     NaCl 0.9%
#
#           DBSOURCE         LINKSTO       CATEGORY  UNITNAME  PARAM_TYPE  \
# 145     metavision  inputevents_mv    Medications        mg    Solution
# 146     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 147     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 148     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 149     metavision  inputevents_mv    Medications        mg    Solution
# ...            ...             ...            ...       ...         ...
# 237516  metavision  inputevents_mv    Medications     units    Solution
# 237517  metavision  inputevents_mv    Medications        mg    Solution
# 237518  metavision  inputevents_mv    Medications     units    Solution
# 237519  metavision  inputevents_mv    Medications      dose    Solution
# 237520  metavision  inputevents_mv  Fluids/Intake        mL    Solution
#
#         CONCEPTID MedTimeFromAdmit   AGE
# 145           NaN  3 days 02:11:00  60.0
# 146           NaN  3 days 04:23:00  60.0
# 147           NaN  3 days 19:57:00  60.0
# 148           NaN  4 days 17:21:00  60.0
# 149           NaN  4 days 18:23:00  60.0
# ...           ...              ...   ...
# 237516        NaN  0 days 20:59:00  66.0
# 237517        NaN  1 days 07:44:00  66.0
# 237518        NaN  1 days 12:09:00  66.0
# 237519        NaN  1 days 19:59:00  66.0
# 237520        NaN  1 days 20:04:00  66.0
#
# [16374 rows x 63 columns]

# %%
import matplotlib.pyplot as plt
med2['AGE'].hist(bins=10)
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ## Filter Labs

# %%
labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))
# labs = labs.rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_40278/608754289.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))

# %%
labs = labs.drop(columns=["Unnamed: 0"])
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 0               249  2075-03-13      F  NaN            0    163327  158975.0
# 1               249  2075-03-13      F  NaN            0    163304  158975.0
# 2               249  2075-03-13      F  NaN            0    163317  158975.0
# 3               249  2075-03-13      F  NaN            0    163315  158975.0
# 4               249  2075-03-13      F  NaN            0    163316  158975.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7260280       44128  2098-07-25      M  NaN            0  20437251  141304.0
# 7260281       44128  2098-07-25      M  NaN            0  20437245  141304.0
# 7260282       44128  2098-07-25      M  NaN            0  20437250  141304.0
# 7260283       44128  2098-07-25      M  NaN            0  20437255  141304.0
# 7260284       44128  2098-07-25      M  NaN            0  20437256  141304.0
#
#          ITEMID            CHARTTIME  VALUE  ...       RELIGION  \
# 0         51274  2156-04-27 15:40:00   20.0  ...       CATHOLIC
# 1         50868  2156-04-27 15:40:00   12.0  ...       CATHOLIC
# 2         51221  2156-04-27 15:40:00   29.5  ...       CATHOLIC
# 3         51146  2156-04-27 15:40:00    0.4  ...       CATHOLIC
# 4         51200  2156-04-27 15:40:00    2.4  ...       CATHOLIC
# ...         ...                  ...    ...  ...            ...
# 7260280   51275  2149-06-14 05:00:00   26.4  ...  NOT SPECIFIED
# 7260281   51237  2149-06-14 05:00:00    1.1  ...  NOT SPECIFIED
# 7260282   51274  2149-06-14 05:00:00   12.8  ...  NOT SPECIFIED
# 7260283   51221  2149-06-15 04:45:00   27.3  ...  NOT SPECIFIED
# 7260284   51221  2149-06-16 12:22:00   28.0  ...  NOT SPECIFIED
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0             DIVORCED     WHITE                  NaN                  NaN
# 1             DIVORCED     WHITE                  NaN                  NaN
# 2             DIVORCED     WHITE                  NaN                  NaN
# 3             DIVORCED     WHITE                  NaN                  NaN
# 4             DIVORCED     WHITE                  NaN                  NaN
# ...                ...       ...                  ...                  ...
# 7260280        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260281        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260282        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260283        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260284        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
#
#                        DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 0        GI BLEEDING\COLONOSCOPY                    0                    1
# 1        GI BLEEDING\COLONOSCOPY                    0                    1
# 2        GI BLEEDING\COLONOSCOPY                    0                    1
# 3        GI BLEEDING\COLONOSCOPY                    0                    1
# 4        GI BLEEDING\COLONOSCOPY                    0                    1
# ...                          ...                  ...                  ...
# 7260280                   TRAUMA                    0                    1
# 7260281                   TRAUMA                    0                    1
# 7260282                   TRAUMA                    0                    1
# 7260283                   TRAUMA                    0                    1
# 7260284                   TRAUMA                    0                    1
#
#          LabTimeFromAdmit   AGE
# 0         0 days 00:07:00  81.0
# 1         0 days 00:07:00  81.0
# 2         0 days 00:07:00  81.0
# 3         0 days 00:07:00  81.0
# 4         0 days 00:07:00  81.0
# ...                   ...   ...
# 7260280   5 days 13:39:00  51.0
# 7260281   5 days 13:39:00  51.0
# 7260282   5 days 13:39:00  51.0
# 7260283   6 days 13:24:00  51.0
# 7260284   7 days 21:01:00  51.0
#
# [7260285 rows x 38 columns]

# %%
labs = labs[labs["AGE"]>=age_b]
labs = labs[labs["AGE"]<=age_a]

# %%
labs = labs[labs["GENDER"]==gender]
labs = labs[labs["ETHNICITY"]==ethnicity]

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 5601            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5602            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5603            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5604            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5605            735  2068-03-06      F  2128-07-04 00:00:00            1
# ...             ...         ...    ...                  ...          ...
# 7258085       44082  2056-04-27      F                  NaN            0
# 7258086       44082  2056-04-27      F                  NaN            0
# 7258087       44082  2056-04-27      F                  NaN            0
# 7258088       44082  2056-04-27      F                  NaN            0
# 7258089       44082  2056-04-27      F                  NaN            0
#
#            ROW_ID   HADM_ID  ITEMID            CHARTTIME  VALUE  ...  \
# 5601       480339  140547.0   51301  2128-05-25 05:05:00    5.8  ...
# 5602       480334  140547.0   51249  2128-05-25 05:05:00   30.9  ...
# 5603       480332  140547.0   51222  2128-05-25 05:05:00    8.4  ...
# 5604       480323  140547.0   50868  2128-05-25 05:05:00    9.0  ...
# 5605       480324  140547.0   50882  2128-05-25 05:05:00   32.0  ...
# ...           ...       ...     ...                  ...    ...  ...
# 7258085  20434787  178322.0   50971  2122-04-14 05:05:00    3.9  ...
# 7258086  20434788  178322.0   50983  2122-04-14 05:05:00  144.0  ...
# 7258087  20434789  178322.0   51006  2122-04-14 05:05:00   15.0  ...
# 7258088  20434799  178322.0   51221  2122-04-15 05:00:00   26.2  ...
# 7258089  20434800  178322.0   51222  2122-04-15 05:00:00    9.2  ...
#
#          RELIGION MARITAL_STATUS ETHNICITY            EDREGTIME  \
# 5601     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5602     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5603     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5604     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5605     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# ...           ...            ...       ...                  ...
# 7258085  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258086  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258087  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258088  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258089  CATHOLIC       DIVORCED     WHITE                  NaN
#
#                    EDOUTTIME                DIAGNOSIS HOSPITAL_EXPIRE_FLAG  \
# 5601     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5602     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5603     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5604     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5605     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# ...                      ...                      ...                  ...
# 7258085                  NaN  CORONARY ARTERY DISEASE                    0
# 7258086                  NaN  CORONARY ARTERY DISEASE                    0
# 7258087                  NaN  CORONARY ARTERY DISEASE                    0
# 7258088                  NaN  CORONARY ARTERY DISEASE                    0
# 7258089                  NaN  CORONARY ARTERY DISEASE                    0
#
#         HAS_CHARTEVENTS_DATA  LabTimeFromAdmit   AGE
# 5601                       1   0 days 13:27:00  60.0
# 5602                       1   0 days 13:27:00  60.0
# 5603                       1   0 days 13:27:00  60.0
# 5604                       1   0 days 13:27:00  60.0
# 5605                       1   0 days 13:27:00  60.0
# ...                      ...               ...   ...
# 7258085                    1   6 days 08:03:00  66.0
# 7258086                    1   6 days 08:03:00  66.0
# 7258087                    1   6 days 08:03:00  66.0
# 7258088                    1   7 days 07:58:00  66.0
# 7258089                    1   7 days 07:58:00  66.0
#
# [535964 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
t = labs[labs["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ## Pairs

# %%
counts = med1.groupby("ITEMID").count()[["HADM_ID"]].sort_values("HADM_ID", ascending=False)
counts[counts["HADM_ID"]>1000]
# Out:
#         HADM_ID
# ITEMID
# 225158     1049

# %%
labitems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_LABITEMS.csv.gz"))
meditems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_ITEMS.csv.gz"))

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 5601            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5602            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5603            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5604            735  2068-03-06      F  2128-07-04 00:00:00            1
# 5605            735  2068-03-06      F  2128-07-04 00:00:00            1
# ...             ...         ...    ...                  ...          ...
# 7258085       44082  2056-04-27      F                  NaN            0
# 7258086       44082  2056-04-27      F                  NaN            0
# 7258087       44082  2056-04-27      F                  NaN            0
# 7258088       44082  2056-04-27      F                  NaN            0
# 7258089       44082  2056-04-27      F                  NaN            0
#
#            ROW_ID   HADM_ID  ITEMID            CHARTTIME  VALUE  ...  \
# 5601       480339  140547.0   51301  2128-05-25 05:05:00    5.8  ...
# 5602       480334  140547.0   51249  2128-05-25 05:05:00   30.9  ...
# 5603       480332  140547.0   51222  2128-05-25 05:05:00    8.4  ...
# 5604       480323  140547.0   50868  2128-05-25 05:05:00    9.0  ...
# 5605       480324  140547.0   50882  2128-05-25 05:05:00   32.0  ...
# ...           ...       ...     ...                  ...    ...  ...
# 7258085  20434787  178322.0   50971  2122-04-14 05:05:00    3.9  ...
# 7258086  20434788  178322.0   50983  2122-04-14 05:05:00  144.0  ...
# 7258087  20434789  178322.0   51006  2122-04-14 05:05:00   15.0  ...
# 7258088  20434799  178322.0   51221  2122-04-15 05:00:00   26.2  ...
# 7258089  20434800  178322.0   51222  2122-04-15 05:00:00    9.2  ...
#
#          RELIGION MARITAL_STATUS ETHNICITY            EDREGTIME  \
# 5601     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5602     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5603     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5604     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# 5605     CATHOLIC        MARRIED     WHITE  2128-05-24 11:12:00
# ...           ...            ...       ...                  ...
# 7258085  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258086  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258087  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258088  CATHOLIC       DIVORCED     WHITE                  NaN
# 7258089  CATHOLIC       DIVORCED     WHITE                  NaN
#
#                    EDOUTTIME                DIAGNOSIS HOSPITAL_EXPIRE_FLAG  \
# 5601     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5602     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5603     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5604     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# 5605     2128-05-24 16:53:00           FEMUR FRACTURE                    0
# ...                      ...                      ...                  ...
# 7258085                  NaN  CORONARY ARTERY DISEASE                    0
# 7258086                  NaN  CORONARY ARTERY DISEASE                    0
# 7258087                  NaN  CORONARY ARTERY DISEASE                    0
# 7258088                  NaN  CORONARY ARTERY DISEASE                    0
# 7258089                  NaN  CORONARY ARTERY DISEASE                    0
#
#         HAS_CHARTEVENTS_DATA  LabTimeFromAdmit   AGE
# 5601                       1   0 days 13:27:00  60.0
# 5602                       1   0 days 13:27:00  60.0
# 5603                       1   0 days 13:27:00  60.0
# 5604                       1   0 days 13:27:00  60.0
# 5605                       1   0 days 13:27:00  60.0
# ...                      ...               ...   ...
# 7258085                    1   6 days 08:03:00  66.0
# 7258086                    1   6 days 08:03:00  66.0
# 7258087                    1   6 days 08:03:00  66.0
# 7258088                    1   7 days 07:58:00  66.0
# 7258089                    1   7 days 07:58:00  66.0
#
# [535964 rows x 38 columns]

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%         1049
# 1                     PO Intake          947
# 2                   Dextrose 5%          929
# 3                      Solution          736
# 4             Magnesium Sulfate          671
# 5            Potassium Chloride          659
# 6  Heparin Sodium (Prophylaxis)          617
# 7             Insulin - Regular          538
# 8     Magnesium Sulfate (Bolus)          527
# 9                    Vancomycin          514

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%         1049
# 1                     PO Intake          947
# 2                   Dextrose 5%          929
# 3                      Solution          736
# 4             Magnesium Sulfate          671
# 5            Potassium Chloride          659
# 6  Heparin Sodium (Prophylaxis)          617
# 7             Insulin - Regular          538
# 8     Magnesium Sulfate (Bolus)          527
# 9                    Vancomycin          514

# %%
med1["STARTTIME"] = pd.to_datetime(med1["STARTTIME"])
med1["ENDTIME"] = pd.to_datetime(med1["ENDTIME"])
med1["ADMITTIME"] = pd.to_datetime(med1["ADMITTIME"])
med1["MedTimeFromAdmit"] = med1["ENDTIME"]-med1["ADMITTIME"]
med2["STARTTIME"] = pd.to_datetime(med2["STARTTIME"])
med2["ENDTIME"] = pd.to_datetime(med2["ENDTIME"])
med2["ADMITTIME"] = pd.to_datetime(med2["ADMITTIME"])
med2["MedTimeFromAdmit"] = med2["ENDTIME"]-med2["ADMITTIME"]
labs["CHARTTIME"] = pd.to_datetime(labs["CHARTTIME"])
labs["ADMITTIME"] = pd.to_datetime(labs["ADMITTIME"])
labs["LabTimeFromAdmit"] = labs["CHARTTIME"]-labs["ADMITTIME"]

# %%
med1["hours_in"] = med1["MedTimeFromAdmit"].dt.total_seconds()/3600
labs["hours_in"] = labs["LabTimeFromAdmit"].dt.total_seconds()/3600

# %%
final_significant_med_lab_pairs = pd.read_csv(os.path.join(res, "significant_intersection_trends_and_med_effect_lab_med_all_new.csv"))

# %%
d = final_significant_med_lab_pairs.sort_values(by=['FDR Benjamini Corrected_y', 'FDR Benjamini Corrected_x']).head(20)[["MED_NAME", "LAB_NAME"]].to_dict()

# %%
d = {k : list(d[k].values()) for k in d}

# %%
meds = []
labtests = []

meds.append('Insulin - Regular')
labtests.append('Glucose')

meds.append('Packed Red Blood Cells')
labtests.append('Hematocrait')

meds.append('Packed Red Blood Cells')
labtests.append('Hemoglobin')

meds.append('Packed Red Blood Cells')
labtests.append('Red Blood Cells')

meds.append('Calcium')
labtests.append('Calcium Total')

meds.append('Albumin 5%')
labtests.append('Hematocrit')

meds.extend(d["MED_NAME"])
labtests.extend(d["LAB_NAME"])

med_vals = list(meds)
labtest_vals = list(labtests)

# %%
[i for i in zip(med_vals, labtest_vals)]
# Out:
# [('Insulin - Regular', 'Glucose'),
#  ('Packed Red Blood Cells', 'Hematocrait'),
#  ('Packed Red Blood Cells', 'Hemoglobin'),
#  ('Packed Red Blood Cells', 'Red Blood Cells'),
#  ('Calcium', 'Calcium Total'),
#  ('Albumin 5%', 'Hematocrit'),
#  ('Magnesium Sulfate (Bolus)', 'Magnesium'),
#  ('Magnesium Sulfate', 'Magnesium'),
#  ('Cefazolin', 'pO2'),
#  ('OR Cell Saver Intake', 'pO2'),
#  ('OR Crystalloid Intake', 'pO2'),
#  ('KCL (Bolus)', 'pO2'),
#  ('Potassium Chloride', 'pO2'),
#  ('Morphine Sulfate', 'pO2'),
#  ('Vancomycin', 'Hematocrit'),
#  ('Calcium Gluconate', 'pO2'),
#  ('OR Cell Saver Intake', 'Base Excess'),
#  ('LR', 'pO2'),
#  ('Insulin - Regular', 'pO2'),
#  ('Magnesium Sulfate', 'pO2'),
#  ('Magnesium Sulfate (Bolus)', 'pO2'),
#  ('Calcium Gluconate', 'Magnesium'),
#  ('Ranitidine (Prophylaxis)', 'pO2'),
#  ('Vancomycin', 'Red Blood Cells'),
#  ('Vancomycin', 'Hemoglobin'),
#  ('Magnesium Sulfate', 'Hematocrit')]

# %%
t_med1 = med1[med1["LABEL"].isin(med_vals)]
t_med2 = med2[med2["LABEL"].isin(med_vals)]

# %%
t_labs = labs[labs["LABEL"].isin(labtest_vals)]

# %%
t_med1.shape, t_med2.shape, t_labs.shape
# Out:
# ((6052, 64), (4203, 63), (111173, 39))

# %% [markdown]
# ## Before After Trend Calculation

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
def check_med2(row):
    if row["HADM_ID"] in t_med2["HADM_ID"].to_list():
        if row["ITEMID"] in t_med2[t_med2["HADM_ID"]==row["HADM_ID"]]["ITEMID"].to_list():
            return True
    return False

def get_med2(row):
    temp = t_med2[t_med2["HADM_ID"]==row["HADM_ID"]] 
    return temp[temp["ITEMID"]==row["ITEMID"]].iloc[0]

# %%
from sklearn import datasets, linear_model, metrics

def get_normalized_trend(data):
    selected = data[['VALUENUM', 'hours_in']]
    if selected.shape[0]<2:
        return float("NaN")
    reg = linear_model.LinearRegression()
    reg.fit(np.array(data['hours_in']).reshape(-1,1), np.array(data['VALUENUM']).reshape(-1,1))
    return reg.coef_[0][0]

# %%
def get_normalized_trend_np(data):
    selected = data[['VALUENUM', 'hours_in']]
    print(selected)
    if selected.shape[0]<2:
        return float("NaN")
    print(np.array(data['hours_in']), np.array(data['VALUENUM']))
    t = np.polyfit(np.array(data['hours_in']), np.array(data['VALUENUM']), 1,full=True)
    coefficients, residuals, _, _, _ = t
    print(t)
    mse = residuals[0]/(len(selected.index))
    nrmse = np.sqrt(mse)/(selected.max() - selected.min())
    return 1

# %%
window = (1,25,4)

# %%
def get_vals(r):

    row = r.copy()
    for i in range(window[0], window[1], window[2]):

        if i==1:
            lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

            b_window_start = row["MedTimeFromAdmit"].total_seconds()
            b_window_end = row["MedTimeFromAdmit"].total_seconds() - 1*3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
            lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"before_abs_0_0"] = {}
                row[f"before_time_0_0"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"before_abs_0_0"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"before_time_0_0"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

            lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
            med2_bool = check_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
            a_window_start = row["MedTimeFromAdmit"].total_seconds()
            a_window_end = row["MedTimeFromAdmit"].total_seconds() + 3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
            lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            if med2_bool:
                med2_val = get_med2(row)
                lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
            
            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"after_abs_0_0"] = {}
                row[f"after_time_0_0"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"after_abs_0_0"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"after_time_0_0"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
    
        lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

        b_window_start = row["MedTimeFromAdmit"].total_seconds() - (i*3600)
        b_window_end = row["MedTimeFromAdmit"].total_seconds() - (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
        lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"before_abs_{i}_{window[2]}"] = {}
            row[f"before_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"before_abs_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"before_time_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

        lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
        med2_bool = check_med2(row)
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
        a_window_start = row["MedTimeFromAdmit"].total_seconds() + (i*3600)
        a_window_end = row["MedTimeFromAdmit"].total_seconds() + (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
        lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        if med2_bool:
            med2_val = get_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
        
        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"after_abs_{i}_{window[2]}"] = {}
            row[f"after_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"after_abs_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"after_time_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
        
    return row

# %%
# type = "abs"
all_types = set(["abs", "time"])
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types]
cols_a = [f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types]
cols_b.extend([f"before_{t}_0_0" for t in all_types])
cols_a.extend([f"after_{t}_0_0" for t in all_types])
cols = cols_b.copy()
cols.extend(cols_a)

# %%
temp = t_med1.copy()
temp = temp.apply(lambda r : get_vals(r), axis=1)

# %%
temp
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 196            735  2068-03-06      F  2128-07-04 00:00:00            1
# 198            735  2068-03-06      F  2128-07-04 00:00:00            1
# 366            111  2075-07-16      F  2144-07-01 00:00:00            1
# 558            222  2073-07-25      F  2143-03-01 00:00:00            1
# 622            384  2093-01-06      F  2163-11-25 00:00:00            1
# ...            ...         ...    ...                  ...          ...
# 322168       43942  2082-01-03      F                  NaN            0
# 322169       43942  2082-01-03      F                  NaN            0
# 322864       44082  2056-04-27      F                  NaN            0
# 322865       44082  2056-04-27      F                  NaN            0
# 322871       44082  2056-04-27      F                  NaN            0
#
#         ITEMID  HADM_ID  ICUSTAY_ID           STARTTIME             ENDTIME  \
# 196     225828   140547    298103.0 2128-05-27 21:27:00 2128-05-27 21:28:00
# 198     225154   140547    298103.0 2128-05-29 08:45:00 2128-05-29 08:46:00
# 366     221456   155897    249202.0 2144-07-01 13:58:00 2144-07-01 14:58:00
# 558     225168   188038    260665.0 2142-06-26 14:00:00 2142-06-26 17:00:00
# 622     223258   122988    279422.0 2163-03-09 23:45:00 2163-03-09 23:46:00
# ...        ...      ...         ...                 ...                 ...
# 322168  225154   163179    211041.0 2148-12-27 09:25:00 2148-12-27 09:26:00
# 322169  225168   163179    211041.0 2148-12-27 11:12:00 2148-12-27 14:00:00
# 322864  222011   178322    233193.0 2122-04-08 00:23:00 2122-04-08 01:21:00
# 322865  227523   178322    233193.0 2122-04-08 00:23:00 2122-04-08 01:21:00
# 322871  225154   178322    233193.0 2122-04-08 06:55:00 2122-04-08 06:56:00
#
#         ...                                     after_abs_13_4  \
# 196     ...                                                 {}
# 198     ...                                                 {}
# 366     ...                                                 {}
# 558     ...                                                 {}
# 622     ...                                                 {}
# ...     ...                                                ...
# 322168  ...                                                 {}
# 322169  ...  {50868: 10.0, 50882: 27.0, 50893: 7.5, 50902: ...
# 322864  ...                                                 {}
# 322865  ...                                                 {}
# 322871  ...                                                 {}
#
#                                           after_time_13_4  \
# 196                                                    {}
# 198                                                    {}
# 366                                                    {}
# 558                                                    {}
# 622                                                    {}
# ...                                                   ...
# 322168                                                 {}
# 322169  {50868: 14.1, 50882: 14.1, 50893: 14.1, 50902:...
# 322864                                                 {}
# 322865                                                 {}
# 322871                                                 {}
#
#                                before_abs_17_4  \
# 196                                         {}
# 198                                         {}
# 366                                         {}
# 558                                         {}
# 622                                         {}
# ...                                        ...
# 322168                                      {}
# 322169  {51221: 21.8, 51222: 7.3, 51279: 2.55}
# 322864                                      {}
# 322865                                      {}
# 322871                                      {}
#
#                                          before_time_17_4 after_abs_17_4  \
# 196                                                    {}             {}
# 198                                                    {}             {}
# 366                                                    {}             {}
# 558                                                    {}             {}
# 622                                                    {}             {}
# ...                                                   ...            ...
# 322168                                                 {}             {}
# 322169  {51221: 15.083333333333334, 51222: 15.08333333...  {51221: 22.8}
# 322864                                                 {}             {}
# 322865                                                 {}             {}
# 322871                                                 {}             {}
#
#         after_time_17_4                                    before_abs_21_4  \
# 196                  {}                                                 {}
# 198                  {}                                                 {}
# 366                  {}                                                 {}
# 558                  {}                                      {51221: 27.6}
# 622                  {}                                                 {}
# ...                 ...                                                ...
# 322168               {}  {50931: 142.0, 50960: 2.2, 51221: 25.1, 51222:...
# 322169   {51221: 18.65}                                                 {}
# 322864               {}                                                 {}
# 322865               {}                                                 {}
# 322871               {}                                                 {}
#
#                                          before_time_21_4 after_abs_21_4  \
# 196                                                    {}             {}
# 198                                                    {}             {}
# 366                                                    {}             {}
# 558                                        {51221: 20.95}             {}
# 622                                                    {}             {}
# ...                                                   ...            ...
# 322168  {50931: 22.2, 50960: 22.2, 51221: 22.2, 51222:...             {}
# 322169                                                 {}             {}
# 322864                                                 {}             {}
# 322865                                                 {}             {}
# 322871                                                 {}             {}
#
#        after_time_21_4
# 196                 {}
# 198                 {}
# 366                 {}
# 558                 {}
# 622                 {}
# ...                ...
# 322168              {}
# 322169              {}
# 322864              {}
# 322865              {}
# 322871              {}
#
# [6052 rows x 92 columns]

# %%
temp.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_first_val_{stratify_prefix}.csv"))

# %%
# import ast
# for c in cols:
#     temp[c] = temp[c].apply(lambda x : ast.literal_eval(x))

# %%
# [c for c in cols for i in temp[c].to_list() if len(i)>0]

# %%
col_vals = []
for col in cols:
    col_vals.append(
        temp.assign(dict=temp[col].map(lambda d: d.items())).explode("dict", ignore_index=True).assign(
            LAB_ITEMID=lambda df: df.dict.str.get(0),
            temp=lambda df: df.dict.str.get(1)
        ).drop(columns=["dict"]+cols).astype({'temp':'float64', 'LAB_ITEMID':'float64'}).rename(columns={"temp":f"{col}_sp"}).dropna(subset=["LAB_ITEMID"])
    )

# %%
for i in range(1, len(col_vals)):
    col_vals[i] = pd.merge(col_vals[i-1], col_vals[i], how="outer", on=list(t_med1.columns)+["LAB_ITEMID"])

# %%
final = col_vals[-1][list(t_med1.columns)+["LAB_ITEMID"]+[f"{col}_sp" for col in cols]]

# %%
t_final = pd.merge(final.rename(columns={"LABEL":"MED_NAME"}), labitems.rename(columns={"ITEMID":"LAB_ITEMID"}), on="LAB_ITEMID", how="inner").rename(columns={"LABEL":"LAB_NAME"})
final = t_final

# %%
final.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_trends_first_val_{stratify_prefix}.csv"))

# %%
final = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_trends_first_val_{stratify_prefix}.csv"))

# %%
t_final = final.copy()
plot_data = {}
for b in [f"{c}_sp" for c in cols_b]:
    if b in t_final.columns:
        plot_data[b] = []
        for a in [f"{c}_sp" for c in cols_a]:
            if a in t_final.columns:
                plot_data[b].append(t_final.dropna(subset=[a,b]))
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data_concat = {}
for i in plot_data:
    plot_data_concat[i] = pd.concat(plot_data[i])

# %%
[(k, plot_data_concat[k].shape) for k in plot_data_concat]
# Out:
# [('before_abs_1_4_sp', (41908, 99)),
#  ('before_time_1_4_sp', (41908, 99)),
#  ('before_abs_5_4_sp', (32990, 99)),
#  ('before_time_5_4_sp', (32990, 99)),
#  ('before_abs_9_4_sp', (21058, 99)),
#  ('before_time_9_4_sp', (21058, 99)),
#  ('before_abs_13_4_sp', (15072, 99)),
#  ('before_time_13_4_sp', (15072, 99)),
#  ('before_abs_17_4_sp', (12834, 99)),
#  ('before_time_17_4_sp', (12834, 99)),
#  ('before_abs_21_4_sp', (9334, 99)),
#  ('before_time_21_4_sp', (9334, 99)),
#  ('before_abs_0_0_sp', (12962, 99)),
#  ('before_time_0_0_sp', (12962, 99))]

# %%
# type = "abs"
a_t = ["abs", "time"]
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b_sp = [(f"before_{a_t[0]}_{i}_{window[2]}_sp", f"before_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2]) ]
cols_a_sp = [(f"after_{a_t[0]}_{i}_{window[2]}_sp", f"after_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2])]
cols_b_sp.append((f"before_abs_0_0_sp", f"before_time_0_0_sp"))
cols_a_sp.append((f"after_abs_0_0_sp", f"after_time_0_0_sp"))
cols_sp = cols_b_sp.copy()
cols_sp.extend(cols_a_sp)

# %%
t_final = final.copy()
plot_data = {}
for b in cols_b_sp:
    if b[0] in t_final.columns:
        plot_data[b[0]] = {}
        for a in cols_a_sp: 
            if a[0] in t_final.columns:
                # print(a, b)
                plot_data[b[0]][a[0]] = t_final.dropna(subset=[a[0], a[1], b[0], b[1]])
                # print(plot_data[b][a][[a, b]])
                # print(plot_data.keys())
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data.keys()
# Out:
# dict_keys(['before_abs_1_4_sp', 'before_abs_5_4_sp', 'before_abs_9_4_sp', 'before_abs_13_4_sp', 'before_abs_17_4_sp', 'before_abs_21_4_sp', 'before_abs_0_0_sp'])

# %%
import pickle
pickle.dump(plot_data, open(f"plot_bw_aw_med_lab_data_{stratify_prefix}.pkl", "wb"))

# %%
cols_sp
# Out:
# [('before_abs_1_4_sp', 'before_time_1_4_sp'),
#  ('before_abs_5_4_sp', 'before_time_5_4_sp'),
#  ('before_abs_9_4_sp', 'before_time_9_4_sp'),
#  ('before_abs_13_4_sp', 'before_time_13_4_sp'),
#  ('before_abs_17_4_sp', 'before_time_17_4_sp'),
#  ('before_abs_21_4_sp', 'before_time_21_4_sp'),
#  ('before_abs_0_0_sp', 'before_time_0_0_sp'),
#  ('after_abs_1_4_sp', 'after_time_1_4_sp'),
#  ('after_abs_5_4_sp', 'after_time_5_4_sp'),
#  ('after_abs_9_4_sp', 'after_time_9_4_sp'),
#  ('after_abs_13_4_sp', 'after_time_13_4_sp'),
#  ('after_abs_17_4_sp', 'after_time_17_4_sp'),
#  ('after_abs_21_4_sp', 'after_time_21_4_sp'),
#  ('after_abs_0_0_sp', 'after_time_0_0_sp')]

# %%
cols_d = dict(cols_sp)

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
# corr, _ = spearmanr(values, time_diff)
p_data = {}
for k in plot_data:
    print("Before Window: ", k)
    for i, (k_a, data) in enumerate(plot_data[k].items()):
        print("After Window: ", k_a)

        t_data = data.set_index([data["MED_NAME"], data["LAB_NAME"]])        
        med_lab_pairs = t_data.index
        
        for med_lab_pair in med_lab_pairs.unique():
            
            if med_lab_pair not in p_data.keys():
                p_data[med_lab_pair] = {}
            if k not in p_data[med_lab_pair].keys():
                p_data[med_lab_pair][k] = []
            
            t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
            t_d['abs'] = t_d[k_a]-t_d[k]
            t_d['percent'] = (t_d['abs']/t_d[k])*100
            t_d['ratio'] = t_d[k_a]/t_d[k]
            t_d.replace([np.inf, -np.inf], np.nan, inplace=True)
            t_d = t_d.dropna()
            
            p_data[med_lab_pair][k].append(t_d)

        # print(med_name_stats)
        # print(data[data["MED_NAME"]==list(med_name_stats.keys())[0]]["SUBJECT_ID"].value_counts().to_dict())
        # print(data[data["MED_NAME"]==list(med_name_stats.keys())[0]]["HADM_ID"].value_counts().to_dict())
        # t_lau = data[data["MED_NAME"]==list(med_name_stats.keys())[0]]
# Out:
# Before Window:  before_abs_1_4_sp
# After Window:  after_abs_1_4_sp
# After Window:  after_abs_5_4_sp
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
# ...
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]

# %%
p_data.keys()
# Out:
# dict_keys([('Magnesium Sulfate', 'Base Excess'), ('Magnesium Sulfate (Bolus)', 'Base Excess'), ('LR', 'Base Excess'), ('Vancomycin', 'Base Excess'), ('Ranitidine (Prophylaxis)', 'Base Excess'), ('OR Crystalloid Intake', 'Base Excess'), ('Insulin - Regular', 'Base Excess'), ('Calcium Gluconate', 'Base Excess'), ('Packed Red Blood Cells', 'Base Excess'), ('OR Cell Saver Intake', 'Base Excess'), ('Cefazolin', 'Base Excess'), ('Albumin 5%', 'Base Excess'), ('Potassium Chloride', 'Base Excess'), ('KCL (Bolus)', 'Base Excess'), ('Morphine Sulfate', 'Base Excess'), ('LR', 'Hemoglobin'), ('Magnesium Sulfate', 'Hemoglobin'), ('OR Crystalloid Intake', 'Hemoglobin'), ('OR Cell Saver Intake', 'Hemoglobin'), ('Insulin - Regular', 'Hemoglobin'), ('KCL (Bolus)', 'Hemoglobin'), ('Potassium Chloride', 'Hemoglobin'), ('Ranitidine (Prophylaxis)', 'Hemoglobin'), ('Albumin 5%', 'Hemoglobin'), ('Magnesium Sulfate (Bolus)', 'Hemoglobin'), ('Calcium Gluconate', 'Hemoglobin'), ('Vancomycin', 'Hemoglobin'), ('Magnesium Sulfate', 'pO2'), ('Magnesium Sulfate (Bolus)', 'pO2'), ('LR', 'pO2'), ('Vancomycin', 'pO2'), ('Ranitidine (Prophylaxis)', 'pO2'), ('OR Crystalloid Intake', 'pO2'), ('Insulin - Regular', 'pO2'), ('Calcium Gluconate', 'pO2'), ('Packed Red Blood Cells', 'pO2'), ('OR Cell Saver Intake', 'pO2'), ('Cefazolin', 'pO2'), ('Albumin 5%', 'pO2'), ('Potassium Chloride', 'pO2'), ('KCL (Bolus)', 'pO2'), ('Morphine Sulfate', 'pO2'), ('Insulin - Regular', 'Glucose'), ('Calcium Gluconate', 'Glucose'), ('LR', 'Glucose'), ('Magnesium Sulfate', 'Glucose'), ('Vancomycin', 'Glucose'), ('Packed Red Blood Cells', 'Glucose'), ('Potassium Chloride', 'Glucose'), ('Magnesium Sulfate (Bolus)', 'Glucose'), ('KCL (Bolus)', 'Glucose'), ('Albumin 5%', 'Glucose'), ('OR Crystalloid Intake', 'Glucose'), ('Morphine Sulfate', 'Glucose'), ('Cefazolin', 'Glucose'), ('Ranitidine (Prophylaxis)', 'Glucose'), ('OR Cell Saver Intake', 'Glucose'), ('Insulin - Regular', 'Magnesium'), ('Calcium Gluconate', 'Magnesium'), ('LR', 'Magnesium'), ('Magnesium Sulfate', 'Magnesium'), ('Vancomycin', 'Magnesium'), ('Packed Red Blood Cells', 'Magnesium'), ('Potassium Chloride', 'Magnesium'), ('Magnesium Sulfate (Bolus)', 'Magnesium'), ('KCL (Bolus)', 'Magnesium'), ('Albumin 5%', 'Magnesium'), ('OR Crystalloid Intake', 'Magnesium'), ('Morphine Sulfate', 'Magnesium'), ('Ranitidine (Prophylaxis)', 'Magnesium'), ('Cefazolin', 'Magnesium'), ('OR Cell Saver Intake', 'Magnesium'), ('Insulin - Regular', 'Hematocrit'), ('Calcium Gluconate', 'Hematocrit'), ('Packed Red Blood Cells', 'Hematocrit'), ('Potassium Chloride', 'Hematocrit'), ('Vancomycin', 'Hematocrit'), ('Magnesium Sulfate', 'Hematocrit'), ('Cefazolin', 'Hematocrit'), ('Albumin 5%', 'Hematocrit'), ('OR Crystalloid Intake', 'Hematocrit'), ('OR Cell Saver Intake', 'Hematocrit'), ('Magnesium Sulfate (Bolus)', 'Hematocrit'), ('LR', 'Hematocrit'), ('KCL (Bolus)', 'Hematocrit'), ('Ranitidine (Prophylaxis)', 'Hematocrit'), ('Morphine Sulfate', 'Hematocrit'), ('Packed Red Blood Cells', 'Hemoglobin'), ('Morphine Sulfate', 'Hemoglobin'), ('Cefazolin', 'Hemoglobin'), ('Insulin - Regular', 'Red Blood Cells'), ('Calcium Gluconate', 'Red Blood Cells'), ('Potassium Chloride', 'Red Blood Cells'), ('Vancomycin', 'Red Blood Cells'), ('Magnesium Sulfate', 'Red Blood Cells'), ('Packed Red Blood Cells', 'Red Blood Cells'), ('Magnesium Sulfate (Bolus)', 'Red Blood Cells'), ('Ranitidine (Prophylaxis)', 'Red Blood Cells'), ('Morphine Sulfate', 'Red Blood Cells'), ('KCL (Bolus)', 'Red Blood Cells'), ('LR', 'Red Blood Cells'), ('Albumin 5%', 'Red Blood Cells'), ('OR Crystalloid Intake', 'Red Blood Cells'), ('OR Cell Saver Intake', 'Red Blood Cells'), ('Cefazolin', 'Red Blood Cells')])

# %%
p_data[('Insulin - Regular', 'Glucose')]['before_abs_1_4_sp'][0]
# Out:
#                             SUBJECT_ID  HADM_ID  before_abs_1_4_sp  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose          384   122988              112.0
#                   Glucose         2667   131592              848.0
#                   Glucose         9061   132744              145.0
#                   Glucose        10835   102994              178.0
#                   Glucose        20410   100771              140.0
# ...                                ...      ...                ...
#                   Glucose        44653   158278               82.0
#                   Glucose        69896   171405              179.0
#                   Glucose        88196   166646              148.0
#                   Glucose        76011   192327              153.0
#                   Glucose        78902   172221              106.0
#
#                             after_abs_1_4_sp  after_time_1_4_sp    abs  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose              137.0           4.866667   25.0
#                   Glucose              280.0           2.983333 -568.0
#                   Glucose              139.0           4.233333   -6.0
#                   Glucose              120.0           4.633333  -58.0
#                   Glucose              147.0           3.200000    7.0
# ...                                      ...                ...    ...
#                   Glucose               97.0           4.216667   15.0
#                   Glucose              124.0           1.333333  -55.0
#                   Glucose              114.0           2.650000  -34.0
#                   Glucose              106.0           1.316667  -47.0
#                   Glucose              154.0           1.383333   48.0
#
#                               percent     ratio
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose   22.321429  1.223214
#                   Glucose  -66.981132  0.330189
#                   Glucose   -4.137931  0.958621
#                   Glucose  -32.584270  0.674157
#                   Glucose    5.000000  1.050000
# ...                               ...       ...
#                   Glucose   18.292683  1.182927
#                   Glucose  -30.726257  0.692737
#                   Glucose  -22.972973  0.770270
#                   Glucose  -30.718954  0.692810
#                   Glucose   45.283019  1.452830
#
# [74 rows x 8 columns]

# %%
import pickle
# pickle.dump(p_data, open(f"plot_med_lab_bw_aw_data_{stratify_prefix}.pkl", "wb"))

# %%
p_data = pickle.load(open(f"plot_med_lab_bw_aw_data_{stratify_prefix}.pkl", "rb"))

# %%
def int_s(s):
    if s[0]=="_":
        return int(s[1:])
    else:
        return int(s)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns

def sort_rows_with_time(p_corrs, s_corrs, after_windows):
    s_p = sorted([k for k in zip(p_corrs, after_windows)])
    p_corrs = [k[0] for k in s_p]
    after_windows1 = [k[1] for k in s_p]
    s_s = sorted([k for k in zip(s_corrs, after_windows)])
    s_corrs = [k[0] for k in s_s]
    after_windows2 = [k[1] for k in s_p]
    return p_corrs, s_corrs, after_windows1, after_windows2

def plot_corrs(corrs, after_windows, ax, title='', plot_name='',  after_window_info=None):

    p_corrs = [c[0] for c in corrs]
    s_corrs = [c[1] for c in corrs]
    final_plot_name = f'{plot_name}_{title}'
    after_windows = [int_s(a[-7:-5]) for a in after_windows]
    
    p_corrs, s_corrs, after_windows1, after_windows2 = sort_rows_with_time(p_corrs, s_corrs, after_windows)
    
    # print(ax, [ k for k in zip(p_corrs, after_windows)])
    # print(ax, [ k for k in zip(s_corrs, after_windows)])
    
    # ax.plot(after_windows, p_corrs)
    # ax.set_title(f'{final_plot_name} Pearsons Corr')
    # ax.set(xlabel='Time in hours', ylabel='Correlation')

    ax[0].plot(after_windows1, p_corrs, '-o')
    ax[0].set_title(f'{final_plot_name} Pearsons Corr')
    ax[0].set(xlabel='Time in hours', ylabel='Correlation')
    ax[0].set_xticks(after_windows1)
    ax[0].grid()
    # ax[0].grid(axis='x')

    ax[1].plot(after_windows2, s_corrs, '-o')
    ax[1].set_title(f'{final_plot_name} Spearmans Corr')
    ax[1].set(xlabel='Time in hours', ylabel='Correlation')
    ax[1].set_xticks(after_windows2)
    # ax[1].grid(axis='x')
    ax[1].grid()
    

def plot_func(presc, lab, d, dirname, window=(1,24), title='', unit='mg/dL', labels=None, plot_name='', ax=None):
    
    plot_data = d
    # plot_data = plot_data.rename(columns={0:'Lab values'})

    # plot_data = plot_data[plot_data['timeFromPrescription'] > window[0]]
    # plot_data = plot_data[plot_data['timeFromPrescription'] < window[1]]

    if ax is None:
        sns.regplot(x = "time", 
                y = 'data', 
                data = plot_data.sort_values(["time"]), 
                truncate=False)
        plt.title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        plt.xlabel('Time in hours')
        plt.ylabel(title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            plt.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))
        if not os.path.isdir(f"{lab}<>{presc}"):
            os.mkdir(f"{lab}<>{presc}")
        if dirname is None or dirname == "":
            plt.savefig(os.path.join(f"{lab}<>{presc}", plot_name+".png"))
        else:
            if not os.path.isdir(os.path.join(f"{lab}<>{presc}", dirname)):
                os.mkdir(os.path.join(f"{lab}<>{presc}", dirname))
            plt.savefig(os.path.join(f"{lab}<>{presc}", dirname, plot_name+".png"))
        plt.clf()
    
    else:
        sns.regplot(
                ax=ax,
                x = "time", 
                y = 'data', 
                data = plot_data.sort_values(["time"]), 
                truncate=False)
        ax.set_title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        ax.set(xlabel='Time in hours', ylabel=title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            ax.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))

def remove_outlier(val, time_diff):
    val = pd.DataFrame(val)
    time_diff = pd.DataFrame(time_diff)
    
    # IQR
    Q1 = np.percentile(val, 25, method = 'midpoint')        
    Q3 = np.percentile(val, 75, method = 'midpoint')
    IQR = Q3 - Q1        
    
    # Upper bound
    upper = np.where(val >= (Q3+1.5*IQR))
    # Lower bound
    lower = np.where(val <= (Q1-1.5*IQR))

    # Filtering
    if len(upper) > 0:
        val.drop(upper[0], inplace = True)
        time_diff.drop(upper[0], inplace = True)
    if len(lower) > 0:
        val.drop(lower[0], inplace = True)
        time_diff.drop(lower[0], inplace = True)
    return val, time_diff

# %%
plot_dir = os.path.join(os.getcwd(), f"plots_{stratify_prefix}")
# os.mkdir(plot_dir)

# %%
types = ['abs', 'percent', 'ratio']
corrs_data_dict = []
for k, v in p_data.items():
    for key in v:
        lab = k[0]
        presc = k[1]
        before_window = int_s(key[-7:-5])

        fig_all, ax_all = plt.subplots(3, figsize=(20, 20))
        fig_all.suptitle(f'{lab}<>{presc} (before window = {str(before_window)})')

        if not os.path.isdir(os.path.join(plot_dir, f"{lab}<>{presc}")):
            os.mkdir(os.path.join(plot_dir, f"{lab}<>{presc}"))
        
        dirname=f"bw_{int_s(key[-7:-5])}"
        if not os.path.isdir(os.path.join(plot_dir, f"{lab}<>{presc}", dirname)):
            os.mkdir(os.path.join(plot_dir, f"{lab}<>{presc}", dirname))

        for i, type in enumerate(types):
            plot_name = f"{k[0]}<>{k[1]}_{key}_{type}"
            data_vals = [d[[list(d.columns)[-4], type]].rename(columns={list(d.columns)[-4] : "time"}) for d in v[key]]
            after_names = [list(d.columns)[3] for d in v[key]]
            print("checking", len(data_vals), len(after_names))
            if len(data_vals)!=len(after_names):
                print(data_vals)
                print(after_names)
                print()
                continue
            
            d = pd.concat(data_vals)
            if d.shape[0]<2:
                continue
            if d.shape[0]>1:
                d1, d2 = remove_outlier(d[type], d["time"])
            else:
                d1, d2 = d[[type]], d[["time"]]
            d = pd.concat([d1, d2], axis=1)

            p_corr, _ = pearsonr(d1[type], d2["time"])
            s_corr, _ = spearmanr(d1[type], d2["time"])

            plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname="", labels=(p_corr, s_corr), title=f"bw({int_s(key[-7:-5])}) {type}", plot_name=f"{plot_name}", ax=ax_all[i])

            fig_corrs, ax_corrs = plt.subplots(2, figsize=(20, 20))
            fig_corrs.suptitle(f'{lab}<>{presc} {type} corrs') 
            corrs = []
            temp_after_names = after_names.copy()
            for i, d in enumerate(data_vals):
                if d.shape[0]<2:
                    temp_after_names.remove(after_names[i])
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])
                corrs.append((p_corr, s_corr))
            after_names = temp_after_names
            plot_corrs(corrs, after_names, ax_corrs, title=type, plot_name=plot_name)
            fig_corrs.savefig(os.path.join(plot_dir, f"{lab}<>{presc}", dirname, f"{plot_name}_{type}_{stratify_prefix}_corrs.png"))
            fig_corrs.clf()

            for d, a, c in zip(data_vals, after_names, corrs):
                if d.shape[0]<2:
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                d = pd.concat([d1, d2], axis=1)

                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])

                plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname=dirname, labels=c, title=f"bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])}) {type}", plot_name=f"{plot_name} bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])})")
                corrs_data_dict.append({
                    "lab" : lab,
                    "med": presc,
                    "bw": before_window,
                    "aw": int_s(a[-7:-5]),
                    "type": type,
                    "p_corr": p_corr,
                    "s_corr": s_corr
                })
                    
        fig_all.savefig(os.path.join(plot_dir, f"{lab}<>{presc}", dirname, f"{plot_name}_{stratify_prefix}.png"))
        fig_all.clf()
corrs_data_df = pd.DataFrame(corrs_data_dict)
corrs_data_df.to_csv(os.path.join(plot_dir, f"corrs_data_{stratify_prefix}.csv"))
# Out:
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_84600/3788539579.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig_all, ax_all = plt.subplots(3, figsize=(20, 20))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 3 3
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 2 2
# checking 2 2
# checking 2 2
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 4 4
# checking 4 4
# checking 4 4
# checking 5 5
# checking 5 5
# checking 5 5
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 2 2
# checking 2 2
# checking 2 2
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4461: NearConstantInputWarning: An input array is nearly constant; the computed correlation coefficient may be inaccurate.
#   warnings.warn(stats.NearConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4461: NearConstantInputWarning: An input array is nearly constant; the computed correlation coefficient may be inaccurate.
#   warnings.warn(stats.NearConstantInputWarning(msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 4 4
# checking 4 4
# checking 4 4
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 3 3
# checking 3 3
# checking 3 3
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 4 4
# checking 4 4
# checking 4 4
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 2 2
# checking 2 2
# checking 2 2
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 2 2
# checking 2 2
# checking 2 2
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 2 2
# checking 2 2
# checking 2 2
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6

# %%
corrs_data_df
# Out:
#                      lab              med  bw  aw     type    p_corr    s_corr
# 0      Magnesium Sulfate      Base Excess   1   1      abs -0.021486 -0.022148
# 1      Magnesium Sulfate      Base Excess   1   5      abs -0.059106 -0.076261
# 2      Magnesium Sulfate      Base Excess   1   9      abs  0.359460  0.360754
# 3      Magnesium Sulfate      Base Excess   1  13      abs -0.015379  0.012015
# 4      Magnesium Sulfate      Base Excess   1  17      abs  0.099675  0.326369
# ...                  ...              ...  ..  ..      ...       ...       ...
# 13318          Cefazolin  Red Blood Cells  21   5      abs  0.999201  1.000000
# 13319          Cefazolin  Red Blood Cells  21   1  percent  0.343610  0.318874
# 13320          Cefazolin  Red Blood Cells  21   5  percent  0.999708  1.000000
# 13321          Cefazolin  Red Blood Cells  21   1    ratio  0.343610  0.318874
# 13322          Cefazolin  Red Blood Cells  21   5    ratio  0.999708  1.000000
#
# [13323 rows x 7 columns]

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
corrs_data_dict = []
types = ['abs', 'percent', 'ratio']
for k, v in p_data.items():
    for key in v:
        lab = k[0]
        presc = k[1]
        before_window = int_s(key[-7:-5])

        for i, type in enumerate(types):
            plot_name = f"{k[0]}<>{k[1]}_{key}_{type}"
            data_vals = [d[[list(d.columns)[-4], type]].rename(columns={list(d.columns)[-4] : "time"}) for d in v[key]]
            after_names = [list(d.columns)[3] for d in v[key]]
            if len(data_vals)!=len(after_names):
                continue

            for d, a in zip(data_vals, after_names):
                if d.shape[0]<2:
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                d = pd.concat([d1, d2], axis=1)

                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])

                corrs_data_dict.append({
                    "lab" : lab,
                    "med": presc,
                    "bw": before_window,
                    "aw": int_s(a[-7:-5]),
                    "type": type,
                    "p_corr": p_corr,
                    "s_corr": s_corr,
                    "num": d.shape[0]
                })
# Out:
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4461: NearConstantInputWarning: An input array is nearly constant; the computed correlation coefficient may be inaccurate.
#   warnings.warn(stats.NearConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))

# %%
corrs_data_df = pd.DataFrame(corrs_data_dict)

# %%
corrs_data_df
# Out:
#                      lab              med  bw  aw     type    p_corr  \
# 0      Magnesium Sulfate      Base Excess   1   1      abs -0.021486
# 1      Magnesium Sulfate      Base Excess   1   5      abs -0.059106
# 2      Magnesium Sulfate      Base Excess   1   9      abs  0.359460
# 3      Magnesium Sulfate      Base Excess   1  13      abs -0.015379
# 4      Magnesium Sulfate      Base Excess   1  17      abs  0.099675
# ...                  ...              ...  ..  ..      ...       ...
# 13783          Cefazolin  Red Blood Cells  21   0  percent  0.996217
# 13784          Cefazolin  Red Blood Cells  21   1    ratio  0.343610
# 13785          Cefazolin  Red Blood Cells  21   5    ratio  0.999708
# 13786          Cefazolin  Red Blood Cells  21  21    ratio  1.000000
# 13787          Cefazolin  Red Blood Cells  21   0    ratio  0.996217
#
#          s_corr  num
# 0     -0.022148   81
# 1     -0.076261   57
# 2      0.360754   40
# 3      0.012015   27
# 4      0.326369   32
# ...         ...  ...
# 13783  1.000000    3
# 13784  0.318874    6
# 13785  1.000000    3
# 13786  1.000000    2
# 13787  1.000000    3
#
# [13788 rows x 8 columns]

# %%
corrs_data_df[corrs_data_df["num"]>10].sort_values(["p_corr"]).head(30)
# Out:
#                              lab              med  bw  aw     type    p_corr  \
# 7711           Insulin - Regular        Magnesium   9   5      abs -0.830544
# 7725           Insulin - Regular        Magnesium   9   5    ratio -0.809063
# 7718           Insulin - Regular        Magnesium   9   5  percent -0.809063
# 9298    Ranitidine (Prophylaxis)        Magnesium   1   5      abs -0.761086
# 706     Ranitidine (Prophylaxis)      Base Excess   0   1  percent -0.759108
# 713     Ranitidine (Prophylaxis)      Base Excess   0   1    ratio -0.759108
# 9304    Ranitidine (Prophylaxis)        Magnesium   1   5  percent -0.751057
# 9310    Ranitidine (Prophylaxis)        Magnesium   1   5    ratio -0.751057
# 5405                 KCL (Bolus)              pO2  17   5  percent -0.720137
# 5412                 KCL (Bolus)              pO2  17   5    ratio -0.720137
# 547                   Vancomycin      Base Excess  21  13  percent -0.709057
# 554                   Vancomycin      Base Excess  21  13    ratio -0.709057
# 8612          Potassium Chloride        Magnesium  21   1    ratio -0.707806
# 8605          Potassium Chloride        Magnesium  21   1  percent -0.707806
# 11469           Morphine Sulfate       Hematocrit   1   0      abs -0.702320
# 3821   Magnesium Sulfate (Bolus)              pO2   0  21      abs -0.699798
# 6318      Packed Red Blood Cells          Glucose   1  21  percent -0.694246
# 6325      Packed Red Blood Cells          Glucose   1  21    ratio -0.694246
# 11476           Morphine Sulfate       Hematocrit   1   0  percent -0.681106
# 11483           Morphine Sulfate       Hematocrit   1   0    ratio -0.681106
# 7982                          LR        Magnesium   5  13    ratio -0.659759
# 7975                          LR        Magnesium   5  13  percent -0.659759
# 8598          Potassium Chloride        Magnesium  21   1      abs -0.658412
# 1027           Calcium Gluconate      Base Excess   9  17      abs -0.658409
# 6311      Packed Red Blood Cells          Glucose   1  21      abs -0.647951
# 12309         Potassium Chloride  Red Blood Cells  21   1  percent -0.637818
# 12315         Potassium Chloride  Red Blood Cells  21   1    ratio -0.637818
# 7395                   Cefazolin          Glucose  17   1    ratio -0.634326
# 7392                   Cefazolin          Glucose  17   1  percent -0.634326
# 3828   Magnesium Sulfate (Bolus)              pO2   0  21  percent -0.628924
#
#          s_corr  num
# 7711  -0.791888   12
# 7725  -0.711776   12
# 7718  -0.711776   12
# 9298  -0.781818   11
# 706   -0.758806   13
# 713   -0.758806   13
# 9304  -0.745455   11
# 9310  -0.745455   11
# 5405  -0.636364   12
# 5412  -0.636364   12
# 547   -0.654478   11
# 554   -0.654478   11
# 8612  -0.747368   12
# 8605  -0.747368   12
# 11469 -0.715702   15
# 3821  -0.464694   11
# 6318  -0.645376   14
# 6325  -0.645376   14
# 11476 -0.719290   15
# 11483 -0.719290   15
# 7982  -0.601368   11
# 7975  -0.601368   11
# 8598  -0.632690   12
# 1027  -0.693043   17
# 6311  -0.604190   14
# 12309 -0.721542   12
# 12315 -0.721542   12
# 7395  -0.609091   11
# 7392  -0.609091   11
# 3828  -0.473805   11

# %%
corrs_data_df[corrs_data_df["num"]>10].sort_values(["p_corr"]).tail(30)
# Out:
#                             lab          med  bw  aw     type    p_corr  \
# 11279               KCL (Bolus)   Hematocrit  13   1    ratio  0.650928
# 5489           Morphine Sulfate          pO2   5   5  percent  0.660714
# 5496           Morphine Sulfate          pO2   5   5    ratio  0.660714
# 5843          Calcium Gluconate      Glucose  21   9      abs  0.661739
# 5389                KCL (Bolus)          pO2  13   0  percent  0.663895
# 5396                KCL (Bolus)          pO2  13   0    ratio  0.663895
# 5850          Calcium Gluconate      Glucose  21   9  percent  0.678150
# 5857          Calcium Gluconate      Glucose  21   9    ratio  0.678150
# 699    Ranitidine (Prophylaxis)  Base Excess   0   1      abs  0.682229
# 11397  Ranitidine (Prophylaxis)   Hematocrit  13   1      abs  0.684565
# 8544         Potassium Chloride    Magnesium   9   0      abs  0.695990
# 11409  Ranitidine (Prophylaxis)   Hematocrit  13   1    ratio  0.701727
# 11403  Ranitidine (Prophylaxis)   Hematocrit  13   1  percent  0.701727
# 8558         Potassium Chloride    Magnesium   9   0    ratio  0.702790
# 8551         Potassium Chloride    Magnesium   9   0  percent  0.702790
# 10373         Magnesium Sulfate   Hematocrit   0  21      abs  0.710421
# 10379         Magnesium Sulfate   Hematocrit   0  21  percent  0.731787
# 10385         Magnesium Sulfate   Hematocrit   0  21    ratio  0.731787
# 8956                 Albumin 5%    Magnesium   9   1  percent  0.739772
# 8963                 Albumin 5%    Magnesium   9   1    ratio  0.739772
# 3623          Magnesium Sulfate          pO2  13  13    ratio  0.756673
# 3616          Magnesium Sulfate          pO2  13  13  percent  0.756673
# 9040      OR Crystalloid Intake    Magnesium   1  13  percent  0.788175
# 9047      OR Crystalloid Intake    Magnesium   1  13    ratio  0.788175
# 8949                 Albumin 5%    Magnesium   9   1      abs  0.797581
# 5382                KCL (Bolus)          pO2  13   0      abs  0.812193
# 9033      OR Crystalloid Intake    Magnesium   1  13      abs  0.816755
# 11293               KCL (Bolus)   Hematocrit  17   1  percent  0.840075
# 11300               KCL (Bolus)   Hematocrit  17   1    ratio  0.840075
# 11286               KCL (Bolus)   Hematocrit  17   1      abs  0.874487
#
#          s_corr  num
# 11279  0.699301   12
# 5489   0.609890   13
# 5496   0.609890   13
# 5843   0.487473   11
# 5389   0.825175   12
# 5396   0.825175   12
# 5850   0.542143   11
# 5857   0.542143   11
# 699    0.718252   13
# 11397  0.572727   11
# 8544   0.781906   11
# 11409  0.572727   11
# 11403  0.572727   11
# 8558   0.775348   11
# 8551   0.775348   11
# 10373  0.701596   11
# 10379  0.763636   11
# 10385  0.763636   11
# 8956   0.602339   11
# 8963   0.602339   11
# 3623   0.739286   15
# 3616   0.739286   15
# 9040   0.863636   11
# 9047   0.863636   11
# 8949   0.611535   11
# 5382   0.853147   12
# 9033   0.865009   11
# 11293  0.804196   12
# 11300  0.804196   12
# 11286  0.797203   12

# %%
corrs_data_df.to_csv(os.path.join(plot_dir, f"corrs_data_{stratify_prefix}.csv"))
