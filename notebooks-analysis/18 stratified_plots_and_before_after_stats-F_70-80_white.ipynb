# %%
data = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/data"
res = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/results"

# %%
import pandas as pd
import os

# %% [markdown]
# ## Medication Patient Data

# %% [markdown]
# ## Filter Meds

# %% [markdown]
# ### Med 1

# %%
# Female, 70-80, WHITE

# %%
gender = "F"
age_b = 70
age_a = 80
ethnicity = "WHITE"
stratify_prefix = f"{age_b}-{age_a}_{gender}_{ethnicity}"

# %%
med1 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med1_vectorized.csv"))

# %%
med1 = med1.drop(columns=["Unnamed: 0"])

# %%
import matplotlib.pyplot as plt
t = med1[med1["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
med1.shape
# Out:
# (323007, 63)

# %%
med1 = med1[med1["AGE"]>=age_b]
med1 = med1[med1["AGE"]<=age_a]

# %%
med1 = med1[med1["GENDER"]==gender]
med1 = med1[med1["ETHNICITY"]==ethnicity]

# %%
pd.DataFrame(med1["AGE"].value_counts()).reset_index().sort_values(["index"])
# Out:
#     index   AGE
# 9    70.0  1790
# 6    71.0  2174
# 8    72.0  1804
# 7    73.0  2105
# 10   74.0  1651
# 1    75.0  2462
# 5    76.0  2213
# 0    77.0  2676
# 4    78.0  2225
# 3    79.0  2322
# 2    80.0  2328

# %%
import matplotlib.pyplot as plt
t = med1[med1["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
med1.shape
# Out:
# (23750, 63)

# %%
med1
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 194            735  2068-03-06      F  2128-07-04 00:00:00            1
# 195            735  2068-03-06      F  2128-07-04 00:00:00            1
# 196            735  2068-03-06      F  2128-07-04 00:00:00            1
# 197            735  2068-03-06      F  2128-07-04 00:00:00            1
# 198            735  2068-03-06      F  2128-07-04 00:00:00            1
# ...            ...         ...    ...                  ...          ...
# 322871       44082  2056-04-27      F                  NaN            0
# 322872       44082  2056-04-27      F                  NaN            0
# 322873       44082  2056-04-27      F                  NaN            0
# 322874       44082  2056-04-27      F                  NaN            0
# 322875       44082  2056-04-27      F                  NaN            0
#
#         ITEMID  HADM_ID  ICUSTAY_ID            STARTTIME              ENDTIME  \
# 194     225158   140547    298103.0  2128-05-27 16:27:00  2128-05-27 16:28:00
# 195     225974   140547    298103.0  2128-05-27 16:41:00  2128-05-27 16:42:00
# 196     225828   140547    298103.0  2128-05-27 21:27:00  2128-05-27 21:28:00
# 197     226452   140547    298103.0  2128-05-29 00:17:00  2128-05-29 00:18:00
# 198     225154   140547    298103.0  2128-05-29 08:45:00  2128-05-29 08:46:00
# ...        ...      ...         ...                  ...                  ...
# 322871  225154   178322    233193.0  2122-04-08 06:55:00  2122-04-08 06:56:00
# 322872  225159   178322    233193.0  2122-04-07 22:43:00  2122-04-08 08:43:00
# 322873  223260   178322    233193.0  2122-04-08 10:00:00  2122-04-08 10:01:00
# 322874  223262   178322    233193.0  2122-04-08 12:00:00  2122-04-08 12:01:00
# 322875  225975   178322    233193.0  2122-04-09 08:30:00  2122-04-09 08:31:00
#
#         ...                         LABEL                  ABBREVIATION  \
# 194     ...                     NaCl 0.9%                     NaCl 0.9%
# 195     ...                    Metoprolol                    Metoprolol
# 196     ...                            LR                            LR
# 197     ...                     PO Intake                     PO Intake
# 198     ...              Morphine Sulfate              Morphine Sulfate
# ...     ...                           ...                           ...
# 322871  ...              Morphine Sulfate              Morphine Sulfate
# 322872  ...                    NaCl 0.45%                    NaCl 0.45%
# 322873  ...            Insulin - Glargine            Insulin - Glargine
# 322874  ...             Insulin - Humalog             Insulin - Humalog
# 322875  ...  Heparin Sodium (Prophylaxis)  Heparin Sodium (Prophylaxis)
#
#           DBSOURCE         LINKSTO       CATEGORY  UNITNAME  PARAM_TYPE  \
# 194     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 195     metavision  inputevents_mv    Medications        mg    Solution
# 196     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 197     metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 198     metavision  inputevents_mv    Medications        mg    Solution
# ...            ...             ...            ...       ...         ...
# 322871  metavision  inputevents_mv    Medications        mg    Solution
# 322872  metavision  inputevents_mv  Fluids/Intake        mL    Solution
# 322873  metavision  inputevents_mv    Medications     units    Solution
# 322874  metavision  inputevents_mv    Medications     units    Solution
# 322875  metavision  inputevents_mv    Medications      dose    Solution
#
#         CONCEPTID MedTimeFromAdmit   AGE
# 194           NaN  3 days 00:50:00  60.0
# 195           NaN  3 days 01:04:00  60.0
# 196           NaN  3 days 05:50:00  60.0
# 197           NaN  4 days 08:40:00  60.0
# 198           NaN  4 days 17:08:00  60.0
# ...           ...              ...   ...
# 322871        NaN  0 days 09:54:00  66.0
# 322872        NaN  0 days 11:41:00  66.0
# 322873        NaN  0 days 12:59:00  66.0
# 322874        NaN  0 days 14:59:00  66.0
# 322875        NaN  1 days 11:29:00  66.0
#
# [22176 rows x 63 columns]

# %% [markdown]
# ### Med 2

# %%
med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/27638116.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))

# %%
med2 = med2.drop(columns=["Unnamed: 0"])

# %%
med2 = med2[med2["AGE"]>=age_b]
med2 = med2[med2["AGE"]<=age_a]

# %%
med2 = med2[med2["GENDER"]==gender]
med2 = med2[med2["ETHNICITY"]==ethnicity]

# %%
med2
# Out:
#         SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG  ITEMID  HADM_ID  \
# 0              249  2075-03-13      F  NaN            0  225168   149546
# 1              249  2075-03-13      F  NaN            0  223258   149546
# 2              249  2075-03-13      F  NaN            0  225910   149546
# 3              249  2075-03-13      F  NaN            0  225943   149546
# 4              249  2075-03-13      F  NaN            0  226452   149546
# ...            ...         ...    ...  ...          ...     ...      ...
# 237168       43982  2065-04-17      F  NaN            0  225154   144231
# 237169       43982  2065-04-17      F  NaN            0  225851   144231
# 237170       43982  2065-04-17      F  NaN            0  223260   144231
# 237320       44035  2054-12-30      F  NaN            0  225975   114515
# 237321       44035  2054-12-30      F  NaN            0  226452   114515
#
#         ICUSTAY_ID            STARTTIME              ENDTIME  ...  \
# 0         269035.0  2155-02-04 03:23:00  2155-02-04 05:31:00  ...
# 1         269035.0  2155-02-04 05:52:00  2155-02-04 05:53:00  ...
# 2         269035.0  2155-02-04 12:00:00  2155-02-04 12:01:00  ...
# 3         269035.0  2155-02-04 12:00:00  2155-02-04 12:01:00  ...
# 4         269035.0  2155-02-04 17:00:00  2155-02-04 17:01:00  ...
# ...            ...                  ...                  ...  ...
# 237168    285986.0  2142-04-06 00:47:00  2142-04-06 00:48:00  ...
# 237169    285986.0  2142-04-07 10:00:00  2142-04-07 10:01:00  ...
# 237170    285986.0  2142-04-08 12:20:00  2142-04-08 12:21:00  ...
# 237320    212634.0  2128-03-09 16:20:00  2128-03-09 16:21:00  ...
# 237321    212634.0  2128-03-09 17:13:00  2128-03-09 17:14:00  ...
#
#                                LABEL                  ABBREVIATION  \
# 0             Packed Red Blood Cells                        PRBC's
# 1                  Insulin - Regular             Insulin - Regular
# 2            Pantoprazole (Protonix)       Pantoprazole (Protonix)
# 3                           Solution                      Solution
# 4                          PO Intake                     PO Intake
# ...                              ...                           ...
# 237168              Morphine Sulfate              Morphine Sulfate
# 237169                      Cefepime                      Cefepime
# 237170            Insulin - Glargine            Insulin - Glargine
# 237320  Heparin Sodium (Prophylaxis)  Heparin Sodium (Prophylaxis)
# 237321                     PO Intake                     PO Intake
#
#           DBSOURCE         LINKSTO                 CATEGORY  UNITNAME  \
# 0       metavision  inputevents_mv  Blood Products/Colloids        mL
# 1       metavision  inputevents_mv              Medications     units
# 2       metavision  inputevents_mv              Medications      dose
# 3       metavision  inputevents_mv            Fluids/Intake        mL
# 4       metavision  inputevents_mv            Fluids/Intake        mL
# ...            ...             ...                      ...       ...
# 237168  metavision  inputevents_mv              Medications        mg
# 237169  metavision  inputevents_mv              Antibiotics      dose
# 237170  metavision  inputevents_mv              Medications     units
# 237320  metavision  inputevents_mv              Medications      dose
# 237321  metavision  inputevents_mv            Fluids/Intake        mL
#
#         PARAM_TYPE  CONCEPTID  MedTimeFromAdmit   AGE
# 0         Solution        NaN   0 days 09:15:00  80.0
# 1         Solution        NaN   0 days 09:37:00  80.0
# 2         Solution        NaN   0 days 15:45:00  80.0
# 3         Solution        NaN   0 days 15:45:00  80.0
# 4         Solution        NaN   0 days 20:45:00  80.0
# ...            ...        ...               ...   ...
# 237168    Solution        NaN  11 days 14:34:00  77.0
# 237169    Solution        NaN  12 days 23:47:00  77.0
# 237170    Solution        NaN  14 days 02:07:00  77.0
# 237320    Solution        NaN   3 days 20:20:00  73.0
# 237321    Solution        NaN   3 days 21:13:00  73.0
#
# [17357 rows x 63 columns]

# %%
import matplotlib.pyplot as plt
t = med2[med2["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ## Filter Labs

# %%
labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))
# labs = labs.rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/608754289.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))

# %%
labs = labs.drop(columns=["Unnamed: 0"])
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 0               249  2075-03-13      F  NaN            0    163327  158975.0
# 1               249  2075-03-13      F  NaN            0    163304  158975.0
# 2               249  2075-03-13      F  NaN            0    163317  158975.0
# 3               249  2075-03-13      F  NaN            0    163315  158975.0
# 4               249  2075-03-13      F  NaN            0    163316  158975.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7260280       44128  2098-07-25      M  NaN            0  20437251  141304.0
# 7260281       44128  2098-07-25      M  NaN            0  20437245  141304.0
# 7260282       44128  2098-07-25      M  NaN            0  20437250  141304.0
# 7260283       44128  2098-07-25      M  NaN            0  20437255  141304.0
# 7260284       44128  2098-07-25      M  NaN            0  20437256  141304.0
#
#          ITEMID            CHARTTIME  VALUE  ...       RELIGION  \
# 0         51274  2156-04-27 15:40:00   20.0  ...       CATHOLIC
# 1         50868  2156-04-27 15:40:00   12.0  ...       CATHOLIC
# 2         51221  2156-04-27 15:40:00   29.5  ...       CATHOLIC
# 3         51146  2156-04-27 15:40:00    0.4  ...       CATHOLIC
# 4         51200  2156-04-27 15:40:00    2.4  ...       CATHOLIC
# ...         ...                  ...    ...  ...            ...
# 7260280   51275  2149-06-14 05:00:00   26.4  ...  NOT SPECIFIED
# 7260281   51237  2149-06-14 05:00:00    1.1  ...  NOT SPECIFIED
# 7260282   51274  2149-06-14 05:00:00   12.8  ...  NOT SPECIFIED
# 7260283   51221  2149-06-15 04:45:00   27.3  ...  NOT SPECIFIED
# 7260284   51221  2149-06-16 12:22:00   28.0  ...  NOT SPECIFIED
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0             DIVORCED     WHITE                  NaN                  NaN
# 1             DIVORCED     WHITE                  NaN                  NaN
# 2             DIVORCED     WHITE                  NaN                  NaN
# 3             DIVORCED     WHITE                  NaN                  NaN
# 4             DIVORCED     WHITE                  NaN                  NaN
# ...                ...       ...                  ...                  ...
# 7260280        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260281        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260282        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260283        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260284        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
#
#                        DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 0        GI BLEEDING\COLONOSCOPY                    0                    1
# 1        GI BLEEDING\COLONOSCOPY                    0                    1
# 2        GI BLEEDING\COLONOSCOPY                    0                    1
# 3        GI BLEEDING\COLONOSCOPY                    0                    1
# 4        GI BLEEDING\COLONOSCOPY                    0                    1
# ...                          ...                  ...                  ...
# 7260280                   TRAUMA                    0                    1
# 7260281                   TRAUMA                    0                    1
# 7260282                   TRAUMA                    0                    1
# 7260283                   TRAUMA                    0                    1
# 7260284                   TRAUMA                    0                    1
#
#          LabTimeFromAdmit   AGE
# 0         0 days 00:07:00  81.0
# 1         0 days 00:07:00  81.0
# 2         0 days 00:07:00  81.0
# 3         0 days 00:07:00  81.0
# 4         0 days 00:07:00  81.0
# ...                   ...   ...
# 7260280   5 days 13:39:00  51.0
# 7260281   5 days 13:39:00  51.0
# 7260282   5 days 13:39:00  51.0
# 7260283   6 days 13:24:00  51.0
# 7260284   7 days 21:01:00  51.0
#
# [7260285 rows x 38 columns]

# %%
labs = labs[labs["AGE"]>=age_b]
labs = labs[labs["AGE"]<=age_a]

# %%
labs = labs[labs["GENDER"]==gender]
labs = labs[labs["ETHNICITY"]==ethnicity]

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 28              249  2075-03-13      F  NaN            0    162912  149546.0
# 29              249  2075-03-13      F  NaN            0    162914  149546.0
# 30              249  2075-03-13      F  NaN            0    162915  149546.0
# 31              249  2075-03-13      F  NaN            0    162913  149546.0
# 32              249  2075-03-13      F  NaN            0    162916  149546.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7252088       44035  2054-12-30      F  NaN            0  20426740  114515.0
# 7252089       44035  2054-12-30      F  NaN            0  20426742  114515.0
# 7252090       44035  2054-12-30      F  NaN            0  20426734  114515.0
# 7252091       44035  2054-12-30      F  NaN            0  20426736  114515.0
# 7252092       44035  2054-12-30      F  NaN            0  20426743  114515.0
#
#          ITEMID            CHARTTIME   VALUE  ...      RELIGION  \
# 28        51221  2155-02-03 23:26:00   26.60  ...      CATHOLIC
# 29        50910  2155-02-04 01:49:00  254.00  ...      CATHOLIC
# 30        50911  2155-02-04 01:49:00   24.00  ...      CATHOLIC
# 31        50908  2155-02-04 01:49:00    9.40  ...      CATHOLIC
# 32        51003  2155-02-04 01:49:00    0.46  ...      CATHOLIC
# ...         ...                  ...     ...  ...           ...
# 7252088   50971  2128-03-15 12:40:00    3.50  ...  UNOBTAINABLE
# 7252089   51006  2128-03-15 12:40:00   18.00  ...  UNOBTAINABLE
# 7252090   50893  2128-03-15 12:40:00    7.80  ...  UNOBTAINABLE
# 7252091   50912  2128-03-15 12:40:00    2.10  ...  UNOBTAINABLE
# 7252092   51221  2128-03-15 12:40:00   35.20  ...  UNOBTAINABLE
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 28            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 29            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 30            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 31            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 32            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# ...                ...       ...                  ...                  ...
# 7252088        MARRIED     WHITE                  NaN                  NaN
# 7252089        MARRIED     WHITE                  NaN                  NaN
# 7252090        MARRIED     WHITE                  NaN                  NaN
# 7252091        MARRIED     WHITE                  NaN                  NaN
# 7252092        MARRIED     WHITE                  NaN                  NaN
#
#                         DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 28           GI BLEED/ CHEST PAIN                    0                    1
# 29           GI BLEED/ CHEST PAIN                    0                    1
# 30           GI BLEED/ CHEST PAIN                    0                    1
# 31           GI BLEED/ CHEST PAIN                    0                    1
# 32           GI BLEED/ CHEST PAIN                    0                    1
# ...                           ...                  ...                  ...
# 7252088  CONGESTIVE HEART FAILURE                    0                    1
# 7252089  CONGESTIVE HEART FAILURE                    0                    1
# 7252090  CONGESTIVE HEART FAILURE                    0                    1
# 7252091  CONGESTIVE HEART FAILURE                    0                    1
# 7252092  CONGESTIVE HEART FAILURE                    0                    1
#
#          LabTimeFromAdmit   AGE
# 28        0 days 03:10:00  80.0
# 29        0 days 05:33:00  80.0
# 30        0 days 05:33:00  80.0
# 31        0 days 05:33:00  80.0
# 32        0 days 05:33:00  80.0
# ...                   ...   ...
# 7252088   9 days 16:39:00  73.0
# 7252089   9 days 16:39:00  73.0
# 7252090   9 days 16:39:00  73.0
# 7252091   9 days 16:39:00  73.0
# 7252092   9 days 16:39:00  73.0
#
# [494667 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
t = labs[labs["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ## Pairs

# %%
counts = med1.groupby("ITEMID").count()[["HADM_ID"]].sort_values("HADM_ID", ascending=False)
counts[counts["HADM_ID"]>1000]
# Out:
#         HADM_ID
# ITEMID
# 225158     1157
# 220949     1005

# %%
labitems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_LABITEMS.csv.gz"))
meditems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_ITEMS.csv.gz"))

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 28              249  2075-03-13      F  NaN            0    162912  149546.0
# 29              249  2075-03-13      F  NaN            0    162914  149546.0
# 30              249  2075-03-13      F  NaN            0    162915  149546.0
# 31              249  2075-03-13      F  NaN            0    162913  149546.0
# 32              249  2075-03-13      F  NaN            0    162916  149546.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7252088       44035  2054-12-30      F  NaN            0  20426740  114515.0
# 7252089       44035  2054-12-30      F  NaN            0  20426742  114515.0
# 7252090       44035  2054-12-30      F  NaN            0  20426734  114515.0
# 7252091       44035  2054-12-30      F  NaN            0  20426736  114515.0
# 7252092       44035  2054-12-30      F  NaN            0  20426743  114515.0
#
#          ITEMID            CHARTTIME   VALUE  ...      RELIGION  \
# 28        51221  2155-02-03 23:26:00   26.60  ...      CATHOLIC
# 29        50910  2155-02-04 01:49:00  254.00  ...      CATHOLIC
# 30        50911  2155-02-04 01:49:00   24.00  ...      CATHOLIC
# 31        50908  2155-02-04 01:49:00    9.40  ...      CATHOLIC
# 32        51003  2155-02-04 01:49:00    0.46  ...      CATHOLIC
# ...         ...                  ...     ...  ...           ...
# 7252088   50971  2128-03-15 12:40:00    3.50  ...  UNOBTAINABLE
# 7252089   51006  2128-03-15 12:40:00   18.00  ...  UNOBTAINABLE
# 7252090   50893  2128-03-15 12:40:00    7.80  ...  UNOBTAINABLE
# 7252091   50912  2128-03-15 12:40:00    2.10  ...  UNOBTAINABLE
# 7252092   51221  2128-03-15 12:40:00   35.20  ...  UNOBTAINABLE
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 28            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 29            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 30            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 31            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 32            DIVORCED     WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# ...                ...       ...                  ...                  ...
# 7252088        MARRIED     WHITE                  NaN                  NaN
# 7252089        MARRIED     WHITE                  NaN                  NaN
# 7252090        MARRIED     WHITE                  NaN                  NaN
# 7252091        MARRIED     WHITE                  NaN                  NaN
# 7252092        MARRIED     WHITE                  NaN                  NaN
#
#                         DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 28           GI BLEED/ CHEST PAIN                    0                    1
# 29           GI BLEED/ CHEST PAIN                    0                    1
# 30           GI BLEED/ CHEST PAIN                    0                    1
# 31           GI BLEED/ CHEST PAIN                    0                    1
# 32           GI BLEED/ CHEST PAIN                    0                    1
# ...                           ...                  ...                  ...
# 7252088  CONGESTIVE HEART FAILURE                    0                    1
# 7252089  CONGESTIVE HEART FAILURE                    0                    1
# 7252090  CONGESTIVE HEART FAILURE                    0                    1
# 7252091  CONGESTIVE HEART FAILURE                    0                    1
# 7252092  CONGESTIVE HEART FAILURE                    0                    1
#
#          LabTimeFromAdmit   AGE
# 28        0 days 03:10:00  80.0
# 29        0 days 05:33:00  80.0
# 30        0 days 05:33:00  80.0
# 31        0 days 05:33:00  80.0
# 32        0 days 05:33:00  80.0
# ...                   ...   ...
# 7252088   9 days 16:39:00  73.0
# 7252089   9 days 16:39:00  73.0
# 7252090   9 days 16:39:00  73.0
# 7252091   9 days 16:39:00  73.0
# 7252092   9 days 16:39:00  73.0
#
# [494667 rows x 38 columns]

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%         1157
# 1                   Dextrose 5%         1005
# 2                     PO Intake          940
# 3                      Solution          792
# 4             Magnesium Sulfate          737
# 5            Potassium Chloride          712
# 6  Heparin Sodium (Prophylaxis)          648
# 7     Magnesium Sulfate (Bolus)          604
# 8             Insulin - Regular          601
# 9            Furosemide (Lasix)          563

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%         1157
# 1                   Dextrose 5%         1005
# 2                     PO Intake          940
# 3                      Solution          792
# 4             Magnesium Sulfate          737
# 5            Potassium Chloride          712
# 6  Heparin Sodium (Prophylaxis)          648
# 7     Magnesium Sulfate (Bolus)          604
# 8             Insulin - Regular          601
# 9            Furosemide (Lasix)          563

# %%
med1["STARTTIME"] = pd.to_datetime(med1["STARTTIME"])
med1["ENDTIME"] = pd.to_datetime(med1["ENDTIME"])
med1["ADMITTIME"] = pd.to_datetime(med1["ADMITTIME"])
med1["MedTimeFromAdmit"] = med1["ENDTIME"]-med1["ADMITTIME"]
med2["STARTTIME"] = pd.to_datetime(med2["STARTTIME"])
med2["ENDTIME"] = pd.to_datetime(med2["ENDTIME"])
med2["ADMITTIME"] = pd.to_datetime(med2["ADMITTIME"])
med2["MedTimeFromAdmit"] = med2["ENDTIME"]-med2["ADMITTIME"]
labs["CHARTTIME"] = pd.to_datetime(labs["CHARTTIME"])
labs["ADMITTIME"] = pd.to_datetime(labs["ADMITTIME"])
labs["LabTimeFromAdmit"] = labs["CHARTTIME"]-labs["ADMITTIME"]

# %%
med1["hours_in"] = med1["MedTimeFromAdmit"].dt.total_seconds()/3600
labs["hours_in"] = labs["LabTimeFromAdmit"].dt.total_seconds()/3600

# %%
final_significant_med_lab_pairs = pd.read_csv(os.path.join(res, "significant_intersection_trends_and_med_effect_lab_med_all_new.csv"))

# %%
d = final_significant_med_lab_pairs.sort_values(by=['FDR Benjamini Corrected_y', 'FDR Benjamini Corrected_x']).head(20)[["MED_NAME", "LAB_NAME"]].to_dict()

# %%
d = {k : list(d[k].values()) for k in d}

# %%
meds = []
labtests = []

meds.append('Insulin - Regular')
labtests.append('Glucose')

meds.append('Packed Red Blood Cells')
labtests.append('Hematocrait')

meds.append('Packed Red Blood Cells')
labtests.append('Hemoglobin')

meds.append('Packed Red Blood Cells')
labtests.append('Red Blood Cells')

meds.append('Calcium')
labtests.append('Calcium Total')

meds.append('Albumin 5%')
labtests.append('Hematocrit')

meds.extend(d["MED_NAME"])
labtests.extend(d["LAB_NAME"])

med_vals = list(meds)
labtest_vals = list(labtests)

# %%
[i for i in zip(med_vals, labtest_vals)]
# Out:
# [('Insulin - Regular', 'Glucose'),
#  ('Packed Red Blood Cells', 'Hematocrait'),
#  ('Packed Red Blood Cells', 'Hemoglobin'),
#  ('Packed Red Blood Cells', 'Red Blood Cells'),
#  ('Calcium', 'Calcium Total'),
#  ('Albumin 5%', 'Hematocrit'),
#  ('Magnesium Sulfate (Bolus)', 'Magnesium'),
#  ('Magnesium Sulfate', 'Magnesium'),
#  ('Cefazolin', 'pO2'),
#  ('OR Cell Saver Intake', 'pO2'),
#  ('OR Crystalloid Intake', 'pO2'),
#  ('KCL (Bolus)', 'pO2'),
#  ('Potassium Chloride', 'pO2'),
#  ('Morphine Sulfate', 'pO2'),
#  ('Vancomycin', 'Hematocrit'),
#  ('Calcium Gluconate', 'pO2'),
#  ('OR Cell Saver Intake', 'Base Excess'),
#  ('LR', 'pO2'),
#  ('Insulin - Regular', 'pO2'),
#  ('Magnesium Sulfate', 'pO2'),
#  ('Magnesium Sulfate (Bolus)', 'pO2'),
#  ('Calcium Gluconate', 'Magnesium'),
#  ('Ranitidine (Prophylaxis)', 'pO2'),
#  ('Vancomycin', 'Red Blood Cells'),
#  ('Vancomycin', 'Hemoglobin'),
#  ('Magnesium Sulfate', 'Hematocrit')]

# %%
t_med1 = med1[med1["LABEL"].isin(med_vals)]
t_med2 = med2[med2["LABEL"].isin(med_vals)]

# %%
t_labs = labs[labs["LABEL"].isin(labtest_vals)]

# %%
t_med1.shape, t_med2.shape, t_labs.shape
# Out:
# ((6825, 64), (4680, 63), (105730, 39))

# %% [markdown]
# ## Before After Trend Calculation

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
def check_med2(row):
    if row["HADM_ID"] in t_med2["HADM_ID"].to_list():
        if row["ITEMID"] in t_med2[t_med2["HADM_ID"]==row["HADM_ID"]]["ITEMID"].to_list():
            return True
    return False

def get_med2(row):
    temp = t_med2[t_med2["HADM_ID"]==row["HADM_ID"]] 
    return temp[temp["ITEMID"]==row["ITEMID"]].iloc[0]

# %%
from sklearn import datasets, linear_model, metrics

def get_normalized_trend(data):
    selected = data[['VALUENUM', 'hours_in']]
    if selected.shape[0]<2:
        return float("NaN")
    reg = linear_model.LinearRegression()
    reg.fit(np.array(data['hours_in']).reshape(-1,1), np.array(data['VALUENUM']).reshape(-1,1))
    return reg.coef_[0][0]

# %%
def get_normalized_trend_np(data):
    selected = data[['VALUENUM', 'hours_in']]
    print(selected)
    if selected.shape[0]<2:
        return float("NaN")
    print(np.array(data['hours_in']), np.array(data['VALUENUM']))
    t = np.polyfit(np.array(data['hours_in']), np.array(data['VALUENUM']), 1,full=True)
    coefficients, residuals, _, _, _ = t
    print(t)
    mse = residuals[0]/(len(selected.index))
    nrmse = np.sqrt(mse)/(selected.max() - selected.min())
    return 1

# %%
window = (1,25,4)

# %%
def get_vals(r):

    row = r.copy()
    for i in range(window[0], window[1], window[2]):

        if i==1:
            lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

            b_window_start = row["MedTimeFromAdmit"].total_seconds()
            b_window_end = row["MedTimeFromAdmit"].total_seconds() - 1*3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
            lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"before_abs_0_0"] = {}
                row[f"before_time_0_0"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"before_abs_0_0"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"before_time_0_0"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

            lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
            med2_bool = check_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
            a_window_start = row["MedTimeFromAdmit"].total_seconds()
            a_window_end = row["MedTimeFromAdmit"].total_seconds() + 3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
            lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            if med2_bool:
                med2_val = get_med2(row)
                lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
            
            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"after_abs_0_0"] = {}
                row[f"after_time_0_0"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"after_abs_0_0"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"after_time_0_0"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
    
        lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

        b_window_start = row["MedTimeFromAdmit"].total_seconds() - (i*3600)
        b_window_end = row["MedTimeFromAdmit"].total_seconds() - (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
        lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"before_abs_{i}_{window[2]}"] = {}
            row[f"before_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"before_abs_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"before_time_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

        lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
        med2_bool = check_med2(row)
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
        a_window_start = row["MedTimeFromAdmit"].total_seconds() + (i*3600)
        a_window_end = row["MedTimeFromAdmit"].total_seconds() + (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
        lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        if med2_bool:
            med2_val = get_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
        
        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"after_abs_{i}_{window[2]}"] = {}
            row[f"after_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"after_abs_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"after_time_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
        
    return row

# %%
# type = "abs"
all_types = set(["abs", "time"])
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types]
cols_a = [f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types]
cols_b.extend([f"before_{t}_0_0" for t in all_types])
cols_a.extend([f"after_{t}_0_0" for t in all_types])
cols = cols_b.copy()
cols.extend(cols_a)

# %%
temp = t_med1.copy()
temp = temp.apply(lambda r : get_vals(r), axis=1)

# %%
temp
# Out:
#         SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG  ITEMID  HADM_ID  \
# 3              249  2075-03-13      F  NaN            0  223258   149546
# 4              249  2075-03-13      F  NaN            0  225168   149546
# 8              249  2075-03-13      F  NaN            0  222011   149546
# 12             249  2075-03-13      F  NaN            0  225166   149546
# 13             249  2075-03-13      F  NaN            0  227522   149546
# ...            ...         ...    ...  ...          ...     ...      ...
# 322381       43982  2065-04-17      F  NaN            0  226372   144231
# 322383       43982  2065-04-17      F  NaN            0  220864   144231
# 322384       43982  2065-04-17      F  NaN            0  225168   144231
# 322386       43982  2065-04-17      F  NaN            0  225154   144231
# 322388       43982  2065-04-17      F  NaN            0  221456   144231
#
#         ICUSTAY_ID           STARTTIME             ENDTIME  ...  \
# 3         269035.0 2155-02-04 00:50:00 2155-02-04 00:51:00  ...
# 4         269035.0 2155-02-04 03:24:00 2155-02-04 05:24:00  ...
# 8         269035.0 2155-02-05 08:49:00 2155-02-05 09:04:00  ...
# 12        263055.0 2155-02-07 23:17:00 2155-02-08 00:17:00  ...
# 13        263055.0 2155-02-07 23:17:00 2155-02-08 00:17:00  ...
# ...            ...                 ...                 ...  ...
# 322381    285986.0 2142-04-05 13:30:00 2142-04-05 13:31:00  ...
# 322383    285986.0 2142-04-05 14:20:00 2142-04-05 14:50:00  ...
# 322384    285986.0 2142-04-05 18:58:00 2142-04-05 19:58:00  ...
# 322386    285986.0 2142-04-05 22:40:00 2142-04-05 22:41:00  ...
# 322388    285986.0 2142-04-06 00:26:00 2142-04-06 01:26:00  ...
#
#                                            after_abs_13_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50808: 1.21, 50809: 169.0, 50820: 7.4, 50822:...
# 322383                                                 {}
# 322384                                                 {}
# 322386                                                 {}
# 322388  {50902: 107.0, 50931: 105.0, 50960: 2.2, 50971...
#
#                                           after_time_13_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50808: 13.8, 50809: 13.8, 50820: 13.8, 50822:...
# 322383                                                 {}
# 322384                                                 {}
# 322386                                                 {}
# 322388  {50902: 13.716666666666667, 50931: 13.71666666...
#
#                                           before_abs_17_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12      {50931: 115.0, 50960: 1.9, 51221: 28.7, 51222:...
# 13      {50931: 115.0, 50960: 1.9, 51221: 28.7, 51222:...
# ...                                                   ...
# 322381                                                 {}
# 322383                                                 {}
# 322384                                                 {}
# 322386  {50931: 195.0, 50960: 2.0, 51221: 32.9, 51222:...
# 322388  {50802: 4.0, 50809: 211.0, 50811: 11.3, 50821:...
#
#                                          before_time_17_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12      {50931: 16.31666666666667, 50960: 16.316666666...
# 13      {50931: 16.31666666666667, 50960: 16.316666666...
# ...                                                   ...
# 322381                                                 {}
# 322383                                                 {}
# 322384                                                 {}
# 322386  {50931: 18.583333333333332, 50960: 18.58333333...
# 322388  {50802: 16.71666666666667, 50809: 16.716666666...
#
#                                            after_abs_17_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50802: -4.0, 50804: 20.0, 50809: 122.0, 50817...
# 322383                                                 {}
# 322384                                                 {}
# 322386                                                 {}
# 322388                                                 {}
#
#                                           after_time_17_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50802: 17.483333333333334, 50804: 17.48333333...
# 322383                                                 {}
# 322384                                                 {}
# 322386                                                 {}
# 322388                                                 {}
#
#                                           before_abs_21_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                           {51221: 31.6}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50960: 2.0, 51221: 35.0, 51222: 11.4, 51279: ...
# 322383  {50960: 2.0, 51221: 35.0, 51222: 11.4, 51279: ...
# 322384                                                 {}
# 322386                                                 {}
# 322388  {50931: 195.0, 50960: 2.0, 51221: 32.9, 51222:...
#
#                                          before_time_21_4  \
# 3                                                      {}
# 4                                                      {}
# 8                             {51221: 21.233333333333334}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50960: 21.333333333333332, 51221: 21.33333333...
# 322383  {50960: 22.166666666666668, 51221: 22.16666666...
# 322384                                                 {}
# 322386                                                 {}
# 322388  {50931: 20.35, 50960: 20.35, 51221: 20.35, 512...
#
#                                            after_abs_21_4  \
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50802: 0.0, 50804: 28.0, 50808: 1.28, 50809: ...
# 322383                                                 {}
# 322384                                                 {}
# 322386                                                 {}
# 322388                                                 {}
#
#                                           after_time_21_4
# 3                                                      {}
# 4                                                      {}
# 8                                                      {}
# 12                                                     {}
# 13                                                     {}
# ...                                                   ...
# 322381  {50802: 21.25, 50804: 21.25, 50808: 23.3666666...
# 322383                                                 {}
# 322384                                                 {}
# 322386                                                 {}
# 322388                                                 {}
#
# [6825 rows x 92 columns]

# %%
temp.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_first_val_{stratify_prefix}.csv"))

# %%
# import ast
# for c in cols:
#     temp[c] = temp[c].apply(lambda x : ast.literal_eval(x))

# %%
# [c for c in cols for i in temp[c].to_list() if len(i)>0]

# %%
col_vals = []
for col in cols:
    col_vals.append(
        temp.assign(dict=temp[col].map(lambda d: d.items())).explode("dict", ignore_index=True).assign(
            LAB_ITEMID=lambda df: df.dict.str.get(0),
            temp=lambda df: df.dict.str.get(1)
        ).drop(columns=["dict"]+cols).astype({'temp':'float64', 'LAB_ITEMID':'float64'}).rename(columns={"temp":f"{col}_sp"}).dropna(subset=["LAB_ITEMID"])
    )

# %%
for i in range(1, len(col_vals)):
    col_vals[i] = pd.merge(col_vals[i-1], col_vals[i], how="outer", on=list(t_med1.columns)+["LAB_ITEMID"])

# %%
final = col_vals[-1][list(t_med1.columns)+["LAB_ITEMID"]+[f"{col}_sp" for col in cols]]

# %%
t_final = pd.merge(final.rename(columns={"LABEL":"MED_NAME"}), labitems.rename(columns={"ITEMID":"LAB_ITEMID"}), on="LAB_ITEMID", how="inner").rename(columns={"LABEL":"LAB_NAME"})
final = t_final

# %%
final.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_trends_first_val_{stratify_prefix}.csv"))

# %%
final = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_trends_first_val_{stratify_prefix}.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/525274090.py:1: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   final = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_trends_first_val_{stratify_prefix}.csv"))

# %%
t_final = final.copy()
plot_data = {}
for b in [f"{c}_sp" for c in cols_b]:
    if b in t_final.columns:
        plot_data[b] = []
        for a in [f"{c}_sp" for c in cols_a]:
            if a in t_final.columns:
                plot_data[b].append(t_final.dropna(subset=[a,b]))
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data_concat = {}
for i in plot_data:
    plot_data_concat[i] = pd.concat(plot_data[i])

# %%
[(k, plot_data_concat[k].shape) for k in plot_data_concat]
# Out:
# [('before_abs_1_4_sp', (49748, 99)),
#  ('before_time_1_4_sp', (49748, 99)),
#  ('before_abs_5_4_sp', (40304, 99)),
#  ('before_time_5_4_sp', (40304, 99)),
#  ('before_abs_9_4_sp', (26118, 99)),
#  ('before_time_9_4_sp', (26118, 99)),
#  ('before_abs_13_4_sp', (18438, 99)),
#  ('before_time_13_4_sp', (18438, 99)),
#  ('before_abs_17_4_sp', (14520, 99)),
#  ('before_time_17_4_sp', (14520, 99)),
#  ('before_abs_21_4_sp', (10320, 99)),
#  ('before_time_21_4_sp', (10320, 99)),
#  ('before_abs_0_0_sp', (16878, 99)),
#  ('before_time_0_0_sp', (16878, 99))]

# %%
# type = "abs"
a_t = ["abs", "time"]
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b_sp = [(f"before_{a_t[0]}_{i}_{window[2]}_sp", f"before_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2]) ]
cols_a_sp = [(f"after_{a_t[0]}_{i}_{window[2]}_sp", f"after_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2])]
cols_b_sp.append((f"before_abs_0_0_sp", f"before_time_0_0_sp"))
cols_a_sp.append((f"after_abs_0_0_sp", f"after_time_0_0_sp"))
cols_sp = cols_b_sp.copy()
cols_sp.extend(cols_a_sp)

# %%
t_final = final.copy()
plot_data = {}
for b in cols_b_sp:
    if b[0] in t_final.columns:
        plot_data[b[0]] = {}
        for a in cols_a_sp: 
            if a[0] in t_final.columns:
                # print(a, b)
                plot_data[b[0]][a[0]] = t_final.dropna(subset=[a[0], a[1], b[0], b[1]])
                # print(plot_data[b][a][[a, b]])
                # print(plot_data.keys())
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data.keys()
# Out:
# dict_keys(['before_abs_1_4_sp', 'before_abs_5_4_sp', 'before_abs_9_4_sp', 'before_abs_13_4_sp', 'before_abs_17_4_sp', 'before_abs_21_4_sp', 'before_abs_0_0_sp'])

# %%
import pickle
pickle.dump(plot_data, open(f"plot_bw_aw_med_lab_data_{stratify_prefix}.pkl", "wb"))

# %%
cols_sp
# Out:
# [('before_abs_1_4_sp', 'before_time_1_4_sp'),
#  ('before_abs_5_4_sp', 'before_time_5_4_sp'),
#  ('before_abs_9_4_sp', 'before_time_9_4_sp'),
#  ('before_abs_13_4_sp', 'before_time_13_4_sp'),
#  ('before_abs_17_4_sp', 'before_time_17_4_sp'),
#  ('before_abs_21_4_sp', 'before_time_21_4_sp'),
#  ('before_abs_0_0_sp', 'before_time_0_0_sp'),
#  ('after_abs_1_4_sp', 'after_time_1_4_sp'),
#  ('after_abs_5_4_sp', 'after_time_5_4_sp'),
#  ('after_abs_9_4_sp', 'after_time_9_4_sp'),
#  ('after_abs_13_4_sp', 'after_time_13_4_sp'),
#  ('after_abs_17_4_sp', 'after_time_17_4_sp'),
#  ('after_abs_21_4_sp', 'after_time_21_4_sp'),
#  ('after_abs_0_0_sp', 'after_time_0_0_sp')]

# %%
cols_d = dict(cols_sp)

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
# corr, _ = spearmanr(values, time_diff)
p_data = {}
for k in plot_data:
    print("Before Window: ", k)
    for i, (k_a, data) in enumerate(plot_data[k].items()):
        print("After Window: ", k_a)

        t_data = data.set_index([data["MED_NAME"], data["LAB_NAME"]])        
        med_lab_pairs = t_data.index
        
        for med_lab_pair in med_lab_pairs.unique():
            
            if med_lab_pair not in p_data.keys():
                p_data[med_lab_pair] = {}
            if k not in p_data[med_lab_pair].keys():
                p_data[med_lab_pair][k] = []
            
            t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
            t_d['abs'] = t_d[k_a]-t_d[k]
            t_d['percent'] = (t_d['abs']/t_d[k])*100
            t_d['ratio'] = t_d[k_a]/t_d[k]
            t_d.replace([np.inf, -np.inf], np.nan, inplace=True)
            t_d = t_d.dropna()
            
            p_data[med_lab_pair][k].append(t_d)

        # print(med_name_stats)
        # print(data[data["MED_NAME"]==list(med_name_stats.keys())[0]]["SUBJECT_ID"].value_counts().to_dict())
        # print(data[data["MED_NAME"]==list(med_name_stats.keys())[0]]["HADM_ID"].value_counts().to_dict())
        # t_lau = data[data["MED_NAME"]==list(med_name_stats.keys())[0]]
# Out:
# Before Window:  before_abs_1_4_sp
# After Window:  after_abs_1_4_sp
# After Window:  after_abs_5_4_sp
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
# ...
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/2718244291.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]

# %%
p_data.keys()
# Out:
# dict_keys([('Insulin - Regular', 'Hematocrit'), ('Calcium Gluconate', 'Hematocrit'), ('KCL (Bolus)', 'Hematocrit'), ('Potassium Chloride', 'Hematocrit'), ('Vancomycin', 'Hematocrit'), ('Magnesium Sulfate', 'Hematocrit'), ('Magnesium Sulfate (Bolus)', 'Hematocrit'), ('Albumin 5%', 'Hematocrit'), ('Cefazolin', 'Hematocrit'), ('LR', 'Hematocrit'), ('Packed Red Blood Cells', 'Hematocrit'), ('OR Cell Saver Intake', 'Hematocrit'), ('OR Crystalloid Intake', 'Hematocrit'), ('Ranitidine (Prophylaxis)', 'Hematocrit'), ('Morphine Sulfate', 'Hematocrit'), ('Insulin - Regular', 'Glucose'), ('Calcium Gluconate', 'Glucose'), ('Vancomycin', 'Glucose'), ('Magnesium Sulfate', 'Glucose'), ('Potassium Chloride', 'Glucose'), ('Cefazolin', 'Glucose'), ('Magnesium Sulfate (Bolus)', 'Glucose'), ('LR', 'Glucose'), ('Packed Red Blood Cells', 'Glucose'), ('KCL (Bolus)', 'Glucose'), ('Ranitidine (Prophylaxis)', 'Glucose'), ('Morphine Sulfate', 'Glucose'), ('OR Crystalloid Intake', 'Glucose'), ('Albumin 5%', 'Glucose'), ('Insulin - Regular', 'Magnesium'), ('Calcium Gluconate', 'Magnesium'), ('Vancomycin', 'Magnesium'), ('Magnesium Sulfate', 'Magnesium'), ('Potassium Chloride', 'Magnesium'), ('Cefazolin', 'Magnesium'), ('Magnesium Sulfate (Bolus)', 'Magnesium'), ('LR', 'Magnesium'), ('Packed Red Blood Cells', 'Magnesium'), ('KCL (Bolus)', 'Magnesium'), ('Ranitidine (Prophylaxis)', 'Magnesium'), ('OR Crystalloid Intake', 'Magnesium'), ('Albumin 5%', 'Magnesium'), ('OR Cell Saver Intake', 'Magnesium'), ('Morphine Sulfate', 'Magnesium'), ('Insulin - Regular', 'Hemoglobin'), ('Calcium Gluconate', 'Hemoglobin'), ('Magnesium Sulfate', 'Hemoglobin'), ('Potassium Chloride', 'Hemoglobin'), ('Cefazolin', 'Hemoglobin'), ('Magnesium Sulfate (Bolus)', 'Hemoglobin'), ('LR', 'Hemoglobin'), ('Packed Red Blood Cells', 'Hemoglobin'), ('OR Cell Saver Intake', 'Hemoglobin'), ('OR Crystalloid Intake', 'Hemoglobin'), ('Vancomycin', 'Hemoglobin'), ('Ranitidine (Prophylaxis)', 'Hemoglobin'), ('Morphine Sulfate', 'Hemoglobin'), ('KCL (Bolus)', 'Hemoglobin'), ('Albumin 5%', 'Hemoglobin'), ('Insulin - Regular', 'Red Blood Cells'), ('Calcium Gluconate', 'Red Blood Cells'), ('Magnesium Sulfate', 'Red Blood Cells'), ('Potassium Chloride', 'Red Blood Cells'), ('Cefazolin', 'Red Blood Cells'), ('Magnesium Sulfate (Bolus)', 'Red Blood Cells'), ('LR', 'Red Blood Cells'), ('Packed Red Blood Cells', 'Red Blood Cells'), ('OR Cell Saver Intake', 'Red Blood Cells'), ('OR Crystalloid Intake', 'Red Blood Cells'), ('Vancomycin', 'Red Blood Cells'), ('Ranitidine (Prophylaxis)', 'Red Blood Cells'), ('Morphine Sulfate', 'Red Blood Cells'), ('KCL (Bolus)', 'Red Blood Cells'), ('Albumin 5%', 'Red Blood Cells'), ('KCL (Bolus)', 'Base Excess'), ('Potassium Chloride', 'Base Excess'), ('Calcium Gluconate', 'Base Excess'), ('Packed Red Blood Cells', 'Base Excess'), ('Vancomycin', 'Base Excess'), ('Magnesium Sulfate', 'Base Excess'), ('Magnesium Sulfate (Bolus)', 'Base Excess'), ('Cefazolin', 'Base Excess'), ('Albumin 5%', 'Base Excess'), ('LR', 'Base Excess'), ('OR Cell Saver Intake', 'Base Excess'), ('OR Crystalloid Intake', 'Base Excess'), ('Insulin - Regular', 'Base Excess'), ('Ranitidine (Prophylaxis)', 'Base Excess'), ('Morphine Sulfate', 'Base Excess'), ('KCL (Bolus)', 'pO2'), ('Potassium Chloride', 'pO2'), ('Calcium Gluconate', 'pO2'), ('Packed Red Blood Cells', 'pO2'), ('Vancomycin', 'pO2'), ('Magnesium Sulfate', 'pO2'), ('Magnesium Sulfate (Bolus)', 'pO2'), ('Cefazolin', 'pO2'), ('Albumin 5%', 'pO2'), ('LR', 'pO2'), ('OR Cell Saver Intake', 'pO2'), ('OR Crystalloid Intake', 'pO2'), ('Insulin - Regular', 'pO2'), ('Ranitidine (Prophylaxis)', 'pO2'), ('Morphine Sulfate', 'pO2'), ('OR Cell Saver Intake', 'Glucose')])

# %%
p_data[('Insulin - Regular', 'Glucose')]['before_abs_1_4_sp'][0]
# Out:
#                             SUBJECT_ID  HADM_ID  before_abs_1_4_sp  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose          384   122988              112.0
#                   Glucose         7477   189745              131.0
#                   Glucose        21580   160948              158.0
#                   Glucose        42221   169763              112.0
#                   Glucose        17692   175081               98.0
# ...                                ...      ...                ...
#                   Glucose        96015   166722              148.0
#                   Glucose        65370   165569              125.0
#                   Glucose        77738   180834              150.0
#                   Glucose        43927   110958              133.0
#                   Glucose        99065   143271             1000.0
#
#                             after_abs_1_4_sp  after_time_1_4_sp    abs  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose              137.0           4.866667   25.0
#                   Glucose              117.0           4.400000  -14.0
#                   Glucose              341.0           4.783333  183.0
#                   Glucose              100.0           2.266667  -12.0
#                   Glucose              104.0           4.683333    6.0
# ...                                      ...                ...    ...
#                   Glucose              120.0           4.266667  -28.0
#                   Glucose              136.0           1.066667   11.0
#                   Glucose              176.0           1.283333   26.0
#                   Glucose              105.0           1.883333  -28.0
#                   Glucose              100.0           3.366667 -900.0
#
#                                percent     ratio
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose    22.321429  1.223214
#                   Glucose   -10.687023  0.893130
#                   Glucose   115.822785  2.158228
#                   Glucose   -10.714286  0.892857
#                   Glucose     6.122449  1.061224
# ...                                ...       ...
#                   Glucose   -18.918919  0.810811
#                   Glucose     8.800000  1.088000
#                   Glucose    17.333333  1.173333
#                   Glucose   -21.052632  0.789474
#                   Glucose   -90.000000  0.100000
#
# [78 rows x 8 columns]

# %%
import pickle
pickle.dump(p_data, open(f"plot_med_lab_bw_aw_data_{stratify_prefix}.pkl", "wb"))

# %%
# p_data = pickle.load(open(f"plot_med_lab_bw_aw_data_{stratify_prefix}.pkl", "rb"))

# %%
def int_s(s):
    if s[0]=="_":
        return int(s[1:])
    else:
        return int(s)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns

def sort_rows_with_time(p_corrs, s_corrs, after_windows):
    s_p = sorted([k for k in zip(p_corrs, after_windows)])
    p_corrs = [k[0] for k in s_p]
    after_windows1 = [k[1] for k in s_p]
    s_s = sorted([k for k in zip(s_corrs, after_windows)])
    s_corrs = [k[0] for k in s_s]
    after_windows2 = [k[1] for k in s_p]
    return p_corrs, s_corrs, after_windows1, after_windows2

def plot_corrs(corrs, after_windows, ax, title='', plot_name='',  after_window_info=None):

    p_corrs = [c[0] for c in corrs]
    s_corrs = [c[1] for c in corrs]
    final_plot_name = f'{plot_name}_{title}'
    after_windows = [int_s(a[-7:-5]) for a in after_windows]
    
    p_corrs, s_corrs, after_windows1, after_windows2 = sort_rows_with_time(p_corrs, s_corrs, after_windows)
    
    # print(ax, [ k for k in zip(p_corrs, after_windows)])
    # print(ax, [ k for k in zip(s_corrs, after_windows)])
    
    # ax.plot(after_windows, p_corrs)
    # ax.set_title(f'{final_plot_name} Pearsons Corr')
    # ax.set(xlabel='Time in hours', ylabel='Correlation')

    ax[0].plot(after_windows1, p_corrs, '-o')
    ax[0].set_title(f'{final_plot_name} Pearsons Corr')
    ax[0].set(xlabel='Time in hours', ylabel='Correlation')
    ax[0].set_xticks(after_windows1)
    ax[0].grid()
    # ax[0].grid(axis='x')

    ax[1].plot(after_windows2, s_corrs, '-o')
    ax[1].set_title(f'{final_plot_name} Spearmans Corr')
    ax[1].set(xlabel='Time in hours', ylabel='Correlation')
    ax[1].set_xticks(after_windows2)
    # ax[1].grid(axis='x')
    ax[1].grid()
    

def plot_func(presc, lab, d, dirname, window=(1,24), title='', unit='mg/dL', labels=None, plot_name='', ax=None):
    
    plot_data = d
    # plot_data = plot_data.rename(columns={0:'Lab values'})

    # plot_data = plot_data[plot_data['timeFromPrescription'] > window[0]]
    # plot_data = plot_data[plot_data['timeFromPrescription'] < window[1]]

    if ax is None:
        sns.regplot(x = "time", 
                y = 'data', 
                data = plot_data.sort_values(["time"]), 
                truncate=False)
        plt.title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        plt.xlabel('Time in hours')
        plt.ylabel(title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            plt.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))
        if not os.path.isdir(f"{lab}<>{presc}"):
            os.mkdir(f"{lab}<>{presc}")
        if dirname is None or dirname == "":
            plt.savefig(os.path.join(f"{lab}<>{presc}", plot_name+".png"))
        else:
            if not os.path.isdir(os.path.join(f"{lab}<>{presc}", dirname)):
                os.mkdir(os.path.join(f"{lab}<>{presc}", dirname))
            plt.savefig(os.path.join(f"{lab}<>{presc}", dirname, plot_name+".png"))
        plt.clf()
    
    else:
        sns.regplot(
                ax=ax,
                x = "time", 
                y = 'data', 
                data = plot_data.sort_values(["time"]), 
                truncate=False)
        ax.set_title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        ax.set(xlabel='Time in hours', ylabel=title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            ax.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))

def remove_outlier(val, time_diff):
    val = pd.DataFrame(val)
    time_diff = pd.DataFrame(time_diff)
    
    # IQR
    Q1 = np.percentile(val, 25, method = 'midpoint')        
    Q3 = np.percentile(val, 75, method = 'midpoint')
    IQR = Q3 - Q1        
    
    # Upper bound
    upper = np.where(val >= (Q3+1.5*IQR))
    # Lower bound
    lower = np.where(val <= (Q1-1.5*IQR))

    # Filtering
    if len(upper) > 0:
        val.drop(upper[0], inplace = True)
        time_diff.drop(upper[0], inplace = True)
    if len(lower) > 0:
        val.drop(lower[0], inplace = True)
        time_diff.drop(lower[0], inplace = True)
    return val, time_diff

# %%
plot_dir = os.path.join(os.getcwd(), f"plots_{stratify_prefix}")
os.mkdir(plot_dir)

# %%
types = ['abs', 'percent', 'ratio']
corrs_data_dict = []
for k, v in p_data.items():
    for key in v:
        lab = k[0]
        presc = k[1]
        before_window = int_s(key[-7:-5])

        fig_all, ax_all = plt.subplots(3, figsize=(20, 20))
        fig_all.suptitle(f'{lab}<>{presc} (before window = {str(before_window)})')

        if not os.path.isdir(os.path.join(plot_dir, f"{lab}<>{presc}")):
            os.mkdir(os.path.join(plot_dir, f"{lab}<>{presc}"))
        
        dirname=f"bw_{int_s(key[-7:-5])}"
        if not os.path.isdir(os.path.join(plot_dir, f"{lab}<>{presc}", dirname)):
            os.mkdir(os.path.join(plot_dir, f"{lab}<>{presc}", dirname))

        for i, type in enumerate(types):
            plot_name = f"{k[0]}<>{k[1]}_{key}_{type}"
            data_vals = [d[[list(d.columns)[-4], type]].rename(columns={list(d.columns)[-4] : "time"}) for d in v[key]]
            after_names = [list(d.columns)[3] for d in v[key]]
            print("checking", len(data_vals), len(after_names))
            if len(data_vals)!=len(after_names):
                print(data_vals)
                print(after_names)
                print()
                continue
            
            d = pd.concat(data_vals)
            if d.shape[0]<2:
                continue
            if d.shape[0]>1:
                d1, d2 = remove_outlier(d[type], d["time"])
            else:
                d1, d2 = d[[type]], d[["time"]]
            d = pd.concat([d1, d2], axis=1)

            p_corr, _ = pearsonr(d1[type], d2["time"])
            s_corr, _ = spearmanr(d1[type], d2["time"])

            plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname="", labels=(p_corr, s_corr), title=f"bw({int_s(key[-7:-5])}) {type}", plot_name=f"{plot_name}", ax=ax_all[i])

            fig_corrs, ax_corrs = plt.subplots(2, figsize=(20, 20))
            fig_corrs.suptitle(f'{lab}<>{presc} {type} corrs') 
            corrs = []
            temp_after_names = after_names.copy()
            for i, d in enumerate(data_vals):
                if d.shape[0]<2:
                    temp_after_names.remove(after_names[i])
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])
                corrs.append((p_corr, s_corr))
            after_names = temp_after_names
            plot_corrs(corrs, after_names, ax_corrs, title=type, plot_name=plot_name)
            fig_corrs.savefig(os.path.join(plot_dir, f"{lab}<>{presc}", dirname, f"{plot_name}_{type}_{stratify_prefix}_corrs.png"))
            fig_corrs.clf()

            for d, a, c in zip(data_vals, after_names, corrs):
                if d.shape[0]<2:
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                d = pd.concat([d1, d2], axis=1)

                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])

                plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname=dirname, labels=c, title=f"bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])}) {type}", plot_name=f"{plot_name} bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])})")
                corrs_data_dict.append({
                    "lab" : lab,
                    "med": presc,
                    "bw": before_window,
                    "aw": int_s(a[-7:-5]),
                    "type": type,
                    "p_corr": p_corr,
                    "s_corr": s_corr,
                    "num": d.shape[0]
                })
                    
        fig_all.savefig(os.path.join(plot_dir, f"{lab}<>{presc}", dirname, f"{plot_name}_{stratify_prefix}.png"))
        fig_all.clf()
corrs_data_df = pd.DataFrame(corrs_data_dict)
corrs_data_df.to_csv(os.path.join(plot_dir, f"corrs_data_{stratify_prefix}.csv"))
# Out:
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_42441/694131616.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig_all, ax_all = plt.subplots(3, figsize=(20, 20))
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 4 4
# checking 4 4
# checking 4 4
# checking 5 5
# checking 5 5
# checking 5 5
# checking 2 2
# checking 2 2
# checking 2 2
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 6 6
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 6 6
# checking 6 6
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 3 3
# checking 3 3
# checking 3 3
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 3 3
# checking 3 3
# checking 3 3
# checking 5 5
# checking 5 5
# checking 5 5
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 3 3
# checking 3 3
# checking 3 3
# checking 5 5
# checking 5 5
# checking 5 5
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 4 4
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 5 5
# checking 5 5
# checking 5 5
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 6 6
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 6 6
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 5 5
# checking 5 5
# checking 5 5
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 6 6
# checking 6 6
# checking 6 6
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 4 4
# checking 4 4
# checking 4 4
# checking 3 3
# checking 3 3
# checking 3 3
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7
# checking 7 7

# %%
corrs_data_df
# Out:
#                         lab         med  bw  aw   type    p_corr    s_corr  \
# 0         Insulin - Regular  Hematocrit   1   1    abs  0.207681  0.092241
# 1         Insulin - Regular  Hematocrit   1   5    abs  0.205236  0.339426
# 2         Insulin - Regular  Hematocrit   1   9    abs -0.254257 -0.303571
# 3         Insulin - Regular  Hematocrit   1  13    abs -0.359681 -0.142857
# 4         Insulin - Regular  Hematocrit   1  17    abs -0.486780 -0.475929
# ...                     ...         ...  ..  ..    ...       ...       ...
# 13657  OR Cell Saver Intake     Glucose   0   9  ratio -0.212536 -0.173290
# 13658  OR Cell Saver Intake     Glucose   0  13  ratio -0.343709 -0.268629
# 13659  OR Cell Saver Intake     Glucose   0  17  ratio -0.065799 -0.039318
# 13660  OR Cell Saver Intake     Glucose   0  21  ratio  0.197527  0.264706
# 13661  OR Cell Saver Intake     Glucose   0   0  ratio  0.198328  0.168357
#
#        num
# 0       73
# 1       24
# 2       15
# 3        6
# 4       13
# ...    ...
# 13657   38
# 13658   33
# 13659   31
# 13660   17
# 13661   40
#
# [13662 rows x 8 columns]

# %%
corrs_data_df[corrs_data_df["num"]>50].sort_values(["p_corr"]).head(30)
# Out:
#                              lab          med  bw  aw     type    p_corr  \
# 13577       OR Cell Saver Intake      Glucose   1   0    ratio -0.339414
# 13570       OR Cell Saver Intake      Glucose   1   0  percent -0.339414
# 601                   Vancomycin   Hematocrit   9   5      abs -0.336069
# 4395           Magnesium Sulfate    Magnesium   5   1      abs -0.335547
# 13563       OR Cell Saver Intake      Glucose   1   0      abs -0.334681
# 615                   Vancomycin   Hematocrit   9   5    ratio -0.317546
# 608                   Vancomycin   Hematocrit   9   5  percent -0.317546
# 4409           Magnesium Sulfate    Magnesium   5   1    ratio -0.303051
# 4402           Magnesium Sulfate    Magnesium   5   1  percent -0.303051
# 10806       OR Cell Saver Intake  Base Excess   1   1      abs -0.302422
# 3698       OR Crystalloid Intake      Glucose   5   9      abs -0.290676
# 3272                 KCL (Bolus)      Glucose   1   1    ratio -0.288382
# 3265                 KCL (Bolus)      Glucose   1   1  percent -0.288382
# 10332  Magnesium Sulfate (Bolus)  Base Excess   9   1      abs -0.280719
# 705            Magnesium Sulfate   Hematocrit   1  13      abs -0.280657
# 2769                   Cefazolin      Glucose   5   1      abs -0.274753
# 12352  Magnesium Sulfate (Bolus)          pO2   1  17      abs -0.256761
# 13018      OR Crystalloid Intake          pO2   1   0  percent -0.256183
# 13025      OR Crystalloid Intake          pO2   1   0    ratio -0.256183
# 2781                   Cefazolin      Glucose   5   1    ratio -0.253035
# 2775                   Cefazolin      Glucose   5   1  percent -0.253035
# 849    Magnesium Sulfate (Bolus)   Hematocrit   1  13      abs -0.248626
# 3712       OR Crystalloid Intake      Glucose   5   9    ratio -0.248287
# 3705       OR Crystalloid Intake      Glucose   5   9  percent -0.248287
# 4375           Magnesium Sulfate    Magnesium   1   5      abs -0.245380
# 4389           Magnesium Sulfate    Magnesium   1   5    ratio -0.242437
# 4382           Magnesium Sulfate    Magnesium   1   5  percent -0.242437
# 2620          Potassium Chloride      Glucose   1   1  percent -0.237884
# 2627          Potassium Chloride      Glucose   1   1    ratio -0.237884
# 10185          Magnesium Sulfate  Base Excess   9   1      abs -0.234961
#
#          s_corr  num
# 13577 -0.320977   67
# 13570 -0.320977   67
# 601   -0.272804   61
# 4395  -0.299572   58
# 13563 -0.309124   67
# 615   -0.274517   61
# 608   -0.274517   61
# 4409  -0.290748   58
# 4402  -0.290284   58
# 10806 -0.328888   83
# 3698  -0.234647   57
# 3272  -0.295602   89
# 3265  -0.295602   89
# 10332 -0.366382   54
# 705   -0.212829   60
# 2769  -0.215290   66
# 12352 -0.125569   51
# 13018 -0.230607  126
# 13025 -0.230607  126
# 2781  -0.226781   66
# 2775  -0.226781   66
# 849   -0.183164   56
# 3712  -0.255052   57
# 3705  -0.255052   57
# 4375  -0.220806   62
# 4389  -0.231912   62
# 4382  -0.231912   62
# 2620  -0.276769   97
# 2627  -0.276769   97
# 10185 -0.303152   55

# %%
corrs_data_df[corrs_data_df["num"]>50].sort_values(["p_corr"]).tail(30)
# Out:
#                           lab          med  bw  aw     type    p_corr  \
# 139         Calcium Gluconate   Hematocrit   1   5      abs  0.233159
# 14          Insulin - Regular   Hematocrit   1   1    ratio  0.233306
# 7           Insulin - Regular   Hematocrit   1   1  percent  0.233306
# 2338               Vancomycin      Glucose   1   9    ratio  0.240507
# 2331               Vancomycin      Glucose   1   9  percent  0.240507
# 174         Calcium Gluconate   Hematocrit   5   5    ratio  0.243070
# 167         Calcium Gluconate   Hematocrit   5   5  percent  0.243070
# 11893       Calcium Gluconate          pO2   0   1  percent  0.254735
# 11900       Calcium Gluconate          pO2   0   1    ratio  0.254735
# 160         Calcium Gluconate   Hematocrit   5   5      abs  0.254919
# 2654       Potassium Chloride      Glucose   5   0    ratio  0.267463
# 2647       Potassium Chloride      Glucose   5   0  percent  0.267463
# 2493        Magnesium Sulfate      Glucose   5  13      abs  0.272489
# 7005               Vancomycin   Hemoglobin   5   1      abs  0.272891
# 12125              Vancomycin          pO2  13   5  percent  0.276022
# 12132              Vancomycin          pO2  13   5    ratio  0.276022
# 10172       Magnesium Sulfate  Base Excess   5   5  percent  0.278351
# 10179       Magnesium Sulfate  Base Excess   5   5    ratio  0.278351
# 11088       Insulin - Regular  Base Excess   5   1      abs  0.287900
# 1400   Packed Red Blood Cells   Hematocrit   5   1    ratio  0.293223
# 1393   Packed Red Blood Cells   Hematocrit   5   1  percent  0.293223
# 7012               Vancomycin   Hemoglobin   5   1  percent  0.305237
# 7019               Vancomycin   Hemoglobin   5   1    ratio  0.305237
# 11346        Morphine Sulfate  Base Excess   5   1      abs  0.307882
# 13184       Insulin - Regular          pO2   5   1    ratio  0.311137
# 13177       Insulin - Regular          pO2   5   1  percent  0.311137
# 1386   Packed Red Blood Cells   Hematocrit   5   1      abs  0.316862
# 13437        Morphine Sulfate          pO2   5   1      abs  0.319939
# 13170       Insulin - Regular          pO2   5   1      abs  0.323787
# 12118              Vancomycin          pO2  13   5      abs  0.374556
#
#          s_corr  num
# 139    0.219486   80
# 14     0.077261   73
# 7      0.077261   73
# 2338   0.212358   53
# 2331   0.212358   53
# 174    0.254069   61
# 167    0.254069   61
# 11893  0.168640   54
# 11900  0.168640   54
# 160    0.251980   61
# 2654   0.192702   55
# 2647   0.192702   55
# 2493   0.235173   56
# 7005   0.312721   55
# 12125  0.289096   53
# 12132  0.289096   53
# 10172  0.161797   52
# 10179  0.161797   52
# 11088  0.300098   55
# 1400   0.263745   65
# 1393   0.263745   65
# 7012   0.327506   55
# 7019   0.327506   55
# 11346  0.279378   57
# 13184  0.314214   66
# 13177  0.314214   66
# 1386   0.278535   65
# 13437  0.255775   72
# 13170  0.336705   66
# 12118  0.340915   53

# %%
# corrs_data_df.to_csv(os.path.join(plot_dir, f"corrs_data_{stratify_prefix}.csv"))
