# %%
data = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/data"
res = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/results"

# %%
import pandas as pd
import os

# %% [markdown]
# ## Lab Patient Data

# %%
l_p_df = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_patient_data.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_33520/3804067241.py:1: DtypeWarning: Columns (19,24,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   l_p_df = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_patient_data.csv"))

# %%
l_p_df = l_p_df.drop(columns=["Unnamed: 0"])

# %%
l_p_df["LabTimeFromAdmit"] = pd.to_datetime(l_p_df["CHARTTIME"])-pd.to_datetime(l_p_df["ADMITTIME"])

# %%
l_p_df
# Out:
#           ROW_ID_x  SUBJECT_ID_x   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              976             3  145834.0   50820  2101-10-22 04:31:00  7.40
# 1              989             3  145834.0   50820  2101-10-22 07:13:00  7.37
# 2              998             3  145834.0   50820  2101-10-22 10:16:00  7.37
# 3             1007             3  145834.0   50820  2101-10-22 11:21:00  7.39
# 4             1020             3  145834.0   50820  2101-10-22 13:02:00  7.39
# ...            ...           ...       ...     ...                  ...   ...
# 22245029  11174338         18054  100572.0   51455  2158-04-24 11:42:00    29
# 22245030  11174339         18054  100572.0   51457  2158-04-24 11:42:00   575
# 22245031  11174340         18054  100572.0   51458  2158-04-24 11:42:00  1325
# 22245032  11174335         18054  100572.0   51447  2158-04-24 11:42:00    10
# 22245033  11174333         18054  100572.0   51444  2158-04-24 11:42:00    31
#
#           VALUENUM VALUEUOM      FLAG  ROW_ID_y  ... LANGUAGE  RELIGION  \
# 0             7.40    units       NaN        21  ...      NaN  CATHOLIC
# 1             7.37    units       NaN        21  ...      NaN  CATHOLIC
# 2             7.37    units       NaN        21  ...      NaN  CATHOLIC
# 3             7.39    units       NaN        21  ...      NaN  CATHOLIC
# 4             7.39    units       NaN        21  ...      NaN  CATHOLIC
# ...            ...      ...       ...       ...  ...      ...       ...
# 22245029     29.00        %  abnormal       655  ...     ENGL  CATHOLIC
# 22245030    575.00     #/uL  abnormal       657  ...     ENGL  CATHOLIC
# 22245031   1325.00     #/uL  abnormal       658  ...     ENGL  CATHOLIC
# 22245032     10.00        %  abnormal       647  ...     ENGL  CATHOLIC
# 22245033     31.00        %  abnormal       644  ...     ENGL  CATHOLIC
#
#          MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0               MARRIED     WHITE  2101-10-20 17:09:00  2101-10-20 19:24:00
# 1               MARRIED     WHITE  2101-10-20 17:09:00  2101-10-20 19:24:00
# 2               MARRIED     WHITE  2101-10-20 17:09:00  2101-10-20 19:24:00
# 3               MARRIED     WHITE  2101-10-20 17:09:00  2101-10-20 19:24:00
# 4               MARRIED     WHITE  2101-10-20 17:09:00  2101-10-20 19:24:00
# ...                 ...       ...                  ...                  ...
# 22245029        MARRIED     WHITE                  NaN                  NaN
# 22245030        MARRIED     WHITE                  NaN                  NaN
# 22245031        MARRIED     WHITE                  NaN                  NaN
# 22245032        MARRIED     WHITE                  NaN                  NaN
# 22245033        MARRIED     WHITE                  NaN                  NaN
#
#                            DIAGNOSIS HOSPITAL_EXPIRE_FLAG  \
# 0                        HYPOTENSION                    0
# 1                        HYPOTENSION                    0
# 2                        HYPOTENSION                    0
# 3                        HYPOTENSION                    0
# 4                        HYPOTENSION                    0
# ...                              ...                  ...
# 22245029  PLEURAL EFFUSION RIGHT/SDA                    0
# 22245030  PLEURAL EFFUSION RIGHT/SDA                    0
# 22245031  PLEURAL EFFUSION RIGHT/SDA                    0
# 22245032  PLEURAL EFFUSION RIGHT/SDA                    0
# 22245033  PLEURAL EFFUSION RIGHT/SDA                    0
#
#          HAS_CHARTEVENTS_DATA LabTimeFromAdmit
# 0                           1  1 days 09:23:00
# 1                           1  1 days 12:05:00
# 2                           1  1 days 15:08:00
# 3                           1  1 days 16:13:00
# 4                           1  1 days 17:54:00
# ...                       ...              ...
# 22245029                    0  0 days 02:57:00
# 22245030                    0  0 days 02:57:00
# 22245031                    0  0 days 02:57:00
# 22245032                    0  0 days 02:57:00
# 22245033                    0  0 days 02:57:00
#
# [22245034 rows x 33 columns]

# %% [markdown]
# ## Medication Patient Data

# %%
m_p_df = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med_patient_data.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_33520/3908620283.py:1: DtypeWarning: Columns (13,19,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   m_p_df = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med_patient_data.csv"))

# %%
m_p_df = m_p_df.drop(columns=["Unnamed: 0"]).rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})

# %%
m_p_df["MedTimeFromAdmit"] = pd.to_datetime(m_p_df["ENDTIME"])-pd.to_datetime(m_p_df["ADMITTIME"])

# %%
m_p_df = m_p_df.sort_values(by="MedTimeFromAdmit")

# %%
m_p_df
# Out:
#          Unnamed: 0.2  Unnamed: 0.1  ROW_ID_x  SUBJECT_ID  HADM_ID  \
# 2888398       2888398       2888398    141679        1339   158998
# 1771130       1771130       1771130    141722        1339   158998
# 1267803       1267803       1267803    141697        1339   158998
# 2888396       2888396       2888396    141636        1339   158998
# 1771128       1771128       1771128    141688        1339   158998
# ...               ...           ...       ...         ...      ...
# 2071107       2071107       2071107   3117387       53863   136210
# 2622088       2622088       2622088   3117386       53863   136210
# 1522100       1522100       1522100    647177       51914   128777
# 744855         744855        744855    647178       51914   128777
# 810827         810827        810827   1049249       50822   125824
#
#          ICUSTAY_ID            STARTTIME              ENDTIME  ITEMID  \
# 2888398    248434.0  2138-10-12 00:00:00  2138-10-12 00:01:00  221385
# 1771130    248434.0  2138-10-12 00:30:00  2138-10-12 00:31:00  221744
# 1267803    248434.0  2138-10-12 01:00:00  2138-10-12 02:16:00  225828
# 2888396    248434.0  2138-10-12 07:00:00  2138-10-12 07:01:00  221385
# 1771128    248434.0  2138-10-12 08:00:00  2138-10-12 08:01:00  221744
# ...             ...                  ...                  ...     ...
# 2071107    291819.0  2161-02-21 22:45:00  2162-01-08 11:15:00  225943
# 2622088    291819.0  2161-02-21 22:45:00  2162-01-08 11:15:00  225942
# 1522100    283771.0  2132-03-25 16:00:00  2133-03-09 19:00:00  221906
# 744855     283771.0  2132-03-25 16:00:00  2133-03-09 19:00:00  225158
# 810827     263713.0  2164-11-02 21:00:00  2166-02-12 02:19:00  225158
#
#               AMOUNT  ... ROW_ID                   LABEL  \
# 2888398     1.000000  ...  12964      Lorazepam (Ativan)
# 1771130    49.999999  ...  12977                Fentanyl
# 1267803    95.000000  ...  14005                      LR
# 2888396     1.000000  ...  12964      Lorazepam (Ativan)
# 1771128    24.999999  ...  12977                Fentanyl
# ...              ...  ...    ...                     ...
# 2071107    30.773265  ...  14375                Solution
# 2622088     1.538663  ...  14374  Fentanyl (Concentrate)
# 1522100     7.758037  ...  12984          Norepinephrine
# 744855    242.438728  ...  13758               NaCl 0.9%
# 810827   4610.930268  ...  13758               NaCl 0.9%
#
#                    ABBREVIATION    DBSOURCE         LINKSTO       CATEGORY  \
# 2888398      Lorazepam (Ativan)  metavision  inputevents_mv    Medications
# 1771130                Fentanyl  metavision  inputevents_mv    Medications
# 1267803                      LR  metavision  inputevents_mv  Fluids/Intake
# 2888396      Lorazepam (Ativan)  metavision  inputevents_mv    Medications
# 1771128                Fentanyl  metavision  inputevents_mv    Medications
# ...                         ...         ...             ...            ...
# 2071107                Solution  metavision  inputevents_mv  Fluids/Intake
# 2622088  Fentanyl (Concentrate)  metavision  inputevents_mv    Medications
# 1522100          Norepinephrine  metavision  inputevents_mv    Medications
# 744855                NaCl 0.9%  metavision  inputevents_mv  Fluids/Intake
# 810827                NaCl 0.9%  metavision  inputevents_mv  Fluids/Intake
#
#          UNITNAME PARAM_TYPE CONCEPTID  MedTimeFromAdmit
# 2888398        mg   Solution       NaN -2 days +12:37:00
# 1771130        mg   Solution       NaN -2 days +13:07:00
# 1267803        mL   Solution       NaN -2 days +14:52:00
# 2888396        mg   Solution       NaN -2 days +19:37:00
# 1771128        mg   Solution       NaN -2 days +20:37:00
# ...           ...        ...       ...               ...
# 2071107        mL   Solution       NaN 321 days 11:09:00
# 2622088        mg   Solution       NaN 321 days 11:09:00
# 1522100        mg   Solution       NaN 363 days 03:29:00
# 744855         mL   Solution       NaN 363 days 03:29:00
# 810827         mL   Solution       NaN 483 days 10:14:00
#
# [3618991 rows x 61 columns]

# %% [markdown]
# ## Filter Meds

# %% [markdown]
# ### Med 1

# %%
med1 = m_p_df.groupby(["HADM_ID", "ITEMID"]).nth(0).reset_index()

# %%
med1 = med1.sort_values("MedTimeFromAdmit")

# %%
# med1[['HADM_ID', 'ITEMID', 'ROW_ID_x', 'SUBJECT_ID_x', 'ICUSTAY_ID',
#        'STARTTIME', 'ENDTIME', 'AMOUNT', 'AMOUNTUOM', 'RATE', 'RATEUOM', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'MedTimeFromAdmit']]

# %%
med1 = med1[med1["MedTimeFromAdmit"].dt.total_seconds()>0]

# %%
med1 = med1.sort_values(by=["ADMITTIME"]).groupby(["SUBJECT_ID", "ITEMID"]).nth(0).reset_index().sort_values(by=["MedTimeFromAdmit"])

# %%
med1
# Out:
#         SUBJECT_ID  ITEMID  HADM_ID  Unnamed: 0.2  Unnamed: 0.1  ROW_ID_x  \
# 28897        29495  225828   182822       1266022       1266022      2947
# 199105       73363  225943   174481       1940648       1940648   1266630
# 71788        47216  225158   167377       1032728       1032728   2598902
# 77294        48348  226372   186981       3464223       3464223   1947331
# 77293        48348  226364   186981       2923674       2923674   1947274
# ...            ...     ...      ...           ...           ...       ...
# 291587       93321  225917   115396       3320414       3320414   3599650
# 291596       93321  226453   115396       1237197       1237197   3599538
# 291567       93321  225797   115396       1264937       1264937   3599579
# 291588       93321  225930   115396       3291211       3291211   3599677
# 291556       93321  221794   115396       1385156       1385156   3599952
#
#         ICUSTAY_ID            STARTTIME              ENDTIME       AMOUNT  \
# 28897     252299.0  2126-01-22 21:51:00  2126-01-22 21:52:00  1000.000000
# 199105    288413.0  2144-01-31 12:21:00  2144-01-31 14:01:00    64.516127
# 71788     246025.0  2155-08-01 11:26:00  2155-08-01 11:27:00  1500.000000
# 77294     274006.0  2177-11-28 12:00:00  2177-11-28 12:01:00   250.000000
# 77293     274006.0  2177-11-28 12:00:00  2177-11-28 12:01:00  2700.000000
# ...            ...                  ...                  ...          ...
# 291587    248745.0  2128-09-11 21:46:00  2128-09-12 13:47:00  2500.000081
# 291596    248745.0  2128-09-12 21:22:00  2128-09-12 21:23:00    60.000000
# 291567    248745.0  2128-09-14 17:58:00  2128-09-14 17:59:00   100.000000
# 291588    248745.0  2128-09-14 15:33:00  2128-09-14 18:43:00    31.666667
# 291556    248745.0  2128-09-16 14:06:00  2128-09-16 14:07:00    20.000001
#
#         ... ROW_ID                  LABEL           ABBREVIATION    DBSOURCE  \
# 28897   ...  14005                     LR                     LR  metavision
# 199105  ...  14375               Solution               Solution  metavision
# 71788   ...  13758              NaCl 0.9%              NaCl 0.9%  metavision
# 77294   ...  14457   OR Cell Saver Intake   OR Cell Saver Intake  metavision
# 77293   ...  14450  OR Crystalloid Intake  OR Crystalloid Intake  metavision
# ...     ...    ...                    ...                    ...         ...
# 291587  ...  14355     TPN without Lipids     TPN without Lipids  metavision
# 291596  ...  14472               GT Flush               GT Flush  metavision
# 291567  ...  13981             Free Water             Free Water  metavision
# 291588  ...  14367    Peptamen 1.5 (Full)    Peptamen 1.5 (Full)  metavision
# 291556  ...  12979     Furosemide (Lasix)     Furosemide (Lasix)  metavision
#
#                LINKSTO                 CATEGORY  UNITNAME PARAM_TYPE  \
# 28897   inputevents_mv            Fluids/Intake        mL   Solution
# 199105  inputevents_mv            Fluids/Intake        mL   Solution
# 71788   inputevents_mv            Fluids/Intake        mL   Solution
# 77294   inputevents_mv  Blood Products/Colloids        mL   Solution
# 77293   inputevents_mv            Fluids/Intake        mL   Solution
# ...                ...                      ...       ...        ...
# 291587  inputevents_mv   Nutrition - Parenteral        mL   Solution
# 291596  inputevents_mv            Fluids/Intake        mL   Solution
# 291567  inputevents_mv            Fluids/Intake        mL   Solution
# 291588  inputevents_mv      Nutrition - Enteral        mL   Solution
# 291556  inputevents_mv              Medications        mg   Solution
#
#        CONCEPTID  MedTimeFromAdmit
# 28897        NaN   0 days 00:01:00
# 199105       NaN   0 days 00:01:00
# 71788        NaN   0 days 00:01:00
# 77294        NaN   0 days 00:01:00
# 77293        NaN   0 days 00:01:00
# ...          ...               ...
# 291587       NaN 171 days 14:46:00
# 291596       NaN 171 days 22:22:00
# 291567       NaN 173 days 18:58:00
# 291588       NaN 173 days 19:42:00
# 291556       NaN 175 days 15:06:00
#
# [323007 rows x 61 columns]

# %% [markdown]
# ### Med 2

# %%
med2 = m_p_df.groupby(["HADM_ID", "ITEMID"]).nth(1).reset_index()

# %%
med2 = med2.sort_values("MedTimeFromAdmit")

# %%
med2 = med2[med2["MedTimeFromAdmit"].dt.total_seconds()>0]

# %%
med2 = med2.sort_values(by=["ADMITTIME"]).groupby(["SUBJECT_ID", "ITEMID"]).nth(0).reset_index().sort_values(by=["MedTimeFromAdmit"])

# %%
med2
# Out:
#         SUBJECT_ID  ITEMID  HADM_ID  Unnamed: 0.2  Unnamed: 0.1  ROW_ID_x  \
# 35719        42353  225828   171342       1289857       1289857   1671151
# 231522       98281  225158   117684        878463        878463   1549345
# 220822       95238  225828   110402       1273081       1273081    546286
# 33451        41624  226372   178751       3464007       3464007   1538868
# 172779       81202  220949   105280        335419        335419   1614569
# ...            ...     ...      ...           ...           ...       ...
# 214311       93321  225912   115396       3356454       3356454   3599562
# 214320       93321  226453   115396       1237194       1237194   3599939
# 214312       93321  225917   115396       3320412       3320412   3599685
# 214313       93321  225930   115396       3291212       3291212   3599948
# 214294       93321  225797   115396       1264938       1264938   3599629
#
#         ICUSTAY_ID            STARTTIME              ENDTIME       AMOUNT  \
# 35719     280877.0  2188-07-28 12:45:00  2188-07-28 12:46:00  1000.000000
# 231522    251214.0  2134-03-30 16:30:00  2134-03-30 17:46:00     3.800000
# 220822    223406.0  2161-04-20 11:45:00  2161-04-20 11:46:00  1000.000000
# 33451     277546.0  2162-05-06 11:00:00  2162-05-06 11:01:00   600.000000
# 172779    272451.0  2103-06-10 08:00:00  2103-06-10 08:01:00   200.000000
# ...            ...                  ...                  ...          ...
# 214311    248745.0  2128-09-12 23:28:00  2128-09-12 23:29:00     1.000000
# 214320    248745.0  2128-09-13 08:00:00  2128-09-13 08:01:00    30.000000
# 214312    248745.0  2128-09-12 18:46:00  2128-09-13 18:47:00  2499.999978
# 214313    248745.0  2128-09-14 18:43:00  2128-09-15 08:22:00   273.000005
# 214294    248745.0  2128-09-15 11:03:00  2128-09-15 11:04:00   100.000000
#
#         ... ROW_ID                  LABEL           ABBREVIATION    DBSOURCE  \
# 35719   ...  14005                     LR                     LR  metavision
# 231522  ...  13758              NaCl 0.9%              NaCl 0.9%  metavision
# 220822  ...  14005                     LR                     LR  metavision
# 33451   ...  14457   OR Cell Saver Intake   OR Cell Saver Intake  metavision
# 172779  ...  12865            Dextrose 5%            Dextrose 5%  metavision
# ...     ...    ...                    ...                    ...         ...
# 214311  ...  14065  Carafate (Sucralfate)  Carafate (Sucralfate)  metavision
# 214320  ...  14472               GT Flush               GT Flush  metavision
# 214312  ...  14355     TPN without Lipids     TPN without Lipids  metavision
# 214313  ...  14367    Peptamen 1.5 (Full)    Peptamen 1.5 (Full)  metavision
# 214294  ...  13981             Free Water             Free Water  metavision
#
#                LINKSTO                 CATEGORY  UNITNAME PARAM_TYPE  \
# 35719   inputevents_mv            Fluids/Intake        mL   Solution
# 231522  inputevents_mv            Fluids/Intake        mL   Solution
# 220822  inputevents_mv            Fluids/Intake        mL   Solution
# 33451   inputevents_mv  Blood Products/Colloids        mL   Solution
# 172779  inputevents_mv            Fluids/Intake        mL   Solution
# ...                ...                      ...       ...        ...
# 214311  inputevents_mv              Medications      dose   Solution
# 214320  inputevents_mv            Fluids/Intake        mL   Solution
# 214312  inputevents_mv   Nutrition - Parenteral        mL   Solution
# 214313  inputevents_mv      Nutrition - Enteral        mL   Solution
# 214294  inputevents_mv            Fluids/Intake        mL   Solution
#
#        CONCEPTID  MedTimeFromAdmit
# 35719        NaN   0 days 00:01:00
# 231522       NaN   0 days 00:01:00
# 220822       NaN   0 days 00:01:00
# 33451        NaN   0 days 00:01:00
# 172779       NaN   0 days 00:01:00
# ...          ...               ...
# 214311       NaN 172 days 00:28:00
# 214320       NaN 172 days 09:00:00
# 214312       NaN 172 days 19:46:00
# 214313       NaN 174 days 09:21:00
# 214294       NaN 174 days 12:03:00
#
# [237607 rows x 61 columns]

# %% [markdown]
# ## Filter Labs

# %%
labs = l_p_df[l_p_df["HADM_ID"].isin(med1["HADM_ID"])]

# %%
labs = labs[labs['LabTimeFromAdmit'].dt.total_seconds()>0]

# %%
labs = labs.sort_values("LabTimeFromAdmit")

# %%
labs = labs[labs['VALUENUM'].notna()]

# %%
labs
# Out:
#           ROW_ID_x  SUBJECT_ID_x   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 14822987  21075805         48882  103146.0   50813  2114-04-23 18:17:00   2.5
# 20517708  27458475         96686  189846.0   51077  2115-04-11 18:50:00   2.9
# 20517709  27458479         96686  189846.0   51097  2115-04-11 18:50:00    25
# 13665680  20690955         46007  178313.0   50893  2138-05-11 14:30:00   7.6
# 18193731  26566842         89929  118735.0   50820  2169-02-09 16:24:00  7.32
# ...            ...           ...       ...     ...                  ...   ...
# 19106318  27017123         93321  115396.0   50813  2128-10-17 05:33:00   5.4
# 19106344  27017124         93321  115396.0   50818  2128-10-17 05:33:00    38
# 19106369  27017126         93321  115396.0   50821  2128-10-17 05:33:00   117
# 19106282  27017122         93321  115396.0   50804  2128-10-17 05:33:00    13
# 19106228  27017125         93321  115396.0   50820  2128-10-17 05:33:00  7.11
#
#           VALUENUM VALUEUOM      FLAG  ROW_ID_y  ... LANGUAGE       RELIGION  \
# 14822987      2.50   mmol/L  abnormal        14  ...     ENGL       CATHOLIC
# 20517708      2.90    mg/dL       NaN       277  ...     ENGL  NOT SPECIFIED
# 20517709     25.00    mEq/L       NaN       297  ...     ENGL  NOT SPECIFIED
# 13665680      7.60    mg/dL  abnormal        94  ...     ENGL  NOT SPECIFIED
# 18193731      7.32    units  abnormal        21  ...     ENGL   UNOBTAINABLE
# ...            ...      ...       ...       ...  ...      ...            ...
# 19106318      5.40   mmol/L  abnormal        14  ...      NaN       CATHOLIC
# 19106344     38.00    mm Hg       NaN        19  ...      NaN       CATHOLIC
# 19106369    117.00    mm Hg  abnormal        22  ...      NaN       CATHOLIC
# 19106282     13.00    mEq/L  abnormal         5  ...      NaN       CATHOLIC
# 19106228      7.11    units  abnormal        21  ...      NaN       CATHOLIC
#
#          MARITAL_STATUS               ETHNICITY            EDREGTIME  \
# 14822987        MARRIED                   WHITE                  NaN
# 20517708         SINGLE  BLACK/AFRICAN AMERICAN  2115-04-11 12:29:00
# 20517709         SINGLE  BLACK/AFRICAN AMERICAN  2115-04-11 12:29:00
# 13665680        MARRIED                   WHITE  2138-05-11 11:41:00
# 18193731            NaN   UNKNOWN/NOT SPECIFIED  2169-02-09 15:00:00
# ...                 ...                     ...                  ...
# 19106318        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106344        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106369        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106282        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106228        WIDOWED                   WHITE  2128-03-24 22:29:00
#
#                     EDOUTTIME               DIAGNOSIS HOSPITAL_EXPIRE_FLAG  \
# 14822987                  NaN         AORTIC STENOSIS                    1
# 20517708  2115-04-11 20:40:00     ACUTE RENAL FAILURE                    0
# 20517709  2115-04-11 20:40:00     ACUTE RENAL FAILURE                    0
# 13665680  2138-05-11 15:28:00  MULITPLE RIB FRACTURES                    0
# 18193731  2169-02-09 18:11:00    OVERDOSE ON DEPAKOTE                    0
# ...                       ...                     ...                  ...
# 19106318  2128-03-25 00:19:00                  ANEMIA                    1
# 19106344  2128-03-25 00:19:00                  ANEMIA                    1
# 19106369  2128-03-25 00:19:00                  ANEMIA                    1
# 19106282  2128-03-25 00:19:00                  ANEMIA                    1
# 19106228  2128-03-25 00:19:00                  ANEMIA                    1
#
#          HAS_CHARTEVENTS_DATA  LabTimeFromAdmit
# 14822987                    1   0 days 00:01:00
# 20517708                    1   0 days 00:01:00
# 20517709                    1   0 days 00:01:00
# 13665680                    1   0 days 00:01:00
# 18193731                    1   0 days 00:01:00
# ...                       ...               ...
# 19106318                    1 206 days 06:32:00
# 19106344                    1 206 days 06:32:00
# 19106369                    1 206 days 06:32:00
# 19106282                    1 206 days 06:32:00
# 19106228                    1 206 days 06:32:00
#
# [7260285 rows x 33 columns]

# %% [markdown]
# ## Pairs

# %%
counts = med1.groupby("ITEMID").count()[["HADM_ID"]].sort_values("HADM_ID", ascending=False)
counts[counts["HADM_ID"]>1000]
# Out:
#         HADM_ID
# ITEMID
# 225158    15866
# 220949    13849
# 226452    13351
# 225943    11183
# 222011     9274
# ...         ...
# 225883     1149
# 225833     1045
# 228315     1044
# 225153     1003
# 221468     1003
#
# [67 rows x 1 columns]

# %%
med1
# Out:
#         SUBJECT_ID  ITEMID  HADM_ID  Unnamed: 0.2  Unnamed: 0.1  ROW_ID_x  \
# 28897        29495  225828   182822       1266022       1266022      2947
# 199105       73363  225943   174481       1940648       1940648   1266630
# 71788        47216  225158   167377       1032728       1032728   2598902
# 77294        48348  226372   186981       3464223       3464223   1947331
# 77293        48348  226364   186981       2923674       2923674   1947274
# ...            ...     ...      ...           ...           ...       ...
# 291587       93321  225917   115396       3320414       3320414   3599650
# 291596       93321  226453   115396       1237197       1237197   3599538
# 291567       93321  225797   115396       1264937       1264937   3599579
# 291588       93321  225930   115396       3291211       3291211   3599677
# 291556       93321  221794   115396       1385156       1385156   3599952
#
#         ICUSTAY_ID            STARTTIME              ENDTIME       AMOUNT  \
# 28897     252299.0  2126-01-22 21:51:00  2126-01-22 21:52:00  1000.000000
# 199105    288413.0  2144-01-31 12:21:00  2144-01-31 14:01:00    64.516127
# 71788     246025.0  2155-08-01 11:26:00  2155-08-01 11:27:00  1500.000000
# 77294     274006.0  2177-11-28 12:00:00  2177-11-28 12:01:00   250.000000
# 77293     274006.0  2177-11-28 12:00:00  2177-11-28 12:01:00  2700.000000
# ...            ...                  ...                  ...          ...
# 291587    248745.0  2128-09-11 21:46:00  2128-09-12 13:47:00  2500.000081
# 291596    248745.0  2128-09-12 21:22:00  2128-09-12 21:23:00    60.000000
# 291567    248745.0  2128-09-14 17:58:00  2128-09-14 17:59:00   100.000000
# 291588    248745.0  2128-09-14 15:33:00  2128-09-14 18:43:00    31.666667
# 291556    248745.0  2128-09-16 14:06:00  2128-09-16 14:07:00    20.000001
#
#         ... ROW_ID                  LABEL           ABBREVIATION    DBSOURCE  \
# 28897   ...  14005                     LR                     LR  metavision
# 199105  ...  14375               Solution               Solution  metavision
# 71788   ...  13758              NaCl 0.9%              NaCl 0.9%  metavision
# 77294   ...  14457   OR Cell Saver Intake   OR Cell Saver Intake  metavision
# 77293   ...  14450  OR Crystalloid Intake  OR Crystalloid Intake  metavision
# ...     ...    ...                    ...                    ...         ...
# 291587  ...  14355     TPN without Lipids     TPN without Lipids  metavision
# 291596  ...  14472               GT Flush               GT Flush  metavision
# 291567  ...  13981             Free Water             Free Water  metavision
# 291588  ...  14367    Peptamen 1.5 (Full)    Peptamen 1.5 (Full)  metavision
# 291556  ...  12979     Furosemide (Lasix)     Furosemide (Lasix)  metavision
#
#                LINKSTO                 CATEGORY  UNITNAME PARAM_TYPE  \
# 28897   inputevents_mv            Fluids/Intake        mL   Solution
# 199105  inputevents_mv            Fluids/Intake        mL   Solution
# 71788   inputevents_mv            Fluids/Intake        mL   Solution
# 77294   inputevents_mv  Blood Products/Colloids        mL   Solution
# 77293   inputevents_mv            Fluids/Intake        mL   Solution
# ...                ...                      ...       ...        ...
# 291587  inputevents_mv   Nutrition - Parenteral        mL   Solution
# 291596  inputevents_mv            Fluids/Intake        mL   Solution
# 291567  inputevents_mv            Fluids/Intake        mL   Solution
# 291588  inputevents_mv      Nutrition - Enteral        mL   Solution
# 291556  inputevents_mv              Medications        mg   Solution
#
#        CONCEPTID  MedTimeFromAdmit
# 28897        NaN   0 days 00:01:00
# 199105       NaN   0 days 00:01:00
# 71788        NaN   0 days 00:01:00
# 77294        NaN   0 days 00:01:00
# 77293        NaN   0 days 00:01:00
# ...          ...               ...
# 291587       NaN 171 days 14:46:00
# 291596       NaN 171 days 22:22:00
# 291567       NaN 173 days 18:58:00
# 291588       NaN 173 days 19:42:00
# 291556       NaN 175 days 15:06:00
#
# [323007 rows x 61 columns]

# %%
med2
# Out:
#         SUBJECT_ID  ITEMID  HADM_ID  Unnamed: 0.2  Unnamed: 0.1  ROW_ID_x  \
# 35719        42353  225828   171342       1289857       1289857   1671151
# 231522       98281  225158   117684        878463        878463   1549345
# 220822       95238  225828   110402       1273081       1273081    546286
# 33451        41624  226372   178751       3464007       3464007   1538868
# 172779       81202  220949   105280        335419        335419   1614569
# ...            ...     ...      ...           ...           ...       ...
# 214311       93321  225912   115396       3356454       3356454   3599562
# 214320       93321  226453   115396       1237194       1237194   3599939
# 214312       93321  225917   115396       3320412       3320412   3599685
# 214313       93321  225930   115396       3291212       3291212   3599948
# 214294       93321  225797   115396       1264938       1264938   3599629
#
#         ICUSTAY_ID            STARTTIME              ENDTIME       AMOUNT  \
# 35719     280877.0  2188-07-28 12:45:00  2188-07-28 12:46:00  1000.000000
# 231522    251214.0  2134-03-30 16:30:00  2134-03-30 17:46:00     3.800000
# 220822    223406.0  2161-04-20 11:45:00  2161-04-20 11:46:00  1000.000000
# 33451     277546.0  2162-05-06 11:00:00  2162-05-06 11:01:00   600.000000
# 172779    272451.0  2103-06-10 08:00:00  2103-06-10 08:01:00   200.000000
# ...            ...                  ...                  ...          ...
# 214311    248745.0  2128-09-12 23:28:00  2128-09-12 23:29:00     1.000000
# 214320    248745.0  2128-09-13 08:00:00  2128-09-13 08:01:00    30.000000
# 214312    248745.0  2128-09-12 18:46:00  2128-09-13 18:47:00  2499.999978
# 214313    248745.0  2128-09-14 18:43:00  2128-09-15 08:22:00   273.000005
# 214294    248745.0  2128-09-15 11:03:00  2128-09-15 11:04:00   100.000000
#
#         ... ROW_ID                  LABEL           ABBREVIATION    DBSOURCE  \
# 35719   ...  14005                     LR                     LR  metavision
# 231522  ...  13758              NaCl 0.9%              NaCl 0.9%  metavision
# 220822  ...  14005                     LR                     LR  metavision
# 33451   ...  14457   OR Cell Saver Intake   OR Cell Saver Intake  metavision
# 172779  ...  12865            Dextrose 5%            Dextrose 5%  metavision
# ...     ...    ...                    ...                    ...         ...
# 214311  ...  14065  Carafate (Sucralfate)  Carafate (Sucralfate)  metavision
# 214320  ...  14472               GT Flush               GT Flush  metavision
# 214312  ...  14355     TPN without Lipids     TPN without Lipids  metavision
# 214313  ...  14367    Peptamen 1.5 (Full)    Peptamen 1.5 (Full)  metavision
# 214294  ...  13981             Free Water             Free Water  metavision
#
#                LINKSTO                 CATEGORY  UNITNAME PARAM_TYPE  \
# 35719   inputevents_mv            Fluids/Intake        mL   Solution
# 231522  inputevents_mv            Fluids/Intake        mL   Solution
# 220822  inputevents_mv            Fluids/Intake        mL   Solution
# 33451   inputevents_mv  Blood Products/Colloids        mL   Solution
# 172779  inputevents_mv            Fluids/Intake        mL   Solution
# ...                ...                      ...       ...        ...
# 214311  inputevents_mv              Medications      dose   Solution
# 214320  inputevents_mv            Fluids/Intake        mL   Solution
# 214312  inputevents_mv   Nutrition - Parenteral        mL   Solution
# 214313  inputevents_mv      Nutrition - Enteral        mL   Solution
# 214294  inputevents_mv            Fluids/Intake        mL   Solution
#
#        CONCEPTID  MedTimeFromAdmit
# 35719        NaN   0 days 00:01:00
# 231522       NaN   0 days 00:01:00
# 220822       NaN   0 days 00:01:00
# 33451        NaN   0 days 00:01:00
# 172779       NaN   0 days 00:01:00
# ...          ...               ...
# 214311       NaN 172 days 00:28:00
# 214320       NaN 172 days 09:00:00
# 214312       NaN 172 days 19:46:00
# 214313       NaN 174 days 09:21:00
# 214294       NaN 174 days 12:03:00
#
# [237607 rows x 61 columns]

# %%
labs = labs.rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})

# %%
labs
# Out:
#           ROW_ID_x  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 14822987  21075805       48882  103146.0   50813  2114-04-23 18:17:00   2.5
# 20517708  27458475       96686  189846.0   51077  2115-04-11 18:50:00   2.9
# 20517709  27458479       96686  189846.0   51097  2115-04-11 18:50:00    25
# 13665680  20690955       46007  178313.0   50893  2138-05-11 14:30:00   7.6
# 18193731  26566842       89929  118735.0   50820  2169-02-09 16:24:00  7.32
# ...            ...         ...       ...     ...                  ...   ...
# 19106318  27017123       93321  115396.0   50813  2128-10-17 05:33:00   5.4
# 19106344  27017124       93321  115396.0   50818  2128-10-17 05:33:00    38
# 19106369  27017126       93321  115396.0   50821  2128-10-17 05:33:00   117
# 19106282  27017122       93321  115396.0   50804  2128-10-17 05:33:00    13
# 19106228  27017125       93321  115396.0   50820  2128-10-17 05:33:00  7.11
#
#           VALUENUM VALUEUOM      FLAG  ROW_ID_y  ... LANGUAGE       RELIGION  \
# 14822987      2.50   mmol/L  abnormal        14  ...     ENGL       CATHOLIC
# 20517708      2.90    mg/dL       NaN       277  ...     ENGL  NOT SPECIFIED
# 20517709     25.00    mEq/L       NaN       297  ...     ENGL  NOT SPECIFIED
# 13665680      7.60    mg/dL  abnormal        94  ...     ENGL  NOT SPECIFIED
# 18193731      7.32    units  abnormal        21  ...     ENGL   UNOBTAINABLE
# ...            ...      ...       ...       ...  ...      ...            ...
# 19106318      5.40   mmol/L  abnormal        14  ...      NaN       CATHOLIC
# 19106344     38.00    mm Hg       NaN        19  ...      NaN       CATHOLIC
# 19106369    117.00    mm Hg  abnormal        22  ...      NaN       CATHOLIC
# 19106282     13.00    mEq/L  abnormal         5  ...      NaN       CATHOLIC
# 19106228      7.11    units  abnormal        21  ...      NaN       CATHOLIC
#
#          MARITAL_STATUS               ETHNICITY            EDREGTIME  \
# 14822987        MARRIED                   WHITE                  NaN
# 20517708         SINGLE  BLACK/AFRICAN AMERICAN  2115-04-11 12:29:00
# 20517709         SINGLE  BLACK/AFRICAN AMERICAN  2115-04-11 12:29:00
# 13665680        MARRIED                   WHITE  2138-05-11 11:41:00
# 18193731            NaN   UNKNOWN/NOT SPECIFIED  2169-02-09 15:00:00
# ...                 ...                     ...                  ...
# 19106318        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106344        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106369        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106282        WIDOWED                   WHITE  2128-03-24 22:29:00
# 19106228        WIDOWED                   WHITE  2128-03-24 22:29:00
#
#                     EDOUTTIME               DIAGNOSIS HOSPITAL_EXPIRE_FLAG  \
# 14822987                  NaN         AORTIC STENOSIS                    1
# 20517708  2115-04-11 20:40:00     ACUTE RENAL FAILURE                    0
# 20517709  2115-04-11 20:40:00     ACUTE RENAL FAILURE                    0
# 13665680  2138-05-11 15:28:00  MULITPLE RIB FRACTURES                    0
# 18193731  2169-02-09 18:11:00    OVERDOSE ON DEPAKOTE                    0
# ...                       ...                     ...                  ...
# 19106318  2128-03-25 00:19:00                  ANEMIA                    1
# 19106344  2128-03-25 00:19:00                  ANEMIA                    1
# 19106369  2128-03-25 00:19:00                  ANEMIA                    1
# 19106282  2128-03-25 00:19:00                  ANEMIA                    1
# 19106228  2128-03-25 00:19:00                  ANEMIA                    1
#
#          HAS_CHARTEVENTS_DATA  LabTimeFromAdmit
# 14822987                    1   0 days 00:01:00
# 20517708                    1   0 days 00:01:00
# 20517709                    1   0 days 00:01:00
# 13665680                    1   0 days 00:01:00
# 18193731                    1   0 days 00:01:00
# ...                       ...               ...
# 19106318                    1 206 days 06:32:00
# 19106344                    1 206 days 06:32:00
# 19106369                    1 206 days 06:32:00
# 19106282                    1 206 days 06:32:00
# 19106228                    1 206 days 06:32:00
#
# [7260285 rows x 33 columns]

# %%
med1["STARTTIME"] = pd.to_datetime(med1["STARTTIME"])
med1["ENDTIME"] = pd.to_datetime(med1["ENDTIME"])
med2["STARTTIME"] = pd.to_datetime(med2["STARTTIME"])
med2["ENDTIME"] = pd.to_datetime(med2["ENDTIME"])
labs["CHARTTIME"] = pd.to_datetime(labs["CHARTTIME"])

# %%
import numpy as np
import pickle
import pandas as pd
meds = []
labtests = []
time_before = [np.random.randint(1, 10) for n in range(0, 42)]

meds.append('Insulin - Regular')
labtests.append('Glucose')

meds.append('Packed Red Blood Cells')
labtests.append('Hematocrait')

meds.append('Packed Red Blood Cells')
labtests.append('Hemoglobin')

meds.append('Packed Red Blood Cells')
labtests.append('Red Blood Cells')

meds.append('Calcium')
labtests.append('Calcium Total')

meds.append('Albumin 5%')
labtests.append('Hematocrit')

# calicium
test_data = pd.DataFrame({
    'Medication': meds,
    'Lab Tests': labtests,
    'Time' : time_before
})

# %%
class AddMedEffect:

    def __init__(self, vitals_data, dataset, label_path=None, admissions=None):
        self.vitals_data = vitals_data
        self.dataset = dataset
        self.admissions = admissions if admissions is not None else self.dataset.admissions
        self.admissions['ADMITTIME'] = pd.to_datetime(self.admissions['ADMITTIME'])

        path = label_path if label_path is not None else '/Users/yanpavan/Desktop/Personal/TAU/DrugLab/data/mimic_extract/itemid_to_variable_map.csv'
        self.meds_label_map = pd.read_csv(path)
        self.meds_label_map = self.meds_label_map[['LEVEL2', 'MIMIC LABEL']]

        self.meds = self._preprocess_meds_data(self.admissions, self.dataset.patient_presc['inputevents'])
        self.vitals_labtests = vitals_labs.columns.to_frame()['LEVEL2'].unique()
        self.vals = []

    def editDistance(self, str1, str2):
        len1 = len(str1)
        len2 = len(str2)
    
        DP = [[0 for i in range(len1 + 1)]
                for j in range(2)]
    
        for i in range(0, len1 + 1):
            DP[0][i] = i
    
        for i in range(1, len2 + 1):
            
            for j in range(0, len1 + 1):
                if (j == 0):
                    DP[i % 2][j] = i
    
                elif(str1[j - 1] == str2[i-1]):
                    DP[i % 2][j] = DP[(i - 1) % 2][j - 1]

                else:
                    DP[i % 2][j] = (1 + min(DP[(i - 1) % 2][j],
                                        min(DP[i % 2][j - 1],
                                    DP[(i - 1) % 2][j - 1])))

        return DP[len2 % 2][len1]

    def are_same(self, str1, str2, threshold=0.25):
        str1 = str1.lower()
        str2 = str2.lower()
        m = len(str1)
        n = len(str2)

        return self.editDistance(str1, str2) / min(m,n) >= threshold

    def check_change_labtest_edit_distance(self, row):
        min_edit = 100000
        final_name = row
        for labtest in self.vitals_labtests:
            k = self.editDistance(row, labtest)
            if k<min_edit:
                min_edit = k
                final_name = labtest
        return final_name
    
    def check_change_labtest(self, row):
        if row in self.vitals_labtests:
            return row
        if row.lower() in self.vitals_labtests:
            return row.lower()
        query = k[k['MIMIC LABEL']==row]
        if query.shape[0]>0:
            return query['LEVEL2'].iloc[0]
        else:
            self.check_change_labtest_edit_distance(row)

    def _preprocess_meds_data(self, admissions, meds):
        admit_time = admissions[['HADM_ID', 'SUBJECT_ID', 'ADMITTIME']]
        # all_meds = dataset.patient_presc['inputevents']
        meds['ENDTIME'] = pd.to_datetime(meds['ENDTIME'])
        temp_data = pd.merge(meds, admit_time, on='HADM_ID', how='inner')
        meds['time_in'] = temp_data['ENDTIME']-temp_data['ADMITTIME']
        meds['hours_in'] = meds['time_in'].apply(lambda x : x.total_seconds()//3600)
        return meds

    def _get_admit_time(self, admit_time, row):
        return admit_time[admit_time['HADM_ID']==row['HADM_ID']]['ADMITTIME'].iloc[0]

    def get_hours(self, time):
        return time.total_seconds()//3600

    def check_subs_with_meds(self, row, meds, sig_meds):
        adm = row.name[1]   # ['hadm_id']
        labtest_hours = row.name[3]     # ['hours_in']

        if adm in meds['HADM_ID'].to_list():
            meds = meds[meds['HADM_ID']==adm]
            # Calculate difference between relative medication time (time from start of admission) and relative time of labtest to get time from prescription
            temp = meds.apply(lambda r : (labtest_hours-r['hours_in'])>0 and (labtest_hours-r['hours_in'])==sig_meds[sig_meds['Medication']==r['LABEL']]['Time'].iloc[0], axis=1) 
            meds = meds[temp]
            return meds.shape[0]

        return 0

    def get_subs_with_meds(self, subjects_vitals, sig_meds, vitals_lab):

        all_meds = self.meds
        meds = all_meds[all_meds['HADM_ID'].isin(subjects_vitals['hadm_id'])]     # filter vital subjects
        meds = meds[meds['LABEL'].isin(sig_meds['Medication'])]    # Is a sig med
        final_subs = vitals_lab.apply(lambda row : self.check_subs_with_meds(row, meds, sig_meds) if row['count']>0 else 0, axis=1)

        return final_subs

    def add_med_effect(self, table):
        vitals_data = self.vitals_data
        labtests_vitals = vitals_data.columns.to_frame()['LEVEL2'].value_counts().keys().to_list()
        table['Lab Tests'] = table['Lab Tests'].apply(self.check_change_labtest)

        res = {}

        # count = 0
        # for labtest in labtests_vitals:
        #     if labtest not in table['Lab Tests'].to_list():
        #         count+=1
        #         continue
        
        for labtest in table['Lab Tests'].to_list():

            print(f'Labtest : {labtest}')

            if labtest in res.keys():
                continue

            sig_labtest_meds = table[table['Lab Tests']==labtest]
            sig_meds = sig_labtest_meds[['Medication', 'Time']]

            labtest_data = vitals_data[labtest]


            data_with_labtest_val = vitals_data[vitals_data[labtest]['count']>0]
            subjects_vitals = data_with_labtest_val.index.to_frame()[['subject_id', 'hadm_id', 'hours_in']]
            

            subs_with_meds = self.get_subs_with_meds(
                subjects_vitals=subjects_vitals,
                vitals_lab=vitals_data[labtest],
                sig_meds=sig_meds            
            )

            print(f'{subs_with_meds[subs_with_meds>0].shape[0]} labtest values updated for {labtest}')
            # labtest_data['sig_counts'] = subs_with_meds

            res[labtest] = {
                'labtest':labtest,
                'counts':subs_with_meds
            }
            pickle.dump(res, open('/Users/yanpavan/Desktop/Personal/TAU/DrugLab/results/mimic_extract/res_label.pkl', 'wb'))

        return res
