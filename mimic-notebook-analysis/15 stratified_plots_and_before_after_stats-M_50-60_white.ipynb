# %%
data = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/data"
res = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/results"

# %%
import pandas as pd
import os

# %% [markdown]
# ## Medication Patient Data

# %% [markdown]
# ## Filter Meds

# %% [markdown]
# ### Med 1

# %%
# Male, 50-60, WHITE

# %%
gender = "M"
age_b = 50
age_a = 60
ethnicity = "WHITE"
stratify_prefix = f"{age_b}-{age_a}_{gender}_{ethnicity}"

# %%
med1 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med1_vectorized.csv"))

# %%
med1 = med1.drop(columns=["Unnamed: 0"])

# %%
import matplotlib.pyplot as plt
t = med1[med1["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
med1.shape
# Out:
# (323007, 63)

# %%
med1 = med1[med1["AGE"]>=age_b]
med1 = med1[med1["AGE"]<=age_a]

# %%
med1 = med1[med1["GENDER"]==gender]
med1 = med1[med1["ETHNICITY"]==ethnicity]

# %%
import matplotlib.pyplot as plt
t = med1[med1["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
med1
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 208            820  2077-04-26      M  2144-03-24 00:00:00            1
# 209            820  2077-04-26      M  2144-03-24 00:00:00            1
# 210            820  2077-04-26      M  2144-03-24 00:00:00            1
# 211            820  2077-04-26      M  2144-03-24 00:00:00            1
# 212            820  2077-04-26      M  2144-03-24 00:00:00            1
# ...            ...         ...    ...                  ...          ...
# 322825       44069  2064-04-08      M                  NaN            0
# 322826       44069  2064-04-08      M                  NaN            0
# 322827       44069  2064-04-08      M                  NaN            0
# 322828       44069  2064-04-08      M                  NaN            0
# 322829       44069  2064-04-08      M                  NaN            0
#
#         ITEMID  HADM_ID  ICUSTAY_ID           STARTTIME             ENDTIME  \
# 208     225158   193603    280074.0 2144-02-24 23:30:00 2144-02-24 23:56:00
# 209     226452   193603    280074.0 2144-02-25 08:00:00 2144-02-25 08:01:00
# 210     225975   193603    280074.0 2144-02-25 08:00:00 2144-02-25 08:01:00
# 211     223257   193603    280074.0 2144-02-25 08:00:00 2144-02-25 08:01:00
# 212     223262   193603    280074.0 2144-02-25 08:00:00 2144-02-25 08:01:00
# ...        ...      ...         ...                 ...                 ...
# 322825  223258   138192    214441.0 2131-02-15 22:30:00 2131-02-15 22:31:00
# 322826  220864   138192    214441.0 2131-02-15 21:53:00 2131-02-15 23:53:00
# 322827  222056   138192    214441.0 2131-02-15 22:32:00 2131-02-16 01:27:00
# 322828  226452   138192    214441.0 2131-02-16 06:00:00 2131-02-16 06:01:00
# 322829  223260   138192    214441.0 2131-02-16 08:00:00 2131-02-16 08:01:00
#
#         ...                  ABBREVIATION    DBSOURCE         LINKSTO  \
# 208     ...                     NaCl 0.9%  metavision  inputevents_mv
# 209     ...                     PO Intake  metavision  inputevents_mv
# 210     ...  Heparin Sodium (Prophylaxis)  metavision  inputevents_mv
# 211     ...               Insulin - 70/30  metavision  inputevents_mv
# 212     ...             Insulin - Humalog  metavision  inputevents_mv
# ...     ...                           ...         ...             ...
# 322825  ...             Insulin - Regular  metavision  inputevents_mv
# 322826  ...                    Albumin 5%  metavision  inputevents_mv
# 322827  ...                 Nitroglycerin  metavision  inputevents_mv
# 322828  ...                     PO Intake  metavision  inputevents_mv
# 322829  ...            Insulin - Glargine  metavision  inputevents_mv
#
#                        CATEGORY UNITNAME  PARAM_TYPE  CONCEPTID  \
# 208               Fluids/Intake       mL    Solution        NaN
# 209               Fluids/Intake       mL    Solution        NaN
# 210                 Medications     dose    Solution        NaN
# 211                 Medications    units    Solution        NaN
# 212                 Medications    units    Solution        NaN
# ...                         ...      ...         ...        ...
# 322825              Medications    units    Solution        NaN
# 322826  Blood Products/Colloids       mL    Solution        NaN
# 322827              Medications       mg    Solution        NaN
# 322828            Fluids/Intake       mL    Solution        NaN
# 322829              Medications    units    Solution        NaN
#
#         MedTimeFromAdmit   AGE   hours_in
# 208      1 days 22:17:00  67.0  46.283333
# 209      2 days 06:22:00  67.0  54.366667
# 210      2 days 06:22:00  67.0  54.366667
# 211      2 days 06:22:00  67.0  54.366667
# 212      2 days 06:22:00  67.0  54.366667
# ...                  ...   ...        ...
# 322825   3 days 04:20:00  67.0  76.333333
# 322826   3 days 05:42:00  67.0  77.700000
# 322827   3 days 07:16:00  67.0  79.266667
# 322828   3 days 11:50:00  67.0  83.833333
# 322829   3 days 13:50:00  67.0  85.833333
#
# [39595 rows x 64 columns]

# %% [markdown]
# ### Med 2

# %%
med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_3471/27638116.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))

# %%
med2 = med2.drop(columns=["Unnamed: 0"])

# %%
med2 = med2[med2["AGE"]>=age_b]
med2 = med2[med2["AGE"]<=age_a]

# %%
med2 = med2[med2["GENDER"]==gender]
med2 = med2[med2["ETHNICITY"]==ethnicity]

# %%
med2
# Out:
#         SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG  ITEMID  HADM_ID  \
# 174            852  2108-05-05      M  NaN            0  225166   162589
# 175            852  2108-05-05      M  NaN            0  225158   162589
# 176            852  2108-05-05      M  NaN            0  226452   162589
# 177            852  2108-05-05      M  NaN            0  225154   162589
# 178            852  2108-05-05      M  NaN            0  221385   162589
# ...            ...         ...    ...  ...          ...     ...      ...
# 237602       44128  2098-07-25      M  NaN            0  220949   141304
# 237603       44128  2098-07-25      M  NaN            0  225850   141304
# 237604       44128  2098-07-25      M  NaN            0  225158   141304
# 237605       44128  2098-07-25      M  NaN            0  225823   141304
# 237606       44128  2098-07-25      M  NaN            0  223258   141304
#
#         ICUSTAY_ID            STARTTIME              ENDTIME  ...  \
# 174       287998.0  2160-11-03 02:00:00  2160-11-03 05:20:00  ...
# 175       287998.0  2160-11-03 02:00:00  2160-11-03 05:20:00  ...
# 176       287998.0  2160-11-03 09:57:00  2160-11-03 09:58:00  ...
# 177       287998.0  2160-11-03 12:00:00  2160-11-03 12:01:00  ...
# 178       287998.0  2160-11-03 12:30:00  2160-11-03 12:31:00  ...
# ...            ...                  ...                  ...  ...
# 237602    253669.0  2149-06-11 16:18:00  2149-06-11 16:19:00  ...
# 237603    253669.0  2149-06-11 16:18:00  2149-06-11 16:19:00  ...
# 237604    253669.0  2149-06-11 20:00:00  2149-06-12 06:00:00  ...
# 237605    253669.0  2149-06-12 06:00:00  2149-06-12 19:16:00  ...
# 237606    253669.0  2149-06-12 20:15:00  2149-06-12 20:16:00  ...
#
#                      LABEL              ABBREVIATION    DBSOURCE  \
# 174     Potassium Chloride  Potassium Chloride - KCL  metavision
# 175              NaCl 0.9%                 NaCl 0.9%  metavision
# 176              PO Intake                 PO Intake  metavision
# 177       Morphine Sulfate          Morphine Sulfate  metavision
# 178     Lorazepam (Ativan)        Lorazepam (Ativan)  metavision
# ...                    ...                       ...         ...
# 237602         Dextrose 5%               Dextrose 5%  metavision
# 237603           Cefazolin                 Cefazolin  metavision
# 237604           NaCl 0.9%                 NaCl 0.9%  metavision
# 237605            D5 1/2NS                  D5 1/2NS  metavision
# 237606   Insulin - Regular         Insulin - Regular  metavision
#
#                LINKSTO       CATEGORY  UNITNAME  PARAM_TYPE  CONCEPTID  \
# 174     inputevents_mv    Medications       mEq    Solution        NaN
# 175     inputevents_mv  Fluids/Intake        mL    Solution        NaN
# 176     inputevents_mv  Fluids/Intake        mL    Solution        NaN
# 177     inputevents_mv    Medications        mg    Solution        NaN
# 178     inputevents_mv    Medications        mg    Solution        NaN
# ...                ...            ...       ...         ...        ...
# 237602  inputevents_mv  Fluids/Intake        mL    Solution        NaN
# 237603  inputevents_mv    Antibiotics      dose    Solution        NaN
# 237604  inputevents_mv  Fluids/Intake        mL    Solution        NaN
# 237605  inputevents_mv  Fluids/Intake        mL    Solution        NaN
# 237606  inputevents_mv    Medications     units    Solution        NaN
#
#        MedTimeFromAdmit   AGE
# 174     0 days 07:17:00  53.0
# 175     0 days 07:17:00  53.0
# 176     0 days 11:55:00  53.0
# 177     0 days 13:58:00  53.0
# 178     0 days 14:28:00  53.0
# ...                 ...   ...
# 237602  3 days 00:58:00  51.0
# 237603  3 days 00:58:00  51.0
# 237604  3 days 14:39:00  51.0
# 237605  4 days 03:55:00  51.0
# 237606  4 days 04:55:00  51.0
#
# [20319 rows x 63 columns]

# %%
import matplotlib.pyplot as plt
med2['AGE'].hist(bins=10)
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ## Filter Labs

# %%
labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))
# labs = labs.rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_40779/608754289.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))

# %%
labs = labs.drop(columns=["Unnamed: 0"])
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 0               249  2075-03-13      F  NaN            0    163327  158975.0
# 1               249  2075-03-13      F  NaN            0    163304  158975.0
# 2               249  2075-03-13      F  NaN            0    163317  158975.0
# 3               249  2075-03-13      F  NaN            0    163315  158975.0
# 4               249  2075-03-13      F  NaN            0    163316  158975.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7260280       44128  2098-07-25      M  NaN            0  20437251  141304.0
# 7260281       44128  2098-07-25      M  NaN            0  20437245  141304.0
# 7260282       44128  2098-07-25      M  NaN            0  20437250  141304.0
# 7260283       44128  2098-07-25      M  NaN            0  20437255  141304.0
# 7260284       44128  2098-07-25      M  NaN            0  20437256  141304.0
#
#          ITEMID            CHARTTIME  VALUE  ...       RELIGION  \
# 0         51274  2156-04-27 15:40:00   20.0  ...       CATHOLIC
# 1         50868  2156-04-27 15:40:00   12.0  ...       CATHOLIC
# 2         51221  2156-04-27 15:40:00   29.5  ...       CATHOLIC
# 3         51146  2156-04-27 15:40:00    0.4  ...       CATHOLIC
# 4         51200  2156-04-27 15:40:00    2.4  ...       CATHOLIC
# ...         ...                  ...    ...  ...            ...
# 7260280   51275  2149-06-14 05:00:00   26.4  ...  NOT SPECIFIED
# 7260281   51237  2149-06-14 05:00:00    1.1  ...  NOT SPECIFIED
# 7260282   51274  2149-06-14 05:00:00   12.8  ...  NOT SPECIFIED
# 7260283   51221  2149-06-15 04:45:00   27.3  ...  NOT SPECIFIED
# 7260284   51221  2149-06-16 12:22:00   28.0  ...  NOT SPECIFIED
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0             DIVORCED     WHITE                  NaN                  NaN
# 1             DIVORCED     WHITE                  NaN                  NaN
# 2             DIVORCED     WHITE                  NaN                  NaN
# 3             DIVORCED     WHITE                  NaN                  NaN
# 4             DIVORCED     WHITE                  NaN                  NaN
# ...                ...       ...                  ...                  ...
# 7260280        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260281        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260282        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260283        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260284        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
#
#                        DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 0        GI BLEEDING\COLONOSCOPY                    0                    1
# 1        GI BLEEDING\COLONOSCOPY                    0                    1
# 2        GI BLEEDING\COLONOSCOPY                    0                    1
# 3        GI BLEEDING\COLONOSCOPY                    0                    1
# 4        GI BLEEDING\COLONOSCOPY                    0                    1
# ...                          ...                  ...                  ...
# 7260280                   TRAUMA                    0                    1
# 7260281                   TRAUMA                    0                    1
# 7260282                   TRAUMA                    0                    1
# 7260283                   TRAUMA                    0                    1
# 7260284                   TRAUMA                    0                    1
#
#          LabTimeFromAdmit   AGE
# 0         0 days 00:07:00  81.0
# 1         0 days 00:07:00  81.0
# 2         0 days 00:07:00  81.0
# 3         0 days 00:07:00  81.0
# 4         0 days 00:07:00  81.0
# ...                   ...   ...
# 7260280   5 days 13:39:00  51.0
# 7260281   5 days 13:39:00  51.0
# 7260282   5 days 13:39:00  51.0
# 7260283   6 days 13:24:00  51.0
# 7260284   7 days 21:01:00  51.0
#
# [7260285 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
t = labs[labs["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %%
labs = labs[labs["AGE"]>=age_b]
labs = labs[labs["AGE"]<=age_a]

# %%
labs = labs[labs["GENDER"]==gender]
labs = labs[labs["ETHNICITY"]==ethnicity]

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 6575            852  2108-05-05      M  NaN            0    562612  162589.0
# 6576            852  2108-05-05      M  NaN            0    562620  162589.0
# 6577            852  2108-05-05      M  NaN            0    562621  162589.0
# 6578            852  2108-05-05      M  NaN            0    562616  162589.0
# 6579            852  2108-05-05      M  NaN            0    562617  162589.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7260280       44128  2098-07-25      M  NaN            0  20437251  141304.0
# 7260281       44128  2098-07-25      M  NaN            0  20437245  141304.0
# 7260282       44128  2098-07-25      M  NaN            0  20437250  141304.0
# 7260283       44128  2098-07-25      M  NaN            0  20437255  141304.0
# 7260284       44128  2098-07-25      M  NaN            0  20437256  141304.0
#
#          ITEMID            CHARTTIME  VALUE  ...           RELIGION  \
# 6575      51237  2160-11-02 23:43:00    1.1  ...  PROTESTANT QUAKER
# 6576      51274  2160-11-02 23:43:00   13.4  ...  PROTESTANT QUAKER
# 6577      51275  2160-11-02 23:43:00   28.8  ...  PROTESTANT QUAKER
# 6578      51250  2160-11-02 23:43:00   90.0  ...  PROTESTANT QUAKER
# 6579      51254  2160-11-02 23:43:00    3.7  ...  PROTESTANT QUAKER
# ...         ...                  ...    ...  ...                ...
# 7260280   51275  2149-06-14 05:00:00   26.4  ...      NOT SPECIFIED
# 7260281   51237  2149-06-14 05:00:00    1.1  ...      NOT SPECIFIED
# 7260282   51274  2149-06-14 05:00:00   12.8  ...      NOT SPECIFIED
# 7260283   51221  2149-06-15 04:45:00   27.3  ...      NOT SPECIFIED
# 7260284   51221  2149-06-16 12:22:00   28.0  ...      NOT SPECIFIED
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 6575           MARRIED     WHITE  2160-11-02 19:12:00  2160-11-02 23:02:00
# 6576           MARRIED     WHITE  2160-11-02 19:12:00  2160-11-02 23:02:00
# 6577           MARRIED     WHITE  2160-11-02 19:12:00  2160-11-02 23:02:00
# 6578           MARRIED     WHITE  2160-11-02 19:12:00  2160-11-02 23:02:00
# 6579           MARRIED     WHITE  2160-11-02 19:12:00  2160-11-02 23:02:00
# ...                ...       ...                  ...                  ...
# 7260280        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260281        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260282        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260283        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260284        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
#
#          DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 6575     VT ARREST                    0                    1
# 6576     VT ARREST                    0                    1
# 6577     VT ARREST                    0                    1
# 6578     VT ARREST                    0                    1
# 6579     VT ARREST                    0                    1
# ...            ...                  ...                  ...
# 7260280     TRAUMA                    0                    1
# 7260281     TRAUMA                    0                    1
# 7260282     TRAUMA                    0                    1
# 7260283     TRAUMA                    0                    1
# 7260284     TRAUMA                    0                    1
#
#          LabTimeFromAdmit   AGE
# 6575      0 days 01:40:00  53.0
# 6576      0 days 01:40:00  53.0
# 6577      0 days 01:40:00  53.0
# 6578      0 days 01:40:00  53.0
# 6579      0 days 01:40:00  53.0
# ...                   ...   ...
# 7260280   5 days 13:39:00  51.0
# 7260281   5 days 13:39:00  51.0
# 7260282   5 days 13:39:00  51.0
# 7260283   6 days 13:24:00  51.0
# 7260284   7 days 21:01:00  51.0
#
# [660771 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
t = labs[labs["AGE"]<100]
t = pd.DataFrame(t["AGE"].value_counts()).reset_index().sort_values(["index"])
plt.bar(t["index"], t["AGE"])
plt.xlabel('Age')
plt.ylabel('Count of Patients')
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ## Pairs

# %%
counts = med1.groupby("ITEMID").count()[["HADM_ID"]].sort_values("HADM_ID", ascending=False)
counts[counts["HADM_ID"]>1000]
# Out:
#         HADM_ID
# ITEMID
# 225158     1767
# 220949     1629
# 226452     1534
# 225943     1380
# 223258     1104
# 225166     1083
# 222011     1082
# 222168     1005

# %%
labitems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_LABITEMS.csv.gz"))
meditems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_ITEMS.csv.gz"))

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 1125            665  2052-05-20      M  2120-02-04 00:00:00            1
# 1126            665  2052-05-20      M  2120-02-04 00:00:00            1
# 1127            665  2052-05-20      M  2120-02-04 00:00:00            1
# 1128            665  2052-05-20      M  2120-02-04 00:00:00            1
# 1129            665  2052-05-20      M  2120-02-04 00:00:00            1
# ...             ...         ...    ...                  ...          ...
# 7258085       44082  2056-04-27      F                  NaN            0
# 7258086       44082  2056-04-27      F                  NaN            0
# 7258087       44082  2056-04-27      F                  NaN            0
# 7258088       44082  2056-04-27      F                  NaN            0
# 7258089       44082  2056-04-27      F                  NaN            0
#
#            ROW_ID   HADM_ID  ITEMID            CHARTTIME   VALUE  ...  \
# 1125       437660  170157.0   50802  2119-04-11 20:18:00    3.00  ...
# 1126       437665  170157.0   50821  2119-04-11 20:18:00  110.00  ...
# 1127       437662  170157.0   50813  2119-04-11 20:18:00    0.70  ...
# 1128       437664  170157.0   50820  2119-04-11 20:18:00    7.45  ...
# 1129       437663  170157.0   50818  2119-04-11 20:18:00   41.00  ...
# ...           ...       ...     ...                  ...     ...  ...
# 7258085  20434787  178322.0   50971  2122-04-14 05:05:00    3.90  ...
# 7258086  20434788  178322.0   50983  2122-04-14 05:05:00  144.00  ...
# 7258087  20434789  178322.0   51006  2122-04-14 05:05:00   15.00  ...
# 7258088  20434799  178322.0   51221  2122-04-15 05:00:00   26.20  ...
# 7258089  20434800  178322.0   51222  2122-04-15 05:00:00    9.20  ...
#
#               RELIGION MARITAL_STATUS               ETHNICITY  \
# 1125     NOT SPECIFIED         SINGLE  BLACK/AFRICAN AMERICAN
# 1126     NOT SPECIFIED         SINGLE  BLACK/AFRICAN AMERICAN
# 1127     NOT SPECIFIED         SINGLE  BLACK/AFRICAN AMERICAN
# 1128     NOT SPECIFIED         SINGLE  BLACK/AFRICAN AMERICAN
# 1129     NOT SPECIFIED         SINGLE  BLACK/AFRICAN AMERICAN
# ...                ...            ...                     ...
# 7258085       CATHOLIC       DIVORCED                   WHITE
# 7258086       CATHOLIC       DIVORCED                   WHITE
# 7258087       CATHOLIC       DIVORCED                   WHITE
# 7258088       CATHOLIC       DIVORCED                   WHITE
# 7258089       CATHOLIC       DIVORCED                   WHITE
#
#                    EDREGTIME            EDOUTTIME                DIAGNOSIS  \
# 1125     2119-04-11 11:26:00  2119-04-11 19:58:00           ABDOMINAL PAIN
# 1126     2119-04-11 11:26:00  2119-04-11 19:58:00           ABDOMINAL PAIN
# 1127     2119-04-11 11:26:00  2119-04-11 19:58:00           ABDOMINAL PAIN
# 1128     2119-04-11 11:26:00  2119-04-11 19:58:00           ABDOMINAL PAIN
# 1129     2119-04-11 11:26:00  2119-04-11 19:58:00           ABDOMINAL PAIN
# ...                      ...                  ...                      ...
# 7258085                  NaN                  NaN  CORONARY ARTERY DISEASE
# 7258086                  NaN                  NaN  CORONARY ARTERY DISEASE
# 7258087                  NaN                  NaN  CORONARY ARTERY DISEASE
# 7258088                  NaN                  NaN  CORONARY ARTERY DISEASE
# 7258089                  NaN                  NaN  CORONARY ARTERY DISEASE
#
#         HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  LabTimeFromAdmit   AGE
# 1125                       0                    1   0 days 01:28:00  67.0
# 1126                       0                    1   0 days 01:28:00  67.0
# 1127                       0                    1   0 days 01:28:00  67.0
# 1128                       0                    1   0 days 01:28:00  67.0
# 1129                       0                    1   0 days 01:28:00  67.0
# ...                      ...                  ...               ...   ...
# 7258085                    0                    1   6 days 08:03:00  66.0
# 7258086                    0                    1   6 days 08:03:00  66.0
# 7258087                    0                    1   6 days 08:03:00  66.0
# 7258088                    0                    1   7 days 07:58:00  66.0
# 7258089                    0                    1   7 days 07:58:00  66.0
#
# [1943849 rows x 38 columns]

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%         3786
# 1                   Dextrose 5%         3435
# 2                     PO Intake         3300
# 3                      Solution         2873
# 4             Magnesium Sulfate         2341
# 5            Potassium Chloride         2323
# 6             Insulin - Regular         2205
# 7  Heparin Sodium (Prophylaxis)         1996
# 8                      Propofol         1983
# 9     Magnesium Sulfate (Bolus)         1899

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%         3786
# 1                   Dextrose 5%         3435
# 2                     PO Intake         3300
# 3                      Solution         2873
# 4             Magnesium Sulfate         2341
# 5            Potassium Chloride         2323
# 6             Insulin - Regular         2205
# 7  Heparin Sodium (Prophylaxis)         1996
# 8                      Propofol         1983
# 9     Magnesium Sulfate (Bolus)         1899

# %%
med1["STARTTIME"] = pd.to_datetime(med1["STARTTIME"])
med1["ENDTIME"] = pd.to_datetime(med1["ENDTIME"])
med1["ADMITTIME"] = pd.to_datetime(med1["ADMITTIME"])
med1["MedTimeFromAdmit"] = med1["ENDTIME"]-med1["ADMITTIME"]
med2["STARTTIME"] = pd.to_datetime(med2["STARTTIME"])
med2["ENDTIME"] = pd.to_datetime(med2["ENDTIME"])
med2["ADMITTIME"] = pd.to_datetime(med2["ADMITTIME"])
med2["MedTimeFromAdmit"] = med2["ENDTIME"]-med2["ADMITTIME"]
labs["CHARTTIME"] = pd.to_datetime(labs["CHARTTIME"])
labs["ADMITTIME"] = pd.to_datetime(labs["ADMITTIME"])
labs["LabTimeFromAdmit"] = labs["CHARTTIME"]-labs["ADMITTIME"]

# %%
med1["hours_in"] = med1["MedTimeFromAdmit"].dt.total_seconds()/3600
labs["hours_in"] = labs["LabTimeFromAdmit"].dt.total_seconds()/3600

# %%
final_significant_med_lab_pairs = pd.read_csv(os.path.join(res, "significant_intersection_trends_and_med_effect_lab_med_all_new.csv"))

# %%
d = final_significant_med_lab_pairs.sort_values(by=['FDR Benjamini Corrected_y', 'FDR Benjamini Corrected_x']).head(20)[["MED_NAME", "LAB_NAME"]].to_dict()

# %%
d = {k : list(d[k].values()) for k in d}

# %%
meds = []
labtests = []

meds.append('Insulin - Regular')
labtests.append('Glucose')

meds.append('Packed Red Blood Cells')
labtests.append('Hematocrait')

meds.append('Packed Red Blood Cells')
labtests.append('Hemoglobin')

meds.append('Packed Red Blood Cells')
labtests.append('Red Blood Cells')

meds.append('Calcium')
labtests.append('Calcium Total')

meds.append('Albumin 5%')
labtests.append('Hematocrit')

meds.extend(d["MED_NAME"])
labtests.extend(d["LAB_NAME"])

med_vals = list(meds)
labtest_vals = list(labtests)

# %%
[i for i in zip(med_vals, labtest_vals)]
# Out:
# [('Insulin - Regular', 'Glucose'),
#  ('Packed Red Blood Cells', 'Hematocrait'),
#  ('Packed Red Blood Cells', 'Hemoglobin'),
#  ('Packed Red Blood Cells', 'Red Blood Cells'),
#  ('Calcium', 'Calcium Total'),
#  ('Albumin 5%', 'Hematocrit'),
#  ('Magnesium Sulfate (Bolus)', 'Magnesium'),
#  ('Magnesium Sulfate', 'Magnesium'),
#  ('Cefazolin', 'pO2'),
#  ('OR Cell Saver Intake', 'pO2'),
#  ('OR Crystalloid Intake', 'pO2'),
#  ('KCL (Bolus)', 'pO2'),
#  ('Potassium Chloride', 'pO2'),
#  ('Morphine Sulfate', 'pO2'),
#  ('Vancomycin', 'Hematocrit'),
#  ('Calcium Gluconate', 'pO2'),
#  ('OR Cell Saver Intake', 'Base Excess'),
#  ('LR', 'pO2'),
#  ('Insulin - Regular', 'pO2'),
#  ('Magnesium Sulfate', 'pO2'),
#  ('Magnesium Sulfate (Bolus)', 'pO2'),
#  ('Calcium Gluconate', 'Magnesium'),
#  ('Ranitidine (Prophylaxis)', 'pO2'),
#  ('Vancomycin', 'Red Blood Cells'),
#  ('Vancomycin', 'Hemoglobin'),
#  ('Magnesium Sulfate', 'Hematocrit')]

# %%
t_med1 = med1[med1["LABEL"].isin(med_vals)]
t_med2 = med2[med2["LABEL"].isin(med_vals)]

# %%
t_labs = labs[labs["LABEL"].isin(labtest_vals)]

# %%
t_med1.shape, t_med2.shape, t_labs.shape
# Out:
# ((11337, 64), (5053, 63), (136655, 39))

# %% [markdown]
# ## Before After Trend Calculation

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
def check_med2(row):
    if row["HADM_ID"] in t_med2["HADM_ID"].to_list():
        if row["ITEMID"] in t_med2[t_med2["HADM_ID"]==row["HADM_ID"]]["ITEMID"].to_list():
            return True
    return False

def get_med2(row):
    temp = t_med2[t_med2["HADM_ID"]==row["HADM_ID"]] 
    return temp[temp["ITEMID"]==row["ITEMID"]].iloc[0]

# %%
from sklearn import datasets, linear_model, metrics

def get_normalized_trend(data):
    selected = data[['VALUENUM', 'hours_in']]
    if selected.shape[0]<2:
        return float("NaN")
    reg = linear_model.LinearRegression()
    reg.fit(np.array(data['hours_in']).reshape(-1,1), np.array(data['VALUENUM']).reshape(-1,1))
    return reg.coef_[0][0]

# %%
def get_normalized_trend_np(data):
    selected = data[['VALUENUM', 'hours_in']]
    print(selected)
    if selected.shape[0]<2:
        return float("NaN")
    print(np.array(data['hours_in']), np.array(data['VALUENUM']))
    t = np.polyfit(np.array(data['hours_in']), np.array(data['VALUENUM']), 1,full=True)
    coefficients, residuals, _, _, _ = t
    print(t)
    mse = residuals[0]/(len(selected.index))
    nrmse = np.sqrt(mse)/(selected.max() - selected.min())
    return 1

# %%
window = (1,25,4)

# %%
def get_vals(r):

    row = r.copy()
    for i in range(window[0], window[1], window[2]):

        if i==1:
            lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

            b_window_start = row["MedTimeFromAdmit"].total_seconds()
            b_window_end = row["MedTimeFromAdmit"].total_seconds() - 1*3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
            lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"before_abs_0_0"] = {}
                row[f"before_time_0_0"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"before_abs_0_0"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"before_time_0_0"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

            lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
            med2_bool = check_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
            a_window_start = row["MedTimeFromAdmit"].total_seconds()
            a_window_end = row["MedTimeFromAdmit"].total_seconds() + 3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
            lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            if med2_bool:
                med2_val = get_med2(row)
                lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
            
            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"after_abs_0_0"] = {}
                row[f"after_time_0_0"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"after_abs_0_0"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"after_time_0_0"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
    
        lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

        b_window_start = row["MedTimeFromAdmit"].total_seconds() - (i*3600)
        b_window_end = row["MedTimeFromAdmit"].total_seconds() - (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
        lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"before_abs_{i}_{window[2]}"] = {}
            row[f"before_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"before_abs_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"before_time_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

        lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
        med2_bool = check_med2(row)
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
        a_window_start = row["MedTimeFromAdmit"].total_seconds() + (i*3600)
        a_window_end = row["MedTimeFromAdmit"].total_seconds() + (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
        lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        if med2_bool:
            med2_val = get_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
        
        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"after_abs_{i}_{window[2]}"] = {}
            row[f"after_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"after_abs_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"after_time_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
        
    return row

# %%
# type = "abs"
all_types = set(["abs", "time"])
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types]
cols_a = [f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types]
cols_b.extend([f"before_{t}_0_0" for t in all_types])
cols_a.extend([f"after_{t}_0_0" for t in all_types])
cols = cols_b.copy()
cols.extend(cols_a)

# %%
temp = t_med1.copy()
temp = temp.apply(lambda r : get_vals(r), axis=1)

# %%
temp
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 214            820  2077-04-26      M  2144-03-24 00:00:00            1
# 255            854  2079-06-12      M                  NaN            0
# 257            854  2079-06-12      M                  NaN            0
# 258            854  2079-06-12      M                  NaN            0
# 593            357  2135-03-22      M  2201-08-02 00:00:00            1
# ...            ...         ...    ...                  ...          ...
# 322821       44069  2064-04-08      M                  NaN            0
# 322822       44069  2064-04-08      M                  NaN            0
# 322824       44069  2064-04-08      M                  NaN            0
# 322825       44069  2064-04-08      M                  NaN            0
# 322826       44069  2064-04-08      M                  NaN            0
#
#         ITEMID  HADM_ID  ICUSTAY_ID           STARTTIME             ENDTIME  \
# 214     222011   193603    280074.0 2144-02-25 11:30:00 2144-02-25 13:30:00
# 255     225168   175684    245192.0 2146-10-03 09:54:00 2146-10-03 10:54:00
# 257     227522   175684    245192.0 2146-10-03 14:54:00 2146-10-03 15:54:00
# 258     225166   175684    245192.0 2146-10-03 14:54:00 2146-10-03 15:54:00
# 593     225798   101651    259107.0 2199-10-20 22:33:00 2199-10-20 22:34:00
# ...        ...      ...         ...                 ...                 ...
# 322821  221456   138192    214441.0 2131-02-15 19:28:00 2131-02-15 20:28:00
# 322822  225850   138192    214441.0 2131-02-15 20:35:00 2131-02-15 20:36:00
# 322824  225798   138192    214441.0 2131-02-15 21:39:00 2131-02-15 21:40:00
# 322825  223258   138192    214441.0 2131-02-15 22:30:00 2131-02-15 22:31:00
# 322826  220864   138192    214441.0 2131-02-15 21:53:00 2131-02-15 23:53:00
#
#         ...  after_abs_13_4 after_time_13_4  before_abs_17_4 before_time_17_4  \
# 214     ...              {}              {}               {}               {}
# 255     ...              {}              {}               {}               {}
# 257     ...              {}              {}               {}               {}
# 258     ...              {}              {}               {}               {}
# 593     ...              {}              {}               {}               {}
# ...     ...             ...             ...              ...              ...
# 322821  ...              {}              {}               {}               {}
# 322822  ...              {}              {}               {}               {}
# 322824  ...              {}              {}               {}               {}
# 322825  ...              {}              {}               {}               {}
# 322826  ...              {}              {}               {}               {}
#
#        after_abs_17_4  after_time_17_4  before_abs_21_4  before_time_21_4  \
# 214                {}               {}               {}                {}
# 255                {}               {}               {}                {}
# 257                {}               {}               {}                {}
# 258                {}               {}               {}                {}
# 593                {}               {}               {}                {}
# ...               ...              ...              ...               ...
# 322821             {}               {}               {}                {}
# 322822             {}               {}               {}                {}
# 322824             {}               {}               {}                {}
# 322825             {}               {}               {}                {}
# 322826             {}               {}               {}                {}
#
#        after_abs_21_4 after_time_21_4
# 214                {}              {}
# 255                {}              {}
# 257                {}              {}
# 258                {}              {}
# 593                {}              {}
# ...               ...             ...
# 322821             {}              {}
# 322822             {}              {}
# 322824             {}              {}
# 322825             {}              {}
# 322826             {}              {}
#
# [11337 rows x 92 columns]

# %%
temp.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_first_val_{stratify_prefix}.csv"))

# %%
# import ast
# for c in cols:
#     temp[c] = temp[c].apply(lambda x : ast.literal_eval(x))

# %%
# [c for c in cols for i in temp[c].to_list() if len(i)>0]

# %%
col_vals = []
for col in cols:
    col_vals.append(
        temp.assign(dict=temp[col].map(lambda d: d.items())).explode("dict", ignore_index=True).assign(
            LAB_ITEMID=lambda df: df.dict.str.get(0),
            temp=lambda df: df.dict.str.get(1)
        ).drop(columns=["dict"]+cols).astype({'temp':'float64', 'LAB_ITEMID':'float64'}).rename(columns={"temp":f"{col}_sp"}).dropna(subset=["LAB_ITEMID"])
    )

# %%
for i in range(1, len(col_vals)):
    col_vals[i] = pd.merge(col_vals[i-1], col_vals[i], how="outer", on=list(t_med1.columns)+["LAB_ITEMID"])

# %%
final = col_vals[-1][list(t_med1.columns)+["LAB_ITEMID"]+[f"{col}_sp" for col in cols]]

# %%
t_final = pd.merge(final.rename(columns={"LABEL":"MED_NAME"}), labitems.rename(columns={"ITEMID":"LAB_ITEMID"}), on="LAB_ITEMID", how="inner").rename(columns={"LABEL":"LAB_NAME"})
final = t_final

# %%
final.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_trends_first_val_{stratify_prefix}.csv"))

# %%
t_final = final.copy()
plot_data = {}
for b in [f"{c}_sp" for c in cols_b]:
    if b in t_final.columns:
        plot_data[b] = []
        for a in [f"{c}_sp" for c in cols_a]:
            if a in t_final.columns:
                plot_data[b].append(t_final.dropna(subset=[a,b]))
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data_concat = {}
for i in plot_data:
    plot_data_concat[i] = pd.concat(plot_data[i])

# %%
[(k, plot_data_concat[k].shape) for k in plot_data_concat]
# Out:
# [('before_time_1_4_sp', (6244, 98)),
#  ('before_abs_1_4_sp', (6244, 98)),
#  ('before_time_5_4_sp', (5198, 98)),
#  ('before_abs_5_4_sp', (5198, 98)),
#  ('before_time_9_4_sp', (2700, 98)),
#  ('before_abs_9_4_sp', (2700, 98)),
#  ('before_time_13_4_sp', (1862, 98)),
#  ('before_abs_13_4_sp', (1862, 98)),
#  ('before_time_17_4_sp', (2048, 98)),
#  ('before_abs_17_4_sp', (2048, 98)),
#  ('before_time_21_4_sp', (1452, 98)),
#  ('before_abs_21_4_sp', (1452, 98)),
#  ('before_time_0_0_sp', (2252, 98)),
#  ('before_abs_0_0_sp', (2252, 98))]

# %%
# type = "abs"
a_t = ["abs", "time"]
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b_sp = [(f"before_{a_t[0]}_{i}_{window[2]}_sp", f"before_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2]) ]
cols_a_sp = [(f"after_{a_t[0]}_{i}_{window[2]}_sp", f"after_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2])]
cols_b_sp.append((f"before_abs_0_0_sp", f"before_time_0_0_sp"))
cols_a_sp.append((f"after_abs_0_0_sp", f"after_time_0_0_sp"))
cols_sp = cols_b_sp.copy()
cols_sp.extend(cols_a_sp)

# %%
t_final = final.copy()
plot_data = {}
for b in cols_b_sp:
    if b[0] in t_final.columns:
        plot_data[b[0]] = {}
        for a in cols_a_sp: 
            if a[0] in t_final.columns:
                # print(a, b)
                plot_data[b[0]][a[0]] = t_final.dropna(subset=[a[0], a[1], b[0], b[1]])
                # print(plot_data[b][a][[a, b]])
                # print(plot_data.keys())
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data.keys()
# Out:
# dict_keys(['before_abs_1_4_sp', 'before_abs_5_4_sp', 'before_abs_9_4_sp', 'before_abs_13_4_sp', 'before_abs_17_4_sp', 'before_abs_21_4_sp', 'before_abs_0_0_sp'])

# %%
import pickle
pickle.dump(plot_data, open(f"plot_bw_aw_med_lab_data_{stratify_prefix}.pkl", "wb"))

# %%
cols_sp
# Out:
# [('before_abs_1_4_sp', 'before_time_1_4_sp'),
#  ('before_abs_5_4_sp', 'before_time_5_4_sp'),
#  ('before_abs_9_4_sp', 'before_time_9_4_sp'),
#  ('before_abs_13_4_sp', 'before_time_13_4_sp'),
#  ('before_abs_17_4_sp', 'before_time_17_4_sp'),
#  ('before_abs_21_4_sp', 'before_time_21_4_sp'),
#  ('before_abs_0_0_sp', 'before_time_0_0_sp'),
#  ('after_abs_1_4_sp', 'after_time_1_4_sp'),
#  ('after_abs_5_4_sp', 'after_time_5_4_sp'),
#  ('after_abs_9_4_sp', 'after_time_9_4_sp'),
#  ('after_abs_13_4_sp', 'after_time_13_4_sp'),
#  ('after_abs_17_4_sp', 'after_time_17_4_sp'),
#  ('after_abs_21_4_sp', 'after_time_21_4_sp'),
#  ('after_abs_0_0_sp', 'after_time_0_0_sp')]

# %%
cols_d = dict(cols_sp)

# %%
p_data.keys()
# Out:
# dict_keys([('Cefazolin', 'Base Excess'), ('KCL (Bolus)', 'Base Excess'), ('OR Crystalloid Intake', 'Base Excess'), ('OR Cell Saver Intake', 'Base Excess'), ('Morphine Sulfate', 'Base Excess'), ('Potassium Chloride', 'Base Excess'), ('Calcium Gluconate', 'Base Excess'), ('Vancomycin', 'Base Excess'), ('Albumin 5%', 'Base Excess'), ('Insulin - Regular', 'Base Excess'), ('Ranitidine (Prophylaxis)', 'Base Excess'), ('Magnesium Sulfate (Bolus)', 'Base Excess'), ('Magnesium Sulfate', 'Base Excess'), ('LR', 'Base Excess'), ('Packed Red Blood Cells', 'Base Excess'), ('Cefazolin', 'pO2'), ('KCL (Bolus)', 'pO2'), ('OR Crystalloid Intake', 'pO2'), ('OR Cell Saver Intake', 'pO2'), ('Morphine Sulfate', 'pO2'), ('Potassium Chloride', 'pO2'), ('Calcium Gluconate', 'pO2'), ('Vancomycin', 'pO2'), ('Albumin 5%', 'pO2'), ('Insulin - Regular', 'pO2'), ('Ranitidine (Prophylaxis)', 'pO2'), ('Magnesium Sulfate (Bolus)', 'pO2'), ('Magnesium Sulfate', 'pO2'), ('LR', 'pO2'), ('Packed Red Blood Cells', 'pO2'), ('Calcium Gluconate', 'Glucose'), ('Ranitidine (Prophylaxis)', 'Glucose'), ('Cefazolin', 'Glucose'), ('Insulin - Regular', 'Glucose'), ('OR Crystalloid Intake', 'Glucose'), ('Magnesium Sulfate', 'Glucose'), ('Potassium Chloride', 'Glucose'), ('Magnesium Sulfate (Bolus)', 'Glucose'), ('KCL (Bolus)', 'Glucose'), ('Albumin 5%', 'Glucose'), ('Vancomycin', 'Glucose'), ('Packed Red Blood Cells', 'Glucose'), ('LR', 'Glucose'), ('Calcium Gluconate', 'Magnesium'), ('Ranitidine (Prophylaxis)', 'Magnesium'), ('Cefazolin', 'Magnesium'), ('Insulin - Regular', 'Magnesium'), ('OR Crystalloid Intake', 'Magnesium'), ('Magnesium Sulfate', 'Magnesium'), ('Potassium Chloride', 'Magnesium'), ('Magnesium Sulfate (Bolus)', 'Magnesium'), ('KCL (Bolus)', 'Magnesium'), ('Albumin 5%', 'Magnesium'), ('Vancomycin', 'Magnesium'), ('Packed Red Blood Cells', 'Magnesium'), ('Morphine Sulfate', 'Magnesium'), ('LR', 'Magnesium'), ('Calcium Gluconate', 'Hematocrit'), ('OR Crystalloid Intake', 'Hematocrit'), ('OR Cell Saver Intake', 'Hematocrit'), ('Insulin - Regular', 'Hematocrit'), ('Potassium Chloride', 'Hematocrit'), ('KCL (Bolus)', 'Hematocrit'), ('Magnesium Sulfate', 'Hematocrit'), ('Morphine Sulfate', 'Hematocrit'), ('Magnesium Sulfate (Bolus)', 'Hematocrit'), ('Albumin 5%', 'Hematocrit'), ('Cefazolin', 'Hematocrit'), ('LR', 'Hematocrit'), ('Vancomycin', 'Hematocrit'), ('Ranitidine (Prophylaxis)', 'Hematocrit'), ('Packed Red Blood Cells', 'Hematocrit'), ('Calcium Gluconate', 'Hemoglobin'), ('Potassium Chloride', 'Hemoglobin'), ('KCL (Bolus)', 'Hemoglobin'), ('Morphine Sulfate', 'Hemoglobin'), ('OR Crystalloid Intake', 'Hemoglobin'), ('Magnesium Sulfate (Bolus)', 'Hemoglobin'), ('Magnesium Sulfate', 'Hemoglobin'), ('Albumin 5%', 'Hemoglobin'), ('Cefazolin', 'Hemoglobin'), ('OR Cell Saver Intake', 'Hemoglobin'), ('LR', 'Hemoglobin'), ('Insulin - Regular', 'Hemoglobin'), ('Vancomycin', 'Hemoglobin'), ('Ranitidine (Prophylaxis)', 'Hemoglobin'), ('Calcium Gluconate', 'Red Blood Cells'), ('Potassium Chloride', 'Red Blood Cells'), ('KCL (Bolus)', 'Red Blood Cells'), ('Morphine Sulfate', 'Red Blood Cells'), ('OR Crystalloid Intake', 'Red Blood Cells'), ('Magnesium Sulfate (Bolus)', 'Red Blood Cells'), ('Magnesium Sulfate', 'Red Blood Cells'), ('Albumin 5%', 'Red Blood Cells'), ('Cefazolin', 'Red Blood Cells'), ('OR Cell Saver Intake', 'Red Blood Cells'), ('LR', 'Red Blood Cells'), ('Insulin - Regular', 'Red Blood Cells'), ('Vancomycin', 'Red Blood Cells'), ('OR Cell Saver Intake', 'Glucose'), ('Morphine Sulfate', 'Glucose'), ('Ranitidine (Prophylaxis)', 'Red Blood Cells'), ('OR Cell Saver Intake', 'Magnesium'), ('Packed Red Blood Cells', 'Hemoglobin'), ('Packed Red Blood Cells', 'Red Blood Cells')])

# %%
p_data[('Insulin - Regular', 'Glucose')]['before_abs_1_4_sp'][0]
# Out:
#                             SUBJECT_ID  HADM_ID  before_abs_1_4_sp  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose        41984   176631              123.0
#                   Glucose        47003   111981              194.0
#                   Glucose        74129   123029              411.0
#                   Glucose        79645   129244              116.0
#                   Glucose        78416   102966              190.0
#                   Glucose        85881   198129              220.0
#                   Glucose        64093   177133              116.0
#                   Glucose        74789   173650              131.0
#                   Glucose        61265   104723              167.0
#                   Glucose        87207   180456              183.0
#                   Glucose        83167   169287              141.0
#                   Glucose        95191   176592              154.0
#                   Glucose        66641   153726              143.0
#                   Glucose        43786   151092              106.0
#
#                             after_abs_1_4_sp  after_time_1_4_sp    abs  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose              105.0           4.850000  -18.0
#                   Glucose              171.0           1.066667  -23.0
#                   Glucose              378.0           3.100000  -33.0
#                   Glucose               98.0           1.583333  -18.0
#                   Glucose              141.0           2.316667  -49.0
#                   Glucose              163.0           3.383333  -57.0
#                   Glucose              127.0           1.033333   11.0
#                   Glucose              141.0           2.500000   10.0
#                   Glucose              151.0           1.333333  -16.0
#                   Glucose              322.0           2.100000  139.0
#                   Glucose              154.0           2.700000   13.0
#                   Glucose              119.0           3.433333  -35.0
#                   Glucose              293.0           1.800000  150.0
#                   Glucose              112.0           2.183333    6.0
#
#                                percent     ratio
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose   -14.634146  0.853659
#                   Glucose   -11.855670  0.881443
#                   Glucose    -8.029197  0.919708
#                   Glucose   -15.517241  0.844828
#                   Glucose   -25.789474  0.742105
#                   Glucose   -25.909091  0.740909
#                   Glucose     9.482759  1.094828
#                   Glucose     7.633588  1.076336
#                   Glucose    -9.580838  0.904192
#                   Glucose    75.956284  1.759563
#                   Glucose     9.219858  1.092199
#                   Glucose   -22.727273  0.772727
#                   Glucose   104.895105  2.048951
#                   Glucose     5.660377  1.056604

# %%
import pickle
# pickle.dump(p_data, open(f"plot_med_lab_bw_aw_data_{stratify_prefix}.pkl", "wb"))

# %%
p_data = pickle.load(open(f"plot_med_lab_bw_aw_data_{stratify_prefix}.pkl", "rb"))

# %%
def int_s(s):
    if s[0]=="_":
        return int(s[1:])
    else:
        return int(s)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns

def sort_rows_with_time(p_corrs, s_corrs, after_windows):
    s_p = sorted([k for k in zip(p_corrs, after_windows)])
    p_corrs = [k[0] for k in s_p]
    after_windows1 = [k[1] for k in s_p]
    s_s = sorted([k for k in zip(s_corrs, after_windows)])
    s_corrs = [k[0] for k in s_s]
    after_windows2 = [k[1] for k in s_p]
    return p_corrs, s_corrs, after_windows1, after_windows2

def plot_corrs(corrs, after_windows, ax, title='', plot_name='',  after_window_info=None):

    p_corrs = [c[0] for c in corrs]
    s_corrs = [c[1] for c in corrs]
    final_plot_name = f'{plot_name}_{title}'
    after_windows = [int_s(a[-7:-5]) for a in after_windows]
    
    p_corrs, s_corrs, after_windows1, after_windows2 = sort_rows_with_time(p_corrs, s_corrs, after_windows)
    
    # print(ax, [ k for k in zip(p_corrs, after_windows)])
    # print(ax, [ k for k in zip(s_corrs, after_windows)])
    
    # ax.plot(after_windows, p_corrs)
    # ax.set_title(f'{final_plot_name} Pearsons Corr')
    # ax.set(xlabel='Time in hours', ylabel='Correlation')

    ax[0].plot(after_windows1, p_corrs, '-o')
    ax[0].set_title(f'{final_plot_name} Pearsons Corr')
    ax[0].set(xlabel='Time in hours', ylabel='Correlation')
    ax[0].set_xticks(after_windows1)
    ax[0].grid()
    # ax[0].grid(axis='x')

    ax[1].plot(after_windows2, s_corrs, '-o')
    ax[1].set_title(f'{final_plot_name} Spearmans Corr')
    ax[1].set(xlabel='Time in hours', ylabel='Correlation')
    ax[1].set_xticks(after_windows2)
    # ax[1].grid(axis='x')
    ax[1].grid()
    

def plot_func(presc, lab, d, dirname, window=(1,24), title='', unit='mg/dL', labels=None, plot_name='', ax=None):
    
    plot_data = d
    # plot_data = plot_data.rename(columns={0:'Lab values'})

    # plot_data = plot_data[plot_data['timeFromPrescription'] > window[0]]
    # plot_data = plot_data[plot_data['timeFromPrescription'] < window[1]]

    if ax is None:
        sns.regplot(x = "time", 
                y = 'data', 
                data = plot_data.sort_values(["time"]), 
                truncate=False)
        plt.title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        plt.xlabel('Time in hours')
        plt.ylabel(title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            plt.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))
        if not os.path.isdir(f"{lab}<>{presc}"):
            os.mkdir(f"{lab}<>{presc}")
        if dirname is None or dirname == "":
            plt.savefig(os.path.join(f"{lab}<>{presc}", plot_name+".png"))
        else:
            if not os.path.isdir(os.path.join(f"{lab}<>{presc}", dirname)):
                os.mkdir(os.path.join(f"{lab}<>{presc}", dirname))
            plt.savefig(os.path.join(f"{lab}<>{presc}", dirname, plot_name+".png"))
        plt.clf()
    
    else:
        sns.regplot(
                ax=ax,
                x = "time", 
                y = 'data', 
                data = plot_data.sort_values(["time"]), 
                truncate=False)
        ax.set_title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        ax.set(xlabel='Time in hours', ylabel=title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            ax.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))

def remove_outlier(val, time_diff):
    val = pd.DataFrame(val)
    time_diff = pd.DataFrame(time_diff)
    
    # IQR
    Q1 = np.percentile(val, 25, method = 'midpoint')        
    Q3 = np.percentile(val, 75, method = 'midpoint')
    IQR = Q3 - Q1        
    
    # Upper bound
    upper = np.where(val >= (Q3+1.5*IQR))
    # Lower bound
    lower = np.where(val <= (Q1-1.5*IQR))

    # Filtering
    if len(upper) > 0:
        val.drop(upper[0], inplace = True)
        time_diff.drop(upper[0], inplace = True)
    if len(lower) > 0:
        val.drop(lower[0], inplace = True)
        time_diff.drop(lower[0], inplace = True)
    return val, time_diff

# %%
types = ['abs', 'percent', 'ratio']
corrs_data_dict = []
for k, v in p_data.items():
    for key in v:
        lab = k[0]
        presc = k[1]
        before_window = int_s(key[-7:-5])

        fig_all, ax_all = plt.subplots(3, figsize=(20, 20))
        fig_all.suptitle(f'{lab}<>{presc} (before window = {str(before_window)})')

        if not os.path.isdir(f"{lab}<>{presc}"):
            os.mkdir(f"{lab}<>{presc}")
        
        dirname=f"bw_{int_s(key[-7:-5])}"
        if not os.path.isdir(os.path.join(f"{lab}<>{presc}", dirname)):
            os.mkdir(os.path.join(f"{lab}<>{presc}", dirname))

        for i, type in enumerate(types):
            plot_name = f"{k[0]}<>{k[1]}_{key}_{type}"
            data_vals = [d[[list(d.columns)[-4], type]].rename(columns={list(d.columns)[-4] : "time"}) for d in v[key]]
            after_names = [list(d.columns)[3] for d in v[key]]
            print("checking", len(data_vals), len(after_names))
            if len(data_vals)!=len(after_names):
                print(data_vals)
                print(after_names)
                print()
                continue
            
            d = pd.concat(data_vals)
            if d.shape[0]<2:
                continue
            if d.shape[0]>1:
                d1, d2 = remove_outlier(d[type], d["time"])
            else:
                d1, d2 = d[[type]], d[["time"]]
            d = pd.concat([d1, d2], axis=1)

            p_corr, _ = pearsonr(d1[type], d2["time"])
            s_corr, _ = spearmanr(d1[type], d2["time"])

            plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname="", labels=(p_corr, s_corr), title=f"bw({int_s(key[-7:-5])}) {type}", plot_name=f"{plot_name}", ax=ax_all[i])

            fig_corrs, ax_corrs = plt.subplots(2, figsize=(20, 20))
            fig_corrs.suptitle(f'{lab}<>{presc} {type} corrs') 
            corrs = []
            temp_after_names = after_names.copy()
            for i, d in enumerate(data_vals):
                if d.shape[0]<2:
                    temp_after_names.remove(after_names[i])
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])
                corrs.append((p_corr, s_corr))
            after_names = temp_after_names
            plot_corrs(corrs, after_names, ax_corrs, title=type, plot_name=plot_name)
            fig_corrs.savefig(os.path.join(f"{lab}<>{presc}", dirname, f"{plot_name}_{type}_{stratify_prefix}_corrs.png"))
            fig_corrs.clf()

            for d, a, c in zip(data_vals, after_names, corrs):
                if d.shape[0]<2:
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                d = pd.concat([d1, d2], axis=1)

                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])

                plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname=dirname, labels=c, title=f"bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])}) {type}", plot_name=f"{plot_name} bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])})")
                corrs_data_dict.append({
                    "lab" : lab,
                    "med": presc,
                    "bw": before_window,
                    "aw": int_s(a[-7:-5]),
                    "type": type
                })
                    
        fig_all.savefig(os.path.join(f"{lab}<>{presc}", dirname, f"{plot_name}_{stratify_prefix}.png"))
        fig_all.clf()
corrs_data_df = pd.DataFrame(corrs_data_dict)
corrs_data_df.to_csv(f"corrs_data_{stratify_prefix}.csv")
# Out:
# checking 5 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb Cell 79 in <cell line: 3>()
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=31'>32</a>     continue
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=32'>33</a> if d.shape[0]>1:
# ---> <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=33'>34</a>     d1, d2 = remove_outlier(d[type], d["time"])
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=34'>35</a> else:
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=35'>36</a>     d1, d2 = d[[type]], d[["time"]]
#
# /Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb Cell 79 in remove_outlier(val, time_diff)
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=88'>89</a> time_diff = pd.DataFrame(time_diff)
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=90'>91</a> # IQR
# ---> <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=91'>92</a> Q1 = np.percentile(val, 25, method = 'midpoint')
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=92'>93</a> Q3 = np.percentile(val, 75, method = 'midpoint')
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y141sZmlsZQ%3D%3D?line=93'>94</a> IQR = Q3 - Q1
#
# NameError: name 'np' is not defined

# %%
plot_dir = os.path.join(os.getcwd(), f"plots_{stratify_prefix}")
os.mkdir(plot_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb Cell 82 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y145sZmlsZQ%3D%3D?line=0'>1</a> plot_dir = os.path.join(os.getcwd(), f"plots_{stratify_prefix}")
# ----> <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/stratified_plots_and_before_after_stats.ipynb#Y145sZmlsZQ%3D%3D?line=1'>2</a> os.mkdir(plot_dir)
#
# FileExistsError: [Errno 17] File exists: '/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/plots_50-60_M_WHITE'

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
corrs_data_dict = []
types = ['abs', 'percent', 'ratio']
for k, v in p_data.items():
    for key in v:
        lab = k[0]
        presc = k[1]
        before_window = int_s(key[-7:-5])

        for i, type in enumerate(types):
            plot_name = f"{k[0]}<>{k[1]}_{key}_{type}"
            data_vals = [d[[list(d.columns)[-4], type]].rename(columns={list(d.columns)[-4] : "time"}) for d in v[key]]
            after_names = [list(d.columns)[3] for d in v[key]]
            if len(data_vals)!=len(after_names):
                continue

            for d, a in zip(data_vals, after_names):
                d = d.replace([np.inf, -np.inf], np.nan).dropna()

                if d.shape[0]<2:
                    continue
                if d.shape[0]>1:
                    d1, d2 = remove_outlier(d[type], d["time"])
                else:
                    d1, d2 = d[[type]], d[["time"]]
                d = pd.concat([d1, d2], axis=1)

                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])

                corrs_data_dict.append({
                    "lab" : lab,
                    "med": presc,
                    "bw": before_window,
                    "aw": int_s(a[-7:-5]),
                    "type": type,
                    "p_corr": p_corr,
                    "s_corr": s_corr,
                    "num": d.shape[0]
                })
# Out:
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/yanpavan/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4878: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))

# %%
corrs_data_df_seperate = pd.DataFrame(corrs_data_dict)

# %%
corrs_data_df_seperate
# Out:
#                          lab              med  bw  aw     type    p_corr  \
# 0                  Cefazolin      Base Excess   1   1      abs  0.022489
# 1                  Cefazolin      Base Excess   1   5      abs  0.615739
# 2                  Cefazolin      Base Excess   1   0      abs  1.000000
# 3                  Cefazolin      Base Excess   1   1  percent -0.115735
# 4                  Cefazolin      Base Excess   1   5  percent -0.744376
# ...                      ...              ...  ..  ..      ...       ...
# 6432  Packed Red Blood Cells  Red Blood Cells  21   1  percent -0.970976
# 6433  Packed Red Blood Cells  Red Blood Cells  21   1    ratio -0.970976
# 6434  Packed Red Blood Cells  Red Blood Cells   0  21      abs  1.000000
# 6435  Packed Red Blood Cells  Red Blood Cells   0  21  percent  1.000000
# 6436  Packed Red Blood Cells  Red Blood Cells   0  21    ratio  1.000000
#
#         s_corr  num
# 0     0.081832    8
# 1     0.410391    5
# 2     1.000000    2
# 3    -0.222718    7
# 4    -0.800000    4
# ...        ...  ...
# 6432 -1.000000    3
# 6433 -1.000000    3
# 6434  1.000000    2
# 6435  1.000000    2
# 6436  1.000000    2
#
# [6437 rows x 8 columns]

# %%
corrs_data_df_seperate[corrs_data_df_seperate["num"]>10].sort_values(["p_corr"]).head(30)
# Out:
#                         lab          med  bw  aw     type    p_corr    s_corr  \
# 5159  OR Crystalloid Intake   Hemoglobin   1   1      abs -0.675996 -0.514808
# 5166  OR Crystalloid Intake   Hemoglobin   1   1  percent -0.649004 -0.509091
# 5173  OR Crystalloid Intake   Hemoglobin   1   1    ratio -0.649004 -0.509091
# 2604  OR Crystalloid Intake      Glucose   1   5      abs -0.619701 -0.788816
# 616       Insulin - Regular  Base Excess   1   1      abs -0.578914 -0.400404
# 2618  OR Crystalloid Intake      Glucose   1   5    ratio -0.572338 -0.791759
# 2611  OR Crystalloid Intake      Glucose   1   5  percent -0.572338 -0.791759
# 2184                     LR          pO2   5   0      abs -0.567599 -0.528897
# 6246   OR Cell Saver Intake      Glucose   1   5      abs -0.550749 -0.706152
# 6266   OR Cell Saver Intake      Glucose   5   1      abs -0.543877 -0.050114
# 6253   OR Cell Saver Intake      Glucose   1   5  percent -0.537384 -0.706152
# 6260   OR Cell Saver Intake      Glucose   1   5    ratio -0.537384 -0.706152
# 1157            KCL (Bolus)          pO2   5   0      abs -0.512500 -0.454545
# 470              Vancomycin  Base Excess   1   9      abs -0.506179 -0.495150
# 1389     Potassium Chloride          pO2   1   0  percent -0.500248 -0.497937
# 1396     Potassium Chloride          pO2   1   0    ratio -0.500248 -0.497937
# 2303      Calcium Gluconate      Glucose   5   1      abs -0.484538 -0.382916
# 1382     Potassium Chloride          pO2   1   0      abs -0.481022 -0.437414
# 1150            KCL (Bolus)          pO2   1   0    ratio -0.479317 -0.495050
# 1143            KCL (Bolus)          pO2   1   0  percent -0.479317 -0.495050
# 2609  OR Crystalloid Intake      Glucose   1   0      abs -0.477747 -0.336364
# 2616  OR Crystalloid Intake      Glucose   1   0  percent -0.475575 -0.354545
# 2623  OR Crystalloid Intake      Glucose   1   0    ratio -0.475575 -0.354545
# 1289   OR Cell Saver Intake          pO2   1   1      abs -0.468696 -0.496709
# 2693  OR Crystalloid Intake      Glucose   0   5    ratio -0.464546 -0.602941
# 2686  OR Crystalloid Intake      Glucose   0   5  percent -0.464546 -0.602941
# 1303   OR Cell Saver Intake          pO2   1   1    ratio -0.449332 -0.445614
# 1296   OR Cell Saver Intake          pO2   1   1  percent -0.449332 -0.445614
# 2186                     LR          pO2   5   0  percent -0.444658 -0.511384
# 2188                     LR          pO2   5   0    ratio -0.444658 -0.511384
#
#       num
# 5159   11
# 5166   11
# 5173   11
# 2604   16
# 616    15
# 2618   16
# 2611   16
# 2184   12
# 6246   11
# 6266   11
# 6253   11
# 6260   11
# 1157   11
# 470    13
# 1389   13
# 1396   13
# 2303   16
# 1382   13
# 1150   14
# 1143   14
# 2609   11
# 2616   11
# 2623   11
# 1289   19
# 2693   16
# 2686   16
# 1303   19
# 1296   19
# 2186   12
# 2188   12

# %%
corrs_data_df_seperate[corrs_data_df_seperate["num"]>10].sort_values(["p_corr"]).tail(30)
# Out:
#                         lab          med  bw  aw     type    p_corr    s_corr  \
# 1502      Calcium Gluconate          pO2   5   1      abs  0.290715  0.278068
# 1404     Potassium Chloride          pO2   5   1  percent  0.293004  0.095588
# 1411     Potassium Chloride          pO2   5   1    ratio  0.293004  0.095588
# 1397     Potassium Chloride          pO2   5   1      abs  0.293541  0.225490
# 3219             Vancomycin      Glucose  13   5      abs  0.300352  0.184573
# 1604             Vancomycin          pO2   1   1      abs  0.333745  0.052671
# 374       Calcium Gluconate  Base Excess   5   1      abs  0.341687  0.254155
# 510              Vancomycin  Base Excess   9   1      abs  0.350723  0.257049
# 224    OR Cell Saver Intake  Base Excess   0   1      abs  0.366325  0.294887
# 3225             Vancomycin      Glucose  13   5  percent  0.383810  0.189821
# 3231             Vancomycin      Glucose  13   5    ratio  0.383810  0.189821
# 1508      Calcium Gluconate          pO2   5   1  percent  0.412633  0.242279
# 1514      Calcium Gluconate          pO2   5   1    ratio  0.412633  0.242279
# 1297   OR Cell Saver Intake          pO2   1   5  percent  0.418698 -0.085400
# 1304   OR Cell Saver Intake          pO2   1   5    ratio  0.418698 -0.085400
# 477              Vancomycin  Base Excess   1   9  percent  0.431013  0.334518
# 484              Vancomycin  Base Excess   1   9    ratio  0.431013  0.334518
# 375       Calcium Gluconate  Base Excess   5   5      abs  0.438325  0.662999
# 1606             Vancomycin          pO2   1   9      abs  0.452780  0.341599
# 1611             Vancomycin          pO2   1   1  percent  0.455146  0.109774
# 1618             Vancomycin          pO2   1   1    ratio  0.455146  0.109774
# 285      Potassium Chloride  Base Excess   5   0      abs  0.502938  0.621419
# 625       Insulin - Regular  Base Excess   5   1      abs  0.519882  0.497922
# 4785             Vancomycin   Hematocrit  13   5      abs  0.534880  0.441915
# 4791             Vancomycin   Hematocrit  13   5  percent  0.570052  0.478361
# 4797             Vancomycin   Hematocrit  13   5    ratio  0.570052  0.478361
# 130   OR Crystalloid Intake  Base Excess   1   5      abs  0.580996  0.546476
# 6335       Morphine Sulfate      Glucose   5   0      abs  0.724798  0.748858
# 6343       Morphine Sulfate      Glucose   5   0    ratio  0.729682  0.751710
# 6339       Morphine Sulfate      Glucose   5   0  percent  0.729682  0.751710
#
#       num
# 1502   24
# 1404   17
# 1411   17
# 1397   17
# 3219   13
# 1604   20
# 374    21
# 510    12
# 224    12
# 3225   13
# 3231   13
# 1508   24
# 1514   24
# 1297   13
# 1304   13
# 477    12
# 484    12
# 375    13
# 1606   13
# 1611   20
# 1618   20
# 285    11
# 625    11
# 4785   11
# 4791   11
# 4797   11
# 130    13
# 6335   11
# 6343   11
# 6339   11

# %%
corrs_data_df_seperate.to_csv(os.path.join(plot_dir, f"corrs_data_{stratify_prefix}.csv"))

# %%
corrs_data_df_seperate
# Out:
#                             lab      med  bw  aw   type    p_corr    s_corr
# 0             Insulin - Regular  Glucose   1   1    abs  0.009684  0.020115
# 1             Insulin - Regular  Glucose   1   5    abs  0.082407  0.235885
# 2             Insulin - Regular  Glucose   1   9    abs  0.328160  0.318561
# 3             Insulin - Regular  Glucose   1  13    abs -0.458833 -0.193376
# 4             Insulin - Regular  Glucose   1  17    abs -0.277181 -0.345455
# ...                         ...      ...  ..  ..    ...       ...       ...
# 14758  Ranitidine (Prophylaxis)      pO2   0   9  ratio -0.016171  0.090686
# 14759  Ranitidine (Prophylaxis)      pO2   0  13  ratio  0.123384  0.490909
# 14760  Ranitidine (Prophylaxis)      pO2   0  17  ratio -0.405529 -0.142857
# 14761  Ranitidine (Prophylaxis)      pO2   0  21  ratio -0.529517 -0.500000
# 14762  Ranitidine (Prophylaxis)      pO2   0   0  ratio  0.369694  0.308712
#
# [14763 rows x 7 columns]
