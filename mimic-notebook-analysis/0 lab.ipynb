# %%
data = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/data"

# %%
import pandas as pd
import os

# %%
admits = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "ADMISSIONS.csv.gz"))

# %%
labevents = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "LABEVENTS.csv.gz"))

# %%
labevents
# Out:
#             ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              281           3       NaN   50820  2101-10-12 16:07:00  7.39
# 1              282           3       NaN   50800  2101-10-12 18:17:00   ART
# 2              283           3       NaN   50802  2101-10-12 18:17:00    -1
# 3              284           3       NaN   50804  2101-10-12 18:17:00    22
# 4              285           3       NaN   50808  2101-10-12 18:17:00  0.93
# ...            ...         ...       ...     ...                  ...   ...
# 27854050  27428435       96443  103219.0   50882  2109-12-30 01:40:00    26
# 27854051  27428436       96443  103219.0   50885  2109-12-30 01:40:00   2.1
# 27854052  27428437       96443  103219.0   50902  2109-12-30 01:40:00    97
# 27854053  27428438       96443  103219.0   50911  2109-12-30 01:40:00     2
# 27854054  27428439       96443  103219.0   50912  2109-12-30 01:40:00   1.6
#
#           VALUENUM VALUEUOM      FLAG
# 0             7.39    units       NaN
# 1              NaN      NaN       NaN
# 2            -1.00    mEq/L       NaN
# 3            22.00    mEq/L       NaN
# 4             0.93   mmol/L  abnormal
# ...            ...      ...       ...
# 27854050     26.00    mEq/L       NaN
# 27854051      2.10    mg/dL  abnormal
# 27854052     97.00    mEq/L       NaN
# 27854053      2.00    ng/mL       NaN
# 27854054      1.60    mg/dL  abnormal
#
# [27854055 rows x 9 columns]

# %%
d_labitems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw",'D_LABITEMS.csv.gz'))

# %%
d_labitems
# Out:
#      ROW_ID  ITEMID                       LABEL                      FLUID  \
# 0       546   51346                      Blasts  Cerebrospinal Fluid (CSF)
# 1       547   51347                 Eosinophils  Cerebrospinal Fluid (CSF)
# 2       548   51348             Hematocrit, CSF  Cerebrospinal Fluid (CSF)
# 3       549   51349  Hypersegmented Neutrophils  Cerebrospinal Fluid (CSF)
# 4       550   51350           Immunophenotyping  Cerebrospinal Fluid (CSF)
# ..      ...     ...                         ...                        ...
# 748     749   51551             VOIDED SPECIMEN           OTHER BODY FLUID
# 749     750   51552             VOIDED SPECIMEN                      STOOL
# 750     751   51553             VOIDED SPECIMEN                      URINE
# 751     752   51554             VOIDED SPECIMEN                JOINT FLUID
# 752     753   51555    SURFACTANT ALBUMIN RATIO           OTHER BODY FLUID
#
#        CATEGORY LOINC_CODE
# 0    Hematology    26447-3
# 1    Hematology    26451-5
# 2    Hematology    30398-2
# 3    Hematology    26506-6
# 4    Hematology        NaN
# ..          ...        ...
# 748  HEMATOLOGY        NaN
# 749   CHEMISTRY        NaN
# 750   CHEMISTRY        NaN
# 751  HEMATOLOGY        NaN
# 752   CHEMISTRY        NaN
#
# [753 rows x 6 columns]

# %%
labevents = pd.merge(labevents, d_labitems, how="inner", on="ITEMID")

# %%
labevents
# Out:
#           ROW_ID_x  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              281           3       NaN   50820  2101-10-12 16:07:00  7.39
# 1              289           3       NaN   50820  2101-10-12 18:17:00  7.42
# 2              396           3       NaN   50820  2101-10-15 12:42:00  7.49
# 3              976           3  145834.0   50820  2101-10-22 04:31:00  7.40
# 4              989           3  145834.0   50820  2101-10-22 07:13:00  7.37
# ...            ...         ...       ...     ...                  ...   ...
# 27854050  27701184       98573  175201.0   51169  2196-01-13 18:31:00     0
# 27854051  27700707       98573  175201.0   51170  2196-01-09 03:00:00    13
# 27854052  27699600       98573  175201.0   51170  2195-12-31 10:15:00     2
# 27854053  27701604       98573  175201.0   51170  2196-01-19 17:22:00     0
# 27854054  27701185       98573  175201.0   51170  2196-01-13 18:31:00     0
#
#           VALUENUM VALUEUOM FLAG  ROW_ID_y                LABEL  FLUID  \
# 0             7.39    units  NaN        21                   pH  Blood
# 1             7.42    units  NaN        21                   pH  Blood
# 2             7.49    units  NaN        21                   pH  Blood
# 3             7.40    units  NaN        21                   pH  Blood
# 4             7.37    units  NaN        21                   pH  Blood
# ...            ...      ...  ...       ...                  ...    ...
# 27854050      0.00        %  NaN       369               CD20 %  Blood
# 27854051     13.00     #/uL  NaN       370  CD20 Absolute Count  Blood
# 27854052      2.00     #/uL  NaN       370  CD20 Absolute Count  Blood
# 27854053      0.00     #/uL  NaN       370  CD20 Absolute Count  Blood
# 27854054      0.00     #/uL  NaN       370  CD20 Absolute Count  Blood
#
#             CATEGORY LOINC_CODE
# 0          Blood Gas    11558-4
# 1          Blood Gas    11558-4
# 2          Blood Gas    11558-4
# 3          Blood Gas    11558-4
# 4          Blood Gas    11558-4
# ...              ...        ...
# 27854050  Hematology        NaN
# 27854051  Hematology        NaN
# 27854052  Hematology        NaN
# 27854053  Hematology        NaN
# 27854054  Hematology        NaN
#
# [27854055 rows x 14 columns]

# %%
labevents = pd.merge(labevents, admits, how="inner", on="HADM_ID")

# %%
labevents
# Out:
#           ROW_ID_x  SUBJECT_ID_x   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              976             3  145834.0   50820  2101-10-22 04:31:00  7.40
# 1              989             3  145834.0   50820  2101-10-22 07:13:00  7.37
# 2              998             3  145834.0   50820  2101-10-22 10:16:00  7.37
# 3             1007             3  145834.0   50820  2101-10-22 11:21:00  7.39
# 4             1020             3  145834.0   50820  2101-10-22 13:02:00  7.39
# ...            ...           ...       ...     ...                  ...   ...
# 22245029  11174338         18054  100572.0   51455  2158-04-24 11:42:00    29
# 22245030  11174339         18054  100572.0   51457  2158-04-24 11:42:00   575
# 22245031  11174340         18054  100572.0   51458  2158-04-24 11:42:00  1325
# 22245032  11174335         18054  100572.0   51447  2158-04-24 11:42:00    10
# 22245033  11174333         18054  100572.0   51444  2158-04-24 11:42:00    31
#
#           VALUENUM VALUEUOM      FLAG  ROW_ID_y  ... INSURANCE LANGUAGE  \
# 0             7.40    units       NaN        21  ...  Medicare      NaN
# 1             7.37    units       NaN        21  ...  Medicare      NaN
# 2             7.37    units       NaN        21  ...  Medicare      NaN
# 3             7.39    units       NaN        21  ...  Medicare      NaN
# 4             7.39    units       NaN        21  ...  Medicare      NaN
# ...            ...      ...       ...       ...  ...       ...      ...
# 22245029     29.00        %  abnormal       655  ...  Medicare     ENGL
# 22245030    575.00     #/uL  abnormal       657  ...  Medicare     ENGL
# 22245031   1325.00     #/uL  abnormal       658  ...  Medicare     ENGL
# 22245032     10.00        %  abnormal       647  ...  Medicare     ENGL
# 22245033     31.00        %  abnormal       644  ...  Medicare     ENGL
#
#           RELIGION MARITAL_STATUS  ETHNICITY            EDREGTIME  \
# 0         CATHOLIC        MARRIED      WHITE  2101-10-20 17:09:00
# 1         CATHOLIC        MARRIED      WHITE  2101-10-20 17:09:00
# 2         CATHOLIC        MARRIED      WHITE  2101-10-20 17:09:00
# 3         CATHOLIC        MARRIED      WHITE  2101-10-20 17:09:00
# 4         CATHOLIC        MARRIED      WHITE  2101-10-20 17:09:00
# ...            ...            ...        ...                  ...
# 22245029  CATHOLIC        MARRIED      WHITE                  NaN
# 22245030  CATHOLIC        MARRIED      WHITE                  NaN
# 22245031  CATHOLIC        MARRIED      WHITE                  NaN
# 22245032  CATHOLIC        MARRIED      WHITE                  NaN
# 22245033  CATHOLIC        MARRIED      WHITE                  NaN
#
#                     EDOUTTIME                   DIAGNOSIS  \
# 0         2101-10-20 19:24:00                 HYPOTENSION
# 1         2101-10-20 19:24:00                 HYPOTENSION
# 2         2101-10-20 19:24:00                 HYPOTENSION
# 3         2101-10-20 19:24:00                 HYPOTENSION
# 4         2101-10-20 19:24:00                 HYPOTENSION
# ...                       ...                         ...
# 22245029                  NaN  PLEURAL EFFUSION RIGHT/SDA
# 22245030                  NaN  PLEURAL EFFUSION RIGHT/SDA
# 22245031                  NaN  PLEURAL EFFUSION RIGHT/SDA
# 22245032                  NaN  PLEURAL EFFUSION RIGHT/SDA
# 22245033                  NaN  PLEURAL EFFUSION RIGHT/SDA
#
#          HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA
# 0                           0                    1
# 1                           0                    1
# 2                           0                    1
# 3                           0                    1
# 4                           0                    1
# ...                       ...                  ...
# 22245029                    0                    0
# 22245030                    0                    0
# 22245031                    0                    0
# 22245032                    0                    0
# 22245033                    0                    0
#
# [22245034 rows x 32 columns]

# %%
def change_col_to_datetime(inputevents_mv, feature):
    inputevents_mv[feature] = pd.to_datetime(inputevents_mv[feature])
    return inputevents_mv
labevents = change_col_to_datetime(labevents, 'ADMITTIME')
labevents = change_col_to_datetime(labevents, 'CHARTTIME')
labevents["LabTimeFromAdmit"] = labevents['CHARTTIME']-labevents['ADMITTIME']

# %%
labevents.columns
# Out:
# Index(['ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'ITEMID', 'CHARTTIME', 'VALUE',
#        'VALUENUM', 'VALUEUOM', 'FLAG', 'ROW_ID_y', 'LABEL', 'FLUID',
#        'CATEGORY', 'LOINC_CODE', 'ROW_ID', 'SUBJECT_ID_y', 'ADMITTIME',
#        'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'ADMISSION_LOCATION',
#        'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE', 'RELIGION',
#        'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME', 'DIAGNOSIS',
#        'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA', 'LabTimeFromAdmit'],
#       dtype='object')

# %%
labevents.describe()
# Out:
#            ROW_ID_x  SUBJECT_ID_x       HADM_ID        ITEMID      VALUENUM  \
# count  2.224503e+07  2.224503e+07  2.224503e+07  2.224503e+07  2.011531e+07
# mean   1.448134e+07  3.343667e+04  1.499675e+05  5.104667e+04  7.662884e+01
# std    8.162637e+06  2.800249e+04  2.886231e+04  2.087628e+02  4.880162e+03
# min    1.000000e+00  2.000000e+00  1.000010e+05  5.080000e+04 -4.140000e+02
# 25%    7.353517e+06  1.181800e+04  1.251080e+05  5.086800e+04  4.400000e+00
# 50%    1.478957e+07  2.388300e+04  1.498490e+05  5.097100e+04  1.900000e+01
# 75%    2.172560e+07  5.345900e+04  1.750200e+05  5.124900e+04  6.000000e+01
# max    2.790765e+07  9.999900e+04  1.999990e+05  5.153700e+04  1.104000e+07
#
#            ROW_ID_y        ROW_ID  SUBJECT_ID_y  HOSPITAL_EXPIRE_FLAG  \
# count  2.224503e+07  2.224503e+07  2.224503e+07          2.224503e+07
# mean   2.472272e+02  2.925274e+04  3.343667e+04          1.670595e-01
# std    2.083144e+02  1.705016e+04  2.800249e+04          3.730290e-01
# min    1.000000e+00  1.000000e+00  2.000000e+00          0.000000e+00
# 25%    6.900000e+01  1.448400e+04  1.181800e+04          0.000000e+00
# 50%    1.720000e+02  2.919100e+04  2.388300e+04          0.000000e+00
# 75%    4.490000e+02  4.409900e+04  5.345900e+04          0.000000e+00
# max    7.370000e+02  5.897600e+04  9.999900e+04          1.000000e+00
#
#        HAS_CHARTEVENTS_DATA            LabTimeFromAdmit
# count          2.224503e+07                    22245034
# mean           9.906246e-01   8 days 12:12:10.289985622
# std            9.637167e-02  13 days 15:29:26.593540843
# min            0.000000e+00           -3 days +12:13:00
# 25%            1.000000e+00             0 days 22:44:00
# 50%            1.000000e+00             3 days 23:58:00
# 75%            1.000000e+00            10 days 11:32:00
# max            1.000000e+00           294 days 07:54:00

# %%
labevents.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_patient_data.csv"))

# %%
mimic_extract_map = pd.read_csv(os.path.join("/Users/yanpavan/Desktop/", "itemid_to_variable_map.csv"))

# %%
mimic_extract_map
# Out:
#                          LEVEL2                    LEVEL1 ALTERNATIVE STATUS  \
# 0      Alanine aminotransferase  Alanine aminotransferase         ALT  ready
# 1      Alanine aminotransferase  Alanine aminotransferase         ALT  ready
# 2      Alanine aminotransferase  Alanine aminotransferase         ALT  ready
# 3                       Albumin                   Albumin         NaN  ready
# 4                       Albumin                   Albumin         NaN  ready
# ...                         ...                       ...         ...    ...
# 13246              Urine output              Urine output         NaN  ready
# 13247              Urine output              Urine output         NaN  ready
# 13248              Urine output              Urine output         NaN  ready
# 13249              Urine output              Urine output    OR Urine  ready
# 13250              Urine output              Urine output         NaN  ready
#
#       STATUS NOTE  ITEMID                     MIMIC LABEL UNITNAME  \
# 0             NaN   50861  ALANINE AMINOTRANSFERASE (ALT)      NaN
# 1             NaN     769                             ALT      NaN
# 2             NaN  220644                             ALT     None
# 3             NaN   50862                         ALBUMIN      NaN
# 4             NaN     772                  Albumin (>3.2)      NaN
# ...           ...     ...                             ...      ...
# 13246         NaN  226565                   L Nephrostomy      NaN
# 13247         NaN  226567                   Straight Cath      NaN
# 13248         NaN  226584                     Ileoconduit      NaN
# 13249         NaN  226627                        OR Urine       mL
# 13250         NaN  227510                     TF Residual      NaN
#
#             LINKSTO     COUNT   CATEGORY  CONCEPTID  FLUID LOINC_CODE  \
# 0         labevents  219475.0  CHEMISTRY        NaN  BLOOD
# 1       chartevents   41594.0    Enzymes        NaN    NaN        NaN
# 2       chartevents   37625.0       Labs        NaN    NaN        NaN
# 3         labevents  146697.0  CHEMISTRY        NaN  BLOOD     1751-7
# 4       chartevents   31022.0  Chemistry        NaN    NaN        NaN
# ...             ...       ...        ...        ...    ...        ...
# 13246  outputevents       NaN        NaN        NaN    NaN        NaN
# 13247  outputevents       NaN        NaN        NaN    NaN        NaN
# 13248  outputevents       NaN        NaN        NaN    NaN        NaN
# 13249  outputevents    5928.0     Output        NaN    NaN        NaN
# 13250  outputevents       NaN        NaN        NaN    NaN        NaN
#
#          DBSOURCE  Unnamed: 15 PARAM_TYPE  NOTE
# 0             NaN          NaN        NaN   NaN
# 1         carevue          NaN        NaN   NaN
# 2      metavision          NaN    Numeric   NaN
# 3             NaN          NaN        NaN   NaN
# 4         carevue          NaN        NaN   NaN
# ...           ...          ...        ...   ...
# 13246  metavision          NaN        NaN   NaN
# 13247  metavision          NaN        NaN   NaN
# 13248  metavision          NaN        NaN   NaN
# 13249  metavision          NaN        NaN   NaN
# 13250  metavision          NaN        NaN   NaN
#
# [13251 rows x 18 columns]

# %%
mimic_extract_map_small = mimic_extract_map[["LEVEL2", "MIMIC LABEL", "ITEMID"]]

# %%
mimic_extract_map_small
# Out:
#                          LEVEL2                     MIMIC LABEL  ITEMID
# 0      Alanine aminotransferase  ALANINE AMINOTRANSFERASE (ALT)   50861
# 1      Alanine aminotransferase                             ALT     769
# 2      Alanine aminotransferase                             ALT  220644
# 3                       Albumin                         ALBUMIN   50862
# 4                       Albumin                  Albumin (>3.2)     772
# ...                         ...                             ...     ...
# 13246              Urine output                   L Nephrostomy  226565
# 13247              Urine output                   Straight Cath  226567
# 13248              Urine output                     Ileoconduit  226584
# 13249              Urine output                        OR Urine  226627
# 13250              Urine output                     TF Residual  227510
#
# [13251 rows x 3 columns]

# %%
mimic_extract_map.LINKSTO.value_counts()
# Out:
# chartevents           5909
# inputevents_cv        2929
# outputevents          1179
# labevents              755
# microbiologyevents     436
# inputevents_mv         422
# datetimeevents         193
# procedureevents_mv     125
# Name: LINKSTO, dtype: int64

# %%
d_m_l_doc = pd.read_csv(os.path.join(data, "mimiciii", "1.4","preprocessed", "mapping_med_itemid_doc.csv")).drop(columns=["Unnamed: 0"])

# %%
lab_names = [k.lower() for k in d_m_l_doc.groupby("lab result").count()[["Medication"]].reset_index()["lab result"].to_list()]
res_dict = {}
for l in lab_names:
    res_dict[l.lower().strip()] = mimic_extract_map_small[mimic_extract_map_small.apply(lambda r: l.lower() in str(r["MIMIC LABEL"]).lower(), axis=1)].dropna()
lab_itemids, lab_labels = {}, {}
for l in res_dict:
    if res_dict[l].shape[0]>0:
        lab_labels[l] = res_dict[l].groupby("LEVEL2")["MIMIC LABEL"].apply(list).to_dict()
        lab_itemids[l] = res_dict[l].groupby("LEVEL2")["ITEMID"].apply(list).to_dict()   
del lab_itemids['ast']['Diastolic blood pressure']

# %%
import pickle
v_r_lab_dict = pickle.load(open(os.path.join(data, "mapping_lab_itemids.pkl"), "rb"))
temp_itemids_list = {k: [i for l in list(v.values()) for i in l] for k, v in lab_itemids.items()}
for l in v_r_lab_dict:
    if l.lower().strip() in temp_itemids_list:
        items = [k[1] for k in v_r_lab_dict[l]]
        names = [k[0] for k in v_r_lab_dict[l]]
        diff = list(set(items).difference(set(temp_itemids_list[l.lower().strip()])))
        if len(diff)>0:
            for k in diff:
               lab_itemids[l.lower().strip()][names[items.index(k)]] = [k]
    else:
        for l1 in v_r_lab_dict[l]:
            if l1[0] not in lab_itemids:
                lab_itemids[l1[0]] = {}
                lab_itemids[l1[0]][l1[0]] = [l1[1]]

# %%
final_mapping_lab_itemids = {v2:k1 for k, v in lab_itemids.items() for k1, v1 in v.items() for v2 in v1}

# %%
# pickle.dump(final_mapping_lab_itemids, open("/Users/yanpavan/Desktop/d.pkl", "wb"))]
import pickle
final_mapping_lab_itemids = pickle.load(open("/Users/yanpavan/Desktop/d.pkl", "rb"))
final_mapping_lab_itemids
# Out:
# {50861: 'Alanine aminotransferase',
#  769: 'Alanine aminotransferase',
#  220644: 'Alanine aminotransferase',
#  189: 'Fraction inspired oxygen',
#  50878: 'Asparate aminotransferase',
#  770: 'Asparate aminotransferase',
#  220587: 'Asparate aminotransferase',
#  50852: 'Hemoglobin percent',
#  51224: 'Hemoglobin C',
#  51225: 'Hemoglobin F',
#  51223: 'Hemoglobin A2',
#  51237: 'Prothrombin time INR',
#  815: 'Prothrombin time INR',
#  1530: 'Prothrombin time INR',
#  227467: 'Prothrombin time INR',
#  51465: 'Bilirubin',
#  50883: 'Bilirubin, Direct',
#  50884: 'Bilirubin, Indirect',
#  50885: 'Bilirubin, Total',
#  51049: 'Bilirubin, Total, Pleural',
#  51028: 'Bilirubin, Total, Body Fluid',
#  50838: 'Bilirubin, Total, Ascites',
#  786: 'Calcium',
#  1522: 'Calcium',
#  3746: 'Calcium',
#  51029: 'Calcium',
#  50893: 'Calcium',
#  225625: 'Calcium',
#  3766: 'Calcium Ionized',
#  50808: 'Calcium ionized',
#  816: 'Calcium ionized',
#  225667: 'Calcium ionized',
#  51066: 'Calcium urine',
#  51077: 'Calcium urine',
#  791: 'Creatinine',
#  1525: 'Creatinine',
#  220615: 'Creatinine',
#  50912: 'Creatinine',
#  3750: 'Creatinine',
#  50841: 'Creatinine ascites',
#  51032: 'Creatinine body fluid',
#  51052: 'Creatinine pleural',
#  51067: 'Creatinine urine',
#  51081: 'Creatinine urine',
#  51082: 'Creatinine urine',
#  51106: 'Creatinine urine',
#  51080: 'Creatinine urine',
#  50931: 'Glucose',
#  807: 'Glucose',
#  811: 'Glucose',
#  1529: 'Glucose',
#  50809: 'Glucose',
#  3745: 'Glucose',
#  225664: 'Glucose',
#  220621: 'Glucose',
#  226537: 'Glucose',
#  51478: 'Glucose urine',
#  51014: 'Glucose, CSF',
#  51529: 'Estimated Actual Glucose',
#  51084: 'Glucose, Urine',
#  51053: 'Glucose, Pleural',
#  51022: 'Glucose, Joint Fluid',
#  50842: 'Glucose, Ascites',
#  51034: 'Glucose, Body Fluid',
#  818: 'Lactic acid',
#  225668: 'Lactic acid',
#  1531: 'Lactic acid',
#  50960: 'Magnesium',
#  51088: 'Magnesium, Urine',
#  828: 'Platelets',
#  51240: 'Large Platelets',
#  829: 'Potassium',
#  1535: 'Potassium',
#  3792: 'Potassium',
#  227464: 'Potassium',
#  50971: 'Potassium',
#  50822: 'Potassium',
#  227442: 'Potassium serum',
#  51041: 'Potassium, Body Fluid',
#  51057: 'Potassium, Pleural',
#  51064: 'Potassium, Stool',
#  51097: 'Potassium, Urine',
#  50847: 'Potassium, Ascites',
#  837: 'Sodium',
#  1536: 'Sodium',
#  3803: 'Sodium',
#  220645: 'Sodium',
#  226534: 'Sodium',
#  50983: 'Sodium',
#  50824: 'Sodium',
#  50848: 'Sodium, Ascites',
#  51042: 'Sodium, Body Fluid',
#  51058: 'Sodium, Pleural',
#  51065: 'Sodium, Stool',
#  51100: 'Sodium, Urine',
#  51007: 'Uric Acid',
#  51105: 'Uric Acid, Urine',
#  51010: 'Vitamin B12',
#  50973: 'Prolactin',
#  50867: 'Amylase',
#  50836: 'Amylase, Ascites',
#  51026: 'Amylase, Body Fluid',
#  51020: 'Amylase, Joint Fluid',
#  51047: 'Amylase, Pleural',
#  51072: 'Amylase, Urine',
#  50956: 'Lipase',
#  50844: 'Lipase, Ascites',
#  51036: 'Lipase, Body Fluid'}

# %%
final_itemids_list = list(final_mapping_lab_itemids.keys())
# chartevents.columns

# %% [markdown]
# ## Labevents

# %%
labevents = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_patient_data.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_59465/1490636941.py:1: DtypeWarning: Columns (19,24,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   labevents = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_patient_data.csv"))

# %%
labevents = labevents[labevents.ITEMID.isin(final_itemids_list)]
labevents["MIMICExtractName"] = labevents.apply(lambda r: final_mapping_lab_itemids[r["ITEMID"]], axis=1)

# %%
labevents["TABLE"] = labevents.apply(lambda r: "LABEVENTS", axis=1)

# %%
labevents
# Out:
#           Unnamed: 0  ROW_ID_x  SUBJECT_ID_x   HADM_ID  ITEMID  \
# 157              157       969             3  145834.0   50808
# 158              158      1077             3  145834.0   50808
# 159              159      1132             3  145834.0   50808
# 160              160      1160             3  145834.0   50808
# 161              161       584             3  145834.0   50808
# ...              ...       ...           ...       ...     ...
# 22244958    22244958  23110264         63320  105826.0   50822
# 22244959    22244959  27254849         95129  133829.0   50822
# 22244960    22244960  27068015         93701  115270.0   50822
# 22244987    22244987  25499792         81429  130919.0   51014
# 22245023    22245023  11174330         18054  100572.0   51053
#
#                     CHARTTIME VALUE  VALUENUM VALUEUOM      FLAG  ...  \
# 157       2101-10-22 04:31:00  1.12      1.12   mmol/L       NaN  ...
# 158       2101-10-23 02:46:00  1.19      1.19   mmol/L       NaN  ...
# 159       2101-10-23 10:14:00  1.11      1.11   mmol/L  abnormal  ...
# 160       2101-10-23 16:10:00  0.80      0.80   mmol/L  abnormal  ...
# 161       2101-10-20 20:04:00  0.98      0.98   mmol/L  abnormal  ...
# ...                       ...   ...       ...      ...       ...  ...
# 22244958  2189-12-29 08:44:00   4.6      4.60    mEq/L       NaN  ...
# 22244959  2161-05-21 10:51:00   4.3      4.30    mEq/L       NaN  ...
# 22244960  2178-01-08 07:21:00   4.3      4.30    mEq/L       NaN  ...
# 22244987  2169-02-08 00:30:00    58     58.00    mg/dL       NaN  ...
# 22245023  2158-04-24 11:42:00    71     71.00    mg/dL       NaN  ...
#
#           MARITAL_STATUS               ETHNICITY            EDREGTIME  \
# 157              MARRIED                   WHITE  2101-10-20 17:09:00
# 158              MARRIED                   WHITE  2101-10-20 17:09:00
# 159              MARRIED                   WHITE  2101-10-20 17:09:00
# 160              MARRIED                   WHITE  2101-10-20 17:09:00
# 161              MARRIED                   WHITE  2101-10-20 17:09:00
# ...                  ...                     ...                  ...
# 22244958         MARRIED  BLACK/AFRICAN AMERICAN                  NaN
# 22244959         MARRIED                   WHITE                  NaN
# 22244960         WIDOWED  BLACK/AFRICAN AMERICAN                  NaN
# 22244987         MARRIED                   WHITE  2169-02-07 18:53:00
# 22245023         MARRIED                   WHITE                  NaN
#
#                     EDOUTTIME                     DIAGNOSIS  \
# 157       2101-10-20 19:24:00                   HYPOTENSION
# 158       2101-10-20 19:24:00                   HYPOTENSION
# 159       2101-10-20 19:24:00                   HYPOTENSION
# 160       2101-10-20 19:24:00                   HYPOTENSION
# 161       2101-10-20 19:24:00                   HYPOTENSION
# ...                       ...                           ...
# 22244958                  NaN             BLADDER TUMOR/SDA
# 22244959                  NaN  RIGHT ORAL TONGUE CANCER/SDA
# 22244960                  NaN     CHRONIC RENAL FAILURE/SDA
# 22244987  2169-02-08 07:22:00   R/O SUBARACHNOID HEMORRHAGE
# 22245023                  NaN    PLEURAL EFFUSION RIGHT/SDA
#
#           HOSPITAL_EXPIRE_FLAG  HAS_CHARTEVENTS_DATA   LabTimeFromAdmit  \
# 157                          0                     1    1 days 09:23:00
# 158                          0                     1    2 days 07:38:00
# 159                          0                     1    2 days 15:06:00
# 160                          0                     1    2 days 21:02:00
# 161                          0                     1    0 days 00:56:00
# ...                        ...                   ...                ...
# 22244958                     0                     0    0 days 01:29:00
# 22244959                     0                     0    0 days 02:21:00
# 22244960                     0                     0    0 days 00:06:00
# 22244987                     0                     1  -1 days +19:23:00
# 22245023                     0                     0    0 days 02:57:00
#
#           MIMICExtractName      TABLE
# 157        Calcium ionized  LABEVENTS
# 158        Calcium ionized  LABEVENTS
# 159        Calcium ionized  LABEVENTS
# 160        Calcium ionized  LABEVENTS
# 161        Calcium ionized  LABEVENTS
# ...                    ...        ...
# 22244958         Potassium  LABEVENTS
# 22244959         Potassium  LABEVENTS
# 22244960         Potassium  LABEVENTS
# 22244987      Glucose, CSF  LABEVENTS
# 22245023  Glucose, Pleural  LABEVENTS
#
# [5453439 rows x 36 columns]

# %%
labevents["HAS_CHARTEVENTS_DATA"].value_counts()
# Out:
# 1    5397268
# 0      56171
# Name: HAS_CHARTEVENTS_DATA, dtype: int64

# %%
labevents.columns
# Out:
# Index(['Unnamed: 0', 'ROW_ID_x', 'SUBJECT_ID_x', 'HADM_ID', 'ITEMID',
#        'CHARTTIME', 'VALUE', 'VALUENUM', 'VALUEUOM', 'FLAG', 'ROW_ID_y',
#        'LABEL', 'FLUID', 'CATEGORY', 'LOINC_CODE', 'ROW_ID', 'SUBJECT_ID_y',
#        'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE',
#        'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE',
#        'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME',
#        'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA',
#        'LabTimeFromAdmit', 'MIMICExtractName', 'TABLE'],
#       dtype='object')

# %%
patients = pd.read_csv(os.path.join(data, "mimiciii/1.4", "raw/PATIENTS.csv.gz"))
labevents = labevents.rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})
labevents = pd.merge(labevents, patients, how="inner", on="SUBJECT_ID")
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_59465/2424521930.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ROW_ID_x'} in the result is deprecated and will raise a MergeError in a future version.
#   labevents = pd.merge(labevents, patients, how="inner", on="SUBJECT_ID")

# %%
labevents.columns
# Out:
# Index(['Unnamed: 0', 'ROW_ID_x', 'SUBJECT_ID', 'HADM_ID', 'ITEMID',
#        'CHARTTIME', 'VALUE', 'VALUENUM', 'VALUEUOM', 'FLAG', 'ROW_ID_y',
#        'LABEL', 'FLUID', 'CATEGORY', 'LOINC_CODE', 'ROW_ID_x', 'SUBJECT_ID_y',
#        'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE',
#        'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE',
#        'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME',
#        'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA',
#        'LabTimeFromAdmit', 'MIMICExtractName', 'TABLE', 'ROW_ID_y', 'GENDER',
#        'DOB', 'DOD', 'DOD_HOSP', 'DOD_SSN', 'EXPIRE_FLAG'],
#       dtype='object')

# %%
labevents["DOB"] = pd.to_datetime(labevents["DOB"])
labevents["ADMITTIME"] = pd.to_datetime(labevents["ADMITTIME"])

# %%
labevents['AGE'] = labevents.apply(lambda r: round((r['ADMITTIME'].to_pydatetime()-r['DOB'].to_pydatetime()).days/365, 0), axis=1)

# %%
labevents
# Out:
#          Unnamed: 0  ROW_ID_x  SUBJECT_ID   HADM_ID  ITEMID  \
# 0               157       969           3  145834.0   50808
# 1               158      1077           3  145834.0   50808
# 2               159      1132           3  145834.0   50808
# 3               160      1160           3  145834.0   50808
# 4               161       584           3  145834.0   50808
# ...             ...       ...         ...       ...     ...
# 5453434    22244924  19819589       32662  169191.0   50883
# 5453435    22244925  19819590       32662  169191.0   50884
# 5453436    22244927   6436764       10358  135827.0   51237
# 5453437    22244947   7910296       12703  144954.0   50809
# 5453438    22244987  25499792       81429  130919.0   51014
#
#                    CHARTTIME VALUE  VALUENUM VALUEUOM      FLAG  ...  \
# 0        2101-10-22 04:31:00  1.12      1.12   mmol/L       NaN  ...
# 1        2101-10-23 02:46:00  1.19      1.19   mmol/L       NaN  ...
# 2        2101-10-23 10:14:00  1.11      1.11   mmol/L  abnormal  ...
# 3        2101-10-23 16:10:00  0.80      0.80   mmol/L  abnormal  ...
# 4        2101-10-20 20:04:00  0.98      0.98   mmol/L  abnormal  ...
# ...                      ...   ...       ...      ...       ...  ...
# 5453434  2194-03-09 14:30:00   0.2      0.20    mg/dL       NaN  ...
# 5453435  2194-03-09 14:30:00   9.8      9.80    mg/dL       NaN  ...
# 5453436  2195-05-11 14:15:00   1.0      1.00      NaN       NaN  ...
# 5453437  2154-06-03 19:24:00    98     98.00    mg/dL       NaN  ...
# 5453438  2169-02-08 00:30:00    58     58.00    mg/dL       NaN  ...
#
#              MIMICExtractName      TABLE ROW_ID_y GENDER        DOB  \
# 0             Calcium ionized  LABEVENTS        2      M 2025-04-11
# 1             Calcium ionized  LABEVENTS        2      M 2025-04-11
# 2             Calcium ionized  LABEVENTS        2      M 2025-04-11
# 3             Calcium ionized  LABEVENTS        2      M 2025-04-11
# 4             Calcium ionized  LABEVENTS        2      M 2025-04-11
# ...                       ...        ...      ...    ...        ...
# 5453434     Bilirubin, Direct  LABEVENTS    30667      M 2194-03-07
# 5453435   Bilirubin, Indirect  LABEVENTS    30667      M 2194-03-07
# 5453436  Prothrombin time INR  LABEVENTS     9803      M 2131-03-17
# 5453437               Glucose  LABEVENTS    12021      M 2154-06-03
# 5453438          Glucose, CSF  LABEVENTS    41678      F 2117-07-13
#
#                          DOD             DOD_HOSP              DOD_SSN  \
# 0        2102-06-14 00:00:00                  NaN  2102-06-14 00:00:00
# 1        2102-06-14 00:00:00                  NaN  2102-06-14 00:00:00
# 2        2102-06-14 00:00:00                  NaN  2102-06-14 00:00:00
# 3        2102-06-14 00:00:00                  NaN  2102-06-14 00:00:00
# 4        2102-06-14 00:00:00                  NaN  2102-06-14 00:00:00
# ...                      ...                  ...                  ...
# 5453434                  NaN                  NaN                  NaN
# 5453435                  NaN                  NaN                  NaN
# 5453436  2195-05-11 00:00:00  2195-05-11 00:00:00  2195-05-11 00:00:00
# 5453437                  NaN                  NaN                  NaN
# 5453438                  NaN                  NaN                  NaN
#
#         EXPIRE_FLAG   AGE
# 0                 1  77.0
# 1                 1  77.0
# 2                 1  77.0
# 3                 1  77.0
# 4                 1  77.0
# ...             ...   ...
# 5453434           0   0.0
# 5453435           0   0.0
# 5453436           1  64.0
# 5453437           0   0.0
# 5453438           0  52.0
#
# [5453439 rows x 44 columns]

# %%
labevents[['ADMISSION_LOCATION',
 'ADMISSION_TYPE',
 'ADMITTIME',
 'AGE',
 'CHARTTIME',
 'DEATHTIME',
 'DIAGNOSIS',
 'DISCHARGE_LOCATION',
 'DISCHTIME',
 'DOB',
 'DOD',
 'DOD_HOSP',
 'DOD_SSN',
 'EDOUTTIME',
 'EDREGTIME',
 'ETHNICITY',
 'EXPIRE_FLAG',
 'GENDER',
 'HADM_ID',
 'HAS_CHARTEVENTS_DATA',
 'HOSPITAL_EXPIRE_FLAG',
 'INSURANCE',
 'ITEMID',
 'LANGUAGE',
 'MARITAL_STATUS',
 'MIMICExtractName',
 'RELIGION',
 'ROW_ID_x',
 'SUBJECT_ID',
 'TABLE',
 'VALUE',
 'VALUENUM',
 'VALUEUOM']].to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_patient_data_with_mimic_extract_names.csv"))

# %% [markdown]
# ## Chartevents

# %%
chartevents = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "CHARTEVENTS.csv.gz"))

# %%
res_paths = []
count = 0
with pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "CHARTEVENTS.csv.gz"), chunksize=50_000_000) as reader:
    for chunk in reader:
        print(count, chunk.shape)
        path = os.path.join(data, "mimiciii", "1.4","preprocessed", "CHARTEVENTS", f"chartevents_with_mimic_extract_{count}.csv.gz")
        chunk = chunk[chunk.ITEMID.isin(final_itemids_list)]
        t = chunk.apply(lambda r: final_mapping_lab_itemids[r["ITEMID"]], axis=1)
        if t.shape[0]>0:
            chunk["MIMICExtractName"] = t
            chunk.to_csv(path)
            print(count, chunk.shape)
            res_paths.append(path)
        else:
            print(count, 0)    
        count += 1
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_59465/624336155.py:4: DtypeWarning: Columns (8,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# 0 (50000000, 15)
# 0 (1813767, 16)
# 1 (50000000, 15)
# 1 (1079200, 16)
# 2 (50000000, 15)
# 2 (1090632, 16)
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_59465/624336155.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# 3 (50000000, 15)
# 3 (1040883, 16)
# 4 (50000000, 15)
# 4 0
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_59465/624336155.py:4: DtypeWarning: Columns (8,10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in reader:
# 5 (50000000, 15)
# 5 0
# 6 (30712483, 15)
# 6 0

# %%
result = pd.concat([pd.read_csv(f) for f in res_paths], ignore_index=True)
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_59465/4178487586.py:1: DtypeWarning: Columns (9,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = pd.concat([pd.read_csv(f) for f in res_paths], ignore_index=True)

# %%
result["TABLE"] = result.apply(lambda r: "CHARTEVENTS", axis=1)

# %%
result
# Out:
#          Unnamed: 0     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID  \
# 0                13        801          36   165660    241249.0  225668
# 1                58        846          36   165660    241249.0  225668
# 2               119        267          23   124321    234044.0  225664
# 3               212         35          23   124321    234044.0  220615
# 4               213         36          23   124321    234044.0  220621
# ...             ...        ...         ...      ...         ...     ...
# 5024477   193776628  192829953       32775   128184    292368.0     791
# 5024478   193776629  192829954       32775   128184    292368.0     811
# 5024479   193776655  192830955       32775   128184    292368.0     807
# 5024480   193776666  192854410       32777   105007    202322.0     828
# 5024481   193776672  192854416       32777   105007    202322.0    1530
#
#                    CHARTTIME            STORETIME     CGID  VALUE  VALUENUM  \
# 0        2134-05-12 12:35:00  2134-05-12 12:38:00  20889.0    1.0       1.0
# 1        2134-05-12 15:22:00  2134-05-12 15:24:00  20889.0    0.7       0.7
# 2        2157-10-22 10:00:00  2157-10-22 09:56:00  20009.0  188.0     188.0
# 3        2157-10-21 14:40:00  2157-10-21 15:53:00  20889.0    0.6       0.6
# 4        2157-10-21 14:40:00  2157-10-21 15:53:00  20889.0  136.0     136.0
# ...                      ...                  ...      ...    ...       ...
# 5024477  2200-09-02 02:07:00  2200-09-02 03:14:00  15331.0     .5       0.5
# 5024478  2200-09-02 02:07:00  2200-09-02 03:14:00  15331.0    108     108.0
# 5024479  2200-09-02 21:00:00  2200-09-02 20:51:00  17249.0    139     139.0
# 5024480  2113-10-12 11:38:00  2113-10-12 11:46:00  15331.0    131     131.0
# 5024481  2113-10-12 11:38:00  2113-10-12 12:10:00  15331.0    1.3       1.3
#
#         VALUEUOM  WARNING  ERROR RESULTSTATUS   STOPPED      MIMICExtractName  \
# 0         mmol/L      0.0    0.0          NaN       NaN           Lactic acid
# 1         mmol/L      0.0    0.0          NaN       NaN           Lactic acid
# 2            NaN      0.0    0.0          NaN       NaN               Glucose
# 3          mg/dL      0.0    0.0          NaN       NaN            Creatinine
# 4          mg/dL      1.0    0.0          NaN       NaN               Glucose
# ...          ...      ...    ...          ...       ...                   ...
# 5024477      NaN      NaN    NaN        Final  NotStopd            Creatinine
# 5024478      NaN      NaN    NaN        Final  NotStopd               Glucose
# 5024479      NaN      NaN    NaN       Manual  NotStopd               Glucose
# 5024480      NaN      NaN    NaN        Final  NotStopd             Platelets
# 5024481      NaN      NaN    NaN        Final  NotStopd  Prothrombin time INR
#
#                TABLE
# 0        CHARTEVENTS
# 1        CHARTEVENTS
# 2        CHARTEVENTS
# 3        CHARTEVENTS
# 4        CHARTEVENTS
# ...              ...
# 5024477  CHARTEVENTS
# 5024478  CHARTEVENTS
# 5024479  CHARTEVENTS
# 5024480  CHARTEVENTS
# 5024481  CHARTEVENTS
#
# [5024482 rows x 18 columns]

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'ROW_ID', 'SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'ITEMID',
#        'CHARTTIME', 'STORETIME', 'CGID', 'VALUE', 'VALUENUM', 'VALUEUOM',
#        'WARNING', 'ERROR', 'RESULTSTATUS', 'STOPPED', 'MIMICExtractName',
#        'TABLE'],
#       dtype='object')

# %%
t_r = pd.merge(result, admits, how="inner", on="HADM_ID")

# %%
result = t_r.copy()

# %%
# chartevents[chartevents.isin(final_itemids_list)].to_csv(os.path.join(data, "mimiciii", "1.4","preprocessed", "CHARTEVENTS", "chartevents_with_mimic_extract.csv.gz"))
# chartevents["MIMICExtractName"] = chartevents.apply(lambda r: final_mapping_lab_itemids[r["ITEMID"]], axis=1)

# %%
result = result.rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})
result = pd.merge(result, patients, how="inner", on="SUBJECT_ID")

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'ROW_ID_x', 'SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID',
#        'ITEMID', 'CHARTTIME', 'STORETIME', 'CGID', 'VALUE', 'VALUENUM',
#        'VALUEUOM', 'WARNING', 'ERROR', 'RESULTSTATUS', 'STOPPED',
#        'MIMICExtractName', 'TABLE', 'ROW_ID_y', 'SUBJECT_ID_y', 'ADMITTIME',
#        'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'ADMISSION_LOCATION',
#        'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE', 'RELIGION',
#        'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME', 'DIAGNOSIS',
#        'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA', 'ROW_ID', 'GENDER',
#        'DOB', 'DOD', 'DOD_HOSP', 'DOD_SSN', 'EXPIRE_FLAG'],
#       dtype='object')

# %%
result["DOB"] = pd.to_datetime(result["DOB"])
result["ADMITTIME"] = pd.to_datetime(result["ADMITTIME"])

# %%
result['AGE'] = result.apply(lambda r: round((r['ADMITTIME'].to_pydatetime()-r['DOB'].to_pydatetime()).days/365, 0), axis=1)

# %%
result
# Out:
#          Unnamed: 0   ROW_ID_x  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID  \
# 0                13        801          36   165660    241249.0  225668
# 1                58        846          36   165660    241249.0  225668
# 2               509        724          36   165660    241249.0  220615
# 3               510        725          36   165660    241249.0  220621
# 4               512        727          36   165660    241249.0  220645
# ...             ...        ...         ...      ...         ...     ...
# 5024477   193243859  192872160       32782   192581    201335.0    3745
# 5024478   193723972  192863311       32780   100455    287347.0    3745
# 5024479   193756245  193123435       32806   104049    262007.0    3792
# 5024480   193756246  193123436       32806   104049    262007.0    3803
# 5024481   193770415  192872294       32784   131855    243928.0    3745
#
#                    CHARTTIME            STORETIME     CGID  VALUE  ...  \
# 0        2134-05-12 12:35:00  2134-05-12 12:38:00  20889.0    1.0  ...
# 1        2134-05-12 15:22:00  2134-05-12 15:24:00  20889.0    0.7  ...
# 2        2134-05-12 08:33:00  2134-05-12 10:01:00  20889.0    0.9  ...
# 3        2134-05-12 08:33:00  2134-05-12 10:01:00  20889.0  126.0  ...
# 4        2134-05-12 08:33:00  2134-05-12 10:01:00  20889.0  139.0  ...
# ...                      ...                  ...      ...    ...  ...
# 5024477  2179-10-03 12:55:00  2179-10-03 13:27:00  18389.0     58  ...
# 5024478  2195-10-02 16:00:00  2195-10-02 16:41:00  14295.0     93  ...
# 5024479  2162-10-24 00:05:00  2162-10-24 03:49:00  15331.0    4.7  ...
# 5024480  2162-10-24 00:05:00  2162-10-24 03:49:00  15331.0    139  ...
# 5024481  2196-11-08 21:55:00  2196-11-08 22:17:00  16426.0     58  ...
#
#          HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  ROW_ID  GENDER        DOB  \
# 0                           0                    1      32       M 2061-08-17
# 1                           0                    1      32       M 2061-08-17
# 2                           0                    1      32       M 2061-08-17
# 3                           0                    1      32       M 2061-08-17
# 4                           0                    1      32       M 2061-08-17
# ...                       ...                  ...     ...     ...        ...
# 5024477                     0                    1   30775       M 2179-10-03
# 5024478                     0                    1   30773       F 2195-10-02
# 5024479                     0                    1   30797       M 2162-10-22
# 5024480                     0                    1   30797       M 2162-10-22
# 5024481                     0                    1   30777       M 2196-11-08
#
#          DOD DOD_HOSP DOD_SSN  EXPIRE_FLAG   AGE
# 0        NaN      NaN     NaN            0  73.0
# 1        NaN      NaN     NaN            0  73.0
# 2        NaN      NaN     NaN            0  73.0
# 3        NaN      NaN     NaN            0  73.0
# 4        NaN      NaN     NaN            0  73.0
# ...      ...      ...     ...          ...   ...
# 5024477  NaN      NaN     NaN            0   0.0
# 5024478  NaN      NaN     NaN            0   0.0
# 5024479  NaN      NaN     NaN            0   0.0
# 5024480  NaN      NaN     NaN            0   0.0
# 5024481  NaN      NaN     NaN            0   0.0
#
# [5024482 rows x 44 columns]

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'ROW_ID_x', 'SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID',
#        'ITEMID', 'CHARTTIME', 'STORETIME', 'CGID', 'VALUE', 'VALUENUM',
#        'VALUEUOM', 'WARNING', 'ERROR', 'RESULTSTATUS', 'STOPPED',
#        'MIMICExtractName', 'TABLE', 'ROW_ID_y', 'SUBJECT_ID_y', 'ADMITTIME',
#        'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'ADMISSION_LOCATION',
#        'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE', 'RELIGION',
#        'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME', 'DIAGNOSIS',
#        'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA', 'ROW_ID', 'GENDER',
#        'DOB', 'DOD', 'DOD_HOSP', 'DOD_SSN', 'EXPIRE_FLAG', 'AGE'],
#       dtype='object')

# %%
result[['ADMISSION_LOCATION',
 'ADMISSION_TYPE',
 'ADMITTIME',
 'AGE',
 'CHARTTIME',
 'DEATHTIME',
 'DIAGNOSIS',
 'DISCHARGE_LOCATION',
 'DISCHTIME',
 'DOB',
 'DOD',
 'DOD_HOSP',
 'DOD_SSN',
 'EDOUTTIME',
 'EDREGTIME',
 'ETHNICITY',
 'EXPIRE_FLAG',
 'GENDER',
 'HADM_ID',
 'HAS_CHARTEVENTS_DATA',
 'HOSPITAL_EXPIRE_FLAG',
 'INSURANCE',
 'ITEMID',
 'LANGUAGE',
 'MARITAL_STATUS',
 'MIMICExtractName',
 'RELIGION',
 'ROW_ID_x',
 'SUBJECT_ID',
 'SUBJECT_ID_y',
 'TABLE',
 'VALUE',
 'VALUENUM',
 'VALUEUOM']].to_csv(os.path.join(data, "mimiciii", "1.4","preprocessed", "CHARTEVENTS", "chartevents_with_mimic_extract_lab.csv.gz"))

# %%
t_r = result[['ADMISSION_LOCATION',
 'ADMISSION_TYPE',
 'ADMITTIME',
 'AGE',
 'CHARTTIME',
 'DEATHTIME',
 'DIAGNOSIS',
 'DISCHARGE_LOCATION',
 'DISCHTIME',
 'DOB',
 'DOD',
 'DOD_HOSP',
 'DOD_SSN',
 'EDOUTTIME',
 'EDREGTIME',
 'ETHNICITY',
 'EXPIRE_FLAG',
 'GENDER',
 'HADM_ID',
 'HAS_CHARTEVENTS_DATA',
 'HOSPITAL_EXPIRE_FLAG',
 'INSURANCE',
 'ITEMID',
 'LANGUAGE',
 'MARITAL_STATUS',
 'MIMICExtractName',
 'RELIGION',
 'SUBJECT_ID',
#  'TABLE',
 'VALUE',
 'VALUENUM',
 'VALUEUOM']]

t_l = labevents[['ADMISSION_LOCATION',
 'ADMISSION_TYPE',
 'ADMITTIME',
 'AGE',
 'CHARTTIME',
 'DEATHTIME',
 'DIAGNOSIS',
 'DISCHARGE_LOCATION',
 'DISCHTIME',
 'DOB',
 'DOD',
 'DOD_HOSP',
 'DOD_SSN',
 'EDOUTTIME',
 'EDREGTIME',
 'ETHNICITY',
 'EXPIRE_FLAG',
 'GENDER',
 'HADM_ID',
 'HAS_CHARTEVENTS_DATA',
 'HOSPITAL_EXPIRE_FLAG',
 'INSURANCE',
 'ITEMID',
 'LANGUAGE',
 'MARITAL_STATUS',
 'MIMICExtractName',
 'RELIGION',
 'SUBJECT_ID',
#  'TABLE',
 'VALUE',
 'VALUENUM',
 'VALUEUOM']]

# %%
t_l[["HAS_CHARTEVENTS_DATA"]].value_counts()
# Out:
# HAS_CHARTEVENTS_DATA
# 1                       5397268
# 0                         56171
# dtype: int64

# %%
t_r[["HAS_CHARTEVENTS_DATA"]].value_counts()
# Out:
# HAS_CHARTEVENTS_DATA
# 1                       5024482
# dtype: int64

# %%
pd.merge(t_l[t_l["HAS_CHARTEVENTS_DATA"]==1], t_r[t_r["HAS_CHARTEVENTS_DATA"]==1], how="inner")
# Out:
# Empty DataFrame
# Columns: [ADMISSION_LOCATION, ADMISSION_TYPE, ADMITTIME, AGE, CHARTTIME, DEATHTIME, DIAGNOSIS, DISCHARGE_LOCATION, DISCHTIME, DOB, DOD, DOD_HOSP, DOD_SSN, EDOUTTIME, EDREGTIME, ETHNICITY, EXPIRE_FLAG, GENDER, HADM_ID, HAS_CHARTEVENTS_DATA, HOSPITAL_EXPIRE_FLAG, INSURANCE, ITEMID, LANGUAGE, MARITAL_STATUS, MIMICExtractName, RELIGION, SUBJECT_ID, VALUE, VALUENUM, VALUEUOM]
# Index: []
#
# [0 rows x 31 columns]

# %%
t_c_l = pd.concat([t_l, t_r]).drop_duplicates(keep="first")

# %%
t_c_l = t_c_l[t_c_l["AGE"]<100]
t_c_l = t_c_l[t_c_l["AGE"]>0]
t_c_l
# Out:
#                 ADMISSION_LOCATION ADMISSION_TYPE           ADMITTIME   AGE  \
# 0             EMERGENCY ROOM ADMIT      EMERGENCY 2101-10-20 19:08:00  77.0
# 1             EMERGENCY ROOM ADMIT      EMERGENCY 2101-10-20 19:08:00  77.0
# 2             EMERGENCY ROOM ADMIT      EMERGENCY 2101-10-20 19:08:00  77.0
# 3             EMERGENCY ROOM ADMIT      EMERGENCY 2101-10-20 19:08:00  77.0
# 4             EMERGENCY ROOM ADMIT      EMERGENCY 2101-10-20 19:08:00  77.0
# ...                            ...            ...                 ...   ...
# 5024472  PHYS REFERRAL/NORMAL DELI       ELECTIVE 2113-10-12 07:15:00  74.0
# 5024473  PHYS REFERRAL/NORMAL DELI       ELECTIVE 2113-10-12 07:15:00  74.0
# 5024474  PHYS REFERRAL/NORMAL DELI       ELECTIVE 2113-10-12 07:15:00  74.0
# 5024475  PHYS REFERRAL/NORMAL DELI       ELECTIVE 2113-10-12 07:15:00  74.0
# 5024476  PHYS REFERRAL/NORMAL DELI       ELECTIVE 2113-10-12 07:15:00  74.0
#
#                    CHARTTIME DEATHTIME  \
# 0        2101-10-22 04:31:00       NaN
# 1        2101-10-23 02:46:00       NaN
# 2        2101-10-23 10:14:00       NaN
# 3        2101-10-23 16:10:00       NaN
# 4        2101-10-20 20:04:00       NaN
# ...                      ...       ...
# 5024472  2113-10-12 11:32:00       NaN
# 5024473  2113-10-12 11:32:00       NaN
# 5024474  2113-10-12 11:38:00       NaN
# 5024475  2113-10-12 11:38:00       NaN
# 5024476  2113-10-12 11:38:00       NaN
#
#                                                  DIAGNOSIS DISCHARGE_LOCATION  \
# 0                                              HYPOTENSION                SNF
# 1                                              HYPOTENSION                SNF
# 2                                              HYPOTENSION                SNF
# 3                                              HYPOTENSION                SNF
# 4                                              HYPOTENSION                SNF
# ...                                                    ...                ...
# 5024472  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...               HOME
# 5024473  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...               HOME
# 5024474  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...               HOME
# 5024475  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...               HOME
# 5024476  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...               HOME
#
#                    DISCHTIME        DOB  ... INSURANCE ITEMID LANGUAGE  \
# 0        2101-10-31 13:58:00 2025-04-11  ...  Medicare  50808      NaN
# 1        2101-10-31 13:58:00 2025-04-11  ...  Medicare  50808      NaN
# 2        2101-10-31 13:58:00 2025-04-11  ...  Medicare  50808      NaN
# 3        2101-10-31 13:58:00 2025-04-11  ...  Medicare  50808      NaN
# 4        2101-10-31 13:58:00 2025-04-11  ...  Medicare  50808      NaN
# ...                      ...        ...  ...       ...    ...      ...
# 5024472  2113-10-18 13:15:00 2039-11-04  ...  Self Pay   1535     ENGL
# 5024473  2113-10-18 13:15:00 2039-11-04  ...  Self Pay   1536     ENGL
# 5024474  2113-10-18 13:15:00 2039-11-04  ...  Self Pay    815     ENGL
# 5024475  2113-10-18 13:15:00 2039-11-04  ...  Self Pay    828     ENGL
# 5024476  2113-10-18 13:15:00 2039-11-04  ...  Self Pay   1530     ENGL
#
#         MARITAL_STATUS      MIMICExtractName           RELIGION  SUBJECT_ID  \
# 0              MARRIED       Calcium ionized           CATHOLIC           3
# 1              MARRIED       Calcium ionized           CATHOLIC           3
# 2              MARRIED       Calcium ionized           CATHOLIC           3
# 3              MARRIED       Calcium ionized           CATHOLIC           3
# 4              MARRIED       Calcium ionized           CATHOLIC           3
# ...                ...                   ...                ...         ...
# 5024472        MARRIED             Potassium  PROTESTANT QUAKER       32777
# 5024473        MARRIED                Sodium  PROTESTANT QUAKER       32777
# 5024474        MARRIED  Prothrombin time INR  PROTESTANT QUAKER       32777
# 5024475        MARRIED             Platelets  PROTESTANT QUAKER       32777
# 5024476        MARRIED  Prothrombin time INR  PROTESTANT QUAKER       32777
#
#         VALUE  VALUENUM  VALUEUOM
# 0        1.12      1.12    mmol/L
# 1        1.19      1.19    mmol/L
# 2        1.11      1.11    mmol/L
# 3        0.80      0.80    mmol/L
# 4        0.98      0.98    mmol/L
# ...       ...       ...       ...
# 5024472   4.2      4.20       NaN
# 5024473   138    138.00       NaN
# 5024474   1.3      1.30       NaN
# 5024475   131    131.00       NaN
# 5024476   1.3      1.30       NaN
#
# [9970300 rows x 31 columns]

# %%
final_labs = t_c_l.groupby(["HADM_ID", "ADMITTIME", "CHARTTIME", "VALUENUM", "MIMICExtractName"]).nth(0).reset_index()

# %%
final_labs = final_labs.dropna(subset=['VALUENUM'])

# %%
final_labs
# Out:
#           HADM_ID           ADMITTIME            CHARTTIME  VALUENUM  \
# 0        100001.0 2117-09-11 11:46:00  2117-09-11 08:22:00       0.5
# 1        100001.0 2117-09-11 11:46:00  2117-09-11 08:22:00       2.7
# 2        100001.0 2117-09-11 11:46:00  2117-09-11 08:22:00       4.9
# 3        100001.0 2117-09-11 11:46:00  2117-09-11 08:22:00      10.0
# 4        100001.0 2117-09-11 11:46:00  2117-09-11 08:22:00      16.0
# ...           ...                 ...                  ...       ...
# 7062478  199999.0 2136-04-04 23:37:00  2136-04-10 02:28:00       4.4
# 7062479  199999.0 2136-04-04 23:37:00  2136-04-10 02:28:00       8.4
# 7062480  199999.0 2136-04-04 23:37:00  2136-04-10 02:28:00     114.0
# 7062481  199999.0 2136-04-04 23:37:00  2136-04-10 02:28:00     138.0
# 7062482  199999.0 2136-04-04 23:37:00  2136-04-10 10:00:00     143.0
#
#                   MIMICExtractName         ADMISSION_LOCATION ADMISSION_TYPE  \
# 0                 Bilirubin, Total  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 1                       Creatinine  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 2                        Potassium  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 3         Alanine aminotransferase  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 4        Asparate aminotransferase  CLINIC REFERRAL/PREMATURE      EMERGENCY
# ...                            ...                        ...            ...
# 7062478            Potassium serum  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 7062479                    Calcium  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 7062480                    Glucose  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 7062481                     Sodium  CLINIC REFERRAL/PREMATURE      EMERGENCY
# 7062482                    Glucose  CLINIC REFERRAL/PREMATURE      EMERGENCY
#
#           AGE DEATHTIME              DIAGNOSIS  ... HAS_CHARTEVENTS_DATA  \
# 0        35.0       NaN  DIABETIC KETOACIDOSIS  ...                    1
# 1        35.0       NaN  DIABETIC KETOACIDOSIS  ...                    1
# 2        35.0       NaN  DIABETIC KETOACIDOSIS  ...                    1
# 3        35.0       NaN  DIABETIC KETOACIDOSIS  ...                    1
# 4        35.0       NaN  DIABETIC KETOACIDOSIS  ...                    1
# ...       ...       ...                    ...  ...                  ...
# 7062478  88.0       NaN              PNEUMONIA  ...                    1
# 7062479  88.0       NaN              PNEUMONIA  ...                    1
# 7062480  88.0       NaN              PNEUMONIA  ...                    1
# 7062481  88.0       NaN              PNEUMONIA  ...                    1
# 7062482  88.0       NaN              PNEUMONIA  ...                    1
#
#         HOSPITAL_EXPIRE_FLAG INSURANCE  ITEMID LANGUAGE MARITAL_STATUS  \
# 0                          0   Private   50885     ENGL       DIVORCED
# 1                          0   Private   50912     ENGL       DIVORCED
# 2                          0   Private   50971     ENGL       DIVORCED
# 3                          0   Private   50861     ENGL       DIVORCED
# 4                          0   Private   50878     ENGL       DIVORCED
# ...                      ...       ...     ...      ...            ...
# 7062478                    0  Medicare  227442     ENGL        MARRIED
# 7062479                    0  Medicare  225625     ENGL        MARRIED
# 7062480                    0  Medicare  220621     ENGL        MARRIED
# 7062481                    0  Medicare  220645     ENGL        MARRIED
# 7062482                    0  Medicare  225664     ENGL        MARRIED
#
#                   RELIGION SUBJECT_ID  VALUE  VALUEUOM
# 0        PROTESTANT QUAKER      58526    0.5     mg/dL
# 1        PROTESTANT QUAKER      58526    2.7     mg/dL
# 2        PROTESTANT QUAKER      58526    4.9     mEq/L
# 3        PROTESTANT QUAKER      58526     10      IU/L
# 4        PROTESTANT QUAKER      58526     16      IU/L
# ...                    ...        ...    ...       ...
# 7062478             JEWISH      40370    4.4     mEq/L
# 7062479             JEWISH      40370    8.4     mg/dL
# 7062480             JEWISH      40370  114.0     mg/dL
# 7062481             JEWISH      40370  138.0     mEq/L
# 7062482             JEWISH      40370  143.0       NaN
#
# [7062483 rows x 31 columns]

# %%
final_labs.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_patient_data_mimic_extract.csv"))

# %%
final_labs.columns
# Out:
# Index(['HADM_ID', 'ADMITTIME', 'CHARTTIME', 'VALUENUM', 'MIMICExtractName',
#        'ADMISSION_LOCATION', 'ADMISSION_TYPE', 'AGE', 'DEATHTIME', 'DIAGNOSIS',
#        'DISCHARGE_LOCATION', 'DISCHTIME', 'DOB', 'DOD', 'DOD_HOSP', 'DOD_SSN',
#        'EDOUTTIME', 'EDREGTIME', 'ETHNICITY', 'EXPIRE_FLAG', 'GENDER',
#        'HAS_CHARTEVENTS_DATA', 'HOSPITAL_EXPIRE_FLAG', 'INSURANCE', 'ITEMID',
#        'LANGUAGE', 'MARITAL_STATUS', 'RELIGION', 'SUBJECT_ID', 'VALUE',
#        'VALUEUOM'],
#       dtype='object')

# %%
final_la
