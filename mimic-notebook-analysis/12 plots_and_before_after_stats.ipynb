# %%
data = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/data"
res = "/Volumes/GoogleDrive/My Drive/TAU/Code/DrugLab/results"

# %%
import pandas as pd
import os

# %% [markdown]
# ## Medication Patient Data

# %% [markdown]
# ## Filter Meds

# %% [markdown]
# ### Med 1

# %%
med1 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med1_vectorized.csv"))

# %%
med1 = med1.drop(columns=["Unnamed: 0"])

# %%
med1
# Out:
#         SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG  ITEMID  HADM_ID  \
# 0              249  2075-03-13      F  NaN            0  226361   149546
# 1              249  2075-03-13      F  NaN            0  225910   149546
# 2              249  2075-03-13      F  NaN            0  225943   149546
# 3              249  2075-03-13      F  NaN            0  223258   149546
# 4              249  2075-03-13      F  NaN            0  225168   149546
# ...            ...         ...    ...  ...          ...     ...      ...
# 323002       44128  2098-07-25      M  NaN            0  225166   141304
# 323003       44128  2098-07-25      M  NaN            0  225158   141304
# 323004       44128  2098-07-25      M  NaN            0  225834   141304
# 323005       44128  2098-07-25      M  NaN            0  223258   141304
# 323006       44128  2098-07-25      M  NaN            0  225154   141304
#
#         ICUSTAY_ID            STARTTIME              ENDTIME  ...  \
# 0         269035.0  2155-02-03 23:00:00  2155-02-03 23:01:00  ...
# 1         269035.0  2155-02-04 00:49:00  2155-02-04 00:50:00  ...
# 2         269035.0  2155-02-04 00:49:00  2155-02-04 00:50:00  ...
# 3         269035.0  2155-02-04 00:50:00  2155-02-04 00:51:00  ...
# 4         269035.0  2155-02-04 03:24:00  2155-02-04 05:24:00  ...
# ...            ...                  ...                  ...  ...
# 323002    253669.0  2149-06-11 02:25:00  2149-06-11 19:59:00  ...
# 323003    253669.0  2149-06-11 20:07:00  2149-06-12 02:04:00  ...
# 323004    253669.0  2149-06-11 20:07:00  2149-06-12 02:04:00  ...
# 323005    253669.0  2149-06-12 14:40:00  2149-06-12 14:41:00  ...
# 323006    253669.0  2149-06-12 17:24:00  2149-06-12 17:25:00  ...
#
#                           LABEL              ABBREVIATION    DBSOURCE  \
# 0          Pre-Admission Intake      Pre-Admission Intake  metavision
# 1       Pantoprazole (Protonix)   Pantoprazole (Protonix)  metavision
# 2                      Solution                  Solution  metavision
# 3             Insulin - Regular         Insulin - Regular  metavision
# 4        Packed Red Blood Cells                    PRBC's  metavision
# ...                         ...                       ...         ...
# 323002       Potassium Chloride  Potassium Chloride - KCL  metavision
# 323003                NaCl 0.9%                 NaCl 0.9%  metavision
# 323004                   K Phos                    K Phos  metavision
# 323005        Insulin - Regular         Insulin - Regular  metavision
# 323006         Morphine Sulfate          Morphine Sulfate  metavision
#
#                LINKSTO                 CATEGORY  UNITNAME  PARAM_TYPE  \
# 0       inputevents_mv            Fluids/Intake        mL    Solution
# 1       inputevents_mv              Medications      dose    Solution
# 2       inputevents_mv            Fluids/Intake        mL    Solution
# 3       inputevents_mv              Medications     units    Solution
# 4       inputevents_mv  Blood Products/Colloids        mL    Solution
# ...                ...                      ...       ...         ...
# 323002  inputevents_mv              Medications       mEq    Solution
# 323003  inputevents_mv            Fluids/Intake        mL    Solution
# 323004  inputevents_mv              Medications      mmol    Solution
# 323005  inputevents_mv              Medications     units    Solution
# 323006  inputevents_mv              Medications        mg    Solution
#
#         CONCEPTID MedTimeFromAdmit   AGE
# 0             NaN  0 days 02:45:00  80.0
# 1             NaN  0 days 04:34:00  80.0
# 2             NaN  0 days 04:34:00  80.0
# 3             NaN  0 days 04:35:00  80.0
# 4             NaN  0 days 09:08:00  80.0
# ...           ...              ...   ...
# 323002        NaN  3 days 04:38:00  51.0
# 323003        NaN  3 days 10:43:00  51.0
# 323004        NaN  3 days 10:43:00  51.0
# 323005        NaN  3 days 23:20:00  51.0
# 323006        NaN  4 days 02:04:00  51.0
#
# [323007 rows x 63 columns]

# %%
v = med1.groupby(["SUBJECT_ID", "HADM_ID"]).count()[["ITEMID"]].reset_index()
t = v.groupby("SUBJECT_ID").count()
# t[t["ITEMID"]>1] # Unique subjects with more than 1 admission = 2586
# t.shape # Unique subjects = 17675

# %%
adm_1 = med1[med1.SUBJECT_ID.isin(t[t["ITEMID"]>1].index.to_list())]

# %%
adm_1
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 0              249  2075-03-13      F                  NaN            0
# 1              249  2075-03-13      F                  NaN            0
# 2              249  2075-03-13      F                  NaN            0
# 3              249  2075-03-13      F                  NaN            0
# 4              249  2075-03-13      F                  NaN            0
# ...            ...         ...    ...                  ...          ...
# 322890       44083  2057-11-15      M  2114-02-20 00:00:00            1
# 322891       44083  2057-11-15      M  2114-02-20 00:00:00            1
# 322892       44083  2057-11-15      M  2114-02-20 00:00:00            1
# 322893       44083  2057-11-15      M  2114-02-20 00:00:00            1
# 322894       44083  2057-11-15      M  2114-02-20 00:00:00            1
#
#         ITEMID  HADM_ID  ICUSTAY_ID            STARTTIME              ENDTIME  \
# 0       226361   149546    269035.0  2155-02-03 23:00:00  2155-02-03 23:01:00
# 1       225910   149546    269035.0  2155-02-04 00:49:00  2155-02-04 00:50:00
# 2       225943   149546    269035.0  2155-02-04 00:49:00  2155-02-04 00:50:00
# 3       223258   149546    269035.0  2155-02-04 00:50:00  2155-02-04 00:51:00
# 4       225168   149546    269035.0  2155-02-04 03:24:00  2155-02-04 05:24:00
# ...        ...      ...         ...                  ...                  ...
# 322890  225975   125157    265615.0  2112-05-06 00:15:00  2112-05-06 00:16:00
# 322891  225823   125157    265615.0  2112-05-06 08:49:00  2112-05-06 17:20:00
# 322892  225166   125157    265615.0  2112-05-06 08:49:00  2112-05-06 17:20:00
# 322893  225850   198330    286428.0  2112-05-31 02:00:00  2112-05-31 02:01:00
# 322894  220949   198330    286428.0  2112-05-31 02:00:00  2112-05-31 02:01:00
#
#         ...                         LABEL                  ABBREVIATION  \
# 0       ...          Pre-Admission Intake          Pre-Admission Intake
# 1       ...       Pantoprazole (Protonix)       Pantoprazole (Protonix)
# 2       ...                      Solution                      Solution
# 3       ...             Insulin - Regular             Insulin - Regular
# 4       ...        Packed Red Blood Cells                        PRBC's
# ...     ...                           ...                           ...
# 322890  ...  Heparin Sodium (Prophylaxis)  Heparin Sodium (Prophylaxis)
# 322891  ...                      D5 1/2NS                      D5 1/2NS
# 322892  ...            Potassium Chloride      Potassium Chloride - KCL
# 322893  ...                     Cefazolin                     Cefazolin
# 322894  ...                   Dextrose 5%                   Dextrose 5%
#
#           DBSOURCE         LINKSTO                 CATEGORY  UNITNAME  \
# 0       metavision  inputevents_mv            Fluids/Intake        mL
# 1       metavision  inputevents_mv              Medications      dose
# 2       metavision  inputevents_mv            Fluids/Intake        mL
# 3       metavision  inputevents_mv              Medications     units
# 4       metavision  inputevents_mv  Blood Products/Colloids        mL
# ...            ...             ...                      ...       ...
# 322890  metavision  inputevents_mv              Medications      dose
# 322891  metavision  inputevents_mv            Fluids/Intake        mL
# 322892  metavision  inputevents_mv              Medications       mEq
# 322893  metavision  inputevents_mv              Antibiotics      dose
# 322894  metavision  inputevents_mv            Fluids/Intake        mL
#
#         PARAM_TYPE  CONCEPTID MedTimeFromAdmit   AGE
# 0         Solution        NaN  0 days 02:45:00  80.0
# 1         Solution        NaN  0 days 04:34:00  80.0
# 2         Solution        NaN  0 days 04:34:00  80.0
# 3         Solution        NaN  0 days 04:35:00  80.0
# 4         Solution        NaN  0 days 09:08:00  80.0
# ...            ...        ...              ...   ...
# 322890    Solution        NaN  1 days 16:16:00  55.0
# 322891    Solution        NaN  2 days 09:20:00  55.0
# 322892    Solution        NaN  2 days 09:20:00  55.0
# 322893    Solution        NaN  2 days 10:16:00  55.0
# 322894    Solution        NaN  2 days 10:16:00  55.0
#
# [73151 rows x 63 columns]

# %%
med1.sort_values(["SUBJECT_ID", "ITEMID", ""])

# %%
'AGE' in med1.columns
# Out:
# True

# %%
med1

# %% [markdown]
# ### Med 2

# %%
med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_87162/27638116.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   med2 = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "med2_vectorized.csv"))

# %%
med2 = med2.drop(columns=["Unnamed: 0"])

# %% [markdown]
# ## Filter Labs

# %%
labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))
# labs = labs.rename(columns={"SUBJECT_ID_x":"SUBJECT_ID"})
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_87162/2399771944.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   labs = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "labs_vectorized.csv"))

# %%
labs = labs.drop(columns=["Unnamed: 0"])
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 0               249  2075-03-13      F  NaN            0    163327  158975.0
# 1               249  2075-03-13      F  NaN            0    163304  158975.0
# 2               249  2075-03-13      F  NaN            0    163317  158975.0
# 3               249  2075-03-13      F  NaN            0    163315  158975.0
# 4               249  2075-03-13      F  NaN            0    163316  158975.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7260280       44128  2098-07-25      M  NaN            0  20437251  141304.0
# 7260281       44128  2098-07-25      M  NaN            0  20437245  141304.0
# 7260282       44128  2098-07-25      M  NaN            0  20437250  141304.0
# 7260283       44128  2098-07-25      M  NaN            0  20437255  141304.0
# 7260284       44128  2098-07-25      M  NaN            0  20437256  141304.0
#
#          ITEMID            CHARTTIME  VALUE  ...       RELIGION  \
# 0         51274  2156-04-27 15:40:00   20.0  ...       CATHOLIC
# 1         50868  2156-04-27 15:40:00   12.0  ...       CATHOLIC
# 2         51221  2156-04-27 15:40:00   29.5  ...       CATHOLIC
# 3         51146  2156-04-27 15:40:00    0.4  ...       CATHOLIC
# 4         51200  2156-04-27 15:40:00    2.4  ...       CATHOLIC
# ...         ...                  ...    ...  ...            ...
# 7260280   51275  2149-06-14 05:00:00   26.4  ...  NOT SPECIFIED
# 7260281   51237  2149-06-14 05:00:00    1.1  ...  NOT SPECIFIED
# 7260282   51274  2149-06-14 05:00:00   12.8  ...  NOT SPECIFIED
# 7260283   51221  2149-06-15 04:45:00   27.3  ...  NOT SPECIFIED
# 7260284   51221  2149-06-16 12:22:00   28.0  ...  NOT SPECIFIED
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0             DIVORCED     WHITE                  NaN                  NaN
# 1             DIVORCED     WHITE                  NaN                  NaN
# 2             DIVORCED     WHITE                  NaN                  NaN
# 3             DIVORCED     WHITE                  NaN                  NaN
# 4             DIVORCED     WHITE                  NaN                  NaN
# ...                ...       ...                  ...                  ...
# 7260280        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260281        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260282        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260283        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260284        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
#
#                        DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 0        GI BLEEDING\COLONOSCOPY                    0                    1
# 1        GI BLEEDING\COLONOSCOPY                    0                    1
# 2        GI BLEEDING\COLONOSCOPY                    0                    1
# 3        GI BLEEDING\COLONOSCOPY                    0                    1
# 4        GI BLEEDING\COLONOSCOPY                    0                    1
# ...                          ...                  ...                  ...
# 7260280                   TRAUMA                    0                    1
# 7260281                   TRAUMA                    0                    1
# 7260282                   TRAUMA                    0                    1
# 7260283                   TRAUMA                    0                    1
# 7260284                   TRAUMA                    0                    1
#
#          LabTimeFromAdmit   AGE
# 0         0 days 00:07:00  81.0
# 1         0 days 00:07:00  81.0
# 2         0 days 00:07:00  81.0
# 3         0 days 00:07:00  81.0
# 4         0 days 00:07:00  81.0
# ...                   ...   ...
# 7260280   5 days 13:39:00  51.0
# 7260281   5 days 13:39:00  51.0
# 7260282   5 days 13:39:00  51.0
# 7260283   6 days 13:24:00  51.0
# 7260284   7 days 21:01:00  51.0
#
# [7260285 rows x 38 columns]

# %% [markdown]
# ## Pairs

# %%
counts = med1.groupby("ITEMID").count()[["HADM_ID"]].sort_values("HADM_ID", ascending=False)
counts[counts["HADM_ID"]>1000]
# Out:
#         HADM_ID
# ITEMID
# 225158    15866
# 220949    13849
# 226452    13351
# 225943    11183
# 222011     9274
# ...         ...
# 225883     1149
# 225833     1045
# 228315     1044
# 225153     1003
# 221468     1003
#
# [67 rows x 1 columns]

# %%
labitems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_LABITEMS.csv.gz"))
meditems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_ITEMS.csv.gz"))

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 0               249  2075-03-13      F  NaN            0    163327  158975.0
# 1               249  2075-03-13      F  NaN            0    163304  158975.0
# 2               249  2075-03-13      F  NaN            0    163317  158975.0
# 3               249  2075-03-13      F  NaN            0    163315  158975.0
# 4               249  2075-03-13      F  NaN            0    163316  158975.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7260280       44128  2098-07-25      M  NaN            0  20437251  141304.0
# 7260281       44128  2098-07-25      M  NaN            0  20437245  141304.0
# 7260282       44128  2098-07-25      M  NaN            0  20437250  141304.0
# 7260283       44128  2098-07-25      M  NaN            0  20437255  141304.0
# 7260284       44128  2098-07-25      M  NaN            0  20437256  141304.0
#
#          ITEMID            CHARTTIME  VALUE  ...       RELIGION  \
# 0         51274  2156-04-27 15:40:00   20.0  ...       CATHOLIC
# 1         50868  2156-04-27 15:40:00   12.0  ...       CATHOLIC
# 2         51221  2156-04-27 15:40:00   29.5  ...       CATHOLIC
# 3         51146  2156-04-27 15:40:00    0.4  ...       CATHOLIC
# 4         51200  2156-04-27 15:40:00    2.4  ...       CATHOLIC
# ...         ...                  ...    ...  ...            ...
# 7260280   51275  2149-06-14 05:00:00   26.4  ...  NOT SPECIFIED
# 7260281   51237  2149-06-14 05:00:00    1.1  ...  NOT SPECIFIED
# 7260282   51274  2149-06-14 05:00:00   12.8  ...  NOT SPECIFIED
# 7260283   51221  2149-06-15 04:45:00   27.3  ...  NOT SPECIFIED
# 7260284   51221  2149-06-16 12:22:00   28.0  ...  NOT SPECIFIED
#
#         MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0             DIVORCED     WHITE                  NaN                  NaN
# 1             DIVORCED     WHITE                  NaN                  NaN
# 2             DIVORCED     WHITE                  NaN                  NaN
# 3             DIVORCED     WHITE                  NaN                  NaN
# 4             DIVORCED     WHITE                  NaN                  NaN
# ...                ...       ...                  ...                  ...
# 7260280        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260281        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260282        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260283        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
# 7260284        MARRIED     WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
#
#                        DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA  \
# 0        GI BLEEDING\COLONOSCOPY                    0                    1
# 1        GI BLEEDING\COLONOSCOPY                    0                    1
# 2        GI BLEEDING\COLONOSCOPY                    0                    1
# 3        GI BLEEDING\COLONOSCOPY                    0                    1
# 4        GI BLEEDING\COLONOSCOPY                    0                    1
# ...                          ...                  ...                  ...
# 7260280                   TRAUMA                    0                    1
# 7260281                   TRAUMA                    0                    1
# 7260282                   TRAUMA                    0                    1
# 7260283                   TRAUMA                    0                    1
# 7260284                   TRAUMA                    0                    1
#
#          LabTimeFromAdmit   AGE
# 0         0 days 00:07:00  81.0
# 1         0 days 00:07:00  81.0
# 2         0 days 00:07:00  81.0
# 3         0 days 00:07:00  81.0
# 4         0 days 00:07:00  81.0
# ...                   ...   ...
# 7260280   5 days 13:39:00  51.0
# 7260281   5 days 13:39:00  51.0
# 7260282   5 days 13:39:00  51.0
# 7260283   6 days 13:24:00  51.0
# 7260284   7 days 21:01:00  51.0
#
# [7260285 rows x 38 columns]

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%        15866
# 1                   Dextrose 5%        13849
# 2                     PO Intake        13351
# 3                      Solution        11183
# 4             Magnesium Sulfate         9274
# 5            Potassium Chloride         9221
# 6  Heparin Sodium (Prophylaxis)         8759
# 7             Insulin - Regular         7948
# 8                    Vancomycin         7377
# 9     Magnesium Sulfate (Bolus)         7279

# %%
pd.DataFrame(med1.groupby(["LABEL", "SUBJECT_ID"]).nth(0).reset_index()["LABEL"].value_counts()).reset_index().rename(columns={"index":"MED_NAME", "LABEL":"DATA_POINTS"}).head(10)
# Out:
#                        MED_NAME  DATA_POINTS
# 0                     NaCl 0.9%        15866
# 1                   Dextrose 5%        13849
# 2                     PO Intake        13351
# 3                      Solution        11183
# 4             Magnesium Sulfate         9274
# 5            Potassium Chloride         9221
# 6  Heparin Sodium (Prophylaxis)         8759
# 7             Insulin - Regular         7948
# 8                    Vancomycin         7377
# 9     Magnesium Sulfate (Bolus)         7279

# %%
med1["STARTTIME"] = pd.to_datetime(med1["STARTTIME"])
med1["ENDTIME"] = pd.to_datetime(med1["ENDTIME"])
med1["ADMITTIME"] = pd.to_datetime(med1["ADMITTIME"])
med1["MedTimeFromAdmit"] = med1["ENDTIME"]-med1["ADMITTIME"]
med2["STARTTIME"] = pd.to_datetime(med2["STARTTIME"])
med2["ENDTIME"] = pd.to_datetime(med2["ENDTIME"])
med2["ADMITTIME"] = pd.to_datetime(med2["ADMITTIME"])
med2["MedTimeFromAdmit"] = med2["ENDTIME"]-med2["ADMITTIME"]
labs["CHARTTIME"] = pd.to_datetime(labs["CHARTTIME"])
labs["ADMITTIME"] = pd.to_datetime(labs["ADMITTIME"])
labs["LabTimeFromAdmit"] = labs["CHARTTIME"]-labs["ADMITTIME"]

# %%
med1["hours_in"] = med1["MedTimeFromAdmit"].dt.total_seconds()/3600
labs["hours_in"] = labs["LabTimeFromAdmit"].dt.total_seconds()/3600

# %%
labs
# Out:
#          SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG    ROW_ID   HADM_ID  \
# 0               249  2075-03-13      F  NaN            0    163327  158975.0
# 1               249  2075-03-13      F  NaN            0    163304  158975.0
# 2               249  2075-03-13      F  NaN            0    163317  158975.0
# 3               249  2075-03-13      F  NaN            0    163315  158975.0
# 4               249  2075-03-13      F  NaN            0    163316  158975.0
# ...             ...         ...    ...  ...          ...       ...       ...
# 7260280       44128  2098-07-25      M  NaN            0  20437251  141304.0
# 7260281       44128  2098-07-25      M  NaN            0  20437245  141304.0
# 7260282       44128  2098-07-25      M  NaN            0  20437250  141304.0
# 7260283       44128  2098-07-25      M  NaN            0  20437255  141304.0
# 7260284       44128  2098-07-25      M  NaN            0  20437256  141304.0
#
#          ITEMID           CHARTTIME  VALUE  ...  MARITAL_STATUS ETHNICITY  \
# 0         51274 2156-04-27 15:40:00   20.0  ...        DIVORCED     WHITE
# 1         50868 2156-04-27 15:40:00   12.0  ...        DIVORCED     WHITE
# 2         51221 2156-04-27 15:40:00   29.5  ...        DIVORCED     WHITE
# 3         51146 2156-04-27 15:40:00    0.4  ...        DIVORCED     WHITE
# 4         51200 2156-04-27 15:40:00    2.4  ...        DIVORCED     WHITE
# ...         ...                 ...    ...  ...             ...       ...
# 7260280   51275 2149-06-14 05:00:00   26.4  ...         MARRIED     WHITE
# 7260281   51237 2149-06-14 05:00:00    1.1  ...         MARRIED     WHITE
# 7260282   51274 2149-06-14 05:00:00   12.8  ...         MARRIED     WHITE
# 7260283   51221 2149-06-15 04:45:00   27.3  ...         MARRIED     WHITE
# 7260284   51221 2149-06-16 12:22:00   28.0  ...         MARRIED     WHITE
#
#                    EDREGTIME            EDOUTTIME                DIAGNOSIS  \
# 0                        NaN                  NaN  GI BLEEDING\COLONOSCOPY
# 1                        NaN                  NaN  GI BLEEDING\COLONOSCOPY
# 2                        NaN                  NaN  GI BLEEDING\COLONOSCOPY
# 3                        NaN                  NaN  GI BLEEDING\COLONOSCOPY
# 4                        NaN                  NaN  GI BLEEDING\COLONOSCOPY
# ...                      ...                  ...                      ...
# 7260280  2149-06-08 11:53:00  2149-06-08 15:31:00                   TRAUMA
# 7260281  2149-06-08 11:53:00  2149-06-08 15:31:00                   TRAUMA
# 7260282  2149-06-08 11:53:00  2149-06-08 15:31:00                   TRAUMA
# 7260283  2149-06-08 11:53:00  2149-06-08 15:31:00                   TRAUMA
# 7260284  2149-06-08 11:53:00  2149-06-08 15:31:00                   TRAUMA
#
#         HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA LabTimeFromAdmit   AGE  \
# 0                          0                    1  0 days 00:07:00  81.0
# 1                          0                    1  0 days 00:07:00  81.0
# 2                          0                    1  0 days 00:07:00  81.0
# 3                          0                    1  0 days 00:07:00  81.0
# 4                          0                    1  0 days 00:07:00  81.0
# ...                      ...                  ...              ...   ...
# 7260280                    0                    1  5 days 13:39:00  51.0
# 7260281                    0                    1  5 days 13:39:00  51.0
# 7260282                    0                    1  5 days 13:39:00  51.0
# 7260283                    0                    1  6 days 13:24:00  51.0
# 7260284                    0                    1  7 days 21:01:00  51.0
#
#            hours_in
# 0          0.116667
# 1          0.116667
# 2          0.116667
# 3          0.116667
# 4          0.116667
# ...             ...
# 7260280  133.650000
# 7260281  133.650000
# 7260282  133.650000
# 7260283  157.400000
# 7260284  189.016667
#
# [7260285 rows x 39 columns]

# %%
med1
# Out:
#         SUBJECT_ID         DOB GENDER  DOD  EXPIRE_FLAG  ITEMID  HADM_ID  \
# 0              249  2075-03-13      F  NaN            0  226361   149546
# 1              249  2075-03-13      F  NaN            0  225910   149546
# 2              249  2075-03-13      F  NaN            0  225943   149546
# 3              249  2075-03-13      F  NaN            0  223258   149546
# 4              249  2075-03-13      F  NaN            0  225168   149546
# ...            ...         ...    ...  ...          ...     ...      ...
# 323002       44128  2098-07-25      M  NaN            0  225166   141304
# 323003       44128  2098-07-25      M  NaN            0  225158   141304
# 323004       44128  2098-07-25      M  NaN            0  225834   141304
# 323005       44128  2098-07-25      M  NaN            0  223258   141304
# 323006       44128  2098-07-25      M  NaN            0  225154   141304
#
#         ICUSTAY_ID           STARTTIME             ENDTIME  ...  \
# 0         269035.0 2155-02-03 23:00:00 2155-02-03 23:01:00  ...
# 1         269035.0 2155-02-04 00:49:00 2155-02-04 00:50:00  ...
# 2         269035.0 2155-02-04 00:49:00 2155-02-04 00:50:00  ...
# 3         269035.0 2155-02-04 00:50:00 2155-02-04 00:51:00  ...
# 4         269035.0 2155-02-04 03:24:00 2155-02-04 05:24:00  ...
# ...            ...                 ...                 ...  ...
# 323002    253669.0 2149-06-11 02:25:00 2149-06-11 19:59:00  ...
# 323003    253669.0 2149-06-11 20:07:00 2149-06-12 02:04:00  ...
# 323004    253669.0 2149-06-11 20:07:00 2149-06-12 02:04:00  ...
# 323005    253669.0 2149-06-12 14:40:00 2149-06-12 14:41:00  ...
# 323006    253669.0 2149-06-12 17:24:00 2149-06-12 17:25:00  ...
#
#                     ABBREVIATION    DBSOURCE         LINKSTO  \
# 0           Pre-Admission Intake  metavision  inputevents_mv
# 1        Pantoprazole (Protonix)  metavision  inputevents_mv
# 2                       Solution  metavision  inputevents_mv
# 3              Insulin - Regular  metavision  inputevents_mv
# 4                         PRBC's  metavision  inputevents_mv
# ...                          ...         ...             ...
# 323002  Potassium Chloride - KCL  metavision  inputevents_mv
# 323003                 NaCl 0.9%  metavision  inputevents_mv
# 323004                    K Phos  metavision  inputevents_mv
# 323005         Insulin - Regular  metavision  inputevents_mv
# 323006          Morphine Sulfate  metavision  inputevents_mv
#
#                        CATEGORY UNITNAME  PARAM_TYPE  CONCEPTID  \
# 0                 Fluids/Intake       mL    Solution        NaN
# 1                   Medications     dose    Solution        NaN
# 2                 Fluids/Intake       mL    Solution        NaN
# 3                   Medications    units    Solution        NaN
# 4       Blood Products/Colloids       mL    Solution        NaN
# ...                         ...      ...         ...        ...
# 323002              Medications      mEq    Solution        NaN
# 323003            Fluids/Intake       mL    Solution        NaN
# 323004              Medications     mmol    Solution        NaN
# 323005              Medications    units    Solution        NaN
# 323006              Medications       mg    Solution        NaN
#
#         MedTimeFromAdmit   AGE   hours_in
# 0        0 days 02:45:00  80.0   2.750000
# 1        0 days 04:34:00  80.0   4.566667
# 2        0 days 04:34:00  80.0   4.566667
# 3        0 days 04:35:00  80.0   4.583333
# 4        0 days 09:08:00  80.0   9.133333
# ...                  ...   ...        ...
# 323002   3 days 04:38:00  51.0  76.633333
# 323003   3 days 10:43:00  51.0  82.716667
# 323004   3 days 10:43:00  51.0  82.716667
# 323005   3 days 23:20:00  51.0  95.333333
# 323006   4 days 02:04:00  51.0  98.066667
#
# [323007 rows x 64 columns]

# %%
med1.columns
# Out:
# Index(['SUBJECT_ID', 'DOB', 'GENDER', 'DOD', 'EXPIRE_FLAG', 'ITEMID',
#        'HADM_ID', 'ICUSTAY_ID', 'STARTTIME', 'ENDTIME', 'AMOUNT', 'AMOUNTUOM',
#        'RATE', 'RATEUOM', 'STORETIME', 'CGID', 'ORDERID', 'LINKORDERID',
#        'ORDERCATEGORYNAME', 'SECONDARYORDERCATEGORYNAME',
#        'ORDERCOMPONENTTYPEDESCRIPTION', 'ORDERCATEGORYDESCRIPTION',
#        'PATIENTWEIGHT', 'TOTALAMOUNT', 'TOTALAMOUNTUOM', 'ISOPENBAG',
#        'CONTINUEINNEXTDEPT', 'CANCELREASON', 'STATUSDESCRIPTION',
#        'COMMENTS_EDITEDBY', 'COMMENTS_CANCELEDBY', 'COMMENTS_DATE',
#        'ORIGINALAMOUNT', 'ORIGINALRATE', 'ROW_ID_y', 'SUBJECT_ID_y',
#        'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE',
#        'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE',
#        'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME',
#        'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA', 'ROW_ID',
#        'LABEL', 'ABBREVIATION', 'DBSOURCE', 'LINKSTO', 'CATEGORY', 'UNITNAME',
#        'PARAM_TYPE', 'CONCEPTID', 'MedTimeFromAdmit', 'AGE', 'hours_in'],
#       dtype='object')

# %%
meds = []
labtests = []

# meds.append('Insulin - Regular')
# labtests.append('Glucose')

# meds.append('Packed Red Blood Cells')
# labtests.append('Hematocrait')

# meds.append('Packed Red Blood Cells')
# labtests.append('Hemoglobin')

# meds.append('Packed Red Blood Cells')
# labtests.append('Red Blood Cells')

# meds.append('Calcium')
# labtests.append('Calcium Total')

# meds.append('Albumin 5%')
# labtests.append('Hematocrit')

meds.append('Insulin - Regular')
labtests.append('pO2')

med_vals = list(meds)
labtest_vals = list(labtests)

# %%
t_med1 = med1[med1["LABEL"].isin(med_vals)]
t_med2 = med2[med2["LABEL"].isin(med_vals)]

# %%
t_labs = labs[labs["LABEL"].isin(labtest_vals)]

# %% [markdown]
# ## Before After Trend Calculation

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
def check_med2(row):
    if row["HADM_ID"] in t_med2["HADM_ID"].to_list():
        if row["ITEMID"] in t_med2[t_med2["HADM_ID"]==row["HADM_ID"]]["ITEMID"].to_list():
            return True
    return False

def get_med2(row):
    temp = t_med2[t_med2["HADM_ID"]==row["HADM_ID"]] 
    return temp[temp["ITEMID"]==row["ITEMID"]].iloc[0]

# %%
from sklearn import datasets, linear_model, metrics

def get_normalized_trend(data):
    selected = data[['VALUENUM', 'hours_in']]
    if selected.shape[0]<2:
        return float("NaN")
    reg = linear_model.LinearRegression()
    reg.fit(np.array(data['hours_in']).reshape(-1,1), np.array(data['VALUENUM']).reshape(-1,1))
    return reg.coef_[0][0]

# %%
def get_normalized_trend_np(data):
    selected = data[['VALUENUM', 'hours_in']]
    print(selected)
    if selected.shape[0]<2:
        return float("NaN")
    print(np.array(data['hours_in']), np.array(data['VALUENUM']))
    t = np.polyfit(np.array(data['hours_in']), np.array(data['VALUENUM']), 1,full=True)
    coefficients, residuals, _, _, _ = t
    print(t)
    mse = residuals[0]/(len(selected.index))
    nrmse = np.sqrt(mse)/(selected.max() - selected.min())
    return 1

# %%
window = (1,100, 5)

# %%
def get_vals(r):

    row = r.copy()
    for i in range(window[0], window[1], window[2]):

        if i==1:
            lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

            b_window_start = row["MedTimeFromAdmit"].total_seconds()
            b_window_end = row["MedTimeFromAdmit"].total_seconds() - 1*3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
            lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"before_abs_{i}_{window[2]}"] = {}
                row[f"before_time_{i}_{window[2]}"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"before_abs_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"before_time_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

            lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
            med2_bool = check_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
            a_window_start = row["MedTimeFromAdmit"].total_seconds()
            a_window_end = row["MedTimeFromAdmit"].total_seconds() + 3600
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
            lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
            lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

            if med2_bool:
                med2_val = get_med2(row)
                lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
            
            t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
            
            val_counts_m = t[t["SUBJECT_ID"]>=1]
            if val_counts_m.shape[0]==0:
                row[f"after_abs_{i}_{window[2]}"] = {}
                row[f"after_time_{i}_{window[2]}"] = {}
            else:
                l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
                row[f"after_abs_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
                row[f"after_time_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
    
        lab_vals = t_labs[t_labs["HADM_ID"]==row["HADM_ID"]]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<row["MedTimeFromAdmit"].total_seconds()]

        b_window_start = row["MedTimeFromAdmit"].total_seconds() - (i*3600)
        b_window_end = row["MedTimeFromAdmit"].total_seconds() - (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<b_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>b_window_end]
        lab_vals["hours_from_med"] = (row["STARTTIME"]-lab_vals["CHARTTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"before_abs_{i}_{window[2]}"] = {}
            row[f"before_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"before_abs_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"before_time_{i}_{window[2]}"] = l_m.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()

        lab_vals = labs[labs["HADM_ID"]==row["HADM_ID"]]
        med2_bool = check_med2(row)
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>row["MedTimeFromAdmit"].total_seconds()]
        a_window_start = row["MedTimeFromAdmit"].total_seconds() + (i*3600)
        a_window_end = row["MedTimeFromAdmit"].total_seconds() + (i+window[2])*3600
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()>a_window_start]
        lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<a_window_end]
        lab_vals["hours_from_med"] = (lab_vals["CHARTTIME"]-row["ENDTIME"]).dt.total_seconds()/3600
        lab_vals = lab_vals.sort_values(["ITEMID", "hours_from_med"])

        if med2_bool:
            med2_val = get_med2(row)
            lab_vals = lab_vals[lab_vals["LabTimeFromAdmit"].dt.total_seconds()<med2_val["MedTimeFromAdmit"].total_seconds()]
        
        t = lab_vals.groupby(["ITEMID"]).count()[["SUBJECT_ID"]]
        
        val_counts_m = t[t["SUBJECT_ID"]>=1]
        if val_counts_m.shape[0]==0:
            row[f"after_abs_{i}_{window[2]}"] = {}
            row[f"after_time_{i}_{window[2]}"] = {}
        else:
            l_m = lab_vals[lab_vals.ITEMID.isin(val_counts_m.index)]
            row[f"after_abs_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["VALUENUM"].dropna().to_dict()
            row[f"after_time_{i}_{window[2]}"] = lab_vals.groupby(["ITEMID"])[["VALUENUM", "hours_from_med"]].first()["hours_from_med"].dropna().to_dict()
        
    return row

# %%
# type = "abs"
all_types = set(["abs", "time"])
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
cols_a = [f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
cols = cols_b.copy()
cols.extend(cols_a)

# %%
temp = t_med1.copy()
temp = temp.apply(lambda r : get_vals(r), axis=1)

# %%
temp
# Out:
#         SUBJECT_ID         DOB GENDER                  DOD  EXPIRE_FLAG  \
# 3              249  2075-03-13      F                  NaN            0
# 44             266  2090-12-17      F                  NaN            0
# 65             665  2052-05-20      M  2120-02-04 00:00:00            1
# 89             671  2148-03-27      M                  NaN            0
# 165            711  2100-03-06      M  2185-05-26 00:00:00            1
# ...            ...         ...    ...                  ...          ...
# 322825       44069  2064-04-08      M                  NaN            0
# 322851       44073  2086-03-29      F                  NaN            0
# 322902       44084  2057-07-18      F                  NaN            0
# 322943       44123  2049-11-26      F  2135-01-12 00:00:00            1
# 323005       44128  2098-07-25      M                  NaN            0
#
#         ITEMID  HADM_ID  ICUSTAY_ID           STARTTIME             ENDTIME  \
# 3       223258   149546    269035.0 2155-02-04 00:50:00 2155-02-04 00:51:00
# 44      223258   186251    293876.0 2168-07-10 20:00:00 2168-07-10 20:01:00
# 65      223258   170157    281431.0 2119-05-15 22:00:00 2119-05-15 22:01:00
# 89      223258   126769    246119.0 2195-12-31 06:30:00 2195-12-31 06:31:00
# 165     223258   158767    270525.0 2185-03-22 17:14:00 2185-03-22 21:00:00
# ...        ...      ...         ...                 ...                 ...
# 322825  223258   138192    214441.0 2131-02-15 22:30:00 2131-02-15 22:31:00
# 322851  223258   183835    204605.0 2174-01-01 01:00:00 2174-01-01 01:29:00
# 322902  223258   174828    281506.0 2115-07-25 14:00:00 2115-07-25 15:00:00
# 322943  223258   116395    264065.0 2135-01-06 15:50:00 2135-01-06 15:51:00
# 323005  223258   141304    253669.0 2149-06-12 14:40:00 2149-06-12 14:41:00
#
#         ...  after_abs_86_5 after_time_86_5  before_abs_91_5 before_time_91_5  \
# 3       ...              {}              {}               {}               {}
# 44      ...              {}              {}               {}               {}
# 65      ...              {}              {}               {}               {}
# 89      ...              {}              {}               {}               {}
# 165     ...              {}              {}               {}               {}
# ...     ...             ...             ...              ...              ...
# 322825  ...              {}              {}               {}               {}
# 322851  ...              {}              {}               {}               {}
# 322902  ...              {}              {}               {}               {}
# 322943  ...              {}              {}               {}               {}
# 323005  ...              {}              {}               {}               {}
#
#        after_abs_91_5  after_time_91_5  before_abs_96_5  before_time_96_5  \
# 3                  {}               {}               {}                {}
# 44                 {}               {}               {}                {}
# 65                 {}               {}               {}                {}
# 89                 {}               {}               {}                {}
# 165                {}               {}               {}                {}
# ...               ...              ...              ...               ...
# 322825             {}               {}               {}                {}
# 322851             {}               {}               {}                {}
# 322902             {}               {}               {}                {}
# 322943             {}               {}               {}                {}
# 323005             {}               {}               {}                {}
#
#        after_abs_96_5 after_time_96_5
# 3                  {}              {}
# 44                 {}              {}
# 65                 {}              {}
# 89                 {}              {}
# 165                {}              {}
# ...               ...             ...
# 322825             {}              {}
# 322851             {}              {}
# 322902             {}              {}
# 322943             {}              {}
# 323005             {}              {}
#
# [7948 rows x 144 columns]

# %%
name =  "Insulin-Regular<>pO2"
temp.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_first_val_{name}.csv"))

# %%
import ast
for c in cols:
    temp[c] = temp[c].apply(lambda x : ast.literal_eval(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb Cell 40 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> import ast
#       <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> for c in cols:
# ----> <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb#X55sZmlsZQ%3D%3D?line=2'>3</a>     temp[c] = temp[c].apply(lambda x : ast.literal_eval(x))
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/pandas/core/apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/pandas/core/apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# /Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb Cell 40 in <lambda>(x)
#       <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> import ast
#       <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> for c in cols:
# ----> <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Analysis/plots_and_before_after_stats.ipynb#X55sZmlsZQ%3D%3D?line=2'>3</a>     temp[c] = temp[c].apply(lambda x : ast.literal_eval(x))
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/ast.py:108, in literal_eval(node_or_string)
#     106                 return left - right
#     107     return _convert_signed_num(node)
# --> 108 return _convert(node_or_string)
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/ast.py:107, in literal_eval.<locals>._convert(node)
#     105         else:
#     106             return left - right
# --> 107 return _convert_signed_num(node)
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/ast.py:81, in literal_eval.<locals>._convert_signed_num(node)
#      79     else:
#      80         return - operand
# ---> 81 return _convert_num(node)
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/ast.py:72, in literal_eval.<locals>._convert_num(node)
#      70 def _convert_num(node):
#      71     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 72         _raise_malformed_node(node)
#      73     return node.value
#
# File ~/anaconda3/envs/mimic_data_extraction/lib/python3.10/ast.py:69, in literal_eval.<locals>._raise_malformed_node(node)
#      67 if lno := getattr(node, 'lineno', None):
#      68     msg += f' on line {lno}'
# ---> 69 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: {}

# %%
# [c for c in cols for i in temp[c].to_list() if len(i)>0]

# %%
col_vals = []
for col in cols:
    col_vals.append(
        temp.assign(dict=temp[col].map(lambda d: d.items())).explode("dict", ignore_index=True).assign(
            LAB_ITEMID=lambda df: df.dict.str.get(0),
            temp=lambda df: df.dict.str.get(1)
        ).drop(columns=["dict"]+cols).astype({'temp':'float64', 'LAB_ITEMID':'float64'}).rename(columns={"temp":f"{col}_sp"}).dropna(subset=["LAB_ITEMID"])
    )

# %%
for i in range(1, len(col_vals)):
    col_vals[i] = pd.merge(col_vals[i-1], col_vals[i], how="outer", on=list(t_med1.columns)+["LAB_ITEMID"])

# %%
final = col_vals[-1][list(t_med1.columns)+["LAB_ITEMID"]+[f"{col}_sp" for col in cols]]

# %%
t_final = pd.merge(final.rename(columns={"LABEL":"MED_NAME"}), labitems.rename(columns={"ITEMID":"LAB_ITEMID"}), on="LAB_ITEMID", how="inner").rename(columns={"LABEL":"LAB_NAME"})
final = t_final

# %%
final.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", f"before_after_windows_main_med_lab_trends_first_val_{name}.csv"))

# %%
t_final = final.copy()
plot_data = {}
for b in [f"{c}_sp" for c in cols_b]:
    if b in t_final.columns:
        plot_data[b] = []
        for a in [f"{c}_sp" for c in cols_a]:
            if a in t_final.columns:
                plot_data[b].append(t_final.dropna(subset=[a,b]))
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data_concat = {}
for i in plot_data:
    plot_data_concat[i] = pd.concat(plot_data[i])

# %%
[(k, plot_data_concat[k].shape) for k in plot_data_concat]
# Out:
# [('before_abs_1_5_sp', (72178, 145)),
#  ('before_time_1_5_sp', (72178, 145)),
#  ('before_abs_6_5_sp', (71846, 145)),
#  ('before_time_6_5_sp', (71846, 145)),
#  ('before_abs_11_5_sp', (57226, 145)),
#  ('before_time_11_5_sp', (57226, 145)),
#  ('before_abs_16_5_sp', (47924, 145)),
#  ('before_time_16_5_sp', (47924, 145)),
#  ('before_abs_21_5_sp', (33908, 145)),
#  ('before_time_21_5_sp', (33908, 145)),
#  ('before_abs_26_5_sp', (29962, 145)),
#  ('before_time_26_5_sp', (29962, 145)),
#  ('before_abs_31_5_sp', (30008, 145)),
#  ('before_time_31_5_sp', (30008, 145)),
#  ('before_abs_36_5_sp', (28302, 145)),
#  ('before_time_36_5_sp', (28302, 145)),
#  ('before_abs_41_5_sp', (27352, 145)),
#  ('before_time_41_5_sp', (27352, 145)),
#  ('before_abs_46_5_sp', (18564, 145)),
#  ('before_time_46_5_sp', (18564, 145)),
#  ('before_abs_51_5_sp', (19002, 145)),
#  ('before_time_51_5_sp', (19002, 145)),
#  ('before_abs_56_5_sp', (20894, 145)),
#  ('before_time_56_5_sp', (20894, 145)),
#  ('before_abs_61_5_sp', (20232, 145)),
#  ('before_time_61_5_sp', (20232, 145)),
#  ('before_abs_66_5_sp', (16476, 145)),
#  ('before_time_66_5_sp', (16476, 145)),
#  ('before_abs_71_5_sp', (12504, 145)),
#  ('before_time_71_5_sp', (12504, 145)),
#  ('before_abs_76_5_sp', (13794, 145)),
#  ('before_time_76_5_sp', (13794, 145)),
#  ('before_abs_81_5_sp', (15282, 145)),
#  ('before_time_81_5_sp', (15282, 145)),
#  ('before_abs_86_5_sp', (15108, 145)),
#  ('before_time_86_5_sp', (15108, 145)),
#  ('before_abs_91_5_sp', (11304, 145)),
#  ('before_time_91_5_sp', (11304, 145)),
#  ('before_abs_96_5_sp', (10742, 145)),
#  ('before_time_96_5_sp', (10742, 145))]

# %%
# type = "abs"
a_t = ["abs", "time"]
# other_cols = [f"before_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])]
# other_cols.extend([f"after_{t}_{i}_{window[2]}" for i in range(window[0], window[1], window[2]) for t in all_types.difference([type])])
cols_b_sp = [(f"before_{a_t[0]}_{i}_{window[2]}_sp", f"before_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2]) ]
cols_a_sp = [(f"after_{a_t[0]}_{i}_{window[2]}_sp", f"after_{a_t[1]}_{i}_{window[2]}_sp") for i in range(window[0], window[1], window[2])]
cols_sp = cols_b_sp.copy()
cols_sp.extend(cols_a_sp)

# %%
t_final = final.copy()
plot_data = {}
for b in cols_b_sp:
    if b[0] in t_final.columns:
        plot_data[b[0]] = {}
        for a in cols_a_sp: 
            if a[0] in t_final.columns:
                # print(a, b)
                plot_data[b[0]][a[0]] = t_final.dropna(subset=[a[0], a[1], b[0], b[1]])
                # print(plot_data[b][a][[a, b]])
                # print(plot_data.keys())
        # a_cols = list(set([f"{c}_sp" for c in cols_a]).intersection(list(t_final.columns)))
        # plot_data[b] = t_final[["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME", b]+a_cols]

# %%
plot_data.keys()
# Out:
# dict_keys(['before_abs_1_5_sp', 'before_abs_6_5_sp', 'before_abs_11_5_sp', 'before_abs_16_5_sp', 'before_abs_21_5_sp', 'before_abs_26_5_sp', 'before_abs_31_5_sp', 'before_abs_36_5_sp', 'before_abs_41_5_sp', 'before_abs_46_5_sp', 'before_abs_51_5_sp', 'before_abs_56_5_sp', 'before_abs_61_5_sp', 'before_abs_66_5_sp', 'before_abs_71_5_sp', 'before_abs_76_5_sp', 'before_abs_81_5_sp', 'before_abs_86_5_sp', 'before_abs_91_5_sp', 'before_abs_96_5_sp'])

# %%
# import pickle
# pickle.dump(plot_data, open("plot_bw_aw_med_lab_data.pkl", "wb"))

# %%
cols_d = dict(cols_sp)

# %%
from scipy.stats import pearsonr, spearmanr
# corr, _ = spearmanr(values, time_diff)
p_data = {}
for k in plot_data:
    print("Before Window: ", k)
    for i, (k_a, data) in enumerate(plot_data[k].items()):
        print("After Window: ", k_a)

        t_data = data.set_index([data["MED_NAME"], data["LAB_NAME"]])        
        med_lab_pairs = t_data.index
        
        for med_lab_pair in med_lab_pairs.unique():
            
            if med_lab_pair not in p_data.keys():
                p_data[med_lab_pair] = {}
            if k not in p_data[med_lab_pair].keys():
                p_data[med_lab_pair][k] = []
            
            t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
            t_d['abs'] = t_d[k_a]-t_d[k]
            t_d['percent'] = (t_d['abs']/t_d[k])*100
            t_d['ratio'] = t_d[k_a]/t_d[k]
            
            p_data[med_lab_pair][k].append(t_d)

        # print(med_name_stats)
        # print(data[data["MED_NAME"]==list(med_name_stats.keys())[0]]["SUBJECT_ID"].value_counts().to_dict())
        # print(data[data["MED_NAME"]==list(med_name_stats.keys())[0]]["HADM_ID"].value_counts().to_dict())
        # t_lau = data[data["MED_NAME"]==list(med_name_stats.keys())[0]]
# Out:
# Before Window:  before_abs_1_5_sp
# After Window:  after_abs_1_5_sp
# After Window:  after_abs_6_5_sp
# After Window:  after_abs_11_5_sp
# After Window:  after_abs_16_5_sp
# After Window:  after_abs_21_5_sp
# After Window:  after_abs_26_5_sp
# After Window:  after_abs_31_5_sp
# After Window:  after_abs_36_5_sp
# After Window:  after_abs_41_5_sp
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# After Window:  after_abs_46_5_sp
# After Window:  after_abs_51_5_sp
# After Window:  after_abs_56_5_sp
# After Window:  after_abs_61_5_sp
# After Window:  after_abs_66_5_sp
# After Window:  after_abs_71_5_sp
# After Window:  after_abs_76_5_sp
# After Window:  after_abs_81_5_sp
# After Window:  after_abs_86_5_sp
# After Window:  after_abs_91_5_sp
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# ...
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# After Window:  after_abs_26_5_sp
# After Window:  after_abs_31_5_sp
# After Window:  after_abs_36_5_sp
# After Window:  after_abs_41_5_sp
# After Window:  after_abs_46_5_sp
# After Window:  after_abs_51_5_sp
# After Window:  after_abs_56_5_sp
# After Window:  after_abs_61_5_sp
# After Window:  after_abs_66_5_sp
# After Window:  after_abs_71_5_sp
# After Window:  after_abs_76_5_sp
# After Window:  after_abs_81_5_sp
# After Window:  after_abs_86_5_sp
# After Window:  after_abs_91_5_sp
# After Window:  after_abs_96_5_sp
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/1901453762.py:19: PerformanceWarning: indexing past lexsort depth may impact performance.
#   t_d = t_data.loc[med_lab_pair][['SUBJECT_ID','HADM_ID', k, k_a, cols_d[k_a]]]

# %%
p_data.keys()
# Out:
# dict_keys([('Insulin - Regular', 'Glucose'), ('Packed Red Blood Cells', 'Glucose'), ('Albumin 5%', 'Glucose'), ('Insulin - Regular', 'Hematocrit'), ('Packed Red Blood Cells', 'Hematocrit'), ('Albumin 5%', 'Hematocrit'), ('Insulin - Regular', 'Hemoglobin'), ('Packed Red Blood Cells', 'Hemoglobin'), ('Albumin 5%', 'Hemoglobin'), ('Insulin - Regular', 'Red Blood Cells'), ('Packed Red Blood Cells', 'Red Blood Cells'), ('Albumin 5%', 'Red Blood Cells')])

# %%
# p_data[('Insulin - Regular', 'Glucose')]['before_abs_1_5_sp'][0]
# Out:
#                             SUBJECT_ID  HADM_ID  before_abs_1_5_sp  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose        82649   194291              148.0
#                   Glucose        67735   141202              110.0
#                   Glucose        69711   135668              138.0
#                   Glucose         2667   131592              848.0
#                   Glucose        21630   100808              121.0
# ...                                ...      ...                ...
#                   Glucose        66412   117412              137.0
#                   Glucose        99065   143271             1000.0
#                   Glucose        57215   181872             1000.0
#                   Glucose        12312   153323              100.0
#                   Glucose        29730   130144              150.0
#
#                             after_abs_1_5_sp  after_time_1_5_sp    abs  \
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose              130.0           2.283333  -18.0
#                   Glucose               88.0           1.266667  -22.0
#                   Glucose              128.0           3.000000  -10.0
#                   Glucose              280.0           2.983333 -568.0
#                   Glucose              165.0           3.533333   44.0
# ...                                      ...                ...    ...
#                   Glucose               94.0           3.583333  -43.0
#                   Glucose              100.0           3.366667 -900.0
#                   Glucose              300.0           4.100000 -700.0
#                   Glucose              100.0           2.516667    0.0
#                   Glucose              300.0           3.200000  150.0
#
#                                percent     ratio
# MED_NAME          LAB_NAME
# Insulin - Regular Glucose   -12.162162  0.878378
#                   Glucose   -20.000000  0.800000
#                   Glucose    -7.246377  0.927536
#                   Glucose   -66.981132  0.330189
#                   Glucose    36.363636  1.363636
# ...                                ...       ...
#                   Glucose   -31.386861  0.686131
#                   Glucose   -90.000000  0.100000
#                   Glucose   -70.000000  0.300000
#                   Glucose     0.000000  1.000000
#                   Glucose   100.000000  2.000000
#
# [1296 rows x 8 columns]

# %%
# import pickle
# pickle.dump(p_data, open("plot_med_lab_bw_aw_data.pkl", "wb"))

# %%
# t_dict_p_data = pickle.load(open("plot_med_lab_bw_aw_data.pkl", "rb"))

# %%
def int_s(s):
    if s[0]=="_":
        return int(s[1:])
    else:
        return int(s)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns

def plot_corrs(corrs, after_windows, ax, title='', plot_name='',  after_window_info=None):

    p_corrs = [c[0] for c in corrs]
    s_corrs = [c[1] for c in corrs]
    final_plot_name = f'{plot_name}_{title}'
    after_windows = [int_s(a[-7:-5]) for a in after_windows]

    
    # print(ax, [ k for k in zip(p_corrs, after_windows)])
    # print(ax, [ k for k in zip(s_corrs, after_windows)])
    
    # ax.plot(after_windows, p_corrs)
    # ax.set_title(f'{final_plot_name} Pearsons Corr')
    # ax.set(xlabel='Time in hours', ylabel='Correlation')

    ax[0].plot(after_windows, p_corrs, '-o')
    ax[0].set_title(f'{final_plot_name} Pearsons Corr')
    ax[0].set(xlabel='Time in hours', ylabel='Correlation')
    ax[0].set_xticks(after_windows)
    ax[0].grid()
    # ax[0].grid(axis='x')

    ax[1].plot(after_windows, s_corrs, '-o')
    ax[1].set_title(f'{final_plot_name} Spearmans Corr')
    ax[1].set(xlabel='Time in hours', ylabel='Correlation')
    ax[1].set_xticks(after_windows)
    # ax[1].grid(axis='x')
    ax[1].grid()
    

def plot_func(presc, lab, d, dirname, window=(1,24), title='', unit='mg/dL', labels=None, plot_name='', ax=None):
    
    plot_data = d
    # plot_data = plot_data.rename(columns={0:'Lab values'})

    # plot_data = plot_data[plot_data['timeFromPrescription'] > window[0]]
    # plot_data = plot_data[plot_data['timeFromPrescription'] < window[1]]

    if ax is None:
        sns.regplot(x = "time", 
                y = 'data', 
                data = plot_data, 
                truncate=False)
        plt.title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        plt.xlabel('Time in hours')
        plt.ylabel(title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            plt.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))
        if not os.path.isdir(f"{lab}<>{presc}"):
            os.mkdir(f"{lab}<>{presc}")
        if dirname is None or dirname == "":
            plt.savefig(os.path.join(f"{lab}<>{presc}", plot_name+".png"))
        else:
            if not os.path.isdir(os.path.join(f"{lab}<>{presc}", dirname)):
                os.mkdir(os.path.join(f"{lab}<>{presc}", dirname))
            plt.savefig(os.path.join(f"{lab}<>{presc}_{name}", dirname, plot_name+".png"))
        plt.clf()
    
    else:
        sns.regplot(
                ax=ax,
                x = "time", 
                y = 'data', 
                data = plot_data, 
                truncate=False)
        ax.set_title(lab+'<>'+presc+'- '+ title+ ' \nchange in lab measurment and time taken for change')
        ax.set(xlabel='Time in hours', ylabel=title+ ' change in '+lab+' lab measurment')
        if labels is not None:
            extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
            ax.legend([extra, extra], (f'Pearson Correlation = {round(labels[0], 4)}', f'Spearmans Correlation = {round(labels[1], 4)}'))

def remove_outlier(val, time_diff):
    val = pd.DataFrame(val)
    time_diff = pd.DataFrame(time_diff)
    
    # IQR
    Q1 = np.percentile(val, 25, method = 'midpoint')        
    Q3 = np.percentile(val, 75, method = 'midpoint')
    IQR = Q3 - Q1        
    
    # Upper bound
    upper = np.where(val >= (Q3+1.5*IQR))
    # Lower bound
    lower = np.where(val <= (Q1-1.5*IQR))

    # Filtering
    if len(upper) > 0:
        val.drop(upper[0], inplace = True)
        time_diff.drop(upper[0], inplace = True)
    if len(lower) > 0:
        val.drop(lower[0], inplace = True)
        time_diff.drop(lower[0], inplace = True)
    return val, time_diff

# %%
types = ['abs', 'percent', 'ratio']
for k, v in p_data.items():
    for key in v:
        lab = k[0]
        presc = k[1]
        before_window = int_s(key[-7:-5])

        fig_all, ax_all = plt.subplots(3, figsize=(20, 20))
        fig_all.suptitle(f'{lab}<>{presc} (before window = {str(before_window)})')

        if not os.path.isdir(f"{lab}<>{presc}"):
            os.mkdir(f"{lab}<>{presc}")
        
        dirname=f"bw_{int_s(key[-7:-5])}"
        if not os.path.isdir(os.path.join(f"{lab}<>{presc}", dirname)):
            os.mkdir(os.path.join(f"{lab}<>{presc}", dirname))

        for i, type in enumerate(types):
            plot_name = f"{k[0]}<>{k[1]}_{key}_{type}"
            data_vals = [d[[list(d.columns)[-4], type]].rename(columns={list(d.columns)[-4] : "time"}) for d in v[key]]
            after_names = [list(d.columns)[3] for d in v[key]]
            
            d = pd.concat(data_vals)
            d1, d2 = remove_outlier(d[type], d["time"])
            d = pd.concat([d1, d2], axis=1)

            p_corr, _ = pearsonr(d1[type], d2["time"])
            s_corr, _ = spearmanr(d1[type], d2["time"])

            plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname="", labels=(p_corr, s_corr), title=f"bw({int_s(key[-7:-5])}) {type}", plot_name=f"{plot_name}", ax=ax_all[i])

            fig_corrs, ax_corrs = plt.subplots(2, figsize=(20, 20))
            fig_corrs.suptitle(f'{lab}<>{presc} {type} corrs') 
            corrs = []
            for d in data_vals:
                d1, d2 = remove_outlier(d[type], d["time"])
                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])
                corrs.append((p_corr, s_corr))
            plot_corrs(corrs, after_names, ax_corrs, title=type, plot_name=plot_name)
            fig_corrs.savefig(os.path.join(f"{lab}<>{presc}", dirname, f"{plot_name}_{type}_{name}_corrs.png"))
            fig_corrs.clf()

            for d, a, c in zip(data_vals, after_names, corrs):
                d1, d2 = remove_outlier(d[type], d["time"])
                d = pd.concat([d1, d2], axis=1)

                p_corr, _ = pearsonr(d1[type], d2["time"])
                s_corr, _ = spearmanr(d1[type], d2["time"])

                plot_func(k[0], k[1], d[[type, "time"]].rename(columns={type:"data"}), dirname=dirname, labels=c, title=f"bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])}) {type}", plot_name=f"{plot_name} bw({int_s(key[-7:-5])}) aw({int_s(a[-7:-5])})")
                    
        fig_all.savefig(os.path.join(f"{lab}<>{presc}", dirname, plot_name+name+".png"))
        fig_all.clf()
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_95336/3022017964.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig_all, ax_all = plt.subplots(3, figsize=(20, 20))

# %%
p_data_after = p_data_before.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends copy 4.ipynb Cell 58 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends%20copy%204.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> p_data_after = p_data_before.copy()
#
# NameError: name 'p_data_before' is not defined

# %%
for k in plot_data:
    # print("Before Window: ", k)
    for i, (k_a, data) in enumerate(plot_data[k].items()):
        # print("After Window: ", k_a, data.shape)
        med_name_stats = data.MED_NAME.value_counts().to_dict()
        t_data = data.set_index([data["MED_NAME"], data["LAB_NAME"]])
        med_lab_pairs = t_data.index
        for med_lab_pair in med_lab_pairs:
            if t_data.loc[med_lab_pair].shape[0]>1:
                d = t_data.loc[med_lab_pair]
                print("Before vals", d[a].to_list())
                print("After vals", d[k_a].to_list())
                # p_data_after[med_lab_pair][k][k_a] = spearmanr(d[a].to_list(), d[k_a].to_list())[0]
                break
        break
# Out:
# Before vals [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# After vals [0.625, -0.12559868707505817, 50.76923076923074, -2.5714285714285703, 1.4219881500987488, 13.333333333333321, 25.729618710040732, 7.058823529411764, -14.999999999999998, -10.500000000000009, -2.068965517241381, 9.545454545454554, 13.282442748091597, -10.153720211024195, 3.8461538461538494, -2.3076923076923057, 4.0490797546012285, 4.778761061946904, -1.090909090909092, 1.7307692307692313, 22.857142857142836, -10.64516129032258, -5.850647096742199, -1.855670103092785, 18.563163802780412, -12.475106685633005, -12.585365853658539, -6.7826086956521685, -23.423980222496905, -4.79868469126781, -6.352941176470587, 3.3620689655172407, 9.512195121951201, 6.1224489795918124, -3.9999999999999982, -4.347826086956541, 34.28571428571432, -10.65420560747663, 5.238780207134639, 3.5483870967741966, 6.670566979265259, 26.97986577181207, -6.371681415929206, -17.058823529411768, 6.42857142857143, -1.1320754716981125, -2.8965517241379244, -1.8750000000000016, -9.691861518941455, 14.545454545454522, -6.71052631578948, 0.9418480199785947, -9.090909090909138, -19.999999999999993, 19.06542056074768, 20.38885347418268, 26.222222222222225, 38.507462686567145, 42.67605633802816, -4.52900810979415, 3.367346938775503, 13.376695267091078, -2.4177524681996894, 3.0927835051546237, 8.571428571428566, -4.334600760456266, -9.23076923076915, -0.719483729232466, 17.07317073170734, -11.304347826086902, -3.2390457383786173, -4.292527821939573, 6.3716814159291815, 0.0, 27.761194029850557, -15.949367088607637, -13.235294117647042, -3.0508474576271603, 18.4615384615383, -1.4373677121416117, 7.501150247942335, -27.93103448275856, -6.4285714285713995, 3.099630996309973, -6.666666666666642, 3.5526315789473677, -10.58823529411765, 4.597701149425286, 5.732622911116514, -9.940828402366863, 25.241379310344847, -4.417177914110439, -3.7500000000000004]
# Before vals [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# After vals [-2.3076923076923057, -1.090909090909092, -5.850647096742199, -12.585365853658539, -6.7826086956521685, -23.423980222496905, -4.79868469126781, -6.352941176470587, 3.3620689655172407, 9.512195121951201, 6.1224489795918124, -3.9999999999999982, -4.347826086956541, -10.65420560747663, 26.97986577181207, -1.1320754716981125, -2.8965517241379244, -1.8750000000000016, 14.545454545454522, -6.71052631578948, 26.222222222222225, -4.52900810979415, 3.367346938775503, -4.334600760456266, -9.23076923076915, -4.292527821939573, 6.3716814159291815, -15.949367088607637, -13.235294117647042, 3.099630996309973, -6.760563380281691, 1.3981358189081206, 4.695652173913049, 13.714285714285657, 7.433628318584047, 2.960905789361063, 5.732622911116514, -8.532110091743121]
# Before vals [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# After vals [-3.9999999999999982, -4.347826086956541, -6.71052631578948, 6.3716814159291815, -6.760563380281691, 1.3981358189081206, 7.433628318584047, -3.800904977375564, 20.357142857142858, 3.287671232876707, 5.4028436018957295]
# Before vals [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 8.07692307692314, nan, nan, nan, nan, nan, nan, nan]
# After vals [-9.85074626865671, -3.636363636363636, 6.9048774569279265, 0.0, -9.338059982431894, 37.76785714285727, -3.272727272727272, -21.33333333333333, -2.296405752461053, -16.463477810395535, -26.739130434782645, -5.675675675675604, 5.283018867924529, -12.34662890996143, 21.81818181818174, -10.909090909090922, 9.65853658536584, -1.451612903225804, 0.5985146352119267, 0.5357142857142855, 2.318840579710114]
# Before vals [nan, nan, nan]
# After vals [-9.691861518941455, 1.4814814814814874, -8.532110091743121]
# Before vals [nan, nan, nan, nan]
# After vals [1.6216216216216202, 2.8888888888888893, -9.230769230769152, 2.708333333333327]
# Before vals [nan, nan, nan, nan]
# After vals [-5.338532435306637, -9.230769230769152, -0.923076923076921, 4.489795918367355]
# Before vals [nan, nan, nan]
# After vals [-1.518987341772156, 2.708333333333327, 4.489795918367355]
# Before vals [nan, nan, nan, nan]
# After vals [-5.338532435306637, -1.518987341772156, 2.708333333333327, 7.941176470588288]
# Before vals [nan, nan]
# After vals [4.695652173913049, -1.2947683380179429]
# Before vals [nan, nan, nan]
# After vals [-5.338532435306637, -0.923076923076921, 2.708333333333327]
# Before vals [nan, nan]
# After vals [1.1386861313868628, 1.1764705882352822]
# Before vals [nan, nan]
# After vals [-5.338532435306637, -0.923076923076921]
# Before vals [nan, nan, nan]
# After vals [23.114754098360354, 0.5985146352119267, -10.270270270270299]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:9: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if t_data.loc[med_lab_pair].shape[0]>1:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_32537/2236961565.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   d = t_data.loc[med_lab_pair]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends copy 3.ipynb Cell 56 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends%20copy%203.ipynb#Y244sZmlsZQ%3D%3D?line=8'>9</a> if t_data.loc[med_lab_pair].shape[0]>1:
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends%20copy%203.ipynb#Y244sZmlsZQ%3D%3D?line=9'>10</a>     d = t_data.loc[med_lab_pair]
# ---> <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends%20copy%203.ipynb#Y244sZmlsZQ%3D%3D?line=10'>11</a>     print("Before vals", d[a].to_list())
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends%20copy%203.ipynb#Y244sZmlsZQ%3D%3D?line=11'>12</a>     print("After vals", d[k_a].to_list())
#      <a href='vscode-notebook-cell:/Users/yanpavan/Desktop/Personal/TAU/modified/DrugLab/notebooks/Scratch_test/before_after_stats_trends%20copy%203.ipynb#Y244sZmlsZQ%3D%3D?line=12'>13</a>     # p_data_after[med_lab_pair][k][k_a] = spearmanr(d[a].to_list(), d[k_a].to_list())[0]
#
# AttributeError: 'numpy.float64' object has no attribute 'to_list'

# %%
p_data_after
# Out:
# {('Insulin - Regular',
#   'Glucose'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_21_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_41_5_sp': {'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_46_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_51_5_sp': {'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_56_5_sp': {'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_61_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_66_5_sp': {}, 'before_trends_71_5_sp': {'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_81_5_sp': {'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_86_5_sp': {'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_91_5_sp': {'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Packed Red Blood Cells',
#   'Glucose'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_21_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=0.9999999999999999, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_41_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_46_5_sp': {'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_51_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_56_5_sp': {'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_61_5_sp': {}, 'before_trends_66_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_71_5_sp': {'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_76_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=0.9999999999999999, pvalue=nan)}, 'before_trends_81_5_sp': {'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Albumin 5%',
#   'Glucose'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_16_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_21_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=0.9999999999999999, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_41_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_46_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_46_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_51_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_56_5_sp': {'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_61_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_66_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_76_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_81_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_86_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_91_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_96_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Insulin - Regular',
#   'Hemoglobin'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {}, 'before_trends_21_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {}, 'before_trends_51_5_sp': {'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_56_5_sp': {'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Packed Red Blood Cells',
#   'Hematocrit'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_21_5_sp': {}, 'before_trends_26_5_sp': {'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_41_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_46_5_sp': {}, 'before_trends_51_5_sp': {'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_66_5_sp': {}, 'before_trends_76_5_sp': {'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Insulin - Regular',
#   'Hematocrit'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_21_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_91_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_41_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_46_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_51_5_sp': {}, 'before_trends_56_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_66_5_sp': {}, 'before_trends_71_5_sp': {'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_76_5_sp': {'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=0.9999999999999999, pvalue=nan)}, 'before_trends_81_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_86_5_sp': {'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_96_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Albumin 5%',
#   'Hematocrit'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_6_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_21_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_41_5_sp': {'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_46_5_sp': {'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_51_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_56_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_61_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_66_5_sp': {}, 'before_trends_71_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_76_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_81_5_sp': {'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_86_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_91_5_sp': {'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_96_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_31_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Albumin 5%',
#   'Hemoglobin'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_66_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_21_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_36_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {}, 'before_trends_41_5_sp': {}, 'before_trends_46_5_sp': {'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_51_5_sp': {'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_56_5_sp': {}, 'before_trends_66_5_sp': {'after_trends_21_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_71_5_sp': {'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_96_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Packed Red Blood Cells',
#   'Hemoglobin'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_36_5_sp': {}, 'before_trends_51_5_sp': {'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}, 'before_trends_66_5_sp': {}},
#  ('Insulin - Regular',
#   'Red Blood Cells'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {}, 'before_trends_21_5_sp': {'after_trends_11_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {}, 'before_trends_36_5_sp': {}, 'before_trends_51_5_sp': {}},
#  ('Albumin 5%',
#   'Red Blood Cells'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_21_5_sp': {'after_trends_51_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_81_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_26_5_sp': {'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {}, 'before_trends_41_5_sp': {}, 'before_trends_56_5_sp': {}, 'before_trends_71_5_sp': {'after_trends_76_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_96_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_26_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_41_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}},
#  ('Packed Red Blood Cells',
#   'Red Blood Cells'): {'before_trends_1_5_sp': {'after_trends_1_5_sp': SpearmanrResult(correlation=nan, pvalue=nan),
#    'after_trends_71_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_6_5_sp': {'after_trends_16_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_11_5_sp': {'after_trends_86_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_16_5_sp': {}, 'before_trends_26_5_sp': {'after_trends_61_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_31_5_sp': {'after_trends_56_5_sp': SpearmanrResult(correlation=nan, pvalue=nan)}, 'before_trends_51_5_sp': {'after_trends_96_5_sp': SpearmanrResult(correlation=1.0, pvalue=0.0)}}}

# %%
t_lau_1 = plot_data["before_trends_1_5_sp"]["after_trends_96_5_sp"]
plot_data["before_trends_1_5_sp"]["after_trends_96_5_sp"].set_index([t_lau_1["MED_NAME"], t_lau_1["LAB_NAME"]]).index
# Out:
# MultiIndex([(       'Albumin 5%',    'Glucose'),
#             (       'Albumin 5%',    'Glucose'),
#             (       'Albumin 5%', 'Hematocrit'),
#             ('Insulin - Regular',    'Glucose')],
#            names=['MED_NAME', 'LAB_NAME'])

# %%
temp = med1.copy()
temp = temp.apply(lambda r : get_std_trends(r), axis=1)
cols = ["before_std", "after_std", "before_trends", "after_trends"]
col_vals = []
for col in cols:
    col_vals.append(
        temp.assign(dict=temp[col].map(lambda d: d.items())).explode("dict", ignore_index=True).assign(
            LAB_ITEMID=lambda df: df.dict.str.get(0),
            temp=lambda df: df.dict.str.get(1)
        ).drop(columns=["dict", col]).rename(columns={"temp":f"{col}_sp"})
    )
for i in range(1, len(col_vals)):
    col_vals[i] = pd.merge(col_vals[i-1], col_vals[i], how="inner", on=list(med1.columns)+["LAB_ITEMID"]).dropna(subset=[f"{cols[i-1]}_sp", f"{cols[i]}_sp"])
final = col_vals[-1][list(med1.columns)+cols+["LAB_ITEMID"]+[f"{col}_sp" for col in cols]]

# %%
labitems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_LABITEMS.csv.gz"))
meditems = pd.read_csv(os.path.join(data, "mimiciii/1.4/raw", "D_ITEMS.csv.gz"))

# %%
final
# Out:
#         SUBJECT_ID  ITEMID  HADM_ID  ICUSTAY_ID           STARTTIME  \
# 0            98195  225168   155149    201281.0 2175-10-11 12:13:00
# 1            87196  225168   121964    255986.0 2186-06-16 04:29:00
# 2            27022  225168   196712    201885.0 2185-01-03 22:00:00
# 3            80592  223258   159996    220682.0 2183-07-04 03:00:00
# 4            82649  223258   194291    200686.0 2138-05-29 02:15:00
# ...            ...     ...      ...         ...                 ...
# 282910       73682  220864   101131    227992.0 2111-02-19 18:23:00
# 282911       63773  223258   105518    237129.0 2151-04-03 05:00:00
# 282912       29317  223258   183600    288856.0 2130-06-05 03:30:00
# 282913       99715  223258   157586    271338.0 2150-10-05 10:54:00
# 282914       86314  225168   176365    259979.0 2168-11-24 17:23:00
#
#                    ENDTIME      AMOUNT AMOUNTUOM         RATE  RATEUOM  ...  \
# 0      2175-10-11 13:13:00  375.000000        ml    375.00000  mL/hour  ...
# 1      2186-06-16 04:31:00  375.000000        ml  11250.00000  mL/hour  ...
# 2      2185-01-03 22:21:00  349.999986        ml    999.99996  mL/hour  ...
# 3      2183-07-04 03:01:00    0.000000     units          NaN      NaN  ...
# 4      2138-05-29 02:16:00    4.000000     units          NaN      NaN  ...
# ...                    ...         ...       ...          ...      ...  ...
# 282910 2111-02-19 19:23:00  499.999980        ml    499.99998  mL/hour  ...
# 282911 2151-04-03 05:01:00    2.000000     units          NaN      NaN  ...
# 282912 2130-06-05 03:31:00    2.000000     units          NaN      NaN  ...
# 282913 2150-10-05 10:55:00    2.000000     units          NaN      NaN  ...
# 282914 2168-11-24 18:23:00  350.000010        ml    350.00001  mL/hour  ...
#
#        after_time_86_5_sp  after_abs_91_5_sp  after_time_91_5_sp  \
# 0                     NaN                NaN                 NaN
# 1                     NaN                NaN                 NaN
# 2                     NaN                NaN                 NaN
# 3                     NaN                NaN                 NaN
# 4                     NaN                NaN                 NaN
# ...                   ...                ...                 ...
# 282910                NaN                NaN                 NaN
# 282911                NaN                NaN                 NaN
# 282912                NaN                NaN                 NaN
# 282913                NaN                NaN                 NaN
# 282914          87.383333                NaN                 NaN
#
#         after_abs_96_5_sp after_time_96_5_sp ROW_ID_y              LAB_NAME  \
# 0                     NaN                NaN      132               Glucose
# 1                     NaN                NaN      132               Glucose
# 2                     NaN                NaN      132               Glucose
# 3                     NaN                NaN      132               Glucose
# 4                     NaN                NaN      132               Glucose
# ...                   ...                ...      ...                   ...
# 282910                NaN                NaN       99  Cancer Antigen 27.29
# 282911                NaN                NaN      633                  NRBC
# 282912                NaN                NaN      266         24 hr Calcium
# 282913                NaN                NaN      191         Thyroglobulin
# 282914                NaN                NaN      263     Osmolality, Stool
#
#                    FLUID  CATEGORY_y  LOINC_CODE
# 0                  Blood   Chemistry      2345-7
# 1                  Blood   Chemistry      2345-7
# 2                  Blood   Chemistry      2345-7
# 3                  Blood   Chemistry      2345-7
# 4                  Blood   Chemistry      2345-7
# ...                  ...         ...         ...
# 282910             Blood   Chemistry     17842-6
# 282911  Other Body Fluid  Hematology         NaN
# 282912             Urine   Chemistry      6874-2
# 282913             Blood   Chemistry      3013-0
# 282914             Stool   Chemistry      2693-0
#
# [282915 rows x 145 columns]

# %%
final
# Out:
#          SUBJECT_ID  ITEMID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0             80778  226361   178404    253009.0  2140-05-11 19:45:00
# 1             80778  226361   178404    253009.0  2140-05-11 19:45:00
# 2             80778  226361   178404    253009.0  2140-05-11 19:45:00
# 3             53149  225154   140593    297609.0  2131-03-21 13:15:00
# 4             53149  225154   140593    297609.0  2131-03-21 13:15:00
# ...             ...     ...      ...         ...                  ...
# 2112125       93321  221794   115396    248745.0  2128-09-16 14:06:00
# 2112126       93321  221794   115396    248745.0  2128-09-16 14:06:00
# 2112127       93321  221794   115396    248745.0  2128-09-16 14:06:00
# 2112128       93321  221794   115396    248745.0  2128-09-16 14:06:00
# 2112129       93321  221794   115396    248745.0  2128-09-16 14:06:00
#
#                      ENDTIME       AMOUNT AMOUNTUOM  RATE RATEUOM  ...  \
# 0        2140-05-11 19:46:00  1000.000000        ml   NaN     NaN  ...
# 1        2140-05-11 19:46:00  1000.000000        ml   NaN     NaN  ...
# 2        2140-05-11 19:46:00  1000.000000        ml   NaN     NaN  ...
# 3        2131-03-21 13:16:00     1.000000        mg   NaN     NaN  ...
# 4        2131-03-21 13:16:00     1.000000        mg   NaN     NaN  ...
# ...                      ...          ...       ...   ...     ...  ...
# 2112125  2128-09-16 14:07:00    20.000001        mg   NaN     NaN  ...
# 2112126  2128-09-16 14:07:00    20.000001        mg   NaN     NaN  ...
# 2112127  2128-09-16 14:07:00    20.000001        mg   NaN     NaN  ...
# 2112128  2128-09-16 14:07:00    20.000001        mg   NaN     NaN  ...
# 2112129  2128-09-16 14:07:00    20.000001        mg   NaN     NaN  ...
#
#             hours_in                                         before_std  \
# 0           0.283333  {50813: 0.07071067811865497, 50817: 7.07106781...
# 1           0.283333  {50813: 0.07071067811865497, 50817: 7.07106781...
# 2           0.283333  {50813: 0.07071067811865497, 50817: 7.07106781...
# 3           0.350000  {50813: 0.2828427124746191, 50820: 0.042426406...
# 4           0.350000  {50813: 0.2828427124746191, 50820: 0.042426406...
# ...              ...                                                ...
# 2112125  4215.100000  {50802: 2.3487195482823218, 50804: 3.173551413...
# 2112126  4215.100000  {50802: 2.3487195482823218, 50804: 3.173551413...
# 2112127  4215.100000  {50802: 2.3487195482823218, 50804: 3.173551413...
# 2112128  4215.100000  {50802: 2.3487195482823218, 50804: 3.173551413...
# 2112129  4215.100000  {50802: 2.3487195482823218, 50804: 3.173551413...
#
#                                                  after_std  \
# 0        {50801: 141.4213562373095, 50802: 4.1719785959...
# 1        {50801: 141.4213562373095, 50802: 4.1719785959...
# 2        {50801: 141.4213562373095, 50802: 4.1719785959...
# 3        {50802: 4.956957592256421, 50804: 6.2507142449...
# 4        {50802: 4.956957592256421, 50804: 6.2507142449...
# ...                                                    ...
# 2112125  {50801: 58.80192740605249, 50802: 2.4642904197...
# 2112126  {50801: 58.80192740605249, 50802: 2.4642904197...
# 2112127  {50801: 58.80192740605249, 50802: 2.4642904197...
# 2112128  {50801: 58.80192740605249, 50802: 2.4642904197...
# 2112129  {50801: 58.80192740605249, 50802: 2.4642904197...
#
#                                              before_trends  \
# 0        {50813: -1.5000000000000018, 50817: -150.00000...
# 1        {50813: -1.5000000000000018, 50817: -150.00000...
# 2        {50813: -1.5000000000000018, 50817: -150.00000...
# 3        {50813: -1.846153846153846, 50820: 0.276923076...
# 4        {50813: -1.846153846153846, 50820: 0.276923076...
# ...                                                    ...
# 2112125  {50802: 0.004096123593928977, 50804: 0.0094638...
# 2112126  {50802: 0.004096123593928977, 50804: 0.0094638...
# 2112127  {50802: 0.004096123593928977, 50804: 0.0094638...
# 2112128  {50802: 0.004096123593928977, 50804: 0.0094638...
# 2112129  {50802: 0.004096123593928977, 50804: 0.0094638...
#
#                                               after_trends LAB_ITEMID  \
# 0        {50801: 1.228124040528093, 50802: 0.0165058487...    50813.0
# 1        {50801: 1.228124040528093, 50802: 0.0165058487...    50817.0
# 2        {50801: 1.228124040528093, 50802: 0.0165058487...    50820.0
# 3        {50802: 0.04777410617700493, 50804: 0.06417918...    50813.0
# 4        {50802: 0.04777410617700493, 50804: 0.06417918...    50820.0
# ...                                                    ...        ...
# 2112125  {50801: -0.9338736881370469, 50802: -0.0580465...    51476.0
# 2112126  {50801: -0.9338736881370469, 50802: -0.0580465...    51491.0
# 2112127  {50801: -0.9338736881370469, 50802: -0.0580465...    51493.0
# 2112128  {50801: -0.9338736881370469, 50802: -0.0580465...    51498.0
# 2112129  {50801: -0.9338736881370469, 50802: -0.0580465...    51516.0
#
#         BeforeStd  AfterStd  LabBeforeTrends  LabAfterTrends
# 0        0.070711  1.236878    -1.500000e+00       -0.009054
# 1        7.071068  7.985723    -1.500000e+02       -0.051650
# 2        0.021213  0.111991    -4.500000e-01        0.000686
# 3        0.282843  0.287374    -1.846154e+00       -0.000729
# 4        0.042426  0.066117     2.769231e-01        0.000349
# ...           ...       ...              ...             ...
# 2112125  0.000000  0.000000     0.000000e+00        0.000000
# 2112126  0.535806  0.288675     5.203068e-05        0.000758
# 2112127  1.169045  5.656854     1.142157e-04        0.065431
# 2112128  0.005744  0.002646    -1.248633e-07        0.000017
# 2112129  5.625198  1.527525     3.284367e-04        0.017177
#
# [2112130 rows x 68 columns]

# %%
final.columns
# Out:
# Index(['SUBJECT_ID', 'ITEMID', 'HADM_ID', 'ICUSTAY_ID', 'STARTTIME', 'ENDTIME',
#        'AMOUNT', 'AMOUNTUOM', 'RATE', 'RATEUOM', 'STORETIME', 'CGID',
#        'ORDERID', 'LINKORDERID', 'ORDERCATEGORYNAME',
#        'SECONDARYORDERCATEGORYNAME', 'ORDERCOMPONENTTYPEDESCRIPTION',
#        'ORDERCATEGORYDESCRIPTION', 'PATIENTWEIGHT', 'TOTALAMOUNT',
#        'TOTALAMOUNTUOM', 'ISOPENBAG', 'CONTINUEINNEXTDEPT', 'CANCELREASON',
#        'STATUSDESCRIPTION', 'COMMENTS_EDITEDBY', 'COMMENTS_CANCELEDBY',
#        'COMMENTS_DATE', 'ORIGINALAMOUNT', 'ORIGINALRATE', 'ROW_ID_y',
#        'SUBJECT_ID_y', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE',
#        'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE',
#        'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME',
#        'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA', 'ROW_ID',
#        'LABEL', 'ABBREVIATION', 'DBSOURCE', 'LINKSTO', 'CATEGORY', 'UNITNAME',
#        'PARAM_TYPE', 'CONCEPTID', 'MedTimeFromAdmit', 'hours_in', 'before_std',
#        'after_std', 'before_trends', 'after_trends', 'LAB_ITEMID', 'BeforeStd',
#        'AfterStd', 'LabBeforeTrends', 'LabAfterTrends'],
#       dtype='object')

# %%
t_final = pd.merge(final.rename(columns={"LABEL":"MED_NAME"}), labitems.rename(columns={"ITEMID":"LAB_ITEMID"}), on="LAB_ITEMID", how="inner").rename(columns={"LABEL":"LAB_NAME"})
final = t_final

# %%
t_final[["MED_NAME", "LAB_NAME", "AMOUNT", "AMOUNTUOM", "LabBeforeTrends", "LabAfterTrends"]]
# Out:
#                          MED_NAME                    LAB_NAME   AMOUNT  \
# 0            Pre-Admission Intake                     Lactate  1000.00
# 1                Morphine Sulfate                     Lactate     1.00
# 2                      Vancomycin                     Lactate     1.00
# 3         Pantoprazole (Protonix)                     Lactate     1.00
# 4                     Vasopressin                     Lactate     2.44
# ...                           ...                         ...      ...
# 2112125         Magnesium Sulfate          Cholesterol, Total     2.00
# 2112126   Pantoprazole (Protonix)          Cholesterol, Total     1.00
# 2112127                Micafungin  Reticulocyte Count, Manual     1.00
# 2112128  Hydromorphone (Dilaudid)  Reticulocyte Count, Manual     1.00
# 2112129         Magnesium Sulfate  Reticulocyte Count, Manual     2.00
#
#         AMOUNTUOM  LabBeforeTrends  LabAfterTrends
# 0              ml        -1.500000       -0.009054
# 1              mg        -1.846154       -0.000729
# 2            dose         0.000000        0.000000
# 3            dose         0.000000        0.000000
# 4           units        -0.857143       -0.020226
# ...           ...              ...             ...
# 2112125     grams        -0.127696        0.243446
# 2112126      dose        -0.127696        0.243446
# 2112127      dose        -0.005071        0.092970
# 2112128        mg        -0.008456        0.061798
# 2112129     grams        -0.008456        0.061798
#
# [2112130 rows x 6 columns]

# %%
final.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_med_all_stats_with_trends_new_17112022.csv"))

# %%
final = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_med_all_stats_with_trends_new_17112022.csv"))
# Out:
# /var/folders/xb/6svjl9sj43z6gfhlcp2nc5540000gr/T/ipykernel_54265/774423638.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   final = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_med_all_stats_with_trends_new_17112022.csv"))

# %%
final = final.rename(columns={"before_trends_sp":"LabBeforeTrends", "before_std_sp":"BeforeStd", "after_trends_sp":"LabAfterTrends", "after_std_sp":"AfterStd"}).drop(columns=["Unnamed: 0"])

# %%
final
# Out:
#          SUBJECT_ID  ITEMID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0             80778  226361   178404    253009.0  2140-05-11 19:45:00
# 1             53149  225154   140593    297609.0  2131-03-21 13:15:00
# 2             55934  225798   169449    237762.0  2135-05-23 22:00:00
# 3             55934  225910   169449    237762.0  2135-05-23 22:00:00
# 4             50501  222315   146105    256101.0  2183-11-20 14:27:00
# ...             ...     ...      ...         ...                  ...
# 2112125       51955  222011   181913    251588.0  2109-08-16 03:33:00
# 2112126       51955  225910   181913    251588.0  2109-08-17 08:00:00
# 2112127       23450  225885   122507    294197.0  2167-04-22 17:55:00
# 2112128       23450  221833   122507    294197.0  2167-04-25 06:30:00
# 2112129       23450  222011   122507    294197.0  2167-04-25 07:01:00
#
#                      ENDTIME   AMOUNT AMOUNTUOM  RATE     RATEUOM  ...  \
# 0        2140-05-11 19:46:00  1000.00        ml   NaN         NaN  ...
# 1        2131-03-21 13:16:00     1.00        mg   NaN         NaN  ...
# 2        2135-05-23 22:01:00     1.00      dose   NaN         NaN  ...
# 3        2135-05-23 22:01:00     1.00      dose   NaN         NaN  ...
# 4        2183-11-20 15:28:00     2.44     units   2.4  units/hour  ...
# ...                      ...      ...       ...   ...         ...  ...
# 2112125  2109-08-16 04:33:00     2.00     grams   NaN         NaN  ...
# 2112126  2109-08-17 08:01:00     1.00      dose   NaN         NaN  ...
# 2112127  2167-04-22 17:56:00     1.00      dose   NaN         NaN  ...
# 2112128  2167-04-25 06:31:00     1.00        mg   NaN         NaN  ...
# 2112129  2167-04-25 08:01:00     2.00     grams   NaN         NaN  ...
#
#         LAB_ITEMID  BeforeStd   AfterStd  LabBeforeTrends LabAfterTrends  \
# 0          50813.0   0.070711   1.236878        -1.500000      -0.009054
# 1          50813.0   0.282843   0.287374        -1.846154      -0.000729
# 2          50813.0   0.000000   0.000000         0.000000       0.000000
# 3          50813.0   0.000000   0.000000         0.000000       0.000000
# 4          50813.0   0.141421   0.303315        -0.857143      -0.020226
# ...            ...        ...        ...              ...            ...
# 2112125    50907.0  34.602023  27.577164        -0.127696       0.243446
# 2112126    50907.0  34.602023  27.577164        -0.127696       0.243446
# 2112127    51284.0   1.972097   4.021608        -0.005071       0.092970
# 2112128    51284.0   2.164948   1.555635        -0.008456       0.061798
# 2112129    51284.0   2.164948   1.555635        -0.008456       0.061798
#
#         ROW_ID_y                    LAB_NAME  FLUID  CATEGORY_y  LOINC_CODE
# 0             14                     Lactate  Blood   Blood Gas     32693-4
# 1             14                     Lactate  Blood   Blood Gas     32693-4
# 2             14                     Lactate  Blood   Blood Gas     32693-4
# 3             14                     Lactate  Blood   Blood Gas     32693-4
# 4             14                     Lactate  Blood   Blood Gas     32693-4
# ...          ...                         ...    ...         ...         ...
# 2112125      108          Cholesterol, Total  Blood   Chemistry      2093-3
# 2112126      108          Cholesterol, Total  Blood   Chemistry      2093-3
# 2112127      484  Reticulocyte Count, Manual  Blood  Hematology     31112-6
# 2112128      484  Reticulocyte Count, Manual  Blood  Hematology     31112-6
# 2112129      484  Reticulocyte Count, Manual  Blood  Hematology     31112-6
#
# [2112130 rows x 73 columns]

# %% [markdown]
# ### Pvals - Hard Threshold

# %%
from scipy import stats
med_lab_all = final.copy()
pvals = []
ttest = []
counts = med_lab_all.groupby(["ITEMID", "MED_NAME", "LAB_ITEMID", "LAB_NAME"]).count()["SUBJECT_ID"]
res_out = pd.DataFrame(counts)
res_out = res_out[res_out["SUBJECT_ID"]>100]

# %%
res_out
# Out:
#                                                          SUBJECT_ID
# ITEMID MED_NAME         LAB_ITEMID LAB_NAME
# 220862 Albumin 25%      50802.0    Base Excess                  321
#                         50804.0    Calculated Total CO2         321
#                         50808.0    Free Calcium                 241
#                         50809.0    Glucose                      141
#                         50813.0    Lactate                      215
# ...                                                             ...
# 228315 Acetaminophen-IV 51274.0    PT                           143
#                         51275.0    PTT                          133
#                         51277.0    RDW                          266
#                         51279.0    Red Blood Cells              266
#                         51301.0    White Blood Cells            266
#
# [3387 rows x 1 columns]

# %%
for i in res_out.index:
    med = i[0]
    lab = i[2]
    k_med = med_lab_all[med_lab_all["ITEMID"]==med]
    k_med = k_med[k_med["LAB_ITEMID"]==lab]
    pvals.append(stats.mannwhitneyu(k_med["LabBeforeTrends"], k_med["LabAfterTrends"])[1])
    ttest.append(stats.ttest_ind(k_med["LabBeforeTrends"], k_med["LabAfterTrends"])[1])
res_out["MannwhitneyuTest"] = pvals
res_out["TTest"] = ttest

# %%
res_out
# Out:
#                                                          SUBJECT_ID  \
# ITEMID MED_NAME         LAB_ITEMID LAB_NAME
# 220862 Albumin 25%      50802.0    Base Excess                  321
#                         50804.0    Calculated Total CO2         321
#                         50808.0    Free Calcium                 241
#                         50809.0    Glucose                      141
#                         50813.0    Lactate                      215
# ...                                                             ...
# 228315 Acetaminophen-IV 51274.0    PT                           143
#                         51275.0    PTT                          133
#                         51277.0    RDW                          266
#                         51279.0    Red Blood Cells              266
#                         51301.0    White Blood Cells            266
#
#                                                          MannwhitneyuTest  \
# ITEMID MED_NAME         LAB_ITEMID LAB_NAME
# 220862 Albumin 25%      50802.0    Base Excess               9.680876e-01
#                         50804.0    Calculated Total CO2      7.473241e-01
#                         50808.0    Free Calcium              3.523526e-01
#                         50809.0    Glucose                   6.658388e-03
#                         50813.0    Lactate                   7.650953e-01
# ...                                                                   ...
# 228315 Acetaminophen-IV 51274.0    PT                        4.638343e-02
#                         51275.0    PTT                       1.220654e-01
#                         51277.0    RDW                       1.913561e-07
#                         51279.0    Red Blood Cells           1.375767e-05
#                         51301.0    White Blood Cells         4.097588e-04
#
#                                                             TTest
# ITEMID MED_NAME         LAB_ITEMID LAB_NAME
# 220862 Albumin 25%      50802.0    Base Excess           0.929166
#                         50804.0    Calculated Total CO2  0.567632
#                         50808.0    Free Calcium          0.316666
#                         50809.0    Glucose               0.008995
#                         50813.0    Lactate               0.658837
# ...                                                           ...
# 228315 Acetaminophen-IV 51274.0    PT                    0.049823
#                         51275.0    PTT                   0.126494
#                         51277.0    RDW                   0.011965
#                         51279.0    Red Blood Cells       0.007392
#                         51301.0    White Blood Cells     0.067430
#
# [3387 rows x 3 columns]

# %%
res_out.to_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_med_pvals_with_trends_new_17112022.csv"))

# %%
res_out[res_out["MannwhitneyuTest"]<=0.05]
# Out:
#                                                            SUBJECT_ID  \
# ITEMID MED_NAME         LAB_ITEMID LAB_NAME
# 220862 Albumin 25%      50809.0    Glucose                        141
#                         50818.0    pCO2                           321
#                         50820.0    pH                             341
#                         50821.0    pO2                            321
#                         50822.0    Potassium, Whole Blood         127
# ...                                                               ...
# 228315 Acetaminophen-IV 51265.0    Platelet Count                 270
#                         51274.0    PT                             143
#                         51277.0    RDW                            266
#                         51279.0    Red Blood Cells                266
#                         51301.0    White Blood Cells              266
#
#                                                            MannwhitneyuTest  \
# ITEMID MED_NAME         LAB_ITEMID LAB_NAME
# 220862 Albumin 25%      50809.0    Glucose                     6.658388e-03
#                         50818.0    pCO2                        5.024984e-03
#                         50820.0    pH                          2.002651e-02
#                         50821.0    pO2                         1.430436e-11
#                         50822.0    Potassium, Whole Blood      7.512914e-04
# ...                                                                     ...
# 228315 Acetaminophen-IV 51265.0    Platelet Count              1.301189e-21
#                         51274.0    PT                          4.638343e-02
#                         51277.0    RDW                         1.913561e-07
#                         51279.0    Red Blood Cells             1.375767e-05
#                         51301.0    White Blood Cells           4.097588e-04
#
#                                                               TTest
# ITEMID MED_NAME         LAB_ITEMID LAB_NAME
# 220862 Albumin 25%      50809.0    Glucose                 0.008995
#                         50818.0    pCO2                    0.815079
#                         50820.0    pH                      0.197519
#                         50821.0    pO2                     0.000464
#                         50822.0    Potassium, Whole Blood  0.001485
# ...                                                             ...
# 228315 Acetaminophen-IV 51265.0    Platelet Count          0.000005
#                         51274.0    PT                      0.049823
#                         51277.0    RDW                     0.011965
#                         51279.0    Red Blood Cells         0.007392
#                         51301.0    White Blood Cells       0.067430
#
# [2112 rows x 3 columns]

# %% [markdown]
# ### pvals - Bonferroni Analysis

# %%
res_out = pd.read_csv(os.path.join(data, "mimiciii/1.4/preprocessed", "lab_med_pvals_with_trends_new_17112022.csv"))

# %%
res_out.shape
# Out:
# (3387, 7)

# %%
from statsmodels.stats.multitest import multipletests

bonferroni_analysis = multipletests(res_out["MannwhitneyuTest"], alpha=0.01, method='bonferroni')
reject, pvals_corrected, _, alphacBonf = bonferroni_analysis

# %%
res_analysis = pd.Series(pvals_corrected)
significant = res_analysis[reject]

# %%
significant
# Out:
# 8       4.844888e-08
# 11      2.222263e-03
# 20      6.445459e-04
# 25      1.163175e-10
# 26      2.013294e-05
#             ...
# 3367    1.259100e-05
# 3375    1.338473e-04
# 3379    1.233055e-04
# 3381    4.407126e-18
# 3384    6.481230e-04
# Length: 997, dtype: float64

# %%
res_out["BonferroniPvals"] = res_analysis

# %%
res_out
# Out:
#       ITEMID          MED_NAME  LAB_ITEMID              LAB_NAME  SUBJECT_ID  \
# 0     220862       Albumin 25%     50802.0           Base Excess         321
# 1     220862       Albumin 25%     50804.0  Calculated Total CO2         321
# 2     220862       Albumin 25%     50808.0          Free Calcium         241
# 3     220862       Albumin 25%     50809.0               Glucose         141
# 4     220862       Albumin 25%     50813.0               Lactate         215
# ...      ...               ...         ...                   ...         ...
# 3382  228315  Acetaminophen-IV     51274.0                    PT         143
# 3383  228315  Acetaminophen-IV     51275.0                   PTT         133
# 3384  228315  Acetaminophen-IV     51277.0                   RDW         266
# 3385  228315  Acetaminophen-IV     51279.0       Red Blood Cells         266
# 3386  228315  Acetaminophen-IV     51301.0     White Blood Cells         266
#
#       MannwhitneyuTest     TTest  BonferroniPvals
# 0         9.680876e-01  0.929166         1.000000
# 1         7.473241e-01  0.567632         1.000000
# 2         3.523526e-01  0.316666         1.000000
# 3         6.658388e-03  0.008995         1.000000
# 4         7.650953e-01  0.658837         1.000000
# ...                ...       ...              ...
# 3382      4.638343e-02  0.049823         1.000000
# 3383      1.220654e-01  0.126494         1.000000
# 3384      1.913561e-07  0.011965         0.000648
# 3385      1.375767e-05  0.007392         0.046597
# 3386      4.097588e-04  0.067430         1.000000
#
# [3387 rows x 8 columns]

# %%
significant_df = res_out[reject]

# %%
significant_df
# Out:
#       ITEMID          MED_NAME  LAB_ITEMID              LAB_NAME  SUBJECT_ID  \
# 8     220862       Albumin 25%     50821.0                   pO2         321
# 11    220862       Albumin 25%     50863.0  Alkaline Phosphatase         135
# 20    220862       Albumin 25%     50960.0             Magnesium         394
# 25    220862       Albumin 25%     51221.0            Hematocrit         436
# 26    220862       Albumin 25%     51222.0            Hemoglobin         397
# ...      ...               ...         ...                   ...         ...
# 3367  228315  Acetaminophen-IV     50902.0              Chloride         293
# 3375  228315  Acetaminophen-IV     51221.0            Hematocrit         311
# 3379  228315  Acetaminophen-IV     51249.0                  MCHC         266
# 3381  228315  Acetaminophen-IV     51265.0        Platelet Count         270
# 3384  228315  Acetaminophen-IV     51277.0                   RDW         266
#
#       MannwhitneyuTest     TTest  BonferroniPvals
# 8         1.430436e-11  0.000464     4.844888e-08
# 11        6.561155e-07  0.000736     2.222263e-03
# 20        1.903000e-07  0.000806     6.445459e-04
# 25        3.434234e-14  0.000060     1.163175e-10
# 26        5.944181e-09  0.399784     2.013294e-05
# ...                ...       ...              ...
# 3367      3.717449e-09  0.037886     1.259100e-05
# 3375      3.951796e-08  0.461546     1.338473e-04
# 3379      3.640551e-08  0.033366     1.233055e-04
# 3381      1.301189e-21  0.000005     4.407126e-18
# 3384      1.913561e-07  0.011965     6.481230e-04
#
# [997 rows x 8 columns]

# %% [markdown]
# ### pvals - FDR Analysis

# %%
fdr1_analysis = multipletests(res_out["MannwhitneyuTest"], alpha=0.01, method='fdr_bh')
reject1, pvals_corrected1, _, alphacBonf = fdr1_analysis

res_out['FDR Benjamini Corrected'] = pd.Series(pvals_corrected1)

# %%
print(pd.Series(pvals_corrected1).describe())
# Out:
# count     3.387000e+03
# mean      1.843177e-01
# std       2.834705e-01
# min      2.932510e-217
# 25%       4.512737e-07
# 50%       1.004700e-02
# 75%       2.937955e-01
# max       1.000000e+00
# dtype: float64

# %%
res_out
# Out:
#       ITEMID          MED_NAME  LAB_ITEMID              LAB_NAME  SUBJECT_ID  \
# 0     220862       Albumin 25%     50802.0           Base Excess         321
# 1     220862       Albumin 25%     50804.0  Calculated Total CO2         321
# 2     220862       Albumin 25%     50808.0          Free Calcium         241
# 3     220862       Albumin 25%     50809.0               Glucose         141
# 4     220862       Albumin 25%     50813.0               Lactate         215
# ...      ...               ...         ...                   ...         ...
# 3382  228315  Acetaminophen-IV     51274.0                    PT         143
# 3383  228315  Acetaminophen-IV     51275.0                   PTT         133
# 3384  228315  Acetaminophen-IV     51277.0                   RDW         266
# 3385  228315  Acetaminophen-IV     51279.0       Red Blood Cells         266
# 3386  228315  Acetaminophen-IV     51301.0     White Blood Cells         266
#
#       MannwhitneyuTest     TTest  BonferroniPvals  FDR Benjamini Corrected
# 0         9.680876e-01  0.929166         1.000000             9.744169e-01
# 1         7.473241e-01  0.567632         1.000000             7.994905e-01
# 2         3.523526e-01  0.316666         1.000000             4.366301e-01
# 3         6.658388e-03  0.008995         1.000000             1.295345e-02
# 4         7.650953e-01  0.658837         1.000000             8.148986e-01
# ...                ...       ...              ...                      ...
# 3382      4.638343e-02  0.049823         1.000000             7.495914e-02
# 3383      1.220654e-01  0.126494         1.000000             1.767438e-01
# 3384      1.913561e-07  0.011965         0.000648             7.441136e-07
# 3385      1.375767e-05  0.007392         0.046597             4.190398e-05
# 3386      4.097588e-04  0.067430         1.000000             1.015255e-03
#
# [3387 rows x 9 columns]

# %%
significant_fdr = res_out[reject1]

# %%
significant_fdr
# Out:
#       ITEMID          MED_NAME  LAB_ITEMID                LAB_NAME  \
# 8     220862       Albumin 25%     50821.0                     pO2
# 9     220862       Albumin 25%     50822.0  Potassium, Whole Blood
# 11    220862       Albumin 25%     50863.0    Alkaline Phosphatase
# 14    220862       Albumin 25%     50882.0             Bicarbonate
# 18    220862       Albumin 25%     50912.0              Creatinine
# ...      ...               ...         ...                     ...
# 3380  228315  Acetaminophen-IV     51250.0                     MCV
# 3381  228315  Acetaminophen-IV     51265.0          Platelet Count
# 3384  228315  Acetaminophen-IV     51277.0                     RDW
# 3385  228315  Acetaminophen-IV     51279.0         Red Blood Cells
# 3386  228315  Acetaminophen-IV     51301.0       White Blood Cells
#
#       SUBJECT_ID  MannwhitneyuTest     TTest  BonferroniPvals  \
# 8            321      1.430436e-11  0.000464     4.844888e-08
# 9            127      7.512914e-04  0.001485     1.000000e+00
# 11           135      6.561155e-07  0.000736     2.222263e-03
# 14           414      2.812917e-03  0.571500     1.000000e+00
# 18           422      7.636621e-05  0.118037     2.586524e-01
# ...          ...               ...       ...              ...
# 3380         266      1.852225e-03  0.031129     1.000000e+00
# 3381         270      1.301189e-21  0.000005     4.407126e-18
# 3384         266      1.913561e-07  0.011965     6.481230e-04
# 3385         266      1.375767e-05  0.007392     4.659723e-02
# 3386         266      4.097588e-04  0.067430     1.000000e+00
#
#       FDR Benjamini Corrected
# 8                8.367682e-11
# 9                1.764649e-03
# 11               2.423406e-06
# 14               5.954594e-03
# 18               2.102865e-04
# ...                       ...
# 3380             4.029214e-03
# 3381             1.573974e-20
# 3384             7.441136e-07
# 3385             4.190398e-05
# 3386             1.015255e-03
#
# [1691 rows x 9 columns]

# %% [markdown]
# ### Final Intersection

# %%
significant_intersection = pd.merge(significant_df, significant_fdr, how="inner")

# %%
significant_intersection
# Out:
#      ITEMID          MED_NAME  LAB_ITEMID              LAB_NAME  SUBJECT_ID  \
# 0    220862       Albumin 25%     50821.0                   pO2         321
# 1    220862       Albumin 25%     50863.0  Alkaline Phosphatase         135
# 2    220862       Albumin 25%     50960.0             Magnesium         394
# 3    220862       Albumin 25%     51221.0            Hematocrit         436
# 4    220862       Albumin 25%     51222.0            Hemoglobin         397
# ..      ...               ...         ...                   ...         ...
# 992  228315  Acetaminophen-IV     50902.0              Chloride         293
# 993  228315  Acetaminophen-IV     51221.0            Hematocrit         311
# 994  228315  Acetaminophen-IV     51249.0                  MCHC         266
# 995  228315  Acetaminophen-IV     51265.0        Platelet Count         270
# 996  228315  Acetaminophen-IV     51277.0                   RDW         266
#
#      MannwhitneyuTest     TTest  BonferroniPvals  FDR Benjamini Corrected
# 0        1.430436e-11  0.000464     4.844888e-08             8.367682e-11
# 1        6.561155e-07  0.000736     2.222263e-03             2.423406e-06
# 2        1.903000e-07  0.000806     6.445459e-04             7.408574e-07
# 3        3.434234e-14  0.000060     1.163175e-10             2.480117e-13
# 4        5.944181e-09  0.399784     2.013294e-05             2.702408e-08
# ..                ...       ...              ...                      ...
# 992      3.717449e-09  0.037886     1.259100e-05             1.727161e-08
# 993      3.951796e-08  0.461546     1.338473e-04             1.636276e-07
# 994      3.640551e-08  0.033366     1.233055e-04             1.524171e-07
# 995      1.301189e-21  0.000005     4.407126e-18             1.573974e-20
# 996      1.913561e-07  0.011965     6.481230e-04             7.441136e-07
#
# [997 rows x 9 columns]

# %%
significant_intersection.sort_values("FDR Benjamini Corrected").head(10)
# Out:
#      ITEMID                   MED_NAME  LAB_ITEMID        LAB_NAME  \
# 278  223260         Insulin - Glargine     51265.0  Platelet Count
# 968  227523  Magnesium Sulfate (Bolus)     51265.0  Platelet Count
# 750  226364      OR Crystalloid Intake     50902.0        Chloride
# 216  222011          Magnesium Sulfate     51265.0  Platelet Count
# 869  226372       OR Cell Saver Intake     50902.0        Chloride
# 153  221794         Furosemide (Lasix)     51265.0  Platelet Count
# 733  226364      OR Crystalloid Intake     50802.0     Base Excess
# 857  226372       OR Cell Saver Intake     50802.0     Base Excess
# 498  225834                     K Phos     51265.0  Platelet Count
# 740  226364      OR Crystalloid Intake     50813.0         Lactate
#
#      SUBJECT_ID  MannwhitneyuTest         TTest  BonferroniPvals  \
# 278        1693     8.658134e-221  4.238960e-01    2.932510e-217
# 968        3249     9.439029e-203  6.311388e-11    3.196999e-199
# 750        2350     5.601557e-202  1.750183e-57    1.897247e-198
# 216        3710     3.068450e-196  4.468144e-11    1.039284e-192
# 869         832     4.919158e-180  2.928498e-88    1.666119e-176
# 153        2148     2.180784e-172  1.421506e-04    7.386316e-169
# 733        2813     1.423702e-161  1.130402e-37    4.822078e-158
# 857        1526     5.351648e-158  1.225772e-79    1.812603e-154
# 498        1437     3.086406e-145  1.391460e-02    1.045366e-141
# 740        1385     2.926445e-143  3.578537e-41    9.911869e-140
#
#      FDR Benjamini Corrected
# 278            2.932510e-217
# 968            1.598500e-199
# 750            6.324157e-199
# 216            2.598210e-193
# 869            3.332238e-177
# 153            1.231053e-169
# 733            6.888684e-159
# 857            2.265754e-155
# 498            1.161518e-142
# 740            9.911869e-141

# %%
significant_intersection[significant_intersection["LAB_NAME"]=="Glucose"]
# Out:
#      ITEMID                   MED_NAME  LAB_ITEMID LAB_NAME  SUBJECT_ID  \
# 35   220949                Dextrose 5%     50809.0  Glucose         250
# 48   220952               Dextrose 50%     50931.0  Glucose         672
# 125  221749              Phenylephrine     50809.0  Glucose         338
# 253  223258          Insulin - Regular     50931.0  Glucose         971
# 263  223260         Insulin - Glargine     50809.0  Glucose         296
# 387  225798                 Vancomycin     50809.0  Glucose         708
# 737  226364      OR Crystalloid Intake     50809.0  Glucose        1837
# 752  226364      OR Crystalloid Intake     50931.0  Glucose        2092
# 776  226365          OR Colloid Intake     50931.0  Glucose         390
# 785  226367              OR FFP Intake     50809.0  Glucose         433
# 794  226367              OR FFP Intake     50931.0  Glucose         401
# 809  226368       OR Packed RBC Intake     50809.0  Glucose         785
# 820  226368       OR Packed RBC Intake     50931.0  Glucose         825
# 835  226369         OR Platelet Intake     50809.0  Glucose         386
# 846  226369         OR Platelet Intake     50931.0  Glucose         309
# 853  226371  OR Cryoprecipitate Intake     50809.0  Glucose         122
# 860  226372       OR Cell Saver Intake     50809.0  Glucose        1308
#
#      MannwhitneyuTest         TTest  BonferroniPvals  FDR Benjamini Corrected
# 35       1.289998e-07  6.360346e-04     4.369224e-04             5.104234e-07
# 48       7.162140e-14  8.410066e-06     2.425817e-10             5.032815e-13
# 125      5.180639e-08  4.221031e-03     1.754682e-04             2.134650e-07
# 253      1.661421e-06  1.234349e-01     5.627232e-03             5.843440e-06
# 263      3.469373e-08  3.923817e-03     1.175077e-04             1.465183e-07
# 387      1.191511e-09  9.600918e-06     4.035646e-06             5.756985e-09
# 737      8.294230e-76  4.896013e-20     2.809256e-72             7.203220e-74
# 752      7.929615e-10  4.285125e-02     2.685761e-06             3.886774e-09
# 776      3.979591e-07  5.383804e-01     1.347888e-03             1.495991e-06
# 785      9.704580e-21  1.430333e-04     3.286941e-17             1.110110e-19
# 794      3.367801e-14  2.771008e-03     1.140674e-10             2.441661e-13
# 809      4.608105e-26  1.122198e-05     1.560765e-22             7.062285e-25
# 820      4.725586e-14  1.451599e-03     1.600556e-10             3.376701e-13
# 835      4.630785e-22  5.254449e-05     1.568447e-18             5.703443e-21
# 846      2.930057e-09  2.745670e-02     9.924103e-06             1.372628e-08
# 853      1.971696e-08  1.942646e-01     6.678136e-05             8.572703e-08
# 860      1.819265e-80  1.066406e-32     6.161850e-77             1.812309e-78

# %%
significant_intersection.to_csv(os.path.join(res, "significant_lab_med_all_trends_med_effect_new.csv"))

# %%
med_effect_significant = pd.read_csv(os.path.join(res, "significant_lab_med_all_med_effect.csv")).drop(columns=["Unnamed: 0"])

# %%
med_effect_significant
# Out:
#       ITEMID                 MED_NAME  LAB_ITEMID         LAB_NAME  \
# 0     220862              Albumin 25%     50821.0              pO2
# 1     220862              Albumin 25%     50960.0        Magnesium
# 2     220862              Albumin 25%     51221.0       Hematocrit
# 3     220862              Albumin 25%     51222.0       Hemoglobin
# 4     220862              Albumin 25%     51265.0   Platelet Count
# ...      ...                      ...         ...              ...
# 1202  226880  Nutren Pulmonary (Full)     51221.0       Hematocrit
# 1203  226880  Nutren Pulmonary (Full)     51222.0       Hemoglobin
# 1204  226880  Nutren Pulmonary (Full)     51279.0  Red Blood Cells
# 1205  227975  NovaSource Renal (Full)     51221.0       Hematocrit
# 1206  227695    Fibersource HN (Full)     50868.0        Anion Gap
#
#       SUBJECT_ID  MannwhitneyuTest         TTest  BonferroniPvals  \
# 0            471      5.395021e-17  8.188215e-37     3.125335e-13
# 1            607      9.078456e-25  7.284733e-18     5.259150e-21
# 2            627      2.887183e-28  1.249454e-32     1.672545e-24
# 3            597      6.343373e-21  4.042760e-25     3.674716e-17
# 4            600      1.478657e-08  1.920522e-04     8.565858e-05
# ...          ...               ...           ...              ...
# 1202         180      5.801484e-08  1.904376e-07     3.360800e-04
# 1203         167      7.948523e-08  7.694680e-08     4.604580e-04
# 1204         167      1.384418e-07  4.146531e-07     8.019935e-04
# 1205         124      4.000450e-07  1.022278e-06     2.317461e-03
# 1206         163      2.493386e-07  3.492846e-06     1.444418e-03
#
#       FDR Benjamini Corrected
# 0                7.007478e-16
# 1                1.838864e-23
# 2                7.117212e-27
# 3                1.038055e-19
# 4                9.290519e-08
# ...                       ...
# 1202             3.374297e-07
# 1203             4.532066e-07
# 1204             7.674579e-07
# 1205             2.093460e-06
# 1206             1.339906e-06
#
# [1207 rows x 9 columns]

# %%
med_effect_significant[med_effect_significant["LAB_NAME"]=="Glucose"]
# Out:
#      ITEMID                      MED_NAME  LAB_ITEMID LAB_NAME  SUBJECT_ID  \
# 37   220949                   Dextrose 5%     50809.0  Glucose        1017
# 48   220952                  Dextrose 50%     50809.0  Glucose         336
# 50   220952                  Dextrose 50%     50931.0  Glucose        1024
# 105  221456             Calcium Gluconate     50931.0  Glucose        4283
# 217  222011             Magnesium Sulfate     50931.0  Glucose        6499
# 266  223258             Insulin - Regular     50809.0  Glucose        1127
# 302  225154              Morphine Sulfate     50809.0  Glucose        1129
# 312  225158                     NaCl 0.9%     50809.0  Glucose         895
# 330  225166            Potassium Chloride     50931.0  Glucose        3454
# 397  225799                  Gastric Meds     50809.0  Glucose         757
# 400  225799                  Gastric Meds     50931.0  Glucose        2877
# 422  225828                            LR     50809.0  Glucose        1211
# 460  225834                        K Phos     50931.0  Glucose        2218
# 489  225850                     Cefazolin     50931.0  Glucose        1492
# 528  225907           Famotidine (Pepcid)     50931.0  Glucose        3106
# 545  225910       Pantoprazole (Protonix)     50931.0  Glucose        3956
# 610  225943                      Solution     50931.0  Glucose        3404
# 639  225974                    Metoprolol     50931.0  Glucose        1903
# 655  225975  Heparin Sodium (Prophylaxis)     50809.0  Glucose         493
# 658  225975  Heparin Sodium (Prophylaxis)     50931.0  Glucose        4986
# 675  226089                     Piggyback     50931.0  Glucose        3690
# 700  226364         OR Crystalloid Intake     50809.0  Glucose        2620
# 801  226372          OR Cell Saver Intake     50809.0  Glucose        1597
# 829  226452                     PO Intake     50931.0  Glucose        3580
# 847  226453                      GT Flush     50809.0  Glucose         430
# 870  227522                   KCL (Bolus)     50931.0  Glucose        2011
# 891  227523     Magnesium Sulfate (Bolus)     50931.0  Glucose        5201
# 989  225159                    NaCl 0.45%     50931.0  Glucose         672
#
#      MannwhitneyuTest         TTest  BonferroniPvals  FDR Benjamini Corrected
# 37       3.834855e-07  7.762062e-03     2.221531e-03             2.012257e-06
# 48       4.736440e-08  3.471898e-06     2.743820e-04             2.799816e-07
# 50       4.228117e-17  5.507923e-19     2.449348e-13             5.529003e-16
# 105      6.966379e-10  8.089424e-13     4.035624e-06             5.108384e-09
# 217      1.254247e-15  1.073772e-20     7.265853e-12             1.495032e-14
# 266      2.184822e-07  7.456146e-02     1.265667e-03             1.176271e-06
# 302      2.600017e-11  9.342531e-03     1.506190e-07             2.224800e-10
# 312      9.530054e-10  3.199121e-02     5.520760e-06             6.892335e-09
# 330      1.233222e-15  5.882134e-18     7.144057e-12             1.473001e-14
# 397      1.537231e-08  1.656325e-08     8.905180e-05             9.648082e-08
# 400      1.015562e-09  3.908318e-16     5.883153e-06             7.317354e-09
# 422      2.805773e-08  6.137498e-01     1.625384e-04             1.701973e-07
# 460      7.554000e-21  1.357523e-17     4.376032e-17             1.225779e-19
# 489      3.981681e-07  9.856478e-10     2.306588e-03             2.085522e-06
# 528      2.543397e-12  3.853947e-13     1.473390e-08             2.357424e-11
# 545      3.152862e-12  5.349944e-15     1.826453e-08             2.908365e-11
# 610      7.800714e-09  2.238602e-08     4.518954e-05             5.066092e-08
# 639      2.731355e-11  9.888626e-14     1.582274e-07             2.333737e-10
# 655      6.252555e-07  7.683112e-09     3.622105e-03             3.163411e-06
# 658      7.153179e-17  6.942562e-23     4.143836e-13             9.188107e-16
# 675      2.328197e-14  6.568759e-16     1.348724e-10             2.564115e-13
# 700      1.090640e-07  6.076926e-01     6.318077e-04             6.122167e-07
# 801      1.913236e-19  1.161789e-04     1.108338e-15             2.863921e-18
# 829      5.166792e-11  4.229903e-12     2.993123e-07             4.294293e-10
# 847      5.708423e-07  2.781398e-06     3.306889e-03             2.923863e-06
# 870      2.348404e-09  1.535796e-13     1.360430e-05             1.615713e-08
# 891      6.178500e-14  6.017160e-17     3.579205e-10             6.567349e-13
# 989      5.741432e-07  1.476298e-08     3.326012e-03             2.932991e-06

# %%
# # med_effect_significant = pd.merge(med_effect_significant, labitems.rename(columns={"ITEMID":"LAB_ITEMID"}), on="LAB_ITEMID", how="inner").rename(columns={"LABEL":"LAB_NAME"})
# med_effect_significant = pd.merge(med_effect_significant, meditems, on="ITEMID", how="inner").rename(columns={"LABEL":"MED_NAME"})[['ITEMID',"MED_NAME", 'LAB_ITEMID', "LAB_NAME",  'SUBJECT_ID', 'MannwhitneyuTest', 'TTest','BonferroniPvals', 'FDR Benjamini Corrected']]
# med_effect_significant.to_csv(os.path.join(res, "significant_lab_med_all_med_effect.csv"))

# %%
final_significant_med_lab_pairs = pd.merge(significant_intersection, med_effect_significant, how="inner", on=["ITEMID", "LAB_ITEMID", "MED_NAME", "LAB_NAME"])

# %%
final_significant_med_lab_pairs
# Out:
#      ITEMID                       MED_NAME  LAB_ITEMID        LAB_NAME  \
# 0    220862                    Albumin 25%     50821.0             pO2
# 1    220862                    Albumin 25%     50960.0       Magnesium
# 2    220862                    Albumin 25%     51221.0      Hematocrit
# 3    220862                    Albumin 25%     51222.0      Hemoglobin
# 4    220862                    Albumin 25%     51265.0  Platelet Count
# ..      ...                            ...         ...             ...
# 602  227533  Sodium Bicarbonate 8.4% (Amp)     50960.0       Magnesium
# 603  227533  Sodium Bicarbonate 8.4% (Amp)     51265.0  Platelet Count
# 604  227533  Sodium Bicarbonate 8.4% (Amp)     51277.0             RDW
# 605  227694          Omeprazole (Prilosec)     51221.0      Hematocrit
# 606  228315               Acetaminophen-IV     51221.0      Hematocrit
#
#      SUBJECT_ID_x  MannwhitneyuTest_x       TTest_x  BonferroniPvals_x  \
# 0             321        1.430436e-11  4.637959e-04       4.844888e-08
# 1             394        1.903000e-07  8.057620e-04       6.445459e-04
# 2             436        3.434234e-14  6.015233e-05       1.163175e-10
# 3             397        5.944181e-09  3.997836e-01       2.013294e-05
# 4             396        1.012719e-34  1.594452e-13       3.430080e-31
# ..            ...                 ...           ...                ...
# 602           181        3.287753e-07  3.161023e-01       1.113562e-03
# 603           227        3.126257e-11  9.952159e-01       1.058863e-07
# 604           220        7.750705e-08  1.650571e-02       2.625164e-04
# 605           440        1.183470e-12  7.639016e-04       4.008412e-09
# 606           311        3.951796e-08  4.615459e-01       1.338473e-04
#
#      FDR Benjamini Corrected_x  SUBJECT_ID_y  MannwhitneyuTest_y  \
# 0                 8.367682e-11           471        5.395021e-17
# 1                 7.408574e-07           607        9.078456e-25
# 2                 2.480117e-13           627        2.887183e-28
# 3                 2.702408e-08           597        6.343373e-21
# 4                 2.256631e-33           600        1.478657e-08
# ..                         ...           ...                 ...
# 602               1.251193e-06           323        2.295202e-10
# 603               1.770674e-10           362        3.836445e-08
# 604               3.136396e-07           355        3.668350e-07
# 605               7.591690e-12           753        1.948180e-07
# 606               1.636276e-07           623        4.131297e-14
#
#           TTest_y  BonferroniPvals_y  FDR Benjamini Corrected_y
# 0    8.188215e-37       3.125335e-13               7.007478e-16
# 1    7.284733e-18       5.259150e-21               1.838864e-23
# 2    1.249454e-32       1.672545e-24               7.117212e-27
# 3    4.042760e-25       3.674716e-17               1.038055e-19
# 4    1.920522e-04       8.565858e-05               9.290519e-08
# ..            ...                ...                        ...
# 602  1.147614e-07       1.329610e-06               1.765751e-09
# 603  2.101411e-07       2.222453e-04               2.298296e-07
# 604  1.047351e-05       2.125075e-03               1.931886e-06
# 605  9.771522e-06       1.128580e-03               1.058706e-06
# 606  1.294480e-14       2.393260e-10               4.456723e-13
#
# [607 rows x 14 columns]

# %%
final_significant_med_lab_pairs.to_csv(os.path.join(res, "significant_intersection_trends_and_med_effect_lab_med_all_new.csv"))

# %%
final_significant_med_lab_pairs = pd.read_csv(os.path.join(res, "significant_intersection_trends_and_med_effect_lab_med_all_new.csv"))

# %%
final_significant_med_lab_pairs[["MED_NAME", "LAB_NAME"]].to_csv(os.path.join(res, "med-lab-pairs-share-doc.csv"))

# %%
final_significant_med_lab_pairs.columns
# Out:
# Index(['ITEMID', 'MED_NAME', 'LAB_ITEMID', 'LAB_NAME', 'SUBJECT_ID_x',
#        'MannwhitneyuTest_x', 'TTest_x', 'BonferroniPvals_x',
#        'FDR Benjamini Corrected_x', 'SUBJECT_ID_y', 'MannwhitneyuTest_y',
#        'TTest_y', 'BonferroniPvals_y', 'FDR Benjamini Corrected_y'],
#       dtype='object')

# %%
final_significant_med_lab_pairs.sort_values(by=['FDR Benjamini Corrected_y', 'FDR Benjamini Corrected_x']).head(10).drop(columns=["Unnamed: 0"])
# Out:
#      ITEMID                   MED_NAME  LAB_ITEMID    LAB_NAME  SUBJECT_ID_x  \
# 586  227523  Magnesium Sulfate (Bolus)     50960.0   Magnesium          2958
# 128  222011          Magnesium Sulfate     50960.0   Magnesium          3412
# 332  225850                  Cefazolin     50821.0         pO2           853
# 528  226372       OR Cell Saver Intake     50821.0         pO2          1526
# 462  226364      OR Crystalloid Intake     50821.0         pO2          2813
# 567  227522                KCL (Bolus)     50821.0         pO2          1217
# 207  225166         Potassium Chloride     50821.0         pO2          1391
# 189  225154           Morphine Sulfate     50821.0         pO2           712
# 243  225798                 Vancomycin     51221.0  Hematocrit          2331
# 60   221456          Calcium Gluconate     50821.0         pO2          2120
#
#      MannwhitneyuTest_x       TTest_x  BonferroniPvals_x  \
# 586        1.506976e-12  9.281992e-09       5.104128e-09
# 128        2.202338e-12  1.319484e-09       7.459319e-09
# 332       2.080586e-106  4.084509e-01      7.046944e-103
# 528        7.742668e-73  4.290314e-50       2.622442e-69
# 462        5.017588e-35  8.172697e-08       1.699457e-31
# 567        2.436032e-48  2.313109e-02       8.250842e-45
# 207        2.697990e-52  8.723397e-03       9.138094e-49
# 189        3.227611e-29  1.680545e-01       1.093192e-25
# 243        6.311865e-48  9.441896e-04       2.137829e-44
# 60         4.908603e-60  1.636662e-07       1.662544e-56
#
#      FDR Benjamini Corrected_x  SUBJECT_ID_y  MannwhitneyuTest_y  \
# 586               9.540426e-12          5257        0.000000e+00
# 128               1.371198e-11          6560        0.000000e+00
# 332              3.203156e-104          1571       7.397826e-261
# 528               5.827648e-71          1707       1.492463e-258
# 462               1.125468e-33          3567       1.746652e-232
# 567               8.685096e-47          2403       3.336171e-222
# 207               1.114402e-50          2900       2.199582e-212
# 189               5.664206e-28          1848       2.794932e-190
# 243               2.203947e-46          5417       7.443586e-168
# 60                2.638958e-58          3506       2.616736e-165
#
#            TTest_y  BonferroniPvals_y  FDR Benjamini Corrected_y
# 586  5.145557e-256       0.000000e+00               0.000000e+00
# 128   0.000000e+00       0.000000e+00               0.000000e+00
# 332   0.000000e+00      4.285561e-257              1.428520e-257
# 528   0.000000e+00      8.645837e-255              2.161459e-255
# 462   0.000000e+00      1.011836e-228              2.023671e-229
# 567   0.000000e+00      1.932644e-218              3.221073e-219
# 207   0.000000e+00      1.274218e-208              1.820311e-209
# 189  1.086944e-321      1.619104e-186              2.023880e-187
# 243  4.358359e-164      4.312070e-164              4.791188e-165
# 60    0.000000e+00      1.515875e-161              1.515875e-162

# %%
final_significant_med_lab_pairs.shape
# Out:
# (607, 14)

# %%
final_significant_med_lab_pairs[final_significant_med_lab_pairs["ITEMID"]==223258]
# Out:
#      ITEMID           MED_NAME  LAB_ITEMID              LAB_NAME  \
# 156  223258  Insulin - Regular     50802.0           Base Excess
# 157  223258  Insulin - Regular     50804.0  Calculated Total CO2
# 158  223258  Insulin - Regular     50821.0                   pO2
# 159  223258  Insulin - Regular     50868.0             Anion Gap
# 160  223258  Insulin - Regular     50960.0             Magnesium
# 161  223258  Insulin - Regular     51221.0            Hematocrit
# 162  223258  Insulin - Regular     51222.0            Hemoglobin
# 163  223258  Insulin - Regular     51265.0        Platelet Count
# 164  223258  Insulin - Regular     51277.0                   RDW
# 165  223258  Insulin - Regular     51279.0       Red Blood Cells
#
#      SUBJECT_ID_x  MannwhitneyuTest_x       TTest_x  BonferroniPvals_x  \
# 156           988        2.511471e-10  2.721277e-01       8.506353e-07
# 157           988        2.131724e-13  2.847297e-01       7.220149e-10
# 158           988        7.675496e-09  6.152170e-01       2.599690e-05
# 159           967        1.060020e-12  1.107342e-01       3.590288e-09
# 160           935        1.910413e-12  1.271387e-05       6.470568e-09
# 161          1133        3.441754e-19  1.038118e-01       1.165722e-15
# 162           899        1.760523e-16  4.668306e-01       5.962891e-13
# 163           924        1.061073e-41  6.627579e-08       3.593854e-38
# 164           888        7.314853e-08  2.416353e-02       2.477541e-04
# 165           888        8.657861e-13  6.543860e-01       2.932418e-09
#
#      FDR Benjamini Corrected_x  SUBJECT_ID_y  MannwhitneyuTest_y  \
# 156               1.300666e-09          2654        1.851781e-13
# 157               1.438277e-12          2654        8.302906e-14
# 158               3.457035e-08          2654       1.678316e-135
# 159               6.851695e-12          3086        1.268445e-49
# 160               1.198253e-11          2958        1.111633e-99
# 161               3.469411e-18          3554        5.953117e-65
# 162               1.525036e-15          2917        1.196694e-42
# 163               2.994878e-40          2943        1.260975e-11
# 164               2.967115e-07          2884        3.796676e-10
# 165               5.650130e-12          2885        9.056541e-41
#
#            TTest_y  BonferroniPvals_y  FDR Benjamini Corrected_y
# 156   5.323703e-02       1.072737e-09               1.908784e-12
# 157   5.101142e-05       4.809873e-10               8.697782e-13
# 158  6.669512e-253      9.722484e-132              7.478834e-133
# 159   2.571270e-37       7.348104e-46               6.619913e-48
# 160   1.792399e-81       6.439687e-96               2.077319e-97
# 161   5.543167e-64       3.448641e-61               4.660326e-63
# 162   2.721451e-43       6.932450e-39               4.814202e-41
# 163   3.253891e-07       7.304827e-08               1.103448e-10
# 164   8.552167e-07       2.199414e-06               2.845296e-09
# 165   5.349991e-39       5.246454e-37               3.521110e-39

# %% [markdown]
# ## Plots

# %%
final
# Out:
#          SUBJECT_ID  ITEMID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0             80778  226361   178404    253009.0  2140-05-11 19:45:00
# 1             53149  225154   140593    297609.0  2131-03-21 13:15:00
# 2             55934  225798   169449    237762.0  2135-05-23 22:00:00
# 3             55934  225910   169449    237762.0  2135-05-23 22:00:00
# 4             50501  222315   146105    256101.0  2183-11-20 14:27:00
# ...             ...     ...      ...         ...                  ...
# 2112125       51955  222011   181913    251588.0  2109-08-16 03:33:00
# 2112126       51955  225910   181913    251588.0  2109-08-17 08:00:00
# 2112127       23450  225885   122507    294197.0  2167-04-22 17:55:00
# 2112128       23450  221833   122507    294197.0  2167-04-25 06:30:00
# 2112129       23450  222011   122507    294197.0  2167-04-25 07:01:00
#
#                      ENDTIME   AMOUNT AMOUNTUOM  RATE     RATEUOM  ...  \
# 0        2140-05-11 19:46:00  1000.00        ml   NaN         NaN  ...
# 1        2131-03-21 13:16:00     1.00        mg   NaN         NaN  ...
# 2        2135-05-23 22:01:00     1.00      dose   NaN         NaN  ...
# 3        2135-05-23 22:01:00     1.00      dose   NaN         NaN  ...
# 4        2183-11-20 15:28:00     2.44     units   2.4  units/hour  ...
# ...                      ...      ...       ...   ...         ...  ...
# 2112125  2109-08-16 04:33:00     2.00     grams   NaN         NaN  ...
# 2112126  2109-08-17 08:01:00     1.00      dose   NaN         NaN  ...
# 2112127  2167-04-22 17:56:00     1.00      dose   NaN         NaN  ...
# 2112128  2167-04-25 06:31:00     1.00        mg   NaN         NaN  ...
# 2112129  2167-04-25 08:01:00     2.00     grams   NaN         NaN  ...
#
#         LAB_ITEMID  BeforeStd   AfterStd  LabBeforeTrends LabAfterTrends  \
# 0          50813.0   0.070711   1.236878        -1.500000      -0.009054
# 1          50813.0   0.282843   0.287374        -1.846154      -0.000729
# 2          50813.0   0.000000   0.000000         0.000000       0.000000
# 3          50813.0   0.000000   0.000000         0.000000       0.000000
# 4          50813.0   0.141421   0.303315        -0.857143      -0.020226
# ...            ...        ...        ...              ...            ...
# 2112125    50907.0  34.602023  27.577164        -0.127696       0.243446
# 2112126    50907.0  34.602023  27.577164        -0.127696       0.243446
# 2112127    51284.0   1.972097   4.021608        -0.005071       0.092970
# 2112128    51284.0   2.164948   1.555635        -0.008456       0.061798
# 2112129    51284.0   2.164948   1.555635        -0.008456       0.061798
#
#         ROW_ID_y                    LAB_NAME  FLUID  CATEGORY_y  LOINC_CODE
# 0             14                     Lactate  Blood   Blood Gas     32693-4
# 1             14                     Lactate  Blood   Blood Gas     32693-4
# 2             14                     Lactate  Blood   Blood Gas     32693-4
# 3             14                     Lactate  Blood   Blood Gas     32693-4
# 4             14                     Lactate  Blood   Blood Gas     32693-4
# ...          ...                         ...    ...         ...         ...
# 2112125      108          Cholesterol, Total  Blood   Chemistry      2093-3
# 2112126      108          Cholesterol, Total  Blood   Chemistry      2093-3
# 2112127      484  Reticulocyte Count, Manual  Blood  Hematology     31112-6
# 2112128      484  Reticulocyte Count, Manual  Blood  Hematology     31112-6
# 2112129      484  Reticulocyte Count, Manual  Blood  Hematology     31112-6
#
# [2112130 rows x 73 columns]

# %%
mapping = pd.read_csv("../../data/mimic_extract/itemid_to_variable_map.csv")

# %%
mapping
# Out:
#                          LEVEL2                    LEVEL1 ALTERNATIVE STATUS  \
# 0      Alanine aminotransferase  Alanine aminotransferase         ALT  ready
# 1      Alanine aminotransferase  Alanine aminotransferase         ALT  ready
# 2      Alanine aminotransferase  Alanine aminotransferase         ALT  ready
# 3                       Albumin                   Albumin         NaN  ready
# 4                       Albumin                   Albumin         NaN  ready
# ...                         ...                       ...         ...    ...
# 13246              Urine output              Urine output         NaN  ready
# 13247              Urine output              Urine output         NaN  ready
# 13248              Urine output              Urine output         NaN  ready
# 13249              Urine output              Urine output    OR Urine  ready
# 13250              Urine output              Urine output         NaN  ready
#
#       STATUS NOTE  ITEMID                     MIMIC LABEL UNITNAME  \
# 0             NaN   50861  ALANINE AMINOTRANSFERASE (ALT)      NaN
# 1             NaN     769                             ALT      NaN
# 2             NaN  220644                             ALT     None
# 3             NaN   50862                         ALBUMIN      NaN
# 4             NaN     772                  Albumin (>3.2)      NaN
# ...           ...     ...                             ...      ...
# 13246         NaN  226565                   L Nephrostomy      NaN
# 13247         NaN  226567                   Straight Cath      NaN
# 13248         NaN  226584                     Ileoconduit      NaN
# 13249         NaN  226627                        OR Urine       mL
# 13250         NaN  227510                     TF Residual      NaN
#
#             LINKSTO     COUNT   CATEGORY  CONCEPTID  FLUID LOINC_CODE  \
# 0         labevents  219475.0  CHEMISTRY        NaN  BLOOD
# 1       chartevents   41594.0    Enzymes        NaN    NaN        NaN
# 2       chartevents   37625.0       Labs        NaN    NaN        NaN
# 3         labevents  146697.0  CHEMISTRY        NaN  BLOOD     1751-7
# 4       chartevents   31022.0  Chemistry        NaN    NaN        NaN
# ...             ...       ...        ...        ...    ...        ...
# 13246  outputevents       NaN        NaN        NaN    NaN        NaN
# 13247  outputevents       NaN        NaN        NaN    NaN        NaN
# 13248  outputevents       NaN        NaN        NaN    NaN        NaN
# 13249  outputevents    5928.0     Output        NaN    NaN        NaN
# 13250  outputevents       NaN        NaN        NaN    NaN        NaN
#
#          DBSOURCE  Unnamed: 15 PARAM_TYPE  NOTE
# 0             NaN          NaN        NaN   NaN
# 1         carevue          NaN        NaN   NaN
# 2      metavision          NaN    Numeric   NaN
# 3             NaN          NaN        NaN   NaN
# 4         carevue          NaN        NaN   NaN
# ...           ...          ...        ...   ...
# 13246  metavision          NaN        NaN   NaN
# 13247  metavision          NaN        NaN   NaN
# 13248  metavision          NaN        NaN   NaN
# 13249  metavision          NaN        NaN   NaN
# 13250  metavision          NaN        NaN   NaN
#
# [13251 rows x 18 columns]

# %%
# [Packed Red Blood Cells <> {Hematocrit, Hemoglobin,Red Blood Cells}] & [Calcium<>Calcium Total] & [Insulin - Regular <> Glucose] & [Albumin 5%<>Hematocrit]

# %%
def get_itemids(type):
    return mapping[mapping["LEVEL2"]==type]["ITEMID"].unique()

# %%
glucose = get_itemids("Glucose")

# %%
hematocrit = get_itemids("Hematocrit")

# %%
calcium = get_itemids("Calcium")

# %%
hemoglobin = get_itemids("Hemoglobin")

# %%
rbc = get_itemids("Red blood cell count")

# %%
lab_itemids = [glucose, hematocrit, calcium, hemoglobin, rbc]

# %%
final.columns
# Out:
# Index(['SUBJECT_ID', 'ITEMID', 'HADM_ID', 'ICUSTAY_ID', 'STARTTIME', 'ENDTIME',
#        'AMOUNT', 'AMOUNTUOM', 'RATE', 'RATEUOM', 'STORETIME', 'CGID',
#        'ORDERID', 'LINKORDERID', 'ORDERCATEGORYNAME',
#        'SECONDARYORDERCATEGORYNAME', 'ORDERCOMPONENTTYPEDESCRIPTION',
#        'ORDERCATEGORYDESCRIPTION', 'PATIENTWEIGHT', 'TOTALAMOUNT',
#        'TOTALAMOUNTUOM', 'ISOPENBAG', 'CONTINUEINNEXTDEPT', 'CANCELREASON',
#        'STATUSDESCRIPTION', 'COMMENTS_EDITEDBY', 'COMMENTS_CANCELEDBY',
#        'COMMENTS_DATE', 'ORIGINALAMOUNT', 'ORIGINALRATE', 'ROW_ID_y',
#        'SUBJECT_ID_y', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE',
#        'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE',
#        'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME',
#        'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA', 'ROW_ID_x',
#        'MED_NAME', 'ABBREVIATION', 'DBSOURCE', 'LINKSTO', 'CATEGORY_x',
#        'UNITNAME', 'PARAM_TYPE', 'CONCEPTID', 'MedTimeFromAdmit', 'hours_in',
#        'before_std', 'after_std', 'before_trends', 'after_trends',
#        'LAB_ITEMID', 'BeforeStd', 'AfterStd', 'LabBeforeTrends',
#        'LabAfterTrends', 'ROW_ID_y', 'LAB_NAME', 'FLUID', 'CATEGORY_y',
#        'LOINC_CODE'],
#       dtype='object')

# %%
# Hematocrit, Hemoglobin,Red Blood Cells
t = final[final["MED_NAME"]=="Packed Red Blood Cells"] 
t = t[t["LAB_NAME"]=="Hematocrit"]

# %%
t.columns
# Out:
# Index(['SUBJECT_ID', 'ITEMID', 'HADM_ID', 'ICUSTAY_ID', 'STARTTIME', 'ENDTIME',
#        'AMOUNT', 'AMOUNTUOM', 'RATE', 'RATEUOM', 'STORETIME', 'CGID',
#        'ORDERID', 'LINKORDERID', 'ORDERCATEGORYNAME',
#        'SECONDARYORDERCATEGORYNAME', 'ORDERCOMPONENTTYPEDESCRIPTION',
#        'ORDERCATEGORYDESCRIPTION', 'PATIENTWEIGHT', 'TOTALAMOUNT',
#        'TOTALAMOUNTUOM', 'ISOPENBAG', 'CONTINUEINNEXTDEPT', 'CANCELREASON',
#        'STATUSDESCRIPTION', 'COMMENTS_EDITEDBY', 'COMMENTS_CANCELEDBY',
#        'COMMENTS_DATE', 'ORIGINALAMOUNT', 'ORIGINALRATE', 'ROW_ID_y',
#        'SUBJECT_ID_y', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE',
#        'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE',
#        'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME',
#        'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA', 'ROW_ID_x',
#        'MED_NAME', 'ABBREVIATION', 'DBSOURCE', 'LINKSTO', 'CATEGORY_x',
#        'UNITNAME', 'PARAM_TYPE', 'CONCEPTID', 'MedTimeFromAdmit', 'hours_in',
#        'before_std', 'after_std', 'before_trends', 'after_trends',
#        'LAB_ITEMID', 'BeforeStd', 'AfterStd', 'LabBeforeTrends',
#        'LabAfterTrends', 'ROW_ID_y', 'LAB_NAME', 'FLUID', 'CATEGORY_y',
#        'LOINC_CODE'],
#       dtype='object')

# %%
t[] = t["ADMITTIME"]+t["MedTimeFromAdmit"]
# Out:
# 519633      2159-01-09 21:16:000 days 01:53:00
# 519719      2141-10-20 16:07:000 days 02:38:00
# 519721      2116-06-29 12:15:000 days 02:39:00
# 519952      2159-08-10 17:29:000 days 04:01:00
# 519963      2106-05-25 14:00:000 days 04:03:00
#                           ...
# 600903     2176-02-27 17:39:0059 days 11:21:00
# 600947     2170-05-19 21:46:0068 days 11:50:00
# 600977     2190-03-02 18:00:0072 days 23:14:00
# 601091    2167-01-08 10:44:00105 days 03:05:00
# 601111    2124-03-01 11:10:00106 days 22:12:00
# Length: 1742, dtype: object

# %%
t[['SUBJECT_ID', 'ITEMID', 'HADM_ID', 'MED_NAME', 'AMOUNT', 'AMOUNTUOM', 'LAB_NAME', 'MedTimeFromAdmit', 'LabBeforeTrends',
       'LabAfterTrends', 'STARTTIME', 'ENDTIME']]
# Out:
#         SUBJECT_ID  ITEMID  HADM_ID                MED_NAME      AMOUNT  \
# 519633       91343  225168   131485  Packed Red Blood Cells  283.000002
# 519719       63017  225168   193864  Packed Red Blood Cells  300.000000
# 519721       91263  225168   122997  Packed Red Blood Cells  350.000000
# 519952       91419  225168   157026  Packed Red Blood Cells   49.999998
# 519963       96527  225168   124517  Packed Red Blood Cells  350.000010
# ...            ...     ...      ...                     ...         ...
# 600903       91333  225168   112508  Packed Red Blood Cells  350.000004
# 600947       28933  225168   118513  Packed Red Blood Cells  274.999989
# 600977       95929  225168   160996  Packed Red Blood Cells  349.999995
# 601091       27766  225168   116756  Packed Red Blood Cells  334.999987
# 601111       43126  225168   124079  Packed Red Blood Cells  270.000007
#
#        AMOUNTUOM    LAB_NAME   MedTimeFromAdmit  LabBeforeTrends  \
# 519633        ml  Hematocrit    0 days 01:53:00         2.611765
# 519719        ml  Hematocrit    0 days 02:38:00         2.122449
# 519721        ml  Hematocrit    0 days 02:39:00        -1.955056
# 519952        ml  Hematocrit    0 days 04:01:00         1.086957
# 519963        ml  Hematocrit    0 days 04:03:00         1.164179
# ...          ...         ...                ...              ...
# 600903        ml  Hematocrit   59 days 11:21:00        -0.003031
# 600947        ml  Hematocrit   68 days 11:50:00        -0.000388
# 600977        ml  Hematocrit   72 days 23:14:00         0.001714
# 601091        ml  Hematocrit  105 days 03:05:00        -0.000533
# 601111        ml  Hematocrit  106 days 22:12:00        -0.000048
#
#         LabAfterTrends            STARTTIME              ENDTIME
# 519633       -0.036414  2159-01-09 22:09:00  2159-01-09 23:09:00
# 519719       -0.007595  2141-10-20 17:45:00  2141-10-20 18:45:00
# 519721       -0.053320  2116-06-29 14:38:00  2116-06-29 14:54:00
# 519952       -0.154250  2159-08-10 21:00:00  2159-08-10 21:30:00
# 519963       -0.056268  2106-05-25 17:03:00  2106-05-25 18:03:00
# ...                ...                  ...                  ...
# 600903       -0.079926  2176-04-27 03:00:00  2176-04-27 05:00:00
# 600947        0.010362  2170-07-27 06:51:00  2170-07-27 09:36:00
# 600977       -0.135680  2190-05-14 13:21:00  2190-05-14 17:14:00
# 601091        1.028312  2167-04-23 10:28:00  2167-04-23 13:49:00
# 601111        0.002027  2124-06-16 06:48:00  2124-06-16 09:22:00
#
# [1742 rows x 12 columns]

# %%
# t1 = [k for k in zip(list(col_vals[21].columns), list(col_vals[21].dtypes))]
# t2 = [k for k in zip(list(col_vals[22].columns), list(col_vals[22].dtypes))]
# def fun(e):
#     return e[0]
# t1.sort(key=fun)
# t2.sort(key=fun)
# l = [(k, k[0][1]==k[1][1])for k in zip(t1, t2)]
# for e in l:
#     if not e[1]:
#         print(e)

# %%
def c(g, t):
    print(g, t)

d = {"g":"i", "t":1}
print(c(**d))
# Out:
# i 1
# None
