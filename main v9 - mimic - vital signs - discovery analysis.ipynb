# %% [markdown]
# ## Utils

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from src.parsers import mimic, hirid
from src.modeling import discovery, plots, querier
from src.utils import constants
from scipy import stats
import numpy as np

# %%
import sys
# import win32com.client
import os
import pandas as pd

def setup_io_config(root_path):
    """
    Input - Output config. Add dataset paths
    :root_path -> Repo path which contains 'data' and 'res' folders
    """

    # MIMIC
    is_shortcut = True if "data.lnk" in os.listdir(root_path) else False 
    
    if (is_shortcut):
        path_shortcut =  os.path.join(root_path, "data.lnk")
        shell = win32com.client.Dispatch("WScript.Shell")
        mimic_data = shell.CreateShortCut(path_shortcut).Targetpath
    else:
        mimic_data = os.path.join(f"{root_path}", "data") 
    mimic_path = os.path.join(f"{root_path}", "results")

    # HIRID
    hirid_data = f'{root_path}/data/hirid-a-high-time-resolution-icu-dataset-1.1.1/raw_stage/'
    hirid_path = f'{root_path}/data/hirid-a-high-time-resolution-icu-dataset-1.1.1'
    
    return mimic_data, mimic_path, hirid_data, hirid_path

def setup_stratification_config():
    gender="MF"
    age_b=40
    age_a=80 
    ethnicity="WHITE" 
    lab_mapping= constants.LAB_MAPPING
    b_w = [(0,6), (6,12)]
    a_w = [(0,4), (4,8), (8,12)]
    before_windows = b_w
    after_windows = a_w
    return gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows

# %% [markdown]
# ## Systolic Blood Pressure

# %%
# IO Config
# root_path ="C:\\Users\\danco\\My Drive\\Master\\Datasets\\MIMIC iii"
root_path = "/Users/pavan/Library/CloudStorage/GoogleDrive-f20190038@hyderabad.bits-pilani.ac.in/My Drive/TAU/Code/DrugLab"
data, res, raw_path, res_path = setup_io_config(root_path=root_path)

# Stratification Config
gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows = setup_stratification_config()

# %%
vital_name = "Systolic blood pressure"

# %%
# med_lab_pairs = pd.read_csv(os.path.join(data, "mimiciii/1.4", "preprocessed", "Systolic blood pressure_lab_patient_data_mimic_extract_2.csv")).drop(columns=["Unnamed: 0"])
med_lab_pairs = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name}.csv")).drop(columns=["Unnamed: 0"])

# %%
for b_w in before_windows:
    for a_w in after_windows:
        print(b_w, a_w)
        med_lab_pairs[f"ratio_{b_w}_{a_w}"] = med_lab_pairs[f"after_abs_{a_w}_sp"] / med_lab_pairs[f"before_abs_{b_w}_sp"]
# Out:
# (0, 6) (0, 4)
# (0, 6) (4, 8)
# (0, 6) (8, 12)
# (6, 12) (0, 4)
# (6, 12) (4, 8)
# (6, 12) (8, 12)

# %%
med_lab_pairs.dropna(subset=["ratio_(0, 6)_(0, 4)"])[["ratio_(0, 6)_(0, 4)"]]
# Out:
#         ratio_(0, 6)_(0, 4)
# 0                  1.050000
# 1                  1.050000
# 2                  1.050000
# 5                  1.142857
# 6                  0.946237
# ...                     ...
# 136151             1.247191
# 136152             0.954955
# 136153             0.936000
# 136154             1.034188
# 136155             1.070866
#
# [115914 rows x 1 columns]

# %%
# # Original size of med lab pairs - 1826730
# for a_w in after_windows:
#     for b_w in before_windows:
#         med_lab_pairs = pd.concat([ med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]<1) & (med_lab_pairs[f"ratio_{b_w}_{a_w}"]!=1)], med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]>=1) | (med_lab_pairs[f"after_time_{a_w}_sp"].isna())] ])

# %%
med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
# Out:
#                                                   HADM_ID
# MED_NAME                 LAB_NAME
# ACD-A Citrate (1000ml)   Systolic blood pressure      147
# ACD-A Citrate (500ml)    Systolic blood pressure        5
# Abciximab (Reopro)       Systolic blood pressure        2
# Acetaminophen-IV         Systolic blood pressure      400
# Acyclovir                Systolic blood pressure      210
# ...                                                   ...
# Verapamil                Systolic blood pressure        9
# Vitamin K (Phytonadione) Systolic blood pressure       93
# Vivonex (1/2)            Systolic blood pressure        1
# Vivonex (Full)           Systolic blood pressure       42
# Voriconazole             Systolic blood pressure       48
#
# [254 rows x 1 columns]

# %%
pairs_df = med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
pairs = pairs_df[pairs_df["HADM_ID"]>100].index
discovery_res1 = []
for med_name, lab_name in pairs:
    stat_test_df = []
    for a_w in after_windows:
        for b_w in before_windows:
            vals = med_lab_pairs[med_lab_pairs["LAB_NAME"]==lab_name]
            vals = vals[vals["MED_NAME"]==med_name]
            vals = vals[f"ratio_{b_w}_{a_w}"].replace([np.inf, -np.inf], np.nan).dropna()
            if vals.shape[0]>0:
                res = stats.ttest_1samp(vals.to_numpy(), popmean=1)
                row = {
                    "Med Name": med_name,
                    "Lab Name": lab_name,
                    "Before Window (in Hours)": b_w,
                    "After Window (in Hours)": a_w,
                    "No. of Patients": vals.shape[0],
                    "1-Sampled Ttest" : res.pvalue
                }
            stat_test_df.append(row)
    if len(stat_test_df)>0:
        discovery_res1.extend(stat_test_df)
res_df1 = pd.DataFrame(discovery_res1)

# %%
res_df = res_df1.copy()

# %%
res_df[res_df["No. of Patients"]>100]
# Out:
#              Med Name                 Lab Name Before Window (in Hours)  \
# 6    Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 7    Acetaminophen-IV  Systolic blood pressure                  (6, 12)
# 8    Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 9    Acetaminophen-IV  Systolic blood pressure                  (6, 12)
# 10   Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# ..                ...                      ...                      ...
# 742       Vasopressin  Systolic blood pressure                   (0, 6)
# 744        Vecuronium  Systolic blood pressure                   (0, 6)
# 745        Vecuronium  Systolic blood pressure                  (6, 12)
# 746        Vecuronium  Systolic blood pressure                   (0, 6)
# 748        Vecuronium  Systolic blood pressure                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 6                    (0, 4)              328     4.413339e-08
# 7                    (0, 4)              233     9.361079e-01
# 8                    (4, 8)              311     1.695153e-04
# 9                    (4, 8)              217     2.629712e-01
# 10                  (8, 12)              213     4.635270e-01
# ..                      ...              ...              ...
# 742                 (8, 12)              102     8.988038e-01
# 744                  (0, 4)              129     1.616918e-03
# 745                  (0, 4)              102     1.866225e-03
# 746                  (4, 8)              111     1.091981e-03
# 748                 (8, 12)              108     2.600184e-03
#
# [551 rows x 6 columns]

# %%
res_df[res_df["No. of Patients"]>100].to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv"))

# %%
res_df = pd.read_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv")).drop(columns=["Unnamed: 0"]).drop_duplicates()

# %%
dis_analyzer = discovery.ClinicalDiscoveryAnalysis([])

# %%
test_pval_data, significant_hard_thres, significant_bonferroni, significant_fdr = dis_analyzer.generate_significant(res_df[res_df["No. of Patients"]>100].dropna(), statistical_test="1-Sampled Ttest")

# %%
test_pval_data
# Out:
#              Med Name                 Lab Name Before Window (in Hours)  \
# 0    Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 1    Acetaminophen-IV  Systolic blood pressure                  (6, 12)
# 2    Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 3    Acetaminophen-IV  Systolic blood pressure                  (6, 12)
# 4    Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# ..                ...                      ...                      ...
# 546       Vasopressin  Systolic blood pressure                   (0, 6)
# 547        Vecuronium  Systolic blood pressure                   (0, 6)
# 548        Vecuronium  Systolic blood pressure                  (6, 12)
# 549        Vecuronium  Systolic blood pressure                   (0, 6)
# 550        Vecuronium  Systolic blood pressure                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest  \
# 0                    (0, 4)              328     4.413339e-08
# 1                    (0, 4)              233     9.361079e-01
# 2                    (4, 8)              311     1.695153e-04
# 3                    (4, 8)              217     2.629712e-01
# 4                   (8, 12)              213     4.635270e-01
# ..                      ...              ...              ...
# 546                 (8, 12)              102     8.988038e-01
# 547                  (0, 4)              129     1.616918e-03
# 548                  (0, 4)              102     1.866225e-03
# 549                  (4, 8)              111     1.091981e-03
# 550                 (8, 12)              108     2.600184e-03
#
#      BonferroniPvals  FDR Benjamini Corrected
# 0           0.000024             5.655232e-07
# 1           1.000000             9.571344e-01
# 2           0.093403             8.193241e-04
# 3           1.000000             3.932012e-01
# 4           1.000000             5.995385e-01
# ..               ...                      ...
# 546         1.000000             9.417096e-01
# 547         0.890922             6.060693e-03
# 548         1.000000             6.821420e-03
# 549         0.601682             4.328645e-03
# 550         1.000000             9.067732e-03
#
# [551 rows x 8 columns]

# %%
significant_hard_thres.shape, significant_bonferroni.shape, significant_fdr.shape
# Out:
# ((195, 8), (88, 8), (162, 8))

# %%
merged_sig_pairs = pd.merge(pd.merge(significant_fdr, significant_bonferroni, how="inner"), significant_hard_thres, how="inner")

# %%
merged_sig_pairs
# Out:
#                 Med Name                 Lab Name Before Window (in Hours)  \
# 0       Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 1             Albumin 5%  Systolic blood pressure                   (0, 6)
# 2             Amiodarone  Systolic blood pressure                   (0, 6)
# 3      Calcium Gluconate  Systolic blood pressure                   (0, 6)
# 4      Calcium Gluconate  Systolic blood pressure                  (6, 12)
# ..                   ...                      ...                      ...
# 83             Platelets  Systolic blood pressure                  (6, 12)
# 84    Potassium Chloride  Systolic blood pressure                   (0, 6)
# 85  Pre-Admission Intake  Systolic blood pressure                   (0, 6)
# 86  Pre-Admission Intake  Systolic blood pressure                   (0, 6)
# 87  Pre-Admission Intake  Systolic blood pressure                   (0, 6)
#
#    After Window (in Hours)  No. of Patients  1-Sampled Ttest  BonferroniPvals  \
# 0                   (0, 4)              328     4.413339e-08     2.431750e-05
# 1                   (0, 4)              991     1.172105e-05     6.458300e-03
# 2                   (4, 8)              327     1.622566e-05     8.940337e-03
# 3                   (0, 4)             2798     3.399097e-13     1.872902e-10
# 4                   (0, 4)             1838     7.193575e-17     3.963660e-14
# ..                     ...              ...              ...              ...
# 83                  (0, 4)              290     2.088772e-07     1.150914e-04
# 84                  (4, 8)             1768     3.559338e-07     1.961195e-04
# 85                  (0, 4)             1245     2.833562e-10     1.561293e-07
# 86                  (4, 8)             1202     1.357516e-08     7.479915e-06
# 87                 (8, 12)             1184     2.192254e-06     1.207932e-03
#
#     FDR Benjamini Corrected
# 0              5.655232e-07
# 1              7.781085e-05
# 2              1.039574e-04
# 3              9.364511e-12
# 4              3.048969e-15
# ..                      ...
# 83             2.397737e-06
# 84             3.700368e-06
# 85             5.036429e-09
# 86             1.869979e-07
# 87             1.830200e-05
#
# [88 rows x 8 columns]

# %%
merged_sig_pairs.to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"sig_pairs_intersection_mimic_vital_sign_{vital_name}.csv"))

# %% [markdown]
# ## Heart Rate

# %%
# IO Config
# root_path ="C:\\Users\\danco\\My Drive\\Master\\Datasets\\MIMIC iii"
root_path = "/Users/pavan/Library/CloudStorage/GoogleDrive-f20190038@hyderabad.bits-pilani.ac.in/My Drive/TAU/Code/DrugLab"
data, res, raw_path, res_path = setup_io_config(root_path=root_path)

# Stratification Config
gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows = setup_stratification_config()

# %%
vital_name = "Heart Rate"

# %%
# med_lab_pairs = pd.read_csv(os.path.join(data, "mimiciii/1.4", "preprocessed", "Systolic blood pressure_lab_patient_data_mimic_extract_2.csv")).drop(columns=["Unnamed: 0"])
med_lab_pairs = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name}.csv")).drop(columns=["Unnamed: 0"])

# %%
for b_w in before_windows:
    for a_w in after_windows:
        print(b_w, a_w)
        med_lab_pairs[f"ratio_{b_w}_{a_w}"] = med_lab_pairs[f"after_abs_{a_w}_sp"] / med_lab_pairs[f"before_abs_{b_w}_sp"]
# Out:
# (0, 6) (0, 4)
# (0, 6) (4, 8)
# (0, 6) (8, 12)
# (6, 12) (0, 4)
# (6, 12) (4, 8)
# (6, 12) (8, 12)

# %%
med_lab_pairs.dropna(subset=["ratio_(0, 6)_(0, 4)"])[["ratio_(0, 6)_(0, 4)"]].describe()
# Out:
#        ratio_(0, 6)_(0, 4)
# count         1.162760e+05
# mean                   inf
# std                    NaN
# min           0.000000e+00
# 25%           9.545455e-01
# 50%           1.000000e+00
# 75%           1.037975e+00
# max                    inf

# %%
# # Original size of med lab pairs - 1826730
# for a_w in after_windows:
#     for b_w in before_windows:
#         med_lab_pairs = pd.concat([ med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]<1) & (med_lab_pairs[f"ratio_{b_w}_{a_w}"]!=1)], med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]>=1) | (med_lab_pairs[f"after_time_{a_w}_sp"].isna())] ])

# %%
med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
# Out:
#                                      HADM_ID
# MED_NAME                 LAB_NAME
# ACD-A Citrate (1000ml)   Heart Rate      147
# ACD-A Citrate (500ml)    Heart Rate        5
# Abciximab (Reopro)       Heart Rate        2
# Acetaminophen-IV         Heart Rate      400
# Acyclovir                Heart Rate      210
# ...                                      ...
# Verapamil                Heart Rate        9
# Vitamin K (Phytonadione) Heart Rate       93
# Vivonex (1/2)            Heart Rate        1
# Vivonex (Full)           Heart Rate       42
# Voriconazole             Heart Rate       48
#
# [254 rows x 1 columns]

# %%
pairs_df = med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
pairs = pairs_df[pairs_df["HADM_ID"]>100].index
discovery_res1 = []
for med_name, lab_name in pairs:
    stat_test_df = []
    for a_w in after_windows:
        for b_w in before_windows:
            vals = med_lab_pairs[med_lab_pairs["LAB_NAME"]==lab_name]
            vals = vals[vals["MED_NAME"]==med_name]
            vals = vals[f"ratio_{b_w}_{a_w}"].replace([np.inf, -np.inf], np.nan).dropna()
            if vals.shape[0]>0:
                res = stats.ttest_1samp(vals.to_numpy(), popmean=1)
                row = {
                    "Med Name": med_name,
                    "Lab Name": lab_name,
                    "Before Window (in Hours)": b_w,
                    "After Window (in Hours)": a_w,
                    "No. of Patients": vals.shape[0],
                    "1-Sampled Ttest" : res.pvalue
                }
            stat_test_df.append(row)
    if len(stat_test_df)>0:
        discovery_res1.extend(stat_test_df)
res_df1 = pd.DataFrame(discovery_res1)

# %%
res_df = res_df1.copy()

# %%
res_df[res_df["No. of Patients"]>100]
# Out:
#              Med Name    Lab Name Before Window (in Hours)  \
# 6    Acetaminophen-IV  Heart Rate                   (0, 6)
# 7    Acetaminophen-IV  Heart Rate                  (6, 12)
# 8    Acetaminophen-IV  Heart Rate                   (0, 6)
# 9    Acetaminophen-IV  Heart Rate                  (6, 12)
# 10   Acetaminophen-IV  Heart Rate                   (0, 6)
# ..                ...         ...                      ...
# 742       Vasopressin  Heart Rate                   (0, 6)
# 744        Vecuronium  Heart Rate                   (0, 6)
# 745        Vecuronium  Heart Rate                  (6, 12)
# 746        Vecuronium  Heart Rate                   (0, 6)
# 748        Vecuronium  Heart Rate                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 6                    (0, 4)              328     8.586671e-06
# 7                    (0, 4)              234     1.782672e-01
# 8                    (4, 8)              313     2.521195e-11
# 9                    (4, 8)              220     2.763394e-02
# 10                  (8, 12)              212     1.942681e-07
# ..                      ...              ...              ...
# 742                 (8, 12)              103     8.314304e-01
# 744                  (0, 4)              130     1.644481e-01
# 745                  (0, 4)              102     9.960966e-01
# 746                  (4, 8)              112     1.272466e-01
# 748                 (8, 12)              109     1.684753e-01
#
# [551 rows x 6 columns]

# %%
res_df[res_df["No. of Patients"]>100].to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv"))

# %%
# res_df = pd.read_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv")).drop(columns=["Unnamed: 0"]).drop_duplicates()

# %%
dis_analyzer = discovery.ClinicalDiscoveryAnalysis([])

# %%
test_pval_data, significant_hard_thres, significant_bonferroni, significant_fdr = dis_analyzer.generate_significant(res_df[res_df["No. of Patients"]>100].dropna(), statistical_test="1-Sampled Ttest")

# %%
test_pval_data
# Out:
#              Med Name    Lab Name Before Window (in Hours)  \
# 0    Acetaminophen-IV  Heart Rate                   (0, 6)
# 1    Acetaminophen-IV  Heart Rate                  (6, 12)
# 2    Acetaminophen-IV  Heart Rate                   (0, 6)
# 3    Acetaminophen-IV  Heart Rate                  (6, 12)
# 4    Acetaminophen-IV  Heart Rate                   (0, 6)
# ..                ...         ...                      ...
# 546       Vasopressin  Heart Rate                   (0, 6)
# 547        Vecuronium  Heart Rate                   (0, 6)
# 548        Vecuronium  Heart Rate                  (6, 12)
# 549        Vecuronium  Heart Rate                   (0, 6)
# 550        Vecuronium  Heart Rate                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest  \
# 0                    (0, 4)              328     8.586671e-06
# 1                    (0, 4)              234     1.782672e-01
# 2                    (4, 8)              313     2.521195e-11
# 3                    (4, 8)              220     2.763394e-02
# 4                   (8, 12)              212     1.942681e-07
# ..                      ...              ...              ...
# 546                 (8, 12)              103     8.314304e-01
# 547                  (0, 4)              130     1.644481e-01
# 548                  (0, 4)              102     9.960966e-01
# 549                  (4, 8)              112     1.272466e-01
# 550                 (8, 12)              109     1.684753e-01
#
#      BonferroniPvals  FDR Benjamini Corrected
# 0       4.731256e-03             7.392587e-05
# 1       1.000000e+00             3.571827e-01
# 2       1.389178e-08             5.342993e-10
# 3       1.000000e+00             8.459055e-02
# 4       1.070417e-04             2.277483e-06
# ..               ...                      ...
# 546     1.000000e+00             9.035861e-01
# 547     1.000000e+00             3.419280e-01
# 548     1.000000e+00             9.962970e-01
# 549     1.000000e+00             2.818406e-01
# 550     1.000000e+00             3.489721e-01
#
# [551 rows x 8 columns]

# %%
significant_hard_thres.shape, significant_bonferroni.shape, significant_fdr.shape
# Out:
# ((148, 8), (66, 8), (106, 8))

# %%
merged_sig_pairs = pd.merge(pd.merge(significant_fdr, significant_bonferroni, how="inner"), significant_hard_thres, how="inner")

# %%
merged_sig_pairs
# Out:
#                 Med Name    Lab Name Before Window (in Hours)  \
# 0       Acetaminophen-IV  Heart Rate                   (0, 6)
# 1       Acetaminophen-IV  Heart Rate                   (0, 6)
# 2       Acetaminophen-IV  Heart Rate                   (0, 6)
# 3             Amiodarone  Heart Rate                  (6, 12)
# 4             Amiodarone  Heart Rate                   (0, 6)
# ..                   ...         ...                      ...
# 61    Potassium Chloride  Heart Rate                   (0, 6)
# 62    Potassium Chloride  Heart Rate                   (0, 6)
# 63  Pre-Admission Intake  Heart Rate                   (0, 6)
# 64  Pre-Admission Intake  Heart Rate                   (0, 6)
# 65              Propofol  Heart Rate                   (0, 6)
#
#    After Window (in Hours)  No. of Patients  1-Sampled Ttest  BonferroniPvals  \
# 0                   (0, 4)              328     8.586671e-06     4.731256e-03
# 1                   (4, 8)              313     2.521195e-11     1.389178e-08
# 2                  (8, 12)              212     1.942681e-07     1.070417e-04
# 3                   (0, 4)              344     6.573602e-08     3.622055e-05
# 4                   (4, 8)              328     6.882087e-18     3.792030e-15
# ..                     ...              ...              ...              ...
# 61                  (4, 8)             1775     1.033733e-09     5.695868e-07
# 62                 (8, 12)             1399     8.541527e-07     4.706381e-04
# 63                  (4, 8)             1262     4.911977e-07     2.706499e-04
# 64                 (8, 12)             1245     3.183580e-11     1.754152e-08
# 65                  (4, 8)              465     4.245018e-08     2.339005e-05
#
#     FDR Benjamini Corrected
# 0              7.392587e-05
# 1              5.342993e-10
# 2              2.277483e-06
# 3              8.423383e-07
# 4              3.415409e-16
# ..                      ...
# 61             1.627391e-08
# 62             9.032774e-06
# 63             5.412998e-06
# 64             6.264830e-10
# 65             5.569060e-07
#
# [66 rows x 8 columns]

# %%
merged_sig_pairs.to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"sig_pairs_intersection_mimic_vital_sign_{vital_name}.csv"))

# %% [markdown]
# ## Diastolic blood pressure

# %%
# IO Config
# root_path ="C:\\Users\\danco\\My Drive\\Master\\Datasets\\MIMIC iii"
root_path = "/Users/pavan/Library/CloudStorage/GoogleDrive-f20190038@hyderabad.bits-pilani.ac.in/My Drive/TAU/Code/DrugLab"
data, res, raw_path, res_path = setup_io_config(root_path=root_path)

# Stratification Config
gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows = setup_stratification_config()

# %%
vital_name = "Diastolic blood pressure"

# %%
# med_lab_pairs = pd.read_csv(os.path.join(data, "mimiciii/1.4", "preprocessed", "Systolic blood pressure_lab_patient_data_mimic_extract_2.csv")).drop(columns=["Unnamed: 0"])
med_lab_pairs = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name}.csv")).drop(columns=["Unnamed: 0"])

# %%
for b_w in before_windows:
    for a_w in after_windows:
        print(b_w, a_w)
        med_lab_pairs[f"ratio_{b_w}_{a_w}"] = med_lab_pairs[f"after_abs_{a_w}_sp"] / med_lab_pairs[f"before_abs_{b_w}_sp"]
# Out:
# (0, 6) (0, 4)
# (0, 6) (4, 8)
# (0, 6) (8, 12)
# (6, 12) (0, 4)
# (6, 12) (4, 8)
# (6, 12) (8, 12)

# %%
med_lab_pairs.dropna(subset=["ratio_(0, 6)_(0, 4)"])[["ratio_(0, 6)_(0, 4)"]].describe()
# Out:
#        ratio_(0, 6)_(0, 4)
# count        115904.000000
# mean              1.034539
# std               5.440290
# min               0.000000
# 25%               0.906250
# 50%               1.000000
# 75%               1.083333
# max            1271.269231

# %%
# # Original size of med lab pairs - 1826730
# for a_w in after_windows:
#     for b_w in before_windows:
#         med_lab_pairs = pd.concat([ med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]<1) & (med_lab_pairs[f"ratio_{b_w}_{a_w}"]!=1)], med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]>=1) | (med_lab_pairs[f"after_time_{a_w}_sp"].isna())] ])

# %%
med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
# Out:
#                                                    HADM_ID
# MED_NAME                 LAB_NAME
# ACD-A Citrate (1000ml)   Diastolic blood pressure      147
# ACD-A Citrate (500ml)    Diastolic blood pressure        5
# Abciximab (Reopro)       Diastolic blood pressure        2
# Acetaminophen-IV         Diastolic blood pressure      400
# Acyclovir                Diastolic blood pressure      210
# ...                                                    ...
# Verapamil                Diastolic blood pressure        9
# Vitamin K (Phytonadione) Diastolic blood pressure       93
# Vivonex (1/2)            Diastolic blood pressure        1
# Vivonex (Full)           Diastolic blood pressure       42
# Voriconazole             Diastolic blood pressure       48
#
# [254 rows x 1 columns]

# %%
pairs_df = med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
pairs = pairs_df[pairs_df["HADM_ID"]>100].index
discovery_res1 = []
for med_name, lab_name in pairs:
    stat_test_df = []
    for a_w in after_windows:
        for b_w in before_windows:
            vals = med_lab_pairs[med_lab_pairs["LAB_NAME"]==lab_name]
            vals = vals[vals["MED_NAME"]==med_name]
            vals = vals[f"ratio_{b_w}_{a_w}"].replace([np.inf, -np.inf], np.nan).dropna()
            if vals.shape[0]>0:
                res = stats.ttest_1samp(vals.to_numpy(), popmean=1)
                row = {
                    "Med Name": med_name,
                    "Lab Name": lab_name,
                    "Before Window (in Hours)": b_w,
                    "After Window (in Hours)": a_w,
                    "No. of Patients": vals.shape[0],
                    "1-Sampled Ttest" : res.pvalue
                }
            stat_test_df.append(row)
    if len(stat_test_df)>0:
        discovery_res1.extend(stat_test_df)
res_df1 = pd.DataFrame(discovery_res1)

# %%
res_df = res_df1.copy()

# %%
res_df[res_df["No. of Patients"]>100]
# Out:
#              Med Name                  Lab Name Before Window (in Hours)  \
# 6    Acetaminophen-IV  Diastolic blood pressure                   (0, 6)
# 7    Acetaminophen-IV  Diastolic blood pressure                  (6, 12)
# 8    Acetaminophen-IV  Diastolic blood pressure                   (0, 6)
# 9    Acetaminophen-IV  Diastolic blood pressure                  (6, 12)
# 10   Acetaminophen-IV  Diastolic blood pressure                   (0, 6)
# ..                ...                       ...                      ...
# 742       Vasopressin  Diastolic blood pressure                   (0, 6)
# 744        Vecuronium  Diastolic blood pressure                   (0, 6)
# 745        Vecuronium  Diastolic blood pressure                  (6, 12)
# 746        Vecuronium  Diastolic blood pressure                   (0, 6)
# 748        Vecuronium  Diastolic blood pressure                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 6                    (0, 4)              328         0.000003
# 7                    (0, 4)              233         0.524005
# 8                    (4, 8)              311         0.000013
# 9                    (4, 8)              217         0.959806
# 10                  (8, 12)              213         0.071872
# ..                      ...              ...              ...
# 742                 (8, 12)              102         0.452940
# 744                  (0, 4)              129         0.003279
# 745                  (0, 4)              102         0.000179
# 746                  (4, 8)              111         0.027241
# 748                 (8, 12)              108         0.249740
#
# [551 rows x 6 columns]

# %%
res_df[res_df["No. of Patients"]>100].to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv"))

# %%
# res_df = pd.read_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv")).drop(columns=["Unnamed: 0"]).drop_duplicates()

# %%
dis_analyzer = discovery.ClinicalDiscoveryAnalysis([])

# %%
test_pval_data, significant_hard_thres, significant_bonferroni, significant_fdr = dis_analyzer.generate_significant(res_df[res_df["No. of Patients"]>100].dropna(), statistical_test="1-Sampled Ttest")

# %%
test_pval_data
# Out:
#              Med Name                  Lab Name Before Window (in Hours)  \
# 0    Acetaminophen-IV  Diastolic blood pressure                   (0, 6)
# 1    Acetaminophen-IV  Diastolic blood pressure                  (6, 12)
# 2    Acetaminophen-IV  Diastolic blood pressure                   (0, 6)
# 3    Acetaminophen-IV  Diastolic blood pressure                  (6, 12)
# 4    Acetaminophen-IV  Diastolic blood pressure                   (0, 6)
# ..                ...                       ...                      ...
# 546       Vasopressin  Diastolic blood pressure                   (0, 6)
# 547        Vecuronium  Diastolic blood pressure                   (0, 6)
# 548        Vecuronium  Diastolic blood pressure                  (6, 12)
# 549        Vecuronium  Diastolic blood pressure                   (0, 6)
# 550        Vecuronium  Diastolic blood pressure                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest  \
# 0                    (0, 4)              328         0.000003
# 1                    (0, 4)              233         0.524005
# 2                    (4, 8)              311         0.000013
# 3                    (4, 8)              217         0.959806
# 4                   (8, 12)              213         0.071872
# ..                      ...              ...              ...
# 546                 (8, 12)              102         0.452940
# 547                  (0, 4)              129         0.003279
# 548                  (0, 4)              102         0.000179
# 549                  (4, 8)              111         0.027241
# 550                 (8, 12)              108         0.249740
#
#      BonferroniPvals  FDR Benjamini Corrected
# 0           0.001575                 0.000043
# 1           1.000000                 0.669352
# 2           0.007048                 0.000160
# 3           1.000000                 0.974489
# 4           1.000000                 0.152314
# ..               ...                      ...
# 546         1.000000                 0.598489
# 547         1.000000                 0.015310
# 548         0.098438                 0.001348
# 549         1.000000                 0.078587
# 550         1.000000                 0.390763
#
# [551 rows x 8 columns]

# %%
significant_hard_thres.shape, significant_bonferroni.shape, significant_fdr.shape
# Out:
# ((155, 8), (47, 8), (108, 8))

# %%
merged_sig_pairs = pd.merge(pd.merge(significant_fdr, significant_bonferroni, how="inner"), significant_hard_thres, how="inner")

# %%
merged_sig_pairs
# Out:
#                         Med Name                  Lab Name  \
# 0               Acetaminophen-IV  Diastolic blood pressure
# 1               Acetaminophen-IV  Diastolic blood pressure
# 2                    Albumin 25%  Diastolic blood pressure
# 3              Calcium Gluconate  Diastolic blood pressure
# 4                Cath Lab Intake  Diastolic blood pressure
# 5             Furosemide (Lasix)  Diastolic blood pressure
# 6             Furosemide (Lasix)  Diastolic blood pressure
# 7             Furosemide (Lasix)  Diastolic blood pressure
# 8             Furosemide (Lasix)  Diastolic blood pressure
# 9                   Gastric Meds  Diastolic blood pressure
# 10  Heparin Sodium (Prophylaxis)  Diastolic blood pressure
# 11  Heparin Sodium (Prophylaxis)  Diastolic blood pressure
# 12  Heparin Sodium (Prophylaxis)  Diastolic blood pressure
# 13                   Hydralazine  Diastolic blood pressure
# 14                   Hydralazine  Diastolic blood pressure
# 15                   Hydralazine  Diastolic blood pressure
# 16             Insulin - Humalog  Diastolic blood pressure
# 17                        K Phos  Diastolic blood pressure
# 18                        K Phos  Diastolic blood pressure
# 19                        K Phos  Diastolic blood pressure
# 20                            LR  Diastolic blood pressure
# 21                            LR  Diastolic blood pressure
# 22       Lansoprazole (Prevacid)  Diastolic blood pressure
# 23            Lorazepam (Ativan)  Diastolic blood pressure
# 24             Magnesium Sulfate  Diastolic blood pressure
# 25     Magnesium Sulfate (Bolus)  Diastolic blood pressure
# 26     Magnesium Sulfate (Bolus)  Diastolic blood pressure
# 27          Meperidine (Demerol)  Diastolic blood pressure
# 28          Meperidine (Demerol)  Diastolic blood pressure
# 29                    Metoprolol  Diastolic blood pressure
# 30                    Metoprolol  Diastolic blood pressure
# 31              Morphine Sulfate  Diastolic blood pressure
# 32              Morphine Sulfate  Diastolic blood pressure
# 33                 Nitroglycerin  Diastolic blood pressure
# 34         OR Crystalloid Intake  Diastolic blood pressure
# 35         OR Crystalloid Intake  Diastolic blood pressure
# 36         Omeprazole (Prilosec)  Diastolic blood pressure
# 37                     PO Intake  Diastolic blood pressure
# 38                     PO Intake  Diastolic blood pressure
# 39        Packed Red Blood Cells  Diastolic blood pressure
# 40        Packed Red Blood Cells  Diastolic blood pressure
# 41        Packed Red Blood Cells  Diastolic blood pressure
# 42        Packed Red Blood Cells  Diastolic blood pressure
# 43        Packed Red Blood Cells  Diastolic blood pressure
# 44       Pantoprazole (Protonix)  Diastolic blood pressure
# 45                 Phenylephrine  Diastolic blood pressure
# 46                 Phenylephrine  Diastolic blood pressure
#
#    Before Window (in Hours) After Window (in Hours)  No. of Patients  \
# 0                    (0, 6)                  (0, 4)              328
# 1                    (0, 6)                  (4, 8)              311
# 2                    (0, 6)                 (8, 12)              238
# 3                    (0, 6)                  (0, 4)             2798
# 4                    (0, 6)                 (8, 12)              263
# 5                    (0, 6)                  (0, 4)             2658
# 6                   (6, 12)                  (0, 4)             2362
# 7                   (6, 12)                  (4, 8)             1922
# 8                   (6, 12)                 (8, 12)             1344
# 9                   (6, 12)                 (8, 12)              894
# 10                  (6, 12)                  (0, 4)             2517
# 11                  (6, 12)                  (4, 8)             2364
# 12                  (6, 12)                 (8, 12)             1078
# 13                   (0, 6)                  (0, 4)             1039
# 14                   (0, 6)                  (4, 8)              791
# 15                   (0, 6)                 (8, 12)              595
# 16                  (6, 12)                  (4, 8)              738
# 17                  (6, 12)                  (0, 4)              976
# 18                  (6, 12)                  (4, 8)              862
# 19                  (6, 12)                 (8, 12)              745
# 20                   (0, 6)                  (0, 4)             2510
# 21                   (0, 6)                 (8, 12)              627
# 22                  (6, 12)                 (8, 12)              229
# 23                   (0, 6)                  (4, 8)              733
# 24                   (0, 6)                  (4, 8)             3112
# 25                   (0, 6)                  (4, 8)             2557
# 26                  (6, 12)                 (8, 12)             1761
# 27                   (0, 6)                  (4, 8)              116
# 28                   (0, 6)                 (8, 12)              112
# 29                  (6, 12)                  (0, 4)             1290
# 30                   (0, 6)                 (8, 12)              667
# 31                   (0, 6)                  (4, 8)              838
# 32                   (0, 6)                 (8, 12)              536
# 33                   (0, 6)                  (0, 4)              852
# 34                   (0, 6)                  (4, 8)             1940
# 35                   (0, 6)                 (8, 12)             1921
# 36                  (6, 12)                  (0, 4)              254
# 37                  (6, 12)                  (0, 4)             4183
# 38                  (6, 12)                  (4, 8)             1563
# 39                   (0, 6)                  (0, 4)             1864
# 40                  (6, 12)                  (0, 4)             1267
# 41                   (0, 6)                  (4, 8)              963
# 42                  (6, 12)                  (4, 8)              753
# 43                  (6, 12)                 (8, 12)              622
# 44                  (6, 12)                  (4, 8)             1309
# 45                   (0, 6)                  (0, 4)             1616
# 46                   (0, 6)                 (8, 12)              332
#
#     1-Sampled Ttest  BonferroniPvals  FDR Benjamini Corrected
# 0      2.857927e-06     1.574718e-03             4.255994e-05
# 1      1.279211e-05     7.048455e-03             1.601922e-04
# 2      5.800048e-06     3.195826e-03             7.989566e-05
# 3      1.479750e-09     8.153421e-07             4.529678e-08
# 4      2.660828e-08     1.466116e-05             6.374419e-07
# 5      9.015555e-08     4.967571e-05             1.910604e-06
# 6      1.155059e-20     6.364374e-18             1.591094e-18
# 7      3.860189e-07     2.126964e-04             6.646763e-06
# 8      4.354707e-08     2.399443e-05             9.997681e-07
# 9      2.058511e-06     1.134240e-03             3.150666e-05
# 10     3.803422e-09     2.095686e-06             1.047843e-07
# 11     1.625294e-10     8.955371e-08             6.888747e-09
# 12     1.067481e-07     5.881823e-05             2.100651e-06
# 13     2.063764e-56     1.137134e-53             1.137134e-53
# 14     1.241561e-37     6.841001e-35             3.420500e-35
# 15     4.272546e-22     2.354173e-19             7.847244e-20
# 16     1.538981e-05     8.479785e-03             1.843431e-04
# 17     2.628200e-07     1.448138e-04             4.671414e-06
# 18     1.153889e-09     6.357930e-07             3.973706e-08
# 19     2.515063e-07     1.385799e-04             4.619332e-06
# 20     4.524278e-09     2.492877e-06             1.187084e-07
# 21     9.199130e-06     5.068720e-03             1.206838e-04
# 22     8.197586e-06     4.516870e-03             1.101676e-04
# 23     4.179382e-06     2.302839e-03             5.904716e-05
# 24     3.732824e-10     2.056786e-07             1.371191e-08
# 25     2.461575e-10     1.356328e-07             9.688055e-09
# 26     1.037274e-05     5.715378e-03             1.329158e-04
# 27     4.559850e-08     2.512478e-05             1.004991e-06
# 28     1.346769e-09     7.420697e-07             4.365116e-08
# 29     1.194167e-18     6.579862e-16             1.096644e-16
# 30     4.696926e-07     2.588006e-04             7.842442e-06
# 31     3.442274e-06     1.896693e-03             4.991297e-05
# 32     1.672695e-07     9.216548e-05             3.178120e-06
# 33     1.529689e-05     8.428585e-03             1.843431e-04
# 34     2.695710e-11     1.485336e-08             1.350306e-09
# 35     3.826567e-18     2.108438e-15             3.012055e-16
# 36     6.724912e-09     3.705427e-06             1.684285e-07
# 37     2.182828e-20     1.202738e-17             2.405476e-18
# 38     1.670782e-05     9.206006e-03             1.958725e-04
# 39     3.660435e-12     2.016900e-09             2.016900e-10
# 40     4.116293e-13     2.268078e-10             2.520086e-11
# 41     2.739143e-09     1.509268e-06             7.943516e-08
# 42     4.645975e-15     2.559932e-12             3.199915e-13
# 43     8.525399e-11     4.697495e-08             3.914579e-09
# 44     9.997624e-08     5.508691e-05             2.040256e-06
# 45     6.707563e-07     3.695867e-04             1.087020e-05
# 46     1.321701e-06     7.282574e-04             2.080736e-05

# %%
merged_sig_pairs.to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"sig_pairs_intersection_mimic_vital_sign_{vital_name}.csv"))

# %% [markdown]
# ## Respiratory rate

# %%
# IO Config
# root_path ="C:\\Users\\danco\\My Drive\\Master\\Datasets\\MIMIC iii"
root_path = "/Users/pavan/Library/CloudStorage/GoogleDrive-f20190038@hyderabad.bits-pilani.ac.in/My Drive/TAU/Code/DrugLab"
data, res, raw_path, res_path = setup_io_config(root_path=root_path)

# Stratification Config
gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows = setup_stratification_config()

# %%
vital_name = "Respiratory rate"

# %%
# med_lab_pairs = pd.read_csv(os.path.join(data, "mimiciii/1.4", "preprocessed", "Systolic blood pressure_lab_patient_data_mimic_extract_2.csv")).drop(columns=["Unnamed: 0"])
med_lab_pairs = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name}.csv")).drop(columns=["Unnamed: 0"])

# %%
for b_w in before_windows:
    for a_w in after_windows:
        print(b_w, a_w)
        med_lab_pairs[f"ratio_{b_w}_{a_w}"] = med_lab_pairs[f"after_abs_{a_w}_sp"] / med_lab_pairs[f"before_abs_{b_w}_sp"]
# Out:
# (0, 6) (0, 4)
# (0, 6) (4, 8)
# (0, 6) (8, 12)
# (6, 12) (0, 4)
# (6, 12) (4, 8)
# (6, 12) (8, 12)

# %%
med_lab_pairs.dropna(subset=["ratio_(0, 6)_(0, 4)"])[["ratio_(0, 6)_(0, 4)"]].describe()
# Out:
#        ratio_(0, 6)_(0, 4)
# count         1.154900e+05
# mean                   inf
# std                    NaN
# min           0.000000e+00
# 25%           8.695652e-01
# 50%           1.000000e+00
# 75%           1.166667e+00
# max                    inf

# %%
# # Original size of med lab pairs - 1826730
# for a_w in after_windows:
#     for b_w in before_windows:
#         med_lab_pairs = pd.concat([ med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]<1) & (med_lab_pairs[f"ratio_{b_w}_{a_w}"]!=1)], med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]>=1) | (med_lab_pairs[f"after_time_{a_w}_sp"].isna())] ])

# %%
med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
# Out:
#                                            HADM_ID
# MED_NAME                 LAB_NAME
# ACD-A Citrate (1000ml)   Respiratory rate      147
# ACD-A Citrate (500ml)    Respiratory rate        5
# Abciximab (Reopro)       Respiratory rate        2
# Acetaminophen-IV         Respiratory rate      399
# Acyclovir                Respiratory rate      210
# ...                                            ...
# Verapamil                Respiratory rate        9
# Vitamin K (Phytonadione) Respiratory rate       93
# Vivonex (1/2)            Respiratory rate        1
# Vivonex (Full)           Respiratory rate       42
# Voriconazole             Respiratory rate       48
#
# [254 rows x 1 columns]

# %%
pairs_df = med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
pairs = pairs_df[pairs_df["HADM_ID"]>100].index
discovery_res1 = []
for med_name, lab_name in pairs:
    stat_test_df = []
    for a_w in after_windows:
        for b_w in before_windows:
            vals = med_lab_pairs[med_lab_pairs["LAB_NAME"]==lab_name]
            vals = vals[vals["MED_NAME"]==med_name]
            vals = vals[f"ratio_{b_w}_{a_w}"].replace([np.inf, -np.inf], np.nan).dropna()
            if vals.shape[0]>0:
                res = stats.ttest_1samp(vals.to_numpy(), popmean=1)
                row = {
                    "Med Name": med_name,
                    "Lab Name": lab_name,
                    "Before Window (in Hours)": b_w,
                    "After Window (in Hours)": a_w,
                    "No. of Patients": vals.shape[0],
                    "1-Sampled Ttest" : res.pvalue
                }
            stat_test_df.append(row)
    if len(stat_test_df)>0:
        discovery_res1.extend(stat_test_df)
res_df1 = pd.DataFrame(discovery_res1)

# %%
res_df = res_df1.copy()

# %%
res_df[res_df["No. of Patients"]>100]
# Out:
#              Med Name          Lab Name Before Window (in Hours)  \
# 6    Acetaminophen-IV  Respiratory rate                   (0, 6)
# 7    Acetaminophen-IV  Respiratory rate                  (6, 12)
# 8    Acetaminophen-IV  Respiratory rate                   (0, 6)
# 9    Acetaminophen-IV  Respiratory rate                  (6, 12)
# 10   Acetaminophen-IV  Respiratory rate                   (0, 6)
# ..                ...               ...                      ...
# 737        Vancomycin  Respiratory rate                  (6, 12)
# 738       Vasopressin  Respiratory rate                   (0, 6)
# 739       Vasopressin  Respiratory rate                  (6, 12)
# 740       Vasopressin  Respiratory rate                   (0, 6)
# 744        Vecuronium  Respiratory rate                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 6                    (0, 4)              313         0.565835
# 7                    (0, 4)              216         0.095535
# 8                    (4, 8)              300         0.050215
# 9                    (4, 8)              202         0.101074
# 10                  (8, 12)              203         0.590981
# ..                      ...              ...              ...
# 737                 (8, 12)             1556         0.002264
# 738                  (0, 4)              201         0.530840
# 739                  (0, 4)              173         0.603075
# 740                  (4, 8)              110         0.915826
# 744                  (0, 4)              112         0.411330
#
# [521 rows x 6 columns]

# %%
res_df[res_df["No. of Patients"]>100].to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv"))

# %%
# res_df = pd.read_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv")).drop(columns=["Unnamed: 0"]).drop_duplicates()

# %%
dis_analyzer = discovery.ClinicalDiscoveryAnalysis([])

# %%
test_pval_data, significant_hard_thres, significant_bonferroni, significant_fdr = dis_analyzer.generate_significant(res_df[res_df["No. of Patients"]>100].dropna(), statistical_test="1-Sampled Ttest")

# %%
test_pval_data
# Out:
#              Med Name          Lab Name Before Window (in Hours)  \
# 0    Acetaminophen-IV  Respiratory rate                   (0, 6)
# 1    Acetaminophen-IV  Respiratory rate                  (6, 12)
# 2    Acetaminophen-IV  Respiratory rate                   (0, 6)
# 3    Acetaminophen-IV  Respiratory rate                  (6, 12)
# 4    Acetaminophen-IV  Respiratory rate                   (0, 6)
# ..                ...               ...                      ...
# 516        Vancomycin  Respiratory rate                  (6, 12)
# 517       Vasopressin  Respiratory rate                   (0, 6)
# 518       Vasopressin  Respiratory rate                  (6, 12)
# 519       Vasopressin  Respiratory rate                   (0, 6)
# 520        Vecuronium  Respiratory rate                   (0, 6)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest  \
# 0                    (0, 4)              313         0.565835
# 1                    (0, 4)              216         0.095535
# 2                    (4, 8)              300         0.050215
# 3                    (4, 8)              202         0.101074
# 4                   (8, 12)              203         0.590981
# ..                      ...              ...              ...
# 516                 (8, 12)             1556         0.002264
# 517                  (0, 4)              201         0.530840
# 518                  (0, 4)              173         0.603075
# 519                  (4, 8)              110         0.915826
# 520                  (0, 4)              112         0.411330
#
#      BonferroniPvals  FDR Benjamini Corrected
# 0                1.0                 0.687303
# 1                1.0                 0.224206
# 2                1.0                 0.142254
# 3                1.0                 0.235088
# 4                1.0                 0.704579
# ..               ...                      ...
# 516              1.0                 0.015527
# 517              1.0                 0.660065
# 518              1.0                 0.715723
# 519              1.0                 0.946717
# 520              1.0                 0.559537
#
# [521 rows x 8 columns]

# %%
significant_hard_thres.shape, significant_bonferroni.shape, significant_fdr.shape
# Out:
# ((110, 8), (23, 8), (65, 8))

# %%
merged_sig_pairs = pd.merge(pd.merge(significant_fdr, significant_bonferroni, how="inner"), significant_hard_thres, how="inner")

# %%
merged_sig_pairs
# Out:
#                      Med Name          Lab Name Before Window (in Hours)  \
# 0           Calcium Gluconate  Respiratory rate                   (0, 6)
# 1           Calcium Gluconate  Respiratory rate                  (6, 12)
# 2                    Dopamine  Respiratory rate                   (0, 6)
# 3          Furosemide (Lasix)  Respiratory rate                  (6, 12)
# 4          Furosemide (Lasix)  Respiratory rate                  (6, 12)
# 5          Furosemide (Lasix)  Respiratory rate                  (6, 12)
# 6                 Hydralazine  Respiratory rate                  (6, 12)
# 7          Insulin - Glargine  Respiratory rate                   (0, 6)
# 8          Insulin - Glargine  Respiratory rate                  (6, 12)
# 9          Insulin - Glargine  Respiratory rate                   (0, 6)
# 10         Insulin - Glargine  Respiratory rate                  (6, 12)
# 11          Magnesium Sulfate  Respiratory rate                   (0, 6)
# 12          Magnesium Sulfate  Respiratory rate                  (6, 12)
# 13  Magnesium Sulfate (Bolus)  Respiratory rate                   (0, 6)
# 14  Magnesium Sulfate (Bolus)  Respiratory rate                  (6, 12)
# 15                 Metoprolol  Respiratory rate                  (6, 12)
# 16       OR Cell Saver Intake  Respiratory rate                   (0, 6)
# 17      OR Crystalloid Intake  Respiratory rate                   (0, 6)
# 18                  PO Intake  Respiratory rate                   (0, 6)
# 19                  PO Intake  Respiratory rate                  (6, 12)
# 20                  PO Intake  Respiratory rate                  (6, 12)
# 21              Phenylephrine  Respiratory rate                   (0, 6)
# 22                   Propofol  Respiratory rate                  (6, 12)
#
#    After Window (in Hours)  No. of Patients  1-Sampled Ttest  BonferroniPvals  \
# 0                  (8, 12)             1755     9.019575e-08     4.699199e-05
# 1                  (8, 12)             1198     1.187049e-05     6.184525e-03
# 2                   (0, 4)              183     6.662744e-06     3.471290e-03
# 3                   (0, 4)             2241     6.047381e-14     3.150685e-11
# 4                   (4, 8)             1827     9.925654e-10     5.171266e-07
# 5                  (8, 12)             1268     3.660026e-08     1.906874e-05
# 6                   (0, 4)              707     3.909062e-12     2.036621e-09
# 7                   (4, 8)             1349     1.400057e-09     7.294297e-07
# 8                   (4, 8)             1229     1.272572e-08     6.630098e-06
# 9                  (8, 12)             1097     1.503962e-06     7.835640e-04
# 10                 (8, 12)              986     1.723691e-06     8.980430e-04
# 11                 (8, 12)             2640     9.550536e-07     4.975829e-04
# 12                 (8, 12)             1963     7.759637e-07     4.042771e-04
# 13                 (8, 12)             2169     6.193699e-07     3.226917e-04
# 14                 (8, 12)             1653     8.110237e-06     4.225433e-03
# 15                  (0, 4)             1239     6.652520e-08     3.465963e-05
# 16                 (8, 12)              475     1.896531e-05     9.880925e-03
# 17                 (8, 12)             1681     5.280623e-06     2.751205e-03
# 18                  (0, 4)             5728     2.022347e-14     1.053643e-11
# 19                  (0, 4)             4138     2.030176e-26     1.057722e-23
# 20                  (4, 8)             1548     4.393294e-10     2.288906e-07
# 21                 (8, 12)              275     3.619673e-06     1.885850e-03
# 22                  (0, 4)              412     6.588254e-09     3.432480e-06
#
#     FDR Benjamini Corrected
# 0              3.915999e-06
# 1              2.811148e-04
# 2              1.735645e-04
# 3              1.050228e-11
# 4              8.618776e-08
# 5              1.906874e-06
# 6              5.091554e-10
# 7              1.042042e-07
# 8              7.366776e-07
# 9              4.897275e-05
# 10             5.282606e-05
# 11             3.317219e-05
# 12             2.887694e-05
# 13             2.482244e-05
# 14             2.012111e-04
# 15             3.150876e-06
# 16             4.296054e-04
# 17             1.448002e-04
# 18             5.268215e-12
# 19             1.057722e-23
# 20             4.577813e-08
# 21             1.047694e-04
# 22             4.290600e-07

# %%
merged_sig_pairs.to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"sig_pairs_intersection_mimic_vital_sign_{vital_name}.csv"))

# %% [markdown]
# ## Temperature

# %%
# IO Config
# root_path ="C:\\Users\\danco\\My Drive\\Master\\Datasets\\MIMIC iii"
root_path = "/Users/pavan/Library/CloudStorage/GoogleDrive-f20190038@hyderabad.bits-pilani.ac.in/My Drive/TAU/Code/DrugLab"
data, res, raw_path, res_path = setup_io_config(root_path=root_path)

# Stratification Config
gender, age_a, age_b, ethnicity, lab_mapping, before_windows, after_windows = setup_stratification_config()

# %%
vital_name = "Temperature"

# %%
# med_lab_pairs_1 = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name} (C).csv")).drop(columns=["Unnamed: 0"])
# med_lab_pairs_2 = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name} (F).csv")).drop(columns=["Unnamed: 0"])
# Out:
# /var/folders/by/jbk3mn054mv4x7_28jxcwvx80000gn/T/ipykernel_36415/3706000715.py:3: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   med_lab_pairs_2 = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name} (F).csv")).drop(columns=["Unnamed: 0"])

# %%
# for a_w in after_windows:
#     med_lab_pairs_2[f"after_abs_{a_w}_sp"] = med_lab_pairs_2[f"after_abs_{a_w}_sp"].apply(lambda x : (x-32)*5/9)
# for b_w in before_windows:
#     med_lab_pairs_2[f"before_abs_{b_w}_sp"] = med_lab_pairs_2[f"before_abs_{b_w}_sp"].apply(lambda x : (x-32)*5/9)

# %%
# med_lab_pairs = pd.concat([med_lab_pairs_1, med_lab_pairs_2]).reset_index().drop(columns=["index"])

# %%
# med_lab_pairs["LAB_NAME"] = med_lab_pairs["LAB_NAME"].apply(lambda x : vital_name)

# %%
med_lab_pairs = pd.read_csv(os.path.join(res, f"med_lab_pairs_vital_signs_{vital_name}.csv")).drop(columns=["Unnamed: 0"])

# %%
for b_w in before_windows:
    for a_w in after_windows:
        print(b_w, a_w)
        med_lab_pairs[f"ratio_{b_w}_{a_w}"] = med_lab_pairs[f"after_abs_{a_w}_sp"] / med_lab_pairs[f"before_abs_{b_w}_sp"]
# Out:
# (0, 6) (0, 4)
# (0, 6) (4, 8)
# (0, 6) (8, 12)
# (6, 12) (0, 4)
# (6, 12) (4, 8)
# (6, 12) (8, 12)

# %%
med_lab_pairs.dropna(subset=["ratio_(0, 6)_(0, 4)"])[["ratio_(0, 6)_(0, 4)"]].describe()
# Out:
#        ratio_(0, 6)_(0, 4)
# count         8.312700e+04
# mean                   inf
# std                    NaN
# min          -2.795652e+00
# 25%           9.930545e-01
# 50%           1.000000e+00
# 75%           1.008403e+00
# max                    inf

# %%
# # Original size of med lab pairs - 1826730
# for a_w in after_windows:
#     for b_w in before_windows:
#         med_lab_pairs = pd.concat([ med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]<1) & (med_lab_pairs[f"ratio_{b_w}_{a_w}"]!=1)], med_lab_pairs[(med_lab_pairs[f"after_time_{a_w}_sp"]>=1) | (med_lab_pairs[f"after_time_{a_w}_sp"].isna())] ])

# %%
med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
# Out:
#                                       HADM_ID
# MED_NAME                 LAB_NAME
# ACD-A Citrate (1000ml)   Temperature      141
# ACD-A Citrate (500ml)    Temperature        4
# Abciximab (Reopro)       Temperature        2
# Acetaminophen-IV         Temperature      387
# Acyclovir                Temperature      218
# ...                                       ...
# Verapamil                Temperature        9
# Vitamin K (Phytonadione) Temperature       94
# Vivonex (1/2)            Temperature        1
# Vivonex (Full)           Temperature       39
# Voriconazole             Temperature       50
#
# [252 rows x 1 columns]

# %%
pairs_df = med_lab_pairs.groupby(["MED_NAME", "LAB_NAME"]).count()[["HADM_ID"]]
pairs = pairs_df[pairs_df["HADM_ID"]>100].index
discovery_res1 = []
for med_name, lab_name in pairs:
    stat_test_df = []
    for a_w in after_windows:
        for b_w in before_windows:
            vals = med_lab_pairs[med_lab_pairs["LAB_NAME"]==lab_name]
            vals = vals[vals["MED_NAME"]==med_name]
            vals = vals[f"ratio_{b_w}_{a_w}"].replace([np.inf, -np.inf], np.nan).dropna()
            if vals.shape[0]>0:
                res = stats.ttest_1samp(vals.to_numpy(), popmean=1)
                row = {
                    "Med Name": med_name,
                    "Lab Name": lab_name,
                    "Before Window (in Hours)": b_w,
                    "After Window (in Hours)": a_w,
                    "No. of Patients": vals.shape[0],
                    "1-Sampled Ttest" : res.pvalue
                }
            stat_test_df.append(row)
    if len(stat_test_df)>0:
        discovery_res1.extend(stat_test_df)
res_df1 = pd.DataFrame(discovery_res1)

# %%
res_df = res_df1.copy()

# %%
res_df[res_df["No. of Patients"]>100]
# Out:
#              Med Name     Lab Name Before Window (in Hours)  \
# 6    Acetaminophen-IV  Temperature                   (0, 6)
# 7    Acetaminophen-IV  Temperature                  (6, 12)
# 8    Acetaminophen-IV  Temperature                   (0, 6)
# 9    Acetaminophen-IV  Temperature                  (6, 12)
# 10   Acetaminophen-IV  Temperature                   (0, 6)
# ..                ...          ...                      ...
# 729        Vancomycin  Temperature                  (6, 12)
# 730        Vancomycin  Temperature                   (0, 6)
# 731        Vancomycin  Temperature                  (6, 12)
# 732       Vasopressin  Temperature                   (0, 6)
# 733       Vasopressin  Temperature                  (6, 12)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 6                    (0, 4)              265         0.013550
# 7                    (0, 4)              179         0.000473
# 8                    (4, 8)              234         0.969004
# 9                    (4, 8)              159         0.295592
# 10                  (8, 12)              168         0.385002
# ..                      ...              ...              ...
# 729                  (4, 8)             1424         0.115612
# 730                 (8, 12)             2037         0.072181
# 731                 (8, 12)             1211         0.105769
# 732                  (0, 4)              140         0.396719
# 733                  (0, 4)              117         0.834899
#
# [487 rows x 6 columns]

# %%
vital_name
# Out:
# 'Temperature'

# %%
res_df[res_df["No. of Patients"]>100].to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv"))

# %%
# res_df = pd.read_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{vital_name}.csv")).drop(columns=["Unnamed: 0"]).drop_duplicates()

# %%
dis_analyzer = discovery.ClinicalDiscoveryAnalysis([])

# %%
test_pval_data, significant_hard_thres, significant_bonferroni, significant_fdr = dis_analyzer.generate_significant(res_df[res_df["No. of Patients"]>100].dropna(), statistical_test="1-Sampled Ttest")

# %%
test_pval_data
# Out:
#              Med Name     Lab Name Before Window (in Hours)  \
# 0    Acetaminophen-IV  Temperature                   (0, 6)
# 1    Acetaminophen-IV  Temperature                  (6, 12)
# 2    Acetaminophen-IV  Temperature                   (0, 6)
# 3    Acetaminophen-IV  Temperature                  (6, 12)
# 4    Acetaminophen-IV  Temperature                   (0, 6)
# ..                ...          ...                      ...
# 482        Vancomycin  Temperature                  (6, 12)
# 483        Vancomycin  Temperature                   (0, 6)
# 484        Vancomycin  Temperature                  (6, 12)
# 485       Vasopressin  Temperature                   (0, 6)
# 486       Vasopressin  Temperature                  (6, 12)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest  \
# 0                    (0, 4)              265         0.013550
# 1                    (0, 4)              179         0.000473
# 2                    (4, 8)              234         0.969004
# 3                    (4, 8)              159         0.295592
# 4                   (8, 12)              168         0.385002
# ..                      ...              ...              ...
# 482                  (4, 8)             1424         0.115612
# 483                 (8, 12)             2037         0.072181
# 484                 (8, 12)             1211         0.105769
# 485                  (0, 4)              140         0.396719
# 486                  (0, 4)              117         0.834899
#
#      BonferroniPvals  FDR Benjamini Corrected
# 0           1.000000                 0.085701
# 1           0.230111                 0.006768
# 2           1.000000                 0.979056
# 3           1.000000                 0.563963
# 4           1.000000                 0.622911
# ..               ...                      ...
# 482         1.000000                 0.383425
# 483         1.000000                 0.290894
# 484         1.000000                 0.365317
# 485         1.000000                 0.633775
# 486         1.000000                 0.905559
#
# [487 rows x 8 columns]

# %%
significant_hard_thres.shape, significant_bonferroni.shape, significant_fdr.shape
# Out:
# ((64, 8), (24, 8), (37, 8))

# %%
merged_sig_pairs = pd.merge(pd.merge(significant_fdr, significant_bonferroni, how="inner"), significant_hard_thres, how="inner")

# %%
merged_sig_pairs
# Out:
#                  Med Name     Lab Name Before Window (in Hours)  \
# 0              Albumin 5%  Temperature                  (6, 12)
# 1             Hydralazine  Temperature                   (0, 6)
# 2             Hydralazine  Temperature                  (6, 12)
# 3             Hydralazine  Temperature                   (0, 6)
# 4             KCL (Bolus)  Temperature                   (0, 6)
# 5                      LR  Temperature                   (0, 6)
# 6               Labetalol  Temperature                   (0, 6)
# 7              Metoprolol  Temperature                  (6, 12)
# 8        Morphine Sulfate  Temperature                  (6, 12)
# 9        Morphine Sulfate  Temperature                   (0, 6)
# 10   OR Cell Saver Intake  Temperature                   (0, 6)
# 11   OR Cell Saver Intake  Temperature                   (0, 6)
# 12      OR Colloid Intake  Temperature                   (0, 6)
# 13      OR Colloid Intake  Temperature                   (0, 6)
# 14  OR Crystalloid Intake  Temperature                   (0, 6)
# 15  OR Crystalloid Intake  Temperature                   (0, 6)
# 16  OR Crystalloid Intake  Temperature                  (6, 12)
# 17          OR FFP Intake  Temperature                   (0, 6)
# 18   OR Packed RBC Intake  Temperature                  (6, 12)
# 19     OR Platelet Intake  Temperature                   (0, 6)
# 20          Phenylephrine  Temperature                   (0, 6)
# 21              Platelets  Temperature                   (0, 6)
# 22     Potassium Chloride  Temperature                   (0, 6)
# 23               Propofol  Temperature                   (0, 6)
#
#    After Window (in Hours)  No. of Patients  1-Sampled Ttest  BonferroniPvals  \
# 0                   (4, 8)              295     9.682158e-06     4.715211e-03
# 1                   (0, 4)              776     5.824910e-07     2.836731e-04
# 2                   (0, 4)              546     1.254490e-05     6.109368e-03
# 3                   (4, 8)              602     3.995885e-13     1.945996e-10
# 4                   (4, 8)              821     6.897575e-06     3.359119e-03
# 5                  (8, 12)              479     7.417275e-08     3.612213e-05
# 6                  (8, 12)              125     2.230092e-06     1.086055e-03
# 7                   (0, 4)              867     2.110573e-08     1.027849e-05
# 8                   (0, 4)              571     1.092495e-07     5.320451e-05
# 9                   (4, 8)              588     2.279986e-06     1.110353e-03
# 10                  (4, 8)              301     1.363792e-27     6.641667e-25
# 11                 (8, 12)              293     6.735958e-46     3.280411e-43
# 12                  (4, 8)              249     2.995686e-13     1.458899e-10
# 13                 (8, 12)              247     3.759408e-15     1.830832e-12
# 14                  (4, 8)             1481     2.565796e-06     1.249543e-03
# 15                 (8, 12)             1436     4.099968e-09     1.996684e-06
# 16                 (8, 12)              441     4.812943e-06     2.343903e-03
# 17                 (8, 12)              205     4.802974e-16     2.339048e-13
# 18                 (8, 12)              135     1.007701e-07     4.907504e-05
# 19                 (8, 12)              119     1.877506e-11     9.143455e-09
# 20                 (8, 12)              225     9.246800e-14     4.503191e-11
# 21                 (8, 12)              273     1.369687e-05     6.670378e-03
# 22                  (4, 8)             1327     1.484871e-07     7.231320e-05
# 23                  (4, 8)              333     3.678973e-17     1.791660e-14
#
#     FDR Benjamini Corrected
# 0              2.143278e-04
# 1              1.772957e-05
# 2              2.656247e-04
# 3              2.432495e-11
# 4              1.599580e-04
# 5              3.010178e-06
# 6              6.168628e-05
# 7              9.344082e-07
# 8              3.800322e-06
# 9              6.168628e-05
# 10             3.320833e-25
# 11             3.280411e-43
# 12             2.084142e-11
# 13             3.661663e-13
# 14             6.576541e-05
# 15             1.996684e-07
# 16             1.171952e-04
# 17             5.847621e-14
# 18             3.775003e-06
# 19             1.015939e-09
# 20             7.505319e-12
# 21             2.779324e-04
# 22             4.820880e-06
# 23             5.972199e-15

# %%
merged_sig_pairs.to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"sig_pairs_intersection_mimic_vital_sign_{vital_name}.csv"))

# %% [markdown]
# ## Combining

# %%
vitals = ["Systolic blood pressure", "Diastolic blood pressure", "Heart Rate", "Temperature", "Respiratory rate"]

# %%
sig_vital_files = [os.path.join(setup_io_config(root_path=root_path)[1], f"sig_pairs_intersection_mimic_vital_sign_{v}.csv") for v in vitals]

# %%
pval_files = [os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_sign_{v}.csv") for v in vitals]

# %%
merged_sig_pairs = pd.concat([pd.read_csv(v).drop(columns=["Unnamed: 0"]) for v in sig_vital_files]).reset_index().drop(columns=["index"])
merged_pvals = pd.concat([pd.read_csv(v).drop(columns=["Unnamed: 0"]) for v in pval_files]).reset_index().drop(columns=["index"])

# %%
merged_sig_pairs
# Out:
#               Med Name                 Lab Name Before Window (in Hours)  \
# 0     Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 1           Albumin 5%  Systolic blood pressure                   (0, 6)
# 2           Amiodarone  Systolic blood pressure                   (0, 6)
# 3    Calcium Gluconate  Systolic blood pressure                   (0, 6)
# 4    Calcium Gluconate  Systolic blood pressure                  (6, 12)
# ..                 ...                      ...                      ...
# 243          PO Intake         Respiratory rate                   (0, 6)
# 244          PO Intake         Respiratory rate                  (6, 12)
# 245          PO Intake         Respiratory rate                  (6, 12)
# 246      Phenylephrine         Respiratory rate                   (0, 6)
# 247           Propofol         Respiratory rate                  (6, 12)
#
#     After Window (in Hours)  No. of Patients  1-Sampled Ttest  \
# 0                    (0, 4)              328     4.413339e-08
# 1                    (0, 4)              991     1.172105e-05
# 2                    (4, 8)              327     1.622566e-05
# 3                    (0, 4)             2798     3.399097e-13
# 4                    (0, 4)             1838     7.193575e-17
# ..                      ...              ...              ...
# 243                  (0, 4)             5728     2.022347e-14
# 244                  (0, 4)             4138     2.030176e-26
# 245                  (4, 8)             1548     4.393294e-10
# 246                 (8, 12)              275     3.619673e-06
# 247                  (0, 4)              412     6.588254e-09
#
#      BonferroniPvals  FDR Benjamini Corrected
# 0       2.431750e-05             5.655232e-07
# 1       6.458300e-03             7.781085e-05
# 2       8.940337e-03             1.039574e-04
# 3       1.872902e-10             9.364511e-12
# 4       3.963660e-14             3.048969e-15
# ..               ...                      ...
# 243     1.053643e-11             5.268215e-12
# 244     1.057722e-23             1.057722e-23
# 245     2.288906e-07             4.577813e-08
# 246     1.885850e-03             1.047694e-04
# 247     3.432480e-06             4.290600e-07
#
# [248 rows x 8 columns]

# %%
merged_pvals
# Out:
#               Med Name                 Lab Name Before Window (in Hours)  \
# 0     Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 1     Acetaminophen-IV  Systolic blood pressure                  (6, 12)
# 2     Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# 3     Acetaminophen-IV  Systolic blood pressure                  (6, 12)
# 4     Acetaminophen-IV  Systolic blood pressure                   (0, 6)
# ...                ...                      ...                      ...
# 2656        Vancomycin         Respiratory rate                  (6, 12)
# 2657       Vasopressin         Respiratory rate                   (0, 6)
# 2658       Vasopressin         Respiratory rate                  (6, 12)
# 2659       Vasopressin         Respiratory rate                   (0, 6)
# 2660        Vecuronium         Respiratory rate                   (0, 6)
#
#      After Window (in Hours)  No. of Patients  1-Sampled Ttest
# 0                     (0, 4)              328     4.413339e-08
# 1                     (0, 4)              233     9.361079e-01
# 2                     (4, 8)              311     1.695153e-04
# 3                     (4, 8)              217     2.629712e-01
# 4                    (8, 12)              213     4.635270e-01
# ...                      ...              ...              ...
# 2656                 (8, 12)             1556     2.264436e-03
# 2657                  (0, 4)              201     5.308395e-01
# 2658                  (0, 4)              173     6.030755e-01
# 2659                  (4, 8)              110     9.158257e-01
# 2660                  (0, 4)              112     4.113298e-01
#
# [2661 rows x 6 columns]

# %%
merged_sig_pairs.to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"sig_pairs_intersection_mimic_vital_signs_all.csv"))
merged_pvals.to_csv(os.path.join(setup_io_config(root_path=root_path)[1], f"pvals_mimic_vital_signs_all.csv"))
